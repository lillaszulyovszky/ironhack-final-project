# %%
# import basic libraries
import pandas as pd
import numpy as np

# %%
import json
import pandas as pd
with open('/Users/lilmac/Documents/GitHub/ironhack-final-project/Data-FT-Ber-03-2021-Slack-export/general/2021-03-21.json', 'r') as f:
    data = json.load(f)
    
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       type       subtype                 ts         user  \
# 0  message  channel_join  1616336527.004700  U01RVSTNRRT
# 1  message  channel_join  1616346191.004900  U01RW140HBP
# 2  message           NaN  1616346264.005900  U01RW140HBP
# 3  message  channel_join  1616394759.000200  U01S65G72SY
#
#                                     text  \
# 0  <@U01RVSTNRRT> has joined the channel
# 1  <@U01RW140HBP> has joined the channel
# 2       hi everyone! see you tomorrow :)
# 3  <@U01S65G72SY> has joined the channel
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  291a9d89-deb5-4a75-8d55-1ed91548b91b  T01RBRV5F7H  T01RBRV5F7H
# 3                                   NaN          NaN          NaN
#
#    source_team                                       user_profile  \
# ...

# %%
import pandas as pd

dfs = []
for file in file_list:
    with open(file) as f:
        for line in f.readlines():
            json_data = pd.json_normalize(json.loads(line))
            dfs.append(json_data)
df = pd.concat(dfs, sort=False) # or sort=True depending on your needs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5ea00aba0e2b> in <module>
#       7             json_data = pd.json_normalize(json.loads(line))
#       8             dfs.append(json_data)
# ----> 9 df = pd.concat(dfs, sort=False) # or sort=True depending on your needs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     340
#     341         if len(objs) == 0:
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
import json
import pandas as pd
with open('/Users/lilmac/Documents/GitHub/ironhack-final-project/Data-FT-Ber-03-2021-Slack-export/general/2021-04-02.json', 'r') as f:
    data = json.load(f)
df2 = pd.DataFrame(data)

# %%
df2.head()
# Out:
#                           client_msg_id     type  \
# 0  5a210511-69fb-4d5a-9d2a-7c37b63bf3ac  message
# 1  29fa505b-0831-4b8e-a54e-583aeb7f767c  message
# 2  bc1a9984-7496-4c9a-9e91-072dde04cbfb  message
# 3  4944eb2c-d791-435f-a65a-b60176848ae4  message
# 4  2a500eaa-79b8-45fe-915b-f4cb00604de8  message
#
#                                                 text         user  \
# 0  Just an idea:\n\nThere is a possibility to cre...  U01RXCQHMHT
# 1  i thought the room was always open? the class ...  U01RW2X7S9Z
# 2  I think zoom is open as long as someone is in ...  U01RN7BVD1C
# 3  we got booted off zoom at 6.25pm last night......  U01S7KCL3DF
# 4               Someone has to host the zoom, right?  U01RXCQHMHT
#
#                   ts         team    user_team  source_team  \
# 0  1617348922.003500  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1  1617348949.003900  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2  1617349072.004000  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...
