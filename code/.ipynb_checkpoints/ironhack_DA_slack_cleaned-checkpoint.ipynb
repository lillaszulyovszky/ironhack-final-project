# %% [markdown]
# **EDA**
# - how much traffic per channel
# - which post in which channel gets the most reaction/traction
# - what time of the day students are posting the most per day
# - distribution of  % links, % memes, % emojis
# - frequency of messages from teaching staff vs students
# - count of messages per person
# - avg length of messages per person
# - statistics of mentions within a date range
# - which channel is the most useful(most messages)
# - measure reactions based on length of messages
# - text features: ??, !!, capital letters, bolded statements, technical terms
#
# **Automated function**
# - a report at the end of each day, with a few summary statistics for that day
# - a daily / weekly extract of all the links/uploads posted in public channels
#
# **NLP**
# - whats the top 5 words used per channel (bi-grams, tri-grams)
# - how negative or positive posts were on the lab help channel specifically
# - who is the happiest/most sad person
# - number of people who asks questions, who are the asking the most
#
# **Network Analysis: (if I have time):**
# - identify people who answer most questions

# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp
#
# ## Wrangle Data
# - create a couple of boolean columns from reactions, files, attachments, replies

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe/channel

# %% [markdown]
# ### channel_gen

# %%
# defining file path
path_to_json = '../data/general/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_gen = pd.concat(dfs, ignore_index=True)
# test
channel_gen.tail(100)
# Out:
#                              client_msg_id     type  \
# 1061  3d62b711-9c19-4aa8-8874-615579ff48e7  message
# 1062  f790d842-a5e8-44e7-be76-678d69cfb06d  message
# 1063  67fff521-642a-4209-82be-42a6b25e91d7  message
# 1064  16c8cc9f-f308-41d9-a642-4120f2fb3041  message
# 1065  9682cdd5-2cf6-4344-9542-9e2711dcf6c1  message
# ...                                    ...      ...
# 1156                                   NaN  message
# 1157                                   NaN  message
# 1158                                   NaN  message
# 1159                                   NaN  message
# 1160                                   NaN  message
#
#                                                    text         user  \
# 1061                         yes and then using the app  U01S79YDELR
# 1062  <!channel>,\ncan you access the content now? W...  U01SJKB2MG8
# 1063                                mine not signing in  U01S0P26NKD
# 1064  yes, thanks. I have problems to go the the cla...  U01S79YDELR
# 1065             <@U01SJKB2MG8> i cannot join the class  U01S79YDELR
# ...                                                 ...          ...
# 1156              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1157              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1158              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1159              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1160              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 1061  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1062  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1063  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1064  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1065  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1156  1.616166e+09          NaN          NaN          NaN
# 1157  1.616167e+09          NaN          NaN          NaN
# 1158  1.616168e+09          NaN          NaN          NaN
# 1159  1.616172e+09          NaN          NaN          NaN
# 1160  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 1061  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1062  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1063  {'avatar_hash': 'g7b30129d02b', 'image_72': 'h...
# 1064  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1065  {'avatar_hash': '606def897de6', 'image_72': 'h...
# ...                                                 ...
# 1156                                                NaN
# 1157                                                NaN
# 1158                                                NaN
# 1159                                                NaN
# 1160                                                NaN
#
#                                                  blocks  ...  upload  \
# 1061  [{'type': 'rich_text', 'block_id': 'Bie', 'ele...  ...     NaN
# 1062  [{'type': 'rich_text', 'block_id': '6p6z', 'el...  ...     NaN
# 1063  [{'type': 'rich_text', 'block_id': 'UCLUf', 'e...  ...     NaN
# 1064  [{'type': 'rich_text', 'block_id': 'Voo', 'ele...  ...     NaN
# 1065  [{'type': 'rich_text', 'block_id': 'upS/I', 'e...  ...     NaN
# ...                                                 ...  ...     ...
# 1156                                                NaN  ...     NaN
# 1157                                                NaN  ...     NaN
# 1158                                                NaN  ...     NaN
# 1159                                                NaN  ...     NaN
# 1160                                                NaN  ...     NaN
#
#      display_as_bot reactions  last_read  bot_id  bot_profile       subtype  \
# 1061            NaN       NaN        NaN     NaN          NaN           NaN
# 1062            NaN       NaN        NaN     NaN          NaN           NaN
# 1063            NaN       NaN        NaN     NaN          NaN           NaN
# 1064            NaN       NaN        NaN     NaN          NaN           NaN
# 1065            NaN       NaN        NaN     NaN          NaN           NaN
# ...             ...       ...        ...     ...          ...           ...
# 1156            NaN       NaN        NaN     NaN          NaN  channel_join
# 1157            NaN       NaN        NaN     NaN          NaN  channel_join
# 1158            NaN       NaN        NaN     NaN          NaN  channel_join
# 1159            NaN       NaN        NaN     NaN          NaN  channel_join
# 1160            NaN       NaN        NaN     NaN          NaN  channel_join
#
#      topic root purpose
# 1061   NaN  NaN     NaN
# 1062   NaN  NaN     NaN
# 1063   NaN  NaN     NaN
# 1064   NaN  NaN     NaN
# 1065   NaN  NaN     NaN
# ...    ...  ...     ...
# 1156   NaN  NaN     NaN
# 1157   NaN  NaN     NaN
# 1158   NaN  NaN     NaN
# 1159   NaN  NaN     NaN
# 1160   NaN  NaN     NaN
#
# [100 rows x 32 columns]

# %%
channel_gen['channel_name'] = 'general'
channel_gen
# Out:
#                              client_msg_id     type  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294  message
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2  message
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d  message
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b  message
# 4     39e4728b-90f7-4d84-b149-74d765ca544a  message
# ...                                    ...      ...
# 1156                                   NaN  message
# 1157                                   NaN  message
# 1158                                   NaN  message
# 1159                                   NaN  message
# 1160                                   NaN  message
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1156              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1157              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1158              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1159              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1160              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 0     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1156  1.616166e+09          NaN          NaN          NaN
# 1157  1.616167e+09          NaN          NaN          NaN
# 1158  1.616168e+09          NaN          NaN          NaN
# 1159  1.616172e+09          NaN          NaN          NaN
# 1160  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                                                 ...
# 1156                                                NaN
# 1157                                                NaN
# 1158                                                NaN
# 1159                                                NaN
# 1160                                                NaN
#
#                                                  blocks  ...  display_as_bot  \
# 0     [{'type': 'rich_text', 'block_id': '8oy', 'ele...  ...             NaN
# 1     [{'type': 'rich_text', 'block_id': 'wr=L', 'el...  ...             NaN
# 2     [{'type': 'rich_text', 'block_id': 'pRRNj', 'e...  ...             NaN
# 3     [{'type': 'rich_text', 'block_id': 'Daw', 'ele...  ...             NaN
# 4     [{'type': 'rich_text', 'block_id': '7YE+G', 'e...  ...             NaN
# ...                                                 ...  ...             ...
# 1156                                                NaN  ...             NaN
# 1157                                                NaN  ...             NaN
# 1158                                                NaN  ...             NaN
# 1159                                                NaN  ...             NaN
# 1160                                                NaN  ...             NaN
#
#      reactions last_read  bot_id  bot_profile       subtype topic root  \
# 0          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 1          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 2          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 3          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 4          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# ...        ...       ...     ...          ...           ...   ...  ...
# 1156       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1157       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1158       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1159       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1160       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
#
#      purpose channel_name
# 0        NaN      general
# 1        NaN      general
# 2        NaN      general
# 3        NaN      general
# 4        NaN      general
# ...      ...          ...
# 1156     NaN      general
# 1157     NaN      general
# 1158     NaN      general
# 1159     NaN      general
# 1160     NaN      general
#
# [1161 rows x 33 columns]

# %%
# save to csv
channel_gen.to_csv(r'../data/general/channel_gen.csv', index = False)

# %% [markdown]
# ### channel_books

# %%
### books channel
# defining file path
path_to_json = '../data/books/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_books = pd.concat(dfs, ignore_index=True)
# test
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks
# 0                                                NaN
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...

# %%
channel_books['channel_name'] = 'books'
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks channel_name
# 0                                                NaN        books
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...        books
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...        books

# %%
# save to csv
channel_books.to_csv(r'../data/books/channel_books.csv', index = False)

# %% [markdown]
# ### channel_dresource

# %%
### data_resources channel
# defining file path
path_to_json = '../data/data_resources/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dresource = pd.concat(dfs, ignore_index=True)
# test
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 183  message           NaN  1.619510e+09  U01S7KCL3DF
# 184  message           NaN  1.619513e+09  U01RW140HBP
# 185  message           NaN  1.619513e+09  U01RW140HBP
# 186  message  channel_join  1.616163e+09  U01S79YDELR
# 187  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 183  aaahhhh yes thanks… i must scroll down more of...
# 184  we are working hard to keep that Notion up to ...
# 185  because of the free slack thing :confounded:- ...
# 186              <@U01S79YDELR> has joined the channel
# 187              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 183  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 184  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 185  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 186                                   NaN          NaN          NaN
# 187                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 183  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 184  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 185  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 186          NaN                                                NaN  ...
# 187          NaN                                                NaN  ...
#
#         last_read                                              files upload  \
# 0             NaN                                                NaN    NaN
# 1             NaN                                                NaN    NaN
# 2    1.619337e+09                                                NaN    NaN
# 3             NaN  [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False
# 4             NaN  [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False
# ..            ...                                                ...    ...
# 183           NaN                                                NaN    NaN
# 184           NaN                                                NaN    NaN
# 185           NaN                                                NaN    NaN
# 186           NaN                                                NaN    NaN
# 187           NaN                                                NaN    NaN
#
#      display_as_bot                                          reactions  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               0.0  [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...
# 4               0.0                                                NaN
# ..              ...                                                ...
# 183             NaN  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...
# 184             NaN                                                NaN
# 185             NaN                                                NaN
# 186             NaN                                                NaN
# 187             NaN                                                NaN
#
#      parent_user_id  bot_id bot_profile inviter  topic
# 0               NaN     NaN         NaN     NaN    NaN
# 1               NaN     NaN         NaN     NaN    NaN
# 2               NaN     NaN         NaN     NaN    NaN
# 3               NaN     NaN         NaN     NaN    NaN
# 4               NaN     NaN         NaN     NaN    NaN
# ..              ...     ...         ...     ...    ...
# 183     U01S7KCL3DF     NaN         NaN     NaN    NaN
# 184             NaN     NaN         NaN     NaN    NaN
# 185             NaN     NaN         NaN     NaN    NaN
# 186             NaN     NaN         NaN     NaN    NaN
# 187             NaN     NaN         NaN     NaN    NaN
#
# [188 rows x 31 columns]

# %%
channel_dresource['channel_name'] = 'dresource'
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 183  message           NaN  1.619510e+09  U01S7KCL3DF
# 184  message           NaN  1.619513e+09  U01RW140HBP
# 185  message           NaN  1.619513e+09  U01RW140HBP
# 186  message  channel_join  1.616163e+09  U01S79YDELR
# 187  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 183  aaahhhh yes thanks… i must scroll down more of...
# 184  we are working hard to keep that Notion up to ...
# 185  because of the free slack thing :confounded:- ...
# 186              <@U01S79YDELR> has joined the channel
# 187              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 183  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 184  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 185  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 186                                   NaN          NaN          NaN
# 187                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 183  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 184  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 185  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 186          NaN                                                NaN  ...
# 187          NaN                                                NaN  ...
#
#                                                  files upload display_as_bot  \
# 0                                                  NaN    NaN            NaN
# 1                                                  NaN    NaN            NaN
# 2                                                  NaN    NaN            NaN
# 3    [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False            0.0
# 4    [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False            0.0
# ..                                                 ...    ...            ...
# 183                                                NaN    NaN            NaN
# 184                                                NaN    NaN            NaN
# 185                                                NaN    NaN            NaN
# 186                                                NaN    NaN            NaN
# 187                                                NaN    NaN            NaN
#
#                                              reactions  parent_user_id  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3    [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 183  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...     U01S7KCL3DF
# 184                                                NaN             NaN
# 185                                                NaN             NaN
# 186                                                NaN             NaN
# 187                                                NaN             NaN
#
#      bot_id  bot_profile inviter topic  channel_name
# 0       NaN          NaN     NaN   NaN     dresource
# 1       NaN          NaN     NaN   NaN     dresource
# 2       NaN          NaN     NaN   NaN     dresource
# 3       NaN          NaN     NaN   NaN     dresource
# 4       NaN          NaN     NaN   NaN     dresource
# ..      ...          ...     ...   ...           ...
# 183     NaN          NaN     NaN   NaN     dresource
# 184     NaN          NaN     NaN   NaN     dresource
# 185     NaN          NaN     NaN   NaN     dresource
# 186     NaN          NaN     NaN   NaN     dresource
# 187     NaN          NaN     NaN   NaN     dresource
#
# [188 rows x 32 columns]

# %%
# save to csv
channel_dresource.to_csv(r'../data/data_resources/channel_dresource.csv', index = False)

# %% [markdown]
# ### channel_dbootcamp

# %%
### data-bootcamp channel
# defining file path
path_to_json = '../data/data-bootcamp/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dbootcamp = pd.concat(dfs, ignore_index=True)
# test
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text
# 0   <@U01RVSTNRRT> has joined the channel
# 1   <@U01RW140HBP> has joined the channel
# 2   <@U01S65G72SY> has joined the channel
# 3   <@U01RSRE0N3D> has joined the channel
# 4   <@U01RRV4JX6Z> has joined the channel
# 5   <@U01S79YDELR> has joined the channel
# 6   <@U01RUTP1ZQB> has joined the channel
# 7   <@U01RUU9SK4K> has joined the channel
# 8   <@U01S7BM4N81> has joined the channel
# 9   <@U01SJKB2MG8> has joined the channel
# 10  <@U01RV3K524T> has joined the channel
# 11  <@U01S133DZ9A> has joined the channel
# 12  <@U01RN7BVD1C> has joined the channel
# 13  <@U01S7KCL3DF> has joined the channel
# 14  <@U01S1CWGTU4> has joined the channel
# 15  <@U01RNEU3SNA> has joined the channel
# 16  <@U01RS9Y6UJH> has joined the channel
# 17  <@U01SK96QF5E> has joined the channel
# 18  <@U01RP2K1606> has joined the channel
# 19  <@U01RW2X7S9Z> has joined the channel

# %%
channel_dbootcamp['channel_name'] = 'dbootcamp'
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text channel_name
# 0   <@U01RVSTNRRT> has joined the channel    dbootcamp
# 1   <@U01RW140HBP> has joined the channel    dbootcamp
# 2   <@U01S65G72SY> has joined the channel    dbootcamp
# 3   <@U01RSRE0N3D> has joined the channel    dbootcamp
# 4   <@U01RRV4JX6Z> has joined the channel    dbootcamp
# 5   <@U01S79YDELR> has joined the channel    dbootcamp
# 6   <@U01RUTP1ZQB> has joined the channel    dbootcamp
# 7   <@U01RUU9SK4K> has joined the channel    dbootcamp
# 8   <@U01S7BM4N81> has joined the channel    dbootcamp
# 9   <@U01SJKB2MG8> has joined the channel    dbootcamp
# 10  <@U01RV3K524T> has joined the channel    dbootcamp
# 11  <@U01S133DZ9A> has joined the channel    dbootcamp
# 12  <@U01RN7BVD1C> has joined the channel    dbootcamp
# 13  <@U01S7KCL3DF> has joined the channel    dbootcamp
# 14  <@U01S1CWGTU4> has joined the channel    dbootcamp
# 15  <@U01RNEU3SNA> has joined the channel    dbootcamp
# 16  <@U01RS9Y6UJH> has joined the channel    dbootcamp
# 17  <@U01SK96QF5E> has joined the channel    dbootcamp
# 18  <@U01RP2K1606> has joined the channel    dbootcamp
# 19  <@U01RW2X7S9Z> has joined the channel    dbootcamp

# %%
# save to csv
channel_dbootcamp.to_csv(r'../data/data-bootcamp/channel_dbootcamp.csv', index = False)

# %% [markdown]
# ### channel_dmemes

# %%
### data-memes channel
# defining file path
path_to_json = '../data/data-memes/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dmemes = pd.concat(dfs, ignore_index=True)
# test
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 252  message  this made me realise there is no krispy branch...
# 253  message
# 254  message                                     <@U01S0E0MRJ7>
# 255  message                               haha this is tots me
# 256  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 252                                                NaN    NaN  U01SK96QF5E
# 253  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 254  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 255                                                NaN    NaN  U01S0E0MRJ7
# 256  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 252            NaN  1.616509e+09  1.616498e+09          NaN
# 253            0.0  1.616518e+09           NaN          NaN
# 254            0.0  1.619509e+09  1.619509e+09          1.0
# 255            NaN  1.619510e+09  1.619509e+09          NaN
# 256            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...  source_team  \
# 0                  NaN  ...          NaN
# 1                  1.0  ...          NaN
# 2                  NaN  ...          NaN
# 3                  NaN  ...          NaN
# 4                  NaN  ...          NaN
# ..                 ...  ...          ...
# 252                NaN  ...  T01RBRV5F7H
# 253                NaN  ...          NaN
# 254                1.0  ...          NaN
# 255                NaN  ...  T01RBRV5F7H
# 256                NaN  ...          NaN
#
#                                           user_profile attachments  bot_id  \
# 0                                                  NaN         NaN     NaN
# 1                                                  NaN         NaN     NaN
# 2                                                  NaN         NaN     NaN
# 3                                                  NaN         NaN     NaN
# 4                                                  NaN         NaN     NaN
# ..                                                 ...         ...     ...
# 252  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...         NaN     NaN
# 253                                                NaN         NaN     NaN
# 254                                                NaN         NaN     NaN
# 255  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...         NaN     NaN
# 256                                                NaN         NaN     NaN
#
#      bot_profile last_read edited subtype purpose inviter
# 0            NaN       NaN    NaN     NaN     NaN     NaN
# 1            NaN       NaN    NaN     NaN     NaN     NaN
# 2            NaN       NaN    NaN     NaN     NaN     NaN
# 3            NaN       NaN    NaN     NaN     NaN     NaN
# 4            NaN       NaN    NaN     NaN     NaN     NaN
# ..           ...       ...    ...     ...     ...     ...
# 252          NaN       NaN    NaN     NaN     NaN     NaN
# 253          NaN       NaN    NaN     NaN     NaN     NaN
# 254          NaN       NaN    NaN     NaN     NaN     NaN
# 255          NaN       NaN    NaN     NaN     NaN     NaN
# 256          NaN       NaN    NaN     NaN     NaN     NaN
#
# [257 rows x 31 columns]

# %%
channel_dmemes['channel_name'] = 'dmemes'
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 252  message  this made me realise there is no krispy branch...
# 253  message
# 254  message                                     <@U01S0E0MRJ7>
# 255  message                               haha this is tots me
# 256  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 252                                                NaN    NaN  U01SK96QF5E
# 253  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 254  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 255                                                NaN    NaN  U01S0E0MRJ7
# 256  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 252            NaN  1.616509e+09  1.616498e+09          NaN
# 253            0.0  1.616518e+09           NaN          NaN
# 254            0.0  1.619509e+09  1.619509e+09          1.0
# 255            NaN  1.619510e+09  1.619509e+09          NaN
# 256            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...  \
# 0                  NaN  ...
# 1                  1.0  ...
# 2                  NaN  ...
# 3                  NaN  ...
# 4                  NaN  ...
# ..                 ...  ...
# 252                NaN  ...
# 253                NaN  ...
# 254                1.0  ...
# 255                NaN  ...
# 256                NaN  ...
#
#                                           user_profile attachments bot_id  \
# 0                                                  NaN         NaN    NaN
# 1                                                  NaN         NaN    NaN
# 2                                                  NaN         NaN    NaN
# 3                                                  NaN         NaN    NaN
# 4                                                  NaN         NaN    NaN
# ..                                                 ...         ...    ...
# 252  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...         NaN    NaN
# 253                                                NaN         NaN    NaN
# 254                                                NaN         NaN    NaN
# 255  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...         NaN    NaN
# 256                                                NaN         NaN    NaN
#
#      bot_profile  last_read edited subtype purpose inviter channel_name
# 0            NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 1            NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 2            NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 3            NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 4            NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# ..           ...        ...    ...     ...     ...     ...          ...
# 252          NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 253          NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 254          NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 255          NaN        NaN    NaN     NaN     NaN     NaN       dmemes
# 256          NaN        NaN    NaN     NaN     NaN     NaN       dmemes
#
# [257 rows x 32 columns]

# %%
# save to csv
channel_dmemes.to_csv(r'../data/data-memes/channel_dmemes.csv', index = False)

# %% [markdown]
# ### channel_dvizbeauties|

# %%
### data-viz-beauties channel
# defining file path
path_to_json = '../data/data-viz-beauties/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dvizbeauties = pd.concat(dfs, ignore_index=True)
# test
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 249  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 250  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 251  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 252  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 253  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 249  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 250  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 251  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 252                                   a late night sam  U01RS9Y6UJH
# 253  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 249  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 250  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 251  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 252  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 253  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 249  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 250  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 251  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 252  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 253  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  subscribed  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...         NaN
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...         NaN
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...         0.0
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...         NaN
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...         NaN
# ..                                                 ...  ...         ...
# 249  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...         0.0
# 250  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...         0.0
# 251  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...         NaN
# 252  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...         NaN
# 253  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...         NaN
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 249  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 250  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 251  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 252  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 253                                                NaN         NaN
#
#                                                 edited bot_id  bot_profile  \
# 0                                                  NaN    NaN          NaN
# 1                                                  NaN    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3                                                  NaN    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 249                                                NaN    NaN          NaN
# 250  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN          NaN
# 251                                                NaN    NaN          NaN
# 252                                                NaN    NaN          NaN
# 253                                                NaN    NaN          NaN
#
#      subtype  purpose inviter last_read
# 0        NaN      NaN     NaN       NaN
# 1        NaN      NaN     NaN       NaN
# 2        NaN      NaN     NaN       NaN
# 3        NaN      NaN     NaN       NaN
# 4        NaN      NaN     NaN       NaN
# ..       ...      ...     ...       ...
# 249      NaN      NaN     NaN       NaN
# 250      NaN      NaN     NaN       NaN
# 251      NaN      NaN     NaN       NaN
# 252      NaN      NaN     NaN       NaN
# 253      NaN      NaN     NaN       NaN
#
# [254 rows x 31 columns]

# %%
channel_dvizbeauties['channel_name'] = 'dvizbeauties'
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 249  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 250  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 251  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 252  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 253  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 249  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 250  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 251  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 252                                   a late night sam  U01RS9Y6UJH
# 253  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 249  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 250  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 251  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 252  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 253  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 249  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 250  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 251  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 252  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 253  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...
# ..                                                 ...  ...
# 249  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...
# 250  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...
# 251  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...
# 252  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...
# 253  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 249  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 250  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 251  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 252  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 253                                                NaN         NaN
#
#                                                 edited bot_id bot_profile  \
# 0                                                  NaN    NaN         NaN
# 1                                                  NaN    NaN         NaN
# 2                                                  NaN    NaN         NaN
# 3                                                  NaN    NaN         NaN
# 4                                                  NaN    NaN         NaN
# ..                                                 ...    ...         ...
# 249                                                NaN    NaN         NaN
# 250  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN         NaN
# 251                                                NaN    NaN         NaN
# 252                                                NaN    NaN         NaN
# 253                                                NaN    NaN         NaN
#
#      subtype  purpose  inviter last_read  channel_name
# 0        NaN      NaN      NaN       NaN  dvizbeauties
# 1        NaN      NaN      NaN       NaN  dvizbeauties
# 2        NaN      NaN      NaN       NaN  dvizbeauties
# 3        NaN      NaN      NaN       NaN  dvizbeauties
# 4        NaN      NaN      NaN       NaN  dvizbeauties
# ..       ...      ...      ...       ...           ...
# 249      NaN      NaN      NaN       NaN  dvizbeauties
# 250      NaN      NaN      NaN       NaN  dvizbeauties
# 251      NaN      NaN      NaN       NaN  dvizbeauties
# 252      NaN      NaN      NaN       NaN  dvizbeauties
# 253      NaN      NaN      NaN       NaN  dvizbeauties
#
# [254 rows x 32 columns]

# %%
# save to csv
channel_dvizbeauties.to_csv(r'../data/data-viz-beauties/channel_dvizbeauties.csv', index = False)

# %% [markdown]
# ### channel_finalproject

# %%
### final-project channel
# defining file path
path_to_json = '../data/final-project/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_finalproject = pd.concat(dfs, ignore_index=True)
# test
channel_finalproject.head(10)
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.620629e+09  U01RSRE0N3D
# 1  message  channel_join  1.620629e+09  U01SJKB2MG8
# 2  message  channel_join  1.620640e+09  U01RXCQHMHT
# 3  message  channel_join  1.620640e+09  U01S7BM4N81
# 4  message  channel_join  1.620640e+09  U01S133DZ9A
# 5  message  channel_join  1.620640e+09  U01S7KCL3DF
# 6  message  channel_join  1.620640e+09  U01RNEU3SNA
# 7  message  channel_join  1.620640e+09  U01RVSTNRRT
# 8  message  channel_join  1.620640e+09  U01RV3K524T
# 9  message  channel_join  1.620640e+09  U01RS9Y6UJH
#
#                                     text      inviter client_msg_id team  \
# 0  <@U01RSRE0N3D> has joined the channel          NaN           NaN  NaN
# 1  <@U01SJKB2MG8> has joined the channel  U01RSRE0N3D           NaN  NaN
# 2  <@U01RXCQHMHT> has joined the channel  U01RSRE0N3D           NaN  NaN
# 3  <@U01S7BM4N81> has joined the channel  U01RSRE0N3D           NaN  NaN
# 4  <@U01S133DZ9A> has joined the channel  U01RSRE0N3D           NaN  NaN
# 5  <@U01S7KCL3DF> has joined the channel  U01RSRE0N3D           NaN  NaN
# 6  <@U01RNEU3SNA> has joined the channel  U01RSRE0N3D           NaN  NaN
# 7  <@U01RVSTNRRT> has joined the channel  U01RSRE0N3D           NaN  NaN
# 8  <@U01RV3K524T> has joined the channel  U01RSRE0N3D           NaN  NaN
# 9  <@U01RS9Y6UJH> has joined the channel  U01RSRE0N3D           NaN  NaN
#
#   user_team source_team  ... blocks thread_ts  reply_count  reply_users_count  \
# 0       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 1       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 2       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 3       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 4       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 5       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 6       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 7       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 8       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 9       NaN         NaN  ...    NaN       NaN          NaN                NaN
#
#    latest_reply  reply_users replies is_locked  subscribed  parent_user_id
# 0           NaN          NaN     NaN       NaN         NaN             NaN
# 1           NaN          NaN     NaN       NaN         NaN             NaN
# 2           NaN          NaN     NaN       NaN         NaN             NaN
# 3           NaN          NaN     NaN       NaN         NaN             NaN
# 4           NaN          NaN     NaN       NaN         NaN             NaN
# 5           NaN          NaN     NaN       NaN         NaN             NaN
# 6           NaN          NaN     NaN       NaN         NaN             NaN
# 7           NaN          NaN     NaN       NaN         NaN             NaN
# 8           NaN          NaN     NaN       NaN         NaN             NaN
# 9           NaN          NaN     NaN       NaN         NaN             NaN
#
# [10 rows x 21 columns]

# %%
channel_finalproject['channel_name'] = 'finalproject'
channel_finalproject
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.620629e+09  U01RSRE0N3D
# 1   message  channel_join  1.620629e+09  U01SJKB2MG8
# 2   message  channel_join  1.620640e+09  U01RXCQHMHT
# 3   message  channel_join  1.620640e+09  U01S7BM4N81
# 4   message  channel_join  1.620640e+09  U01S133DZ9A
# 5   message  channel_join  1.620640e+09  U01S7KCL3DF
# 6   message  channel_join  1.620640e+09  U01RNEU3SNA
# 7   message  channel_join  1.620640e+09  U01RVSTNRRT
# 8   message  channel_join  1.620640e+09  U01RV3K524T
# 9   message  channel_join  1.620640e+09  U01RS9Y6UJH
# 10  message  channel_join  1.620640e+09  U01RKN0EGDV
# 11  message  channel_join  1.620640e+09  U01SK96QF5E
# 12  message  channel_join  1.620640e+09  U01S79YDELR
# 13  message  channel_join  1.620640e+09  U01RN7BVD1C
# 14  message  channel_join  1.620640e+09  U01S6LCPM0C
# 15  message  channel_join  1.620640e+09  U01S0P26NKD
# 16  message  channel_join  1.620640e+09  U01RP2K1606
# 17  message  channel_join  1.620640e+09  U01S65G72SY
# 18  message  channel_join  1.620640e+09  U01RRV4JX6Z
# 19  message  channel_join  1.620640e+09  U01S081EULS
# 20  message  channel_join  1.620640e+09  U01S0E0MRJ7
# 21  message  channel_join  1.620640e+09  U01S1CWGTU4
# 22  message  channel_join  1.620640e+09  U01S0MFJ3HR
# 23  message  channel_join  1.620640e+09  U01SD3CDH9P
# 24  message  channel_join  1.620640e+09  U01RW2X7S9Z
# 25  message  channel_join  1.620640e+09  U01S6L7HLUC
# 26  message  channel_join  1.620640e+09  U01RW140HBP
# 27  message           NaN  1.620640e+09  U01S7BM4N81
# 28  message           NaN  1.620641e+09  U01RW140HBP
#
#                                                  text      inviter  \
# 0               <@U01RSRE0N3D> has joined the channel          NaN
# 1               <@U01SJKB2MG8> has joined the channel  U01RSRE0N3D
# 2               <@U01RXCQHMHT> has joined the channel  U01RSRE0N3D
# 3               <@U01S7BM4N81> has joined the channel  U01RSRE0N3D
# 4               <@U01S133DZ9A> has joined the channel  U01RSRE0N3D
# 5               <@U01S7KCL3DF> has joined the channel  U01RSRE0N3D
# 6               <@U01RNEU3SNA> has joined the channel  U01RSRE0N3D
# 7               <@U01RVSTNRRT> has joined the channel  U01RSRE0N3D
# 8               <@U01RV3K524T> has joined the channel  U01RSRE0N3D
# 9               <@U01RS9Y6UJH> has joined the channel  U01RSRE0N3D
# 10              <@U01RKN0EGDV> has joined the channel  U01RSRE0N3D
# 11              <@U01SK96QF5E> has joined the channel  U01RSRE0N3D
# 12              <@U01S79YDELR> has joined the channel  U01RSRE0N3D
# 13              <@U01RN7BVD1C> has joined the channel  U01RSRE0N3D
# 14              <@U01S6LCPM0C> has joined the channel  U01RSRE0N3D
# 15              <@U01S0P26NKD> has joined the channel  U01RSRE0N3D
# 16              <@U01RP2K1606> has joined the channel  U01RSRE0N3D
# 17              <@U01S65G72SY> has joined the channel  U01RSRE0N3D
# 18              <@U01RRV4JX6Z> has joined the channel  U01RSRE0N3D
# 19              <@U01S081EULS> has joined the channel  U01RSRE0N3D
# 20              <@U01S0E0MRJ7> has joined the channel  U01RSRE0N3D
# 21              <@U01S1CWGTU4> has joined the channel  U01RSRE0N3D
# 22              <@U01S0MFJ3HR> has joined the channel  U01RSRE0N3D
# 23              <@U01SD3CDH9P> has joined the channel  U01RSRE0N3D
# 24              <@U01RW2X7S9Z> has joined the channel  U01RSRE0N3D
# 25              <@U01S6L7HLUC> has joined the channel  U01RSRE0N3D
# 26              <@U01RW140HBP> has joined the channel  U01RSRE0N3D
# 27  Any collab experts here? :slightly_smiling_fac...          NaN
# 28  im certainly not an expert but happy to try to...          NaN
#
#                            client_msg_id         team    user_team  \
# 0                                    NaN          NaN          NaN
# 1                                    NaN          NaN          NaN
# 2                                    NaN          NaN          NaN
# 3                                    NaN          NaN          NaN
# 4                                    NaN          NaN          NaN
# 5                                    NaN          NaN          NaN
# 6                                    NaN          NaN          NaN
# 7                                    NaN          NaN          NaN
# 8                                    NaN          NaN          NaN
# 9                                    NaN          NaN          NaN
# 10                                   NaN          NaN          NaN
# 11                                   NaN          NaN          NaN
# 12                                   NaN          NaN          NaN
# 13                                   NaN          NaN          NaN
# 14                                   NaN          NaN          NaN
# 15                                   NaN          NaN          NaN
# 16                                   NaN          NaN          NaN
# 17                                   NaN          NaN          NaN
# 18                                   NaN          NaN          NaN
# 19                                   NaN          NaN          NaN
# 20                                   NaN          NaN          NaN
# 21                                   NaN          NaN          NaN
# 22                                   NaN          NaN          NaN
# 23                                   NaN          NaN          NaN
# 24                                   NaN          NaN          NaN
# 25                                   NaN          NaN          NaN
# 26                                   NaN          NaN          NaN
# 27  34f05050-4356-4328-912a-80f1fa11e6e7  T01RBRV5F7H  T01RBRV5F7H
# 28  210d5a28-d10f-4f1c-b8d0-874f25c8251f  T01RBRV5F7H  T01RBRV5F7H
#
#     source_team  ...     thread_ts reply_count  reply_users_count  \
# 0           NaN  ...           NaN         NaN                NaN
# 1           NaN  ...           NaN         NaN                NaN
# 2           NaN  ...           NaN         NaN                NaN
# 3           NaN  ...           NaN         NaN                NaN
# 4           NaN  ...           NaN         NaN                NaN
# 5           NaN  ...           NaN         NaN                NaN
# 6           NaN  ...           NaN         NaN                NaN
# 7           NaN  ...           NaN         NaN                NaN
# 8           NaN  ...           NaN         NaN                NaN
# 9           NaN  ...           NaN         NaN                NaN
# 10          NaN  ...           NaN         NaN                NaN
# 11          NaN  ...           NaN         NaN                NaN
# 12          NaN  ...           NaN         NaN                NaN
# 13          NaN  ...           NaN         NaN                NaN
# 14          NaN  ...           NaN         NaN                NaN
# 15          NaN  ...           NaN         NaN                NaN
# 16          NaN  ...           NaN         NaN                NaN
# 17          NaN  ...           NaN         NaN                NaN
# 18          NaN  ...           NaN         NaN                NaN
# 19          NaN  ...           NaN         NaN                NaN
# 20          NaN  ...           NaN         NaN                NaN
# 21          NaN  ...           NaN         NaN                NaN
# 22          NaN  ...           NaN         NaN                NaN
# 23          NaN  ...           NaN         NaN                NaN
# 24          NaN  ...           NaN         NaN                NaN
# 25          NaN  ...           NaN         NaN                NaN
# 26          NaN  ...           NaN         NaN                NaN
# 27  T01RBRV5F7H  ...  1.620640e+09         1.0                1.0
# 28  T01RBRV5F7H  ...  1.620640e+09         NaN                NaN
#
#     latest_reply    reply_users  \
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
# 5            NaN            NaN
# 6            NaN            NaN
# 7            NaN            NaN
# 8            NaN            NaN
# 9            NaN            NaN
# 10           NaN            NaN
# 11           NaN            NaN
# 12           NaN            NaN
# 13           NaN            NaN
# 14           NaN            NaN
# 15           NaN            NaN
# 16           NaN            NaN
# 17           NaN            NaN
# 18           NaN            NaN
# 19           NaN            NaN
# 20           NaN            NaN
# 21           NaN            NaN
# 22           NaN            NaN
# 23           NaN            NaN
# 24           NaN            NaN
# 25           NaN            NaN
# 26           NaN            NaN
# 27  1.620641e+09  [U01RW140HBP]
# 28           NaN            NaN
#
#                                               replies is_locked subscribed  \
# 0                                                 NaN       NaN        NaN
# 1                                                 NaN       NaN        NaN
# 2                                                 NaN       NaN        NaN
# 3                                                 NaN       NaN        NaN
# 4                                                 NaN       NaN        NaN
# 5                                                 NaN       NaN        NaN
# 6                                                 NaN       NaN        NaN
# 7                                                 NaN       NaN        NaN
# 8                                                 NaN       NaN        NaN
# 9                                                 NaN       NaN        NaN
# 10                                                NaN       NaN        NaN
# 11                                                NaN       NaN        NaN
# 12                                                NaN       NaN        NaN
# 13                                                NaN       NaN        NaN
# 14                                                NaN       NaN        NaN
# 15                                                NaN       NaN        NaN
# 16                                                NaN       NaN        NaN
# 17                                                NaN       NaN        NaN
# 18                                                NaN       NaN        NaN
# 19                                                NaN       NaN        NaN
# 20                                                NaN       NaN        NaN
# 21                                                NaN       NaN        NaN
# 22                                                NaN       NaN        NaN
# 23                                                NaN       NaN        NaN
# 24                                                NaN       NaN        NaN
# 25                                                NaN       NaN        NaN
# 26                                                NaN       NaN        NaN
# 27  [{'user': 'U01RW140HBP', 'ts': '1620640747.006...       0.0        0.0
# 28                                                NaN       NaN        NaN
#
#     parent_user_id  channel_name
# 0              NaN  finalproject
# 1              NaN  finalproject
# 2              NaN  finalproject
# 3              NaN  finalproject
# 4              NaN  finalproject
# 5              NaN  finalproject
# 6              NaN  finalproject
# 7              NaN  finalproject
# 8              NaN  finalproject
# 9              NaN  finalproject
# 10             NaN  finalproject
# 11             NaN  finalproject
# 12             NaN  finalproject
# 13             NaN  finalproject
# 14             NaN  finalproject
# 15             NaN  finalproject
# 16             NaN  finalproject
# 17             NaN  finalproject
# 18             NaN  finalproject
# 19             NaN  finalproject
# 20             NaN  finalproject
# 21             NaN  finalproject
# 22             NaN  finalproject
# 23             NaN  finalproject
# 24             NaN  finalproject
# 25             NaN  finalproject
# 26             NaN  finalproject
# 27             NaN  finalproject
# 28     U01S7BM4N81  finalproject
#
# [29 rows x 22 columns]

# %%
# save to csv
channel_finalproject.to_csv(r'../data/final-project/finalproject.csv', index = False)

# %% [markdown]
# ### channel_frustrations

# %%
### frustrations-shared channel
# defining file path
path_to_json = '../data/frustrations-shared/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_frustrations = pd.concat(dfs, ignore_index=True)
# test
channel_frustrations
# Out:
#       type          subtype            ts         user  \
# 0  message     channel_join  1.616696e+09  U01S133DZ9A
# 1  message  channel_purpose  1.616696e+09  U01S133DZ9A
# 2  message              NaN  1.616696e+09  U01S133DZ9A
#
#                                                 text  \
# 0              <@U01S133DZ9A> has joined the channel
# 1  <@U01S133DZ9A> set the channel description: A ...
# 2  Finally got my files to upload to github.\nWhy...
#
#                                              purpose  \
# 0                                                NaN
# 1  A place to vent your frustration with the worl...
# 2                                                NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  9325906b-46b4-4d98-82e9-d8475aaca20b  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  T01RBRV5F7H  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                               edited  \
# 0                                                NaN
# 1                                                NaN
# 2  {'user': 'U01S133DZ9A', 'ts': '1616695732.0000...
#
#                                               blocks
# 0                                                NaN
# 1                                                NaN
# 2  [{'type': 'rich_text', 'block_id': 'NFV', 'ele...

# %%
channel_frustrations['channel_name'] = 'frustrations'
channel_frustrations
# Out:
#       type          subtype            ts         user  \
# 0  message     channel_join  1.616696e+09  U01S133DZ9A
# 1  message  channel_purpose  1.616696e+09  U01S133DZ9A
# 2  message              NaN  1.616696e+09  U01S133DZ9A
#
#                                                 text  \
# 0              <@U01S133DZ9A> has joined the channel
# 1  <@U01S133DZ9A> set the channel description: A ...
# 2  Finally got my files to upload to github.\nWhy...
#
#                                              purpose  \
# 0                                                NaN
# 1  A place to vent your frustration with the worl...
# 2                                                NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  9325906b-46b4-4d98-82e9-d8475aaca20b  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  T01RBRV5F7H  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                               edited  \
# 0                                                NaN
# 1                                                NaN
# 2  {'user': 'U01S133DZ9A', 'ts': '1616695732.0000...
#
#                                               blocks  channel_name
# 0                                                NaN  frustrations
# 1                                                NaN  frustrations
# 2  [{'type': 'rich_text', 'block_id': 'NFV', 'ele...  frustrations

# %%
# save to csv
channel_frustrations.to_csv(r'../data/frustrations-shared/frustrations.csv', index = False)

# %% [markdown]
# ### channel_funcommittee

# %%
### fun_committee channel
# defining file path
path_to_json = '../data/fun_committee/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_funcommittee = pd.concat(dfs, ignore_index=True)
# test
channel_funcommittee
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619595e+09  U01S7KCL3DF
# 2    message           NaN  1.617614e+09  U01SK96QF5E
# 3    message           NaN  1.617615e+09  U01RRV4JX6Z
# 4    message           NaN  1.617615e+09  U01S0E0MRJ7
# ..       ...           ...           ...          ...
# 147  message           NaN  1.619546e+09  U01RW2X7S9Z
# 148  message           NaN  1.619547e+09  U01S7KCL3DF
# 149  message           NaN  1.619547e+09  U01RXCQHMHT
# 150  message  channel_join  1.616166e+09  U01RNEU3SNA
# 151  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    in case anyone is hungry for feijoada on satur...
# 2    What did you guys do for Easter? :eyes: I went...
# 3    Its astonishing how Alpacas/Llamas/vicunas are...
# 4                                easter egg coloring:)
# ..                                                 ...
# 147                 this is what i'm needing right now
# 148                       Thank you Japanese fisherman
# 149      <https://www.youtube.com/watch?v=ZXsQAXx_ao0>
# 150              <@U01RNEU3SNA> has joined the channel
# 151              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    38b1be29-6601-49f2-9ec2-a99524c9484d  T01RBRV5F7H  T01RBRV5F7H
# 2    6C6C6CE9-8155-4728-A64B-83ABECAC9A7F          NaN          NaN
# 3    1ea1e83f-b494-493b-80a2-deacfa2f3d26  T01RBRV5F7H  T01RBRV5F7H
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 147  2aabb6c6-f8be-4294-b2d1-546622c56aa8  T01RBRV5F7H  T01RBRV5F7H
# 148  0d88d0f4-2fca-45ab-829e-2c61f762b0c9  T01RBRV5F7H  T01RBRV5F7H
# 149  6352006c-7e75-46fc-868c-8f57a72663c2  T01RBRV5F7H  T01RBRV5F7H
# 150                                   NaN          NaN          NaN
# 151                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 2            NaN                                                NaN  ...
# 3    T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 147  T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# 148  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 149  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 150          NaN                                                NaN  ...
# 151          NaN                                                NaN  ...
#
#                                                replies is_locked subscribed  \
# 0                                                  NaN       NaN        NaN
# 1                                                  NaN       NaN        NaN
# 2    [{'user': 'U01RRV4JX6Z', 'ts': '1617615034.003...       0.0        0.0
# 3                                                  NaN       NaN        NaN
# 4                                                  NaN       NaN        NaN
# ..                                                 ...       ...        ...
# 147                                                NaN       NaN        NaN
# 148                                                NaN       NaN        NaN
# 149                                                NaN       NaN        NaN
# 150                                                NaN       NaN        NaN
# 151                                                NaN       NaN        NaN
#
#     parent_user_id bot_id  bot_profile  last_read  \
# 0              NaN    NaN          NaN        NaN
# 1              NaN    NaN          NaN        NaN
# 2              NaN    NaN          NaN        NaN
# 3      U01SK96QF5E    NaN          NaN        NaN
# 4      U01SK96QF5E    NaN          NaN        NaN
# ..             ...    ...          ...        ...
# 147    U01RXCQHMHT    NaN          NaN        NaN
# 148    U01RXCQHMHT    NaN          NaN        NaN
# 149            NaN    NaN          NaN        NaN
# 150            NaN    NaN          NaN        NaN
# 151            NaN    NaN          NaN        NaN
#
#                                            attachments  edited inviter
# 0                                                  NaN     NaN     NaN
# 1                                                  NaN     NaN     NaN
# 2                                                  NaN     NaN     NaN
# 3                                                  NaN     NaN     NaN
# 4                                                  NaN     NaN     NaN
# ..                                                 ...     ...     ...
# 147                                                NaN     NaN     NaN
# 148                                                NaN     NaN     NaN
# 149  [{'service_name': 'YouTube', 'service_url': 'h...     NaN     NaN
# 150                                                NaN     NaN     NaN
# 151                                                NaN     NaN     NaN
#
# [152 rows x 30 columns]

# %%
channel_funcommittee['channel_name'] = 'funcommittee'
channel_funcommittee
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619595e+09  U01S7KCL3DF
# 2    message           NaN  1.617614e+09  U01SK96QF5E
# 3    message           NaN  1.617615e+09  U01RRV4JX6Z
# 4    message           NaN  1.617615e+09  U01S0E0MRJ7
# ..       ...           ...           ...          ...
# 147  message           NaN  1.619546e+09  U01RW2X7S9Z
# 148  message           NaN  1.619547e+09  U01S7KCL3DF
# 149  message           NaN  1.619547e+09  U01RXCQHMHT
# 150  message  channel_join  1.616166e+09  U01RNEU3SNA
# 151  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    in case anyone is hungry for feijoada on satur...
# 2    What did you guys do for Easter? :eyes: I went...
# 3    Its astonishing how Alpacas/Llamas/vicunas are...
# 4                                easter egg coloring:)
# ..                                                 ...
# 147                 this is what i'm needing right now
# 148                       Thank you Japanese fisherman
# 149      <https://www.youtube.com/watch?v=ZXsQAXx_ao0>
# 150              <@U01RNEU3SNA> has joined the channel
# 151              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    38b1be29-6601-49f2-9ec2-a99524c9484d  T01RBRV5F7H  T01RBRV5F7H
# 2    6C6C6CE9-8155-4728-A64B-83ABECAC9A7F          NaN          NaN
# 3    1ea1e83f-b494-493b-80a2-deacfa2f3d26  T01RBRV5F7H  T01RBRV5F7H
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 147  2aabb6c6-f8be-4294-b2d1-546622c56aa8  T01RBRV5F7H  T01RBRV5F7H
# 148  0d88d0f4-2fca-45ab-829e-2c61f762b0c9  T01RBRV5F7H  T01RBRV5F7H
# 149  6352006c-7e75-46fc-868c-8f57a72663c2  T01RBRV5F7H  T01RBRV5F7H
# 150                                   NaN          NaN          NaN
# 151                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 2            NaN                                                NaN  ...
# 3    T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 147  T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# 148  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 149  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 150          NaN                                                NaN  ...
# 151          NaN                                                NaN  ...
#
#     is_locked subscribed parent_user_id bot_id bot_profile  last_read  \
# 0         NaN        NaN            NaN    NaN         NaN        NaN
# 1         NaN        NaN            NaN    NaN         NaN        NaN
# 2         0.0        0.0            NaN    NaN         NaN        NaN
# 3         NaN        NaN    U01SK96QF5E    NaN         NaN        NaN
# 4         NaN        NaN    U01SK96QF5E    NaN         NaN        NaN
# ..        ...        ...            ...    ...         ...        ...
# 147       NaN        NaN    U01RXCQHMHT    NaN         NaN        NaN
# 148       NaN        NaN    U01RXCQHMHT    NaN         NaN        NaN
# 149       NaN        NaN            NaN    NaN         NaN        NaN
# 150       NaN        NaN            NaN    NaN         NaN        NaN
# 151       NaN        NaN            NaN    NaN         NaN        NaN
#
#                                            attachments  edited  inviter  \
# 0                                                  NaN     NaN      NaN
# 1                                                  NaN     NaN      NaN
# 2                                                  NaN     NaN      NaN
# 3                                                  NaN     NaN      NaN
# 4                                                  NaN     NaN      NaN
# ..                                                 ...     ...      ...
# 147                                                NaN     NaN      NaN
# 148                                                NaN     NaN      NaN
# 149  [{'service_name': 'YouTube', 'service_url': 'h...     NaN      NaN
# 150                                                NaN     NaN      NaN
# 151                                                NaN     NaN      NaN
#
#      channel_name
# 0    funcommittee
# 1    funcommittee
# 2    funcommittee
# 3    funcommittee
# 4    funcommittee
# ..            ...
# 147  funcommittee
# 148  funcommittee
# 149  funcommittee
# 150  funcommittee
# 151  funcommittee
#
# [152 rows x 31 columns]

# %%
# save to csv
channel_funcommittee.to_csv(r'../data/fun_committee/channel_funcommittee.csv', index = False)

# %% [markdown]
# ### channel_katas

# %%
### katas channel
# defining file path
path_to_json = '../data/katas/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_katas = pd.concat(dfs, ignore_index=True)
# test
channel_katas
# Out:
#                             client_msg_id     type  \
# 0    593fe4d1-4a6b-4827-9c53-260376d6493f  message
# 1    c2d95c8b-3e50-4d48-8135-648704bf35d3  message
# 2    33452e06-616f-439e-9ad6-02aeb31269b5  message
# 3    67dc2652-03b5-4f43-b826-e8883ea5bc58  message
# 4    b63eafaf-fd31-4a13-b26b-81ee65d897fd  message
# ..                                    ...      ...
# 141  2be1b256-f82f-4595-9bac-52058ec61358  message
# 142  ffcf0cf8-92a3-4235-8210-0dd5421d4f4c  message
# 143  627524f7-2692-4e03-a542-61c3f55d6d67  message
# 144  dbd3a788-8ac0-4da3-b16e-5acd857ab571  message
# 145  a98df046-4c44-4bf2-ae2c-1a1f970dee86  message
#
#                                                   text         user  \
# 0    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01RSRE0N3D
# 1                               Who was first? :smile:  U01S7BM4N81
# 2                                         Where is it?  U01RRV4JX6Z
# 3    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01SD3CDH9P
# 4    to know the answer or to put the tick? :girl-g...  U01RW2X7S9Z
# ..                                                 ...          ...
# 141  no… you might find people do and on a new line...  U01RW140HBP
# 142  <https://www.codewars.com/kata/5a8ed96bfd8c066...  U01RSRE0N3D
# 143  ```hint… WHERE country IN('United States of Am...  U01RW140HBP
# 144  <https://www.codewars.com/kata/5abcf0f930488ff...  U01SJKB2MG8
# 145                                     :harry-potter:  U01RW140HBP
#
#                ts         team    user_team  source_team  \
# 0    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 141  1.617715e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 142  1.617798e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 143  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 144  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 145  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 2    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    {'avatar_hash': '735d50ad8f34', 'image_72': 'h...
# 4    {'avatar_hash': '7e12d75d168a', 'image_72': 'h...
# ..                                                 ...
# 141  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 142  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 143  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 144  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 145  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#                                            attachments  ...  \
# 0    [{'service_name': 'Codewars', 'title': 'Traini...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 141                                                NaN  ...
# 142  [{'service_name': 'Codewars', 'title': 'Traini...  ...
# 143                                                NaN  ...
# 144  [{'service_name': 'Codewars', 'title': 'SQL wi...  ...
# 145                                                NaN  ...
#
#                                                 edited  parent_user_id  \
# 0                                                  NaN             NaN
# 1    {'user': 'U01S7BM4N81', 'ts': '1618229077.0000...     U01RSRE0N3D
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN     U01RSRE0N3D
# ..                                                 ...             ...
# 141                                                NaN     U01SJKB2MG8
# 142                                                NaN             NaN
# 143                                                NaN     U01RSRE0N3D
# 144                                                NaN             NaN
# 145                                                NaN     U01SJKB2MG8
#
#      bot_id  bot_profile  files upload display_as_bot  subtype  inviter  topic
# 0       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 1       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 2       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 3       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 4       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# ..      ...          ...    ...    ...            ...      ...      ...    ...
# 141     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 142     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 143     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 144     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 145     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
#
# [146 rows x 31 columns]

# %%
channel_katas['channel_name'] = 'katas'
channel_katas
# Out:
#                             client_msg_id     type  \
# 0    593fe4d1-4a6b-4827-9c53-260376d6493f  message
# 1    c2d95c8b-3e50-4d48-8135-648704bf35d3  message
# 2    33452e06-616f-439e-9ad6-02aeb31269b5  message
# 3    67dc2652-03b5-4f43-b826-e8883ea5bc58  message
# 4    b63eafaf-fd31-4a13-b26b-81ee65d897fd  message
# ..                                    ...      ...
# 141  2be1b256-f82f-4595-9bac-52058ec61358  message
# 142  ffcf0cf8-92a3-4235-8210-0dd5421d4f4c  message
# 143  627524f7-2692-4e03-a542-61c3f55d6d67  message
# 144  dbd3a788-8ac0-4da3-b16e-5acd857ab571  message
# 145  a98df046-4c44-4bf2-ae2c-1a1f970dee86  message
#
#                                                   text         user  \
# 0    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01RSRE0N3D
# 1                               Who was first? :smile:  U01S7BM4N81
# 2                                         Where is it?  U01RRV4JX6Z
# 3    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01SD3CDH9P
# 4    to know the answer or to put the tick? :girl-g...  U01RW2X7S9Z
# ..                                                 ...          ...
# 141  no… you might find people do and on a new line...  U01RW140HBP
# 142  <https://www.codewars.com/kata/5a8ed96bfd8c066...  U01RSRE0N3D
# 143  ```hint… WHERE country IN('United States of Am...  U01RW140HBP
# 144  <https://www.codewars.com/kata/5abcf0f930488ff...  U01SJKB2MG8
# 145                                     :harry-potter:  U01RW140HBP
#
#                ts         team    user_team  source_team  \
# 0    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 141  1.617715e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 142  1.617798e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 143  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 144  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 145  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 2    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    {'avatar_hash': '735d50ad8f34', 'image_72': 'h...
# 4    {'avatar_hash': '7e12d75d168a', 'image_72': 'h...
# ..                                                 ...
# 141  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 142  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 143  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 144  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 145  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#                                            attachments  ... parent_user_id  \
# 0    [{'service_name': 'Codewars', 'title': 'Traini...  ...            NaN
# 1                                                  NaN  ...    U01RSRE0N3D
# 2                                                  NaN  ...            NaN
# 3                                                  NaN  ...            NaN
# 4                                                  NaN  ...    U01RSRE0N3D
# ..                                                 ...  ...            ...
# 141                                                NaN  ...    U01SJKB2MG8
# 142  [{'service_name': 'Codewars', 'title': 'Traini...  ...            NaN
# 143                                                NaN  ...    U01RSRE0N3D
# 144  [{'service_name': 'Codewars', 'title': 'SQL wi...  ...            NaN
# 145                                                NaN  ...    U01SJKB2MG8
#
#      bot_id  bot_profile  files  upload display_as_bot subtype  inviter  \
# 0       NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 1       NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 2       NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 3       NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 4       NaN          NaN    NaN     NaN            NaN     NaN      NaN
# ..      ...          ...    ...     ...            ...     ...      ...
# 141     NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 142     NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 143     NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 144     NaN          NaN    NaN     NaN            NaN     NaN      NaN
# 145     NaN          NaN    NaN     NaN            NaN     NaN      NaN
#
#      topic  channel_name
# 0      NaN         katas
# 1      NaN         katas
# 2      NaN         katas
# 3      NaN         katas
# 4      NaN         katas
# ..     ...           ...
# 141    NaN         katas
# 142    NaN         katas
# 143    NaN         katas
# 144    NaN         katas
# 145    NaN         katas
#
# [146 rows x 32 columns]

# %%
# save to csv
channel_katas.to_csv(r'../data/katas/channel_katas.csv', index = False)

# %% [markdown]
# ### channel_labhelp

# %%
### lab-help channel
# defining file path
path_to_json = '../data/lab-help/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_labhelp = pd.concat(dfs, ignore_index=True)
# test
channel_labhelp
# Out:
#          type       subtype            ts         user  \
# 0     message  channel_join  1.616237e+09  U01S1CWGTU4
# 1     message           NaN  1.617866e+09  U01S79YDELR
# 2     message           NaN  1.617866e+09  U01RW140HBP
# 3     message           NaN  1.617867e+09  U01RW140HBP
# 4     message           NaN  1.617867e+09  U01S79YDELR
# ...       ...           ...           ...          ...
# 1455  message           NaN  1.619542e+09  U01S0E0MRJ7
# 1456  message           NaN  1.619543e+09  U01RW140HBP
# 1457  message           NaN  1.619543e+09  U01RW140HBP
# 1458  message           NaN  1.619543e+09  U01S0E0MRJ7
# 1459  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                    text  \
# 0                 <@U01S1CWGTU4> has joined the channel
# 1     <@U01RSRE0N3D>  <https://www.ibm.com/docs/en/i...
# 2     we will do more on this today in the lesson Ka...
# 3     ok no problem we will revisit rank this mornin...
# 4     it is the syntax in dbeaver, sakila is the dat...
# ...                                                 ...
# 1455  hey im confused. what is this data? i was work...
# 1456  i think Andrea decided to work on a dashboard ...
# 1457                so this is from the superstore data
# 1458  ah ok NP I just saw Phine also had US map and ...
# 1459              <@U01RW2X7S9Z> has joined the channel
#
#                              client_msg_id         team    user_team  \
# 0                                      NaN          NaN          NaN
# 1     d1f113e1-d517-427f-8f17-a8b2695ca580  T01RBRV5F7H  T01RBRV5F7H
# 2     547c153e-d251-492f-8502-81a3b04809cb  T01RBRV5F7H  T01RBRV5F7H
# 3     e04e1c54-28fd-46a3-a61e-f2c976be85d6  T01RBRV5F7H  T01RBRV5F7H
# 4     90ed80d9-2e55-4f1d-ad2c-52f112e8f70f  T01RBRV5F7H  T01RBRV5F7H
# ...                                    ...          ...          ...
# 1455  e1c01335-c973-43d8-b462-161e3735243c  T01RBRV5F7H  T01RBRV5F7H
# 1456  233723f5-fe02-4f1c-8b08-1de2b2913610  T01RBRV5F7H  T01RBRV5F7H
# 1457  a02ee96f-e064-45d8-ac54-dab50887a95e  T01RBRV5F7H  T01RBRV5F7H
# 1458  9214dcbf-8ffe-447b-b970-c182e7260801  T01RBRV5F7H  T01RBRV5F7H
# 1459                                   NaN          NaN          NaN
#
#       source_team                                       user_profile  ...  \
# 0             NaN                                                NaN  ...
# 1     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 3     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 4     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# ...           ...                                                ...  ...
# 1455  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1456  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1457  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1458  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1459          NaN                                                NaN  ...
#
#      attachments last_read  bot_id bot_profile root  old_name  name  inviter  \
# 0            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 2            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 3            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 4            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# ...          ...       ...     ...         ...  ...       ...   ...      ...
# 1455         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1456         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1457         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1458         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1459         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
#
#      hidden x_files
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...     ...     ...
# 1455    NaN     NaN
# 1456    NaN     NaN
# 1457    NaN     NaN
# 1458    NaN     NaN
# 1459    NaN     NaN
#
# [1460 rows x 35 columns]

# %%
channel_labhelp['channel_name'] = 'labhelp'
channel_labhelp
# Out:
#          type       subtype            ts         user  \
# 0     message  channel_join  1.616237e+09  U01S1CWGTU4
# 1     message           NaN  1.617866e+09  U01S79YDELR
# 2     message           NaN  1.617866e+09  U01RW140HBP
# 3     message           NaN  1.617867e+09  U01RW140HBP
# 4     message           NaN  1.617867e+09  U01S79YDELR
# ...       ...           ...           ...          ...
# 1455  message           NaN  1.619542e+09  U01S0E0MRJ7
# 1456  message           NaN  1.619543e+09  U01RW140HBP
# 1457  message           NaN  1.619543e+09  U01RW140HBP
# 1458  message           NaN  1.619543e+09  U01S0E0MRJ7
# 1459  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                    text  \
# 0                 <@U01S1CWGTU4> has joined the channel
# 1     <@U01RSRE0N3D>  <https://www.ibm.com/docs/en/i...
# 2     we will do more on this today in the lesson Ka...
# 3     ok no problem we will revisit rank this mornin...
# 4     it is the syntax in dbeaver, sakila is the dat...
# ...                                                 ...
# 1455  hey im confused. what is this data? i was work...
# 1456  i think Andrea decided to work on a dashboard ...
# 1457                so this is from the superstore data
# 1458  ah ok NP I just saw Phine also had US map and ...
# 1459              <@U01RW2X7S9Z> has joined the channel
#
#                              client_msg_id         team    user_team  \
# 0                                      NaN          NaN          NaN
# 1     d1f113e1-d517-427f-8f17-a8b2695ca580  T01RBRV5F7H  T01RBRV5F7H
# 2     547c153e-d251-492f-8502-81a3b04809cb  T01RBRV5F7H  T01RBRV5F7H
# 3     e04e1c54-28fd-46a3-a61e-f2c976be85d6  T01RBRV5F7H  T01RBRV5F7H
# 4     90ed80d9-2e55-4f1d-ad2c-52f112e8f70f  T01RBRV5F7H  T01RBRV5F7H
# ...                                    ...          ...          ...
# 1455  e1c01335-c973-43d8-b462-161e3735243c  T01RBRV5F7H  T01RBRV5F7H
# 1456  233723f5-fe02-4f1c-8b08-1de2b2913610  T01RBRV5F7H  T01RBRV5F7H
# 1457  a02ee96f-e064-45d8-ac54-dab50887a95e  T01RBRV5F7H  T01RBRV5F7H
# 1458  9214dcbf-8ffe-447b-b970-c182e7260801  T01RBRV5F7H  T01RBRV5F7H
# 1459                                   NaN          NaN          NaN
#
#       source_team                                       user_profile  ...  \
# 0             NaN                                                NaN  ...
# 1     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 3     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 4     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# ...           ...                                                ...  ...
# 1455  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1456  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1457  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1458  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1459          NaN                                                NaN  ...
#
#      last_read bot_id  bot_profile root old_name  name  inviter  hidden  \
# 0          NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 1          NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 2          NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 3          NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 4          NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# ...        ...    ...          ...  ...      ...   ...      ...     ...
# 1455       NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 1456       NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 1457       NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 1458       NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
# 1459       NaN    NaN          NaN  NaN      NaN   NaN      NaN     NaN
#
#      x_files channel_name
# 0        NaN      labhelp
# 1        NaN      labhelp
# 2        NaN      labhelp
# 3        NaN      labhelp
# 4        NaN      labhelp
# ...      ...          ...
# 1455     NaN      labhelp
# 1456     NaN      labhelp
# 1457     NaN      labhelp
# 1458     NaN      labhelp
# 1459     NaN      labhelp
#
# [1460 rows x 36 columns]

# %%
# save to csv
channel_labhelp.to_csv(r'../data/lab-help/channel_labhelp.csv', index = False)

# %% [markdown]
# ### channel_music

# %%
### music channel
# defining file path
path_to_json = '../data/music/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_music = pd.concat(dfs, ignore_index=True)
# test
channel_music
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.617897e+09  U01S7BM4N81
# 2    message           NaN  1.620200e+09  U01S7KCL3DF
# 3    message           NaN  1.620211e+09  U01RSRE0N3D
# 4    message           NaN  1.620213e+09  U01RW2X7S9Z
# ..       ...           ...           ...          ...
# 157  message           NaN  1.619530e+09  U01RXCQHMHT
# 158  message           NaN  1.619535e+09  U01SK96QF5E
# 159  message           NaN  1.619554e+09  U01RXCQHMHT
# 160  message           NaN  1.619586e+09  U01RXCQHMHT
# 161  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1        <https://www.youtube.com/watch?v=qW1eTP9CKSE>
# 2    <@U01RXCQHMHT> here’s a bangin track about Nig...
# 3    For all of you LotR ravers\n<https://www.youtu...
# 4    my recommender:\n`input("introduce your song:"...
# ..                                                 ...
# 157  someone showed me a video from the pre-corona ...
# 158  got totally addicted to this playlist since Fr...
# 159  <https://www.youtube.com/watch?v=HeyfOEb7ET0&a...
# 160  <https://soundcloud.com/hate_music/premiere-vo...
# 161              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 2    a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 3    41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# 4    003f3fc9-1d77-4811-9017-68c20dd995bd  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 157  3bd07a1a-d9b4-401a-ab6d-9da03d5c109c  T01RBRV5F7H  T01RBRV5F7H
# 158  d8b6518c-f8d6-4527-b70d-8eceee1bb1df  T01RBRV5F7H  T01RBRV5F7H
# 159  d255756e-a269-4280-9ca6-5f50b2b1cabf  T01RBRV5F7H  T01RBRV5F7H
# 160  3079ffd3-2d1e-41db-a66e-a611d080d371  T01RBRV5F7H  T01RBRV5F7H
# 161                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 3    T01RBRV5F7H  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...  ...
# 4    T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# ..           ...                                                ...  ...
# 157  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 158  T01RBRV5F7H  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...  ...
# 159  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 160  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 161          NaN                                                NaN  ...
#
#     subscribed     last_read  \
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          1.0  1.620242e+09
# 4          NaN           NaN
# ..         ...           ...
# 157        NaN           NaN
# 158        NaN           NaN
# 159        NaN           NaN
# 160        NaN           NaN
# 161        NaN           NaN
#
#                                              reactions  parent_user_id  files  \
# 0                                                  NaN             NaN    NaN
# 1                                                  NaN             NaN    NaN
# 2                                                  NaN             NaN    NaN
# 3    [{'name': 'white_check_mark', 'users': ['U01RW...             NaN    NaN
# 4    [{'name': 'rickroll', 'users': ['U01RSRE0N3D',...     U01RSRE0N3D    NaN
# ..                                                 ...             ...    ...
# 157                                                NaN     U01RXCQHMHT    NaN
# 158  [{'name': 'man_dancing', 'users': ['U01RW140HB...             NaN    NaN
# 159                                                NaN             NaN    NaN
# 160                                                NaN             NaN    NaN
# 161                                                NaN             NaN    NaN
#
#      upload  display_as_bot bot_id bot_profile inviter
# 0       NaN             NaN    NaN         NaN     NaN
# 1       NaN             NaN    NaN         NaN     NaN
# 2       NaN             NaN    NaN         NaN     NaN
# 3       NaN             NaN    NaN         NaN     NaN
# 4       NaN             NaN    NaN         NaN     NaN
# ..      ...             ...    ...         ...     ...
# 157     NaN             NaN    NaN         NaN     NaN
# 158     NaN             NaN    NaN         NaN     NaN
# 159     NaN             NaN    NaN         NaN     NaN
# 160     NaN             NaN    NaN         NaN     NaN
# 161     NaN             NaN    NaN         NaN     NaN
#
# [162 rows x 30 columns]

# %%
channel_music['channel_name'] = 'music'
channel_music
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.617897e+09  U01S7BM4N81
# 2    message           NaN  1.620200e+09  U01S7KCL3DF
# 3    message           NaN  1.620211e+09  U01RSRE0N3D
# 4    message           NaN  1.620213e+09  U01RW2X7S9Z
# ..       ...           ...           ...          ...
# 157  message           NaN  1.619530e+09  U01RXCQHMHT
# 158  message           NaN  1.619535e+09  U01SK96QF5E
# 159  message           NaN  1.619554e+09  U01RXCQHMHT
# 160  message           NaN  1.619586e+09  U01RXCQHMHT
# 161  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1        <https://www.youtube.com/watch?v=qW1eTP9CKSE>
# 2    <@U01RXCQHMHT> here’s a bangin track about Nig...
# 3    For all of you LotR ravers\n<https://www.youtu...
# 4    my recommender:\n`input("introduce your song:"...
# ..                                                 ...
# 157  someone showed me a video from the pre-corona ...
# 158  got totally addicted to this playlist since Fr...
# 159  <https://www.youtube.com/watch?v=HeyfOEb7ET0&a...
# 160  <https://soundcloud.com/hate_music/premiere-vo...
# 161              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 2    a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 3    41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# 4    003f3fc9-1d77-4811-9017-68c20dd995bd  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 157  3bd07a1a-d9b4-401a-ab6d-9da03d5c109c  T01RBRV5F7H  T01RBRV5F7H
# 158  d8b6518c-f8d6-4527-b70d-8eceee1bb1df  T01RBRV5F7H  T01RBRV5F7H
# 159  d255756e-a269-4280-9ca6-5f50b2b1cabf  T01RBRV5F7H  T01RBRV5F7H
# 160  3079ffd3-2d1e-41db-a66e-a611d080d371  T01RBRV5F7H  T01RBRV5F7H
# 161                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 3    T01RBRV5F7H  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...  ...
# 4    T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# ..           ...                                                ...  ...
# 157  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 158  T01RBRV5F7H  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...  ...
# 159  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 160  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 161          NaN                                                NaN  ...
#
#         last_read                                          reactions  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3    1.620242e+09  [{'name': 'white_check_mark', 'users': ['U01RW...
# 4             NaN  [{'name': 'rickroll', 'users': ['U01RSRE0N3D',...
# ..            ...                                                ...
# 157           NaN                                                NaN
# 158           NaN  [{'name': 'man_dancing', 'users': ['U01RW140HB...
# 159           NaN                                                NaN
# 160           NaN                                                NaN
# 161           NaN                                                NaN
#
#     parent_user_id  files  upload  display_as_bot  bot_id bot_profile inviter  \
# 0              NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 1              NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 2              NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 3              NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 4      U01RSRE0N3D    NaN     NaN             NaN     NaN         NaN     NaN
# ..             ...    ...     ...             ...     ...         ...     ...
# 157    U01RXCQHMHT    NaN     NaN             NaN     NaN         NaN     NaN
# 158            NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 159            NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 160            NaN    NaN     NaN             NaN     NaN         NaN     NaN
# 161            NaN    NaN     NaN             NaN     NaN         NaN     NaN
#
#     channel_name
# 0          music
# 1          music
# 2          music
# 3          music
# 4          music
# ..           ...
# 157        music
# 158        music
# 159        music
# 160        music
# 161        music
#
# [162 rows x 31 columns]

# %%
# save to csv
channel_music.to_csv(r'../data/music/channel_music.csv', index = False)

# %% [markdown]
# ### channel_random

# %%
### random channel
# defining file path
path_to_json = '../data/random/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_random = pd.concat(dfs, ignore_index=True)
# test
channel_random
# Out:
#         type                                               text  \
# 0    message                                     <@U01S7BM4N81>
# 1    message  decentralized (which is the original spirit of...
# 2    message  leute we’re missing the bigger picture….Gold, ...
# 3    message                       Oooof how could I miss this?
# 4    message  I think it very much depends on the issuing co...
# ..       ...                                                ...
# 422  message              <@U01RNEU3SNA> has joined the channel
# 423  message              <@U01RS9Y6UJH> has joined the channel
# 424  message              <@U01SK96QF5E> has joined the channel
# 425  message              <@U01RP2K1606> has joined the channel
# 426  message              <@U01RW2X7S9Z> has joined the channel
#
#                                                  files upload  \
# 0    [{'id': 'F021HK4BWG4', 'created': 1620544574, ...    0.0
# 1                                                  NaN    NaN
# 2    [{'id': 'F0218DDJN7P', 'created': 1620549030, ...    0.0
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 422                                                NaN    NaN
# 423                                                NaN    NaN
# 424                                                NaN    NaN
# 425                                                NaN    NaN
# 426                                                NaN    NaN
#
#                                                 blocks         user  \
# 0    [{'type': 'rich_text', 'block_id': 'p4HE', 'el...  U01RRV4JX6Z
# 1    [{'type': 'rich_text', 'block_id': 'Fal', 'ele...  U01S7BM4N81
# 2    [{'type': 'rich_text', 'block_id': 'aFRzS', 'e...  U01S7KCL3DF
# 3    [{'type': 'rich_text', 'block_id': 'mgxv', 'el...  U01S7BM4N81
# 4    [{'type': 'rich_text', 'block_id': 'OMH/u', 'e...  U01RRV4JX6Z
# ..                                                 ...          ...
# 422                                                NaN  U01RNEU3SNA
# 423                                                NaN  U01RS9Y6UJH
# 424                                                NaN  U01SK96QF5E
# 425                                                NaN  U01RP2K1606
# 426                                                NaN  U01RW2X7S9Z
#
#      display_as_bot            ts                         client_msg_id  \
# 0               0.0  1.620545e+09  dd000aef-264c-4bd5-8426-e1e08552643b
# 1               NaN  1.620546e+09  0ad68149-64a1-454e-9e9c-6abf8c3d185c
# 2               0.0  1.620549e+09                                   NaN
# 3               NaN  1.620551e+09  579D4E6F-0E09-4FC7-A811-656CC403647F
# 4               NaN  1.620555e+09  78e0293a-be09-4b28-bf3d-2f70ab3b48fb
# ..              ...           ...                                   ...
# 422             NaN  1.616166e+09                                   NaN
# 423             NaN  1.616167e+09                                   NaN
# 424             NaN  1.616168e+09                                   NaN
# 425             NaN  1.616172e+09                                   NaN
# 426             NaN  1.616172e+09                                   NaN
#
#         thread_ts  ...  source_team  \
# 0    1.620545e+09  ...          NaN
# 1    1.620545e+09  ...  T01RBRV5F7H
# 2    1.620369e+09  ...          NaN
# 3    1.620369e+09  ...  T01RBRV5F7H
# 4    1.620545e+09  ...  T01RBRV5F7H
# ..            ...  ...          ...
# 422           NaN  ...          NaN
# 423           NaN  ...          NaN
# 424           NaN  ...          NaN
# 425           NaN  ...          NaN
# 426           NaN  ...          NaN
#
#                                           user_profile  parent_user_id  \
# 0                                                  NaN             NaN
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RRV4JX6Z
# 2                                                  NaN     U01RN7BVD1C
# 3    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RN7BVD1C
# 4    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...     U01RRV4JX6Z
# ..                                                 ...             ...
# 422                                                NaN             NaN
# 423                                                NaN             NaN
# 424                                                NaN             NaN
# 425                                                NaN             NaN
# 426                                                NaN             NaN
#
#                                              reactions edited  attachments  \
# 0                                                  NaN    NaN          NaN
# 1    [{'name': 'dart', 'users': ['U01S1CWGTU4'], 'c...    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3    [{'name': 'stonks', 'users': ['U01S7KCL3DF', '...    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 422                                                NaN    NaN          NaN
# 423                                                NaN    NaN          NaN
# 424                                                NaN    NaN          NaN
# 425                                                NaN    NaN          NaN
# 426                                                NaN    NaN          NaN
#
#      last_read bot_id bot_profile       subtype
# 0          NaN    NaN         NaN           NaN
# 1          NaN    NaN         NaN           NaN
# 2          NaN    NaN         NaN           NaN
# 3          NaN    NaN         NaN           NaN
# 4          NaN    NaN         NaN           NaN
# ..         ...    ...         ...           ...
# 422        NaN    NaN         NaN  channel_join
# 423        NaN    NaN         NaN  channel_join
# 424        NaN    NaN         NaN  channel_join
# 425        NaN    NaN         NaN  channel_join
# 426        NaN    NaN         NaN  channel_join
#
# [427 rows x 29 columns]

# %%
channel_random['channel_name'] = 'random'
channel_random
# Out:
#         type                                               text  \
# 0    message                                     <@U01S7BM4N81>
# 1    message  decentralized (which is the original spirit of...
# 2    message  leute we’re missing the bigger picture….Gold, ...
# 3    message                       Oooof how could I miss this?
# 4    message  I think it very much depends on the issuing co...
# ..       ...                                                ...
# 422  message              <@U01RNEU3SNA> has joined the channel
# 423  message              <@U01RS9Y6UJH> has joined the channel
# 424  message              <@U01SK96QF5E> has joined the channel
# 425  message              <@U01RP2K1606> has joined the channel
# 426  message              <@U01RW2X7S9Z> has joined the channel
#
#                                                  files upload  \
# 0    [{'id': 'F021HK4BWG4', 'created': 1620544574, ...    0.0
# 1                                                  NaN    NaN
# 2    [{'id': 'F0218DDJN7P', 'created': 1620549030, ...    0.0
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 422                                                NaN    NaN
# 423                                                NaN    NaN
# 424                                                NaN    NaN
# 425                                                NaN    NaN
# 426                                                NaN    NaN
#
#                                                 blocks         user  \
# 0    [{'type': 'rich_text', 'block_id': 'p4HE', 'el...  U01RRV4JX6Z
# 1    [{'type': 'rich_text', 'block_id': 'Fal', 'ele...  U01S7BM4N81
# 2    [{'type': 'rich_text', 'block_id': 'aFRzS', 'e...  U01S7KCL3DF
# 3    [{'type': 'rich_text', 'block_id': 'mgxv', 'el...  U01S7BM4N81
# 4    [{'type': 'rich_text', 'block_id': 'OMH/u', 'e...  U01RRV4JX6Z
# ..                                                 ...          ...
# 422                                                NaN  U01RNEU3SNA
# 423                                                NaN  U01RS9Y6UJH
# 424                                                NaN  U01SK96QF5E
# 425                                                NaN  U01RP2K1606
# 426                                                NaN  U01RW2X7S9Z
#
#      display_as_bot            ts                         client_msg_id  \
# 0               0.0  1.620545e+09  dd000aef-264c-4bd5-8426-e1e08552643b
# 1               NaN  1.620546e+09  0ad68149-64a1-454e-9e9c-6abf8c3d185c
# 2               0.0  1.620549e+09                                   NaN
# 3               NaN  1.620551e+09  579D4E6F-0E09-4FC7-A811-656CC403647F
# 4               NaN  1.620555e+09  78e0293a-be09-4b28-bf3d-2f70ab3b48fb
# ..              ...           ...                                   ...
# 422             NaN  1.616166e+09                                   NaN
# 423             NaN  1.616167e+09                                   NaN
# 424             NaN  1.616168e+09                                   NaN
# 425             NaN  1.616172e+09                                   NaN
# 426             NaN  1.616172e+09                                   NaN
#
#         thread_ts  ...                                       user_profile  \
# 0    1.620545e+09  ...                                                NaN
# 1    1.620545e+09  ...  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 2    1.620369e+09  ...                                                NaN
# 3    1.620369e+09  ...  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 4    1.620545e+09  ...  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ..            ...  ...                                                ...
# 422           NaN  ...                                                NaN
# 423           NaN  ...                                                NaN
# 424           NaN  ...                                                NaN
# 425           NaN  ...                                                NaN
# 426           NaN  ...                                                NaN
#
#      parent_user_id                                          reactions edited  \
# 0               NaN                                                NaN    NaN
# 1       U01RRV4JX6Z  [{'name': 'dart', 'users': ['U01S1CWGTU4'], 'c...    NaN
# 2       U01RN7BVD1C                                                NaN    NaN
# 3       U01RN7BVD1C  [{'name': 'stonks', 'users': ['U01S7KCL3DF', '...    NaN
# 4       U01RRV4JX6Z                                                NaN    NaN
# ..              ...                                                ...    ...
# 422             NaN                                                NaN    NaN
# 423             NaN                                                NaN    NaN
# 424             NaN                                                NaN    NaN
# 425             NaN                                                NaN    NaN
# 426             NaN                                                NaN    NaN
#
#     attachments  last_read  bot_id bot_profile       subtype channel_name
# 0           NaN        NaN     NaN         NaN           NaN       random
# 1           NaN        NaN     NaN         NaN           NaN       random
# 2           NaN        NaN     NaN         NaN           NaN       random
# 3           NaN        NaN     NaN         NaN           NaN       random
# 4           NaN        NaN     NaN         NaN           NaN       random
# ..          ...        ...     ...         ...           ...          ...
# 422         NaN        NaN     NaN         NaN  channel_join       random
# 423         NaN        NaN     NaN         NaN  channel_join       random
# 424         NaN        NaN     NaN         NaN  channel_join       random
# 425         NaN        NaN     NaN         NaN  channel_join       random
# 426         NaN        NaN     NaN         NaN  channel_join       random
#
# [427 rows x 30 columns]

# %%
# save to csv
channel_random.to_csv(r'../data/random/channel_random.csv', index = False)

# %% [markdown]
# ### channel_vanilla

# %%
### vanilla_plus_more channel
# defining file path
path_to_json = '../data/vanilla_plus_more/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_vanilla = pd.concat(dfs, ignore_index=True)
# test
channel_vanilla
# Out:
#                            client_msg_id     type  \
# 0   8e064300-53cc-41fc-ba3d-4e91e2c08c29  message
# 1                                    NaN  message
# 2                                    NaN  message
# 3                                    NaN  message
# 4                                    NaN  message
# 5                                    NaN  message
# 6                                    NaN  message
# 7   4fa27f27-ab48-484f-a533-618372e1fc2a  message
# 8   ee7a5ff1-78a3-405f-9708-cdd1341e63fe  message
# 9                                    NaN  message
# 10                                   NaN  message
# 11                                   NaN  message
# 12  d4dbab7e-4cf4-41b2-a757-cb742906e69c  message
# 13                                   NaN  message
# 14                                   NaN  message
# 15                                   NaN  message
# 16                                   NaN  message
# 17                                   NaN  message
# 18  91408448-9d71-4e9c-b843-027ac87d700a  message
# 19                                   NaN  message
# 20                                   NaN  message
# 21                                   NaN  message
# 22  7d6a7c94-05cd-4f77-90cd-b0ea898dcf51  message
# 23                                   NaN  message
# 24  bf443b38-0344-4475-8566-cff212d62e95  message
# 25  3d4e6b69-bf6c-4c44-9b3f-73d06a942f56  message
# 26  688c219f-d79d-4d97-90b1-4775ca9fc066  message
# 27  8379b0d9-3f32-4640-b862-bfc145490afa  message
# 28  2e58f4f3-c217-424a-a2bf-b5e8ae0599ae  message
# 29  479b925a-b941-42c6-99a1-ba3f6101cd91  message
# 30  8ef58321-5220-46aa-9f53-f0df443cd398  message
# 31  e40bbb01-efc0-4ab9-a7dd-665bf168af0c  message
#
#                                                  text         user  \
# 0   I think there's no need in treating Pandas as ...  U01SJKB2MG8
# 1               <@U01RW140HBP> has joined the channel  U01RW140HBP
# 2   <@U01RW140HBP> set the channel description: th...  U01RW140HBP
# 3               <@U01SJKB2MG8> has joined the channel  U01SJKB2MG8
# 4               <@U01RSRE0N3D> has joined the channel  U01RSRE0N3D
# 5                                                      U01SJKB2MG8
# 6               <@U01RKN0EGDV> has joined the channel  U01RKN0EGDV
# 7   Pandas intro on Kaggle - this is a great littl...  U01RW140HBP
# 8                might be good for you <@U01S79YDELR>  U01RW140HBP
# 9               <@U01S79YDELR> has joined the channel  U01S79YDELR
# 10              <@U01S7KCL3DF> has joined the channel  U01S7KCL3DF
# 11              <@U01S133DZ9A> has joined the channel  U01S133DZ9A
# 12  if you find yourself asking: “what are these *...  U01RW140HBP
# 13                                   generic dtypes :  U01RW140HBP
# 14                                    python dtypes :  U01RW140HBP
# 15                                     mysql dtypes :  U01RW140HBP
# 16                                   tableau dtypes :  U01RW140HBP
# 17              <@U01S0MFJ3HR> has joined the channel  U01S0MFJ3HR
# 18  a quick bonus lab on STRINGS <https://github.c...  U01RW140HBP
# 19              <@U01RV3K524T> has joined the channel  U01RV3K524T
# 20              <@U01SD3CDH9P> has joined the channel  U01SD3CDH9P
# 21              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 22  1.5 hours in. I'm struggling with Question 2. ...  U01S133DZ9A
# 23              <@U01RN7BVD1C> has joined the channel  U01RN7BVD1C
# 24  thats ok… we can do a breakout call and go thr...  U01RW140HBP
# 25  i’ve been going back over the Kaggles chapters...  U01S7KCL3DF
# 26  or ask one of the TAs to do the same with you,...  U01RW140HBP
# 27                              Just saw this. Thanks  U01S133DZ9A
# 28  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 29          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 30      I will have a look after the presentation :v:  U01RSRE0N3D
# 31  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#               ts         team    user_team  source_team  \
# 0   1.617869e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1.617637e+09          NaN          NaN          NaN
# 2   1.617637e+09          NaN          NaN          NaN
# 3   1.617637e+09          NaN          NaN          NaN
# 4   1.617637e+09          NaN          NaN          NaN
# 5   1.617637e+09          NaN          NaN          NaN
# 6   1.617637e+09          NaN          NaN          NaN
# 7   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9   1.617637e+09          NaN          NaN          NaN
# 10  1.617637e+09          NaN          NaN          NaN
# 11  1.617638e+09          NaN          NaN          NaN
# 12  1.617638e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 13  1.617638e+09          NaN          NaN          NaN
# 14  1.617638e+09          NaN          NaN          NaN
# 15  1.617638e+09          NaN          NaN          NaN
# 16  1.617638e+09          NaN          NaN          NaN
# 17  1.617638e+09          NaN          NaN          NaN
# 18  1.617639e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 19  1.617644e+09          NaN          NaN          NaN
# 20  1.617644e+09          NaN          NaN          NaN
# 21  1.617652e+09          NaN          NaN          NaN
# 22  1.617658e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 23  1.617691e+09          NaN          NaN          NaN
# 24  1.617692e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 25  1.619986e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 26  1.617693e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 27  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 28  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 29  1.620399e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 30  1.620400e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 31  1.617832e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                          user_profile  \
# 0   {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 8   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 23                                                NaN
# 24  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 25  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 26  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 27  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 28  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 29  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 30  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 31  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                                edited  ... display_as_bot  \
# 0   {'user': 'U01SJKB2MG8', 'ts': '1617869310.0000...  ...            NaN
# 1                                                 NaN  ...            NaN
# 2                                                 NaN  ...            NaN
# 3                                                 NaN  ...            NaN
# 4                                                 NaN  ...            NaN
# 5                                                 NaN  ...            0.0
# 6                                                 NaN  ...            NaN
# 7                                                 NaN  ...            NaN
# 8                                                 NaN  ...            NaN
# 9                                                 NaN  ...            NaN
# 10                                                NaN  ...            NaN
# 11                                                NaN  ...            NaN
# 12  {'user': 'U01RW140HBP', 'ts': '1617638000.0000...  ...            NaN
# 13                                                NaN  ...            0.0
# 14                                                NaN  ...            0.0
# 15                                                NaN  ...            0.0
# 16                                                NaN  ...            0.0
# 17                                                NaN  ...            NaN
# 18  {'user': 'U01RW140HBP', 'ts': '1617638650.0000...  ...            NaN
# 19                                                NaN  ...            NaN
# 20                                                NaN  ...            NaN
# 21                                                NaN  ...            NaN
# 22                                                NaN  ...            NaN
# 23                                                NaN  ...            NaN
# 24                                                NaN  ...            NaN
# 25                                                NaN  ...            NaN
# 26                                                NaN  ...            NaN
# 27                                                NaN  ...            NaN
# 28                                                NaN  ...            NaN
# 29                                                NaN  ...            NaN
# 30                                                NaN  ...            NaN
# 31                                                NaN  ...            NaN
#
#                                           attachments reply_count  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7   [{'title': 'Learn Pandas Tutorials', 'title_li...         1.0
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         4.0
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18                                                NaN         5.0
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25  [{'title': 'Summary Functions and Maps', 'titl...         2.0
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         1.0
#
#    reply_users_count  latest_reply                 reply_users  \
# 0                NaN           NaN                         NaN
# 1                NaN           NaN                         NaN
# 2                NaN           NaN                         NaN
# 3                NaN           NaN                         NaN
# 4                NaN           NaN                         NaN
# 5                NaN           NaN                         NaN
# 6                NaN           NaN                         NaN
# 7                1.0  1.617637e+09               [U01RW140HBP]
# 8                NaN           NaN                         NaN
# 9                NaN           NaN                         NaN
# 10               NaN           NaN                         NaN
# 11               NaN           NaN                         NaN
# 12               1.0  1.617638e+09               [U01RW140HBP]
# 13               NaN           NaN                         NaN
# 14               NaN           NaN                         NaN
# 15               NaN           NaN                         NaN
# 16               NaN           NaN                         NaN
# 17               NaN           NaN                         NaN
# 18               2.0  1.617727e+09  [U01S133DZ9A, U01RW140HBP]
# 19               NaN           NaN                         NaN
# 20               NaN           NaN                         NaN
# 21               NaN           NaN                         NaN
# 22               NaN           NaN                         NaN
# 23               NaN           NaN                         NaN
# 24               NaN           NaN                         NaN
# 25               2.0  1.620400e+09  [U01S7KCL3DF, U01RSRE0N3D]
# 26               NaN           NaN                         NaN
# 27               NaN           NaN                         NaN
# 28               NaN           NaN                         NaN
# 29               NaN           NaN                         NaN
# 30               NaN           NaN                         NaN
# 31               1.0  1.617869e+09               [U01SJKB2MG8]
#
#                                               replies is_locked  subscribed  \
# 0                                                 NaN       NaN         NaN
# 1                                                 NaN       NaN         NaN
# 2                                                 NaN       NaN         NaN
# 3                                                 NaN       NaN         NaN
# 4                                                 NaN       NaN         NaN
# 5                                                 NaN       NaN         NaN
# 6                                                 NaN       NaN         NaN
# 7   [{'user': 'U01RW140HBP', 'ts': '1617637354.002...       0.0         0.0
# 8                                                 NaN       NaN         NaN
# 9                                                 NaN       NaN         NaN
# 10                                                NaN       NaN         NaN
# 11                                                NaN       NaN         NaN
# 12  [{'user': 'U01RW140HBP', 'ts': '1617638007.007...       0.0         0.0
# 13                                                NaN       NaN         NaN
# 14                                                NaN       NaN         NaN
# 15                                                NaN       NaN         NaN
# 16                                                NaN       NaN         NaN
# 17                                                NaN       NaN         NaN
# 18  [{'user': 'U01S133DZ9A', 'ts': '1617658367.010...       0.0         0.0
# 19                                                NaN       NaN         NaN
# 20                                                NaN       NaN         NaN
# 21                                                NaN       NaN         NaN
# 22                                                NaN       NaN         NaN
# 23                                                NaN       NaN         NaN
# 24                                                NaN       NaN         NaN
# 25  [{'user': 'U01S7KCL3DF', 'ts': '1620398926.000...     False        True
# 26                                                NaN       NaN         NaN
# 27                                                NaN       NaN         NaN
# 28                                                NaN       NaN         NaN
# 29                                                NaN       NaN         NaN
# 30                                                NaN       NaN         NaN
# 31  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...     False       False
#
#        last_read
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25  1.620399e+09
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
#
# [32 rows x 29 columns]

# %%
channel_vanilla['channel_name'] = 'vanilla'
channel_vanilla
# Out:
#                            client_msg_id     type  \
# 0   8e064300-53cc-41fc-ba3d-4e91e2c08c29  message
# 1                                    NaN  message
# 2                                    NaN  message
# 3                                    NaN  message
# 4                                    NaN  message
# 5                                    NaN  message
# 6                                    NaN  message
# 7   4fa27f27-ab48-484f-a533-618372e1fc2a  message
# 8   ee7a5ff1-78a3-405f-9708-cdd1341e63fe  message
# 9                                    NaN  message
# 10                                   NaN  message
# 11                                   NaN  message
# 12  d4dbab7e-4cf4-41b2-a757-cb742906e69c  message
# 13                                   NaN  message
# 14                                   NaN  message
# 15                                   NaN  message
# 16                                   NaN  message
# 17                                   NaN  message
# 18  91408448-9d71-4e9c-b843-027ac87d700a  message
# 19                                   NaN  message
# 20                                   NaN  message
# 21                                   NaN  message
# 22  7d6a7c94-05cd-4f77-90cd-b0ea898dcf51  message
# 23                                   NaN  message
# 24  bf443b38-0344-4475-8566-cff212d62e95  message
# 25  3d4e6b69-bf6c-4c44-9b3f-73d06a942f56  message
# 26  688c219f-d79d-4d97-90b1-4775ca9fc066  message
# 27  8379b0d9-3f32-4640-b862-bfc145490afa  message
# 28  2e58f4f3-c217-424a-a2bf-b5e8ae0599ae  message
# 29  479b925a-b941-42c6-99a1-ba3f6101cd91  message
# 30  8ef58321-5220-46aa-9f53-f0df443cd398  message
# 31  e40bbb01-efc0-4ab9-a7dd-665bf168af0c  message
#
#                                                  text         user  \
# 0   I think there's no need in treating Pandas as ...  U01SJKB2MG8
# 1               <@U01RW140HBP> has joined the channel  U01RW140HBP
# 2   <@U01RW140HBP> set the channel description: th...  U01RW140HBP
# 3               <@U01SJKB2MG8> has joined the channel  U01SJKB2MG8
# 4               <@U01RSRE0N3D> has joined the channel  U01RSRE0N3D
# 5                                                      U01SJKB2MG8
# 6               <@U01RKN0EGDV> has joined the channel  U01RKN0EGDV
# 7   Pandas intro on Kaggle - this is a great littl...  U01RW140HBP
# 8                might be good for you <@U01S79YDELR>  U01RW140HBP
# 9               <@U01S79YDELR> has joined the channel  U01S79YDELR
# 10              <@U01S7KCL3DF> has joined the channel  U01S7KCL3DF
# 11              <@U01S133DZ9A> has joined the channel  U01S133DZ9A
# 12  if you find yourself asking: “what are these *...  U01RW140HBP
# 13                                   generic dtypes :  U01RW140HBP
# 14                                    python dtypes :  U01RW140HBP
# 15                                     mysql dtypes :  U01RW140HBP
# 16                                   tableau dtypes :  U01RW140HBP
# 17              <@U01S0MFJ3HR> has joined the channel  U01S0MFJ3HR
# 18  a quick bonus lab on STRINGS <https://github.c...  U01RW140HBP
# 19              <@U01RV3K524T> has joined the channel  U01RV3K524T
# 20              <@U01SD3CDH9P> has joined the channel  U01SD3CDH9P
# 21              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 22  1.5 hours in. I'm struggling with Question 2. ...  U01S133DZ9A
# 23              <@U01RN7BVD1C> has joined the channel  U01RN7BVD1C
# 24  thats ok… we can do a breakout call and go thr...  U01RW140HBP
# 25  i’ve been going back over the Kaggles chapters...  U01S7KCL3DF
# 26  or ask one of the TAs to do the same with you,...  U01RW140HBP
# 27                              Just saw this. Thanks  U01S133DZ9A
# 28  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 29          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 30      I will have a look after the presentation :v:  U01RSRE0N3D
# 31  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#               ts         team    user_team  source_team  \
# 0   1.617869e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1.617637e+09          NaN          NaN          NaN
# 2   1.617637e+09          NaN          NaN          NaN
# 3   1.617637e+09          NaN          NaN          NaN
# 4   1.617637e+09          NaN          NaN          NaN
# 5   1.617637e+09          NaN          NaN          NaN
# 6   1.617637e+09          NaN          NaN          NaN
# 7   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9   1.617637e+09          NaN          NaN          NaN
# 10  1.617637e+09          NaN          NaN          NaN
# 11  1.617638e+09          NaN          NaN          NaN
# 12  1.617638e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 13  1.617638e+09          NaN          NaN          NaN
# 14  1.617638e+09          NaN          NaN          NaN
# 15  1.617638e+09          NaN          NaN          NaN
# 16  1.617638e+09          NaN          NaN          NaN
# 17  1.617638e+09          NaN          NaN          NaN
# 18  1.617639e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 19  1.617644e+09          NaN          NaN          NaN
# 20  1.617644e+09          NaN          NaN          NaN
# 21  1.617652e+09          NaN          NaN          NaN
# 22  1.617658e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 23  1.617691e+09          NaN          NaN          NaN
# 24  1.617692e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 25  1.619986e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 26  1.617693e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 27  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 28  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 29  1.620399e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 30  1.620400e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 31  1.617832e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                          user_profile  \
# 0   {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 8   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 23                                                NaN
# 24  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 25  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 26  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 27  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 28  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 29  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 30  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 31  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                                edited  ...  \
# 0   {'user': 'U01SJKB2MG8', 'ts': '1617869310.0000...  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12  {'user': 'U01RW140HBP', 'ts': '1617638000.0000...  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                                                NaN  ...
# 18  {'user': 'U01RW140HBP', 'ts': '1617638650.0000...  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24                                                NaN  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27                                                NaN  ...
# 28                                                NaN  ...
# 29                                                NaN  ...
# 30                                                NaN  ...
# 31                                                NaN  ...
#
#                                           attachments  reply_count  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7   [{'title': 'Learn Pandas Tutorials', 'title_li...          1.0
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          4.0
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          5.0
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25  [{'title': 'Summary Functions and Maps', 'titl...          2.0
# 26                                                NaN          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          1.0
#
#    reply_users_count  latest_reply                 reply_users  \
# 0                NaN           NaN                         NaN
# 1                NaN           NaN                         NaN
# 2                NaN           NaN                         NaN
# 3                NaN           NaN                         NaN
# 4                NaN           NaN                         NaN
# 5                NaN           NaN                         NaN
# 6                NaN           NaN                         NaN
# 7                1.0  1.617637e+09               [U01RW140HBP]
# 8                NaN           NaN                         NaN
# 9                NaN           NaN                         NaN
# 10               NaN           NaN                         NaN
# 11               NaN           NaN                         NaN
# 12               1.0  1.617638e+09               [U01RW140HBP]
# 13               NaN           NaN                         NaN
# 14               NaN           NaN                         NaN
# 15               NaN           NaN                         NaN
# 16               NaN           NaN                         NaN
# 17               NaN           NaN                         NaN
# 18               2.0  1.617727e+09  [U01S133DZ9A, U01RW140HBP]
# 19               NaN           NaN                         NaN
# 20               NaN           NaN                         NaN
# 21               NaN           NaN                         NaN
# 22               NaN           NaN                         NaN
# 23               NaN           NaN                         NaN
# 24               NaN           NaN                         NaN
# 25               2.0  1.620400e+09  [U01S7KCL3DF, U01RSRE0N3D]
# 26               NaN           NaN                         NaN
# 27               NaN           NaN                         NaN
# 28               NaN           NaN                         NaN
# 29               NaN           NaN                         NaN
# 30               NaN           NaN                         NaN
# 31               1.0  1.617869e+09               [U01SJKB2MG8]
#
#                                               replies is_locked subscribed  \
# 0                                                 NaN       NaN        NaN
# 1                                                 NaN       NaN        NaN
# 2                                                 NaN       NaN        NaN
# 3                                                 NaN       NaN        NaN
# 4                                                 NaN       NaN        NaN
# 5                                                 NaN       NaN        NaN
# 6                                                 NaN       NaN        NaN
# 7   [{'user': 'U01RW140HBP', 'ts': '1617637354.002...       0.0        0.0
# 8                                                 NaN       NaN        NaN
# 9                                                 NaN       NaN        NaN
# 10                                                NaN       NaN        NaN
# 11                                                NaN       NaN        NaN
# 12  [{'user': 'U01RW140HBP', 'ts': '1617638007.007...       0.0        0.0
# 13                                                NaN       NaN        NaN
# 14                                                NaN       NaN        NaN
# 15                                                NaN       NaN        NaN
# 16                                                NaN       NaN        NaN
# 17                                                NaN       NaN        NaN
# 18  [{'user': 'U01S133DZ9A', 'ts': '1617658367.010...       0.0        0.0
# 19                                                NaN       NaN        NaN
# 20                                                NaN       NaN        NaN
# 21                                                NaN       NaN        NaN
# 22                                                NaN       NaN        NaN
# 23                                                NaN       NaN        NaN
# 24                                                NaN       NaN        NaN
# 25  [{'user': 'U01S7KCL3DF', 'ts': '1620398926.000...     False       True
# 26                                                NaN       NaN        NaN
# 27                                                NaN       NaN        NaN
# 28                                                NaN       NaN        NaN
# 29                                                NaN       NaN        NaN
# 30                                                NaN       NaN        NaN
# 31  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...     False      False
#
#        last_read  channel_name
# 0            NaN       vanilla
# 1            NaN       vanilla
# 2            NaN       vanilla
# 3            NaN       vanilla
# 4            NaN       vanilla
# 5            NaN       vanilla
# 6            NaN       vanilla
# 7            NaN       vanilla
# 8            NaN       vanilla
# 9            NaN       vanilla
# 10           NaN       vanilla
# 11           NaN       vanilla
# 12           NaN       vanilla
# 13           NaN       vanilla
# 14           NaN       vanilla
# 15           NaN       vanilla
# 16           NaN       vanilla
# 17           NaN       vanilla
# 18           NaN       vanilla
# 19           NaN       vanilla
# 20           NaN       vanilla
# 21           NaN       vanilla
# 22           NaN       vanilla
# 23           NaN       vanilla
# 24           NaN       vanilla
# 25  1.620399e+09       vanilla
# 26           NaN       vanilla
# 27           NaN       vanilla
# 28           NaN       vanilla
# 29           NaN       vanilla
# 30           NaN       vanilla
# 31           NaN       vanilla
#
# [32 rows x 30 columns]

# %%
# save to csv
channel_vanilla.to_csv(r'../data/vanilla_plus_more/channel_vanilla.csv', index = False)

# %%
#frames = [channel_gen, channel_books, channel_dmemes, channel_dresource, channel_dbootcamp, channel_funcommittee, channel_dvizbeauties, channel_frustrations, channel_finalproject, channel_frustrations, channel_funcommittee, channel_katas, channel_labhelp, channel_music, channel_random, channel_vanilla]

df = pd.concat([channel_gen, channel_books,
                    channel_dmemes, channel_dresource, 
                    channel_dbootcamp, channel_funcommittee,
                    channel_dvizbeauties, channel_frustrations, 
                    channel_finalproject, channel_frustrations, 
                    channel_funcommittee, channel_katas, 
                    channel_labhelp, channel_music, 
                    channel_random, channel_vanilla], ignore_index=True, join="outer")

# %% [markdown]
# **Assessment Part1**

# %%
# assess shape
df.shape
# Out:
# (4449, 38)

# %%
# make a copy
df_copy = df.copy()

# %%
# assess column names
df.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'blocks', 'thread_ts', 'parent_user_id',
#        'edited', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'attachments',
#        'files', 'upload', 'display_as_bot', 'reactions', 'last_read', 'bot_id',
#        'bot_profile', 'subtype', 'topic', 'root', 'purpose', 'channel_name',
#        'inviter', 'old_name', 'name', 'hidden', 'x_files'],
#       dtype='object')

# %%
# check how many values each channel has
df.channel_name.value_counts()
# Out:
# labhelp         1460
# general         1161
# random           427
# funcommittee     304
# dmemes           257
# dvizbeauties     254
# dresource        188
# music            162
# katas            146
# vanilla           32
# finalproject      29
# dbootcamp         20
# frustrations       6
# books              3
# Name: channel_name, dtype: int64

# %%
# check for outliers in the numerical part
df.describe()
# Out:
#                  ts     thread_ts  reply_count  reply_users_count  \
# count  4.449000e+03  3.307000e+03   508.000000         508.000000
# mean   1.618429e+09  1.618603e+09     5.509843           2.572835
# std    1.429846e+06  1.356774e+06     5.696283           1.614960
# min    1.616107e+09  1.616406e+09     1.000000           1.000000
# 25%    1.617025e+09  1.617357e+09     2.000000           2.000000
# 50%    1.618406e+09  1.618593e+09     4.000000           2.000000
# 75%    1.619705e+09  1.619887e+09     7.000000           3.000000
# max    1.620645e+09  1.620642e+09    45.000000          16.000000
#
#        latest_reply     last_read  hidden
# count  5.080000e+02  8.100000e+01     1.0
# mean   1.618442e+09  1.618277e+09     1.0
# std    1.348007e+06  1.303624e+06     NaN
# min    1.616414e+09  1.616414e+09     1.0
# 25%    1.617202e+09  1.617120e+09     1.0
# 50%    1.618401e+09  1.618229e+09     1.0
# 75%    1.619616e+09  1.619451e+09     1.0
# max    1.620645e+09  1.620399e+09     1.0

# %% [markdown]
# There are no outliers in this data, it seems healthy.

# %% [markdown]
# **Summary of Assesment Part1**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# **Columns to clean & wrangle:**
# - subtype: filter out it's values from df, remove the original column
# - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day
# - user_profile: extract real_name in new column, remove the original
# - attachments: extract title, text, link in new columns
# - files: extract url_private and who shared
# - attachments: extract title, text, link in new columns
# - reactions: extract user, count, name of the emoji
# - text: ?
#
# **Columns to visualise**
# - reply_count: how many
# - reply_users_count: how many
# - reply_users: who
# - replies: who and when
# - files, attachment, reactions

# %% [markdown]
# **Cleaning Part1**

# %%
# drop columns
df.drop(['type', 'client_msg_id', 'team',
       'user_team', 'source_team', 'blocks', 'upload', 'display_as_bot',
       'thread_ts', 'latest_reply', 'is_locked', 'subscribed',
       'parent_user_id', 'bot_id', 'bot_profile', 'last_read', 'edited',
       'purpose', 'inviter', 'topic', 'root', 'old_name', 'name', 'hidden',
       'x_files'], axis=1, inplace=True)

# %%
# test
df.shape
# Out:
# (4449, 13)

# %%
df.head()
# Out:
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#              ts                                       user_profile  \
# 0  1.620547e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1  1.620547e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2  1.620574e+09  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3  1.620574e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4  1.620574e+09  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#    reply_count  reply_users_count                 reply_users  \
# 0          NaN                NaN                         NaN
# 1          NaN                NaN                         NaN
# 2         31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3          NaN                NaN                         NaN
# 4          NaN                NaN                         NaN
#
#                                              replies attachments files  \
# 0                                                NaN         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                NaN         NaN   NaN
# 4                                                NaN         NaN   NaN
#
#   reactions subtype channel_name
# 0       NaN     NaN      general
# 1       NaN     NaN      general
# 2       NaN     NaN      general
# 3       NaN     NaN      general
# 4       NaN     NaN      general

# %% [markdown]
# **Assessment Part2**

# %%
# list of columns, their non-null objects and data type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4449 entries, 0 to 4448
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               4449 non-null   object
#  1   user               4449 non-null   object
#  2   ts                 4449 non-null   float64
#  3   user_profile       3552 non-null   object
#  4   reply_count        508 non-null    float64
#  5   reply_users_count  508 non-null    float64
#  6   reply_users        508 non-null    object
#  7   replies            508 non-null    object
#  8   attachments        350 non-null    object
#  9   files              465 non-null    object
#  10  reactions          975 non-null    object
#  11  subtype            333 non-null    object
#  12  channel_name       4449 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 452.0+ KB

# %%
# check, if there are any nulls and NaN values in our data set
df.isna().sum()
# Out:
# text                    0
# user                    0
# ts                      0
# user_profile          897
# reply_count          3941
# reply_users_count    3941
# reply_users          3941
# replies              3941
# attachments          4099
# files                3984
# reactions            3474
# subtype              4116
# channel_name            0
# dtype: int64

# %%
#to summarise this in one line of code and round the values 
df.isna().mean().round(4) *100
# Out:
# text                  0.00
# user                  0.00
# ts                    0.00
# user_profile         20.16
# reply_count          88.58
# reply_users_count    88.58
# reply_users          88.58
# replies              88.58
# attachments          92.13
# files                89.55
# reactions            78.08
# subtype              92.52
# channel_name          0.00
# dtype: float64

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. The only important thing is that each value is coming from a user, and it is because I can see there are no missing values at the text or user columns. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
df['subtype'].value_counts()
# Out:
# channel_join        312
# channel_topic         9
# channel_purpose       7
# thread_broadcast      2
# channel_name          2
# tombstone             1
# Name: subtype, dtype: int64

# %%
# filter out for the rows which has subtype values
df_clean = df[(df.subtype != 'channel_join') & 
                                (df.subtype != 'channel_join') &
                                (df.subtype != 'channel_purpose') &
                                (df.subtype != 'thread_broadcast')]


#test 
df_clean.shape
# Out:
# (4128, 13)

# %%
# drop subtype column
df_clean.drop('subtype', axis=1, inplace=True) 

#test
df_clean.shape
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (4128, 12)

# %%
#convert ts to datetime from float
from datetime import datetime
df_clean['ts'] = pd.to_datetime(df['ts'], unit='s')

# remove miliseconds 
df_clean['ts'] = df_clean['ts'].astype('datetime64[s]')

df_clean
# Out:
# <ipython-input-958-c34f63df5ac6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['ts'] = pd.to_datetime(df['ts'], unit='s')
# <ipython-input-958-c34f63df5ac6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['ts'] = df_clean['ts'].astype('datetime64[s]')
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 4444 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4445 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4446 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 4447 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 4448 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
# [4128 rows x 12 columns]

# %%
# create a column for the days of the week using the ts column

df_clean['day_name'] = df_clean['ts'].dt.day_name()
df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
df_clean
# Out:
# <ipython-input-959-caaf00226462>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_name'] = df_clean['ts'].dt.day_name()
# <ipython-input-959-caaf00226462>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 4444 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4445 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4446 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 4447 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 4448 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number
# 0        Sunday           9
# 1        Sunday           9
# 2        Sunday           9
# 3        Sunday           9
# 4        Sunday           9
# ...         ...         ...
# 4444    Tuesday           6
# 4445    Tuesday           6
# 4446     Friday           7
# 4447     Friday           7
# 4448  Wednesday           7
#
# [4128 rows x 14 columns]

# %%
# create a column for the months of the year using the ts column
df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month

# convert values to date time and then month names

df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
df_clean
# Out:
# <ipython-input-960-6f5a2bd291be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month
# <ipython-input-960-6f5a2bd291be>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 4444 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4445 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4446 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 4447 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 4448 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month
# 0        Sunday           9    May
# 1        Sunday           9    May
# 2        Sunday           9    May
# 3        Sunday           9    May
# 4        Sunday           9    May
# ...         ...         ...    ...
# 4444    Tuesday           6  April
# 4445    Tuesday           6  April
# 4446     Friday           7    May
# 4447     Friday           7    May
# 4448  Wednesday           7  April
#
# [4128 rows x 15 columns]

# %%
# create a column for the type of the weekday using the ts column
df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x < 5 else 'Weekend')
df_clean
# Out:
# <ipython-input-961-995b0273217e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 4444 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4445 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4446 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 4447 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 4448 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type
# 0        Sunday           9    May  Weekend
# 1        Sunday           9    May  Weekend
# 2        Sunday           9    May  Weekend
# 3        Sunday           9    May  Weekend
# 4        Sunday           9    May  Weekend
# ...         ...         ...    ...      ...
# 4444    Tuesday           6  April  Weekday
# 4445    Tuesday           6  April  Weekday
# 4446     Friday           7    May  Weekday
# 4447     Friday           7    May  Weekday
# 4448  Wednesday           7  April  Weekday
#
# [4128 rows x 16 columns]

# %%
# create a column for the hour of the day using the ts column
df_clean['time']= df_clean['ts'].dt.strftime('%H:%M')
df_clean
# Out:
# <ipython-input-962-be84bb072b59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['time']= df_clean['ts'].dt.strftime('%H:%M')
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 4444 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4445 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 4446 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 4447 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 4448 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type   time
# 0        Sunday           9    May  Weekend  08:00
# 1        Sunday           9    May  Weekend  08:01
# 2        Sunday           9    May  Weekend  15:27
# 3        Sunday           9    May  Weekend  15:30
# 4        Sunday           9    May  Weekend  15:32
# ...         ...         ...    ...      ...    ...
# 4444    Tuesday           6  April  Weekday  16:43
# 4445    Tuesday           6  April  Weekday  16:44
# 4446     Friday           7    May  Weekday  14:48
# 4447     Friday           7    May  Weekday  15:00
# 4448  Wednesday           7  April  Weekday  21:44
#
# [4128 rows x 17 columns]

# %%
# drop ts column
df_clean.drop('ts', axis=1, inplace=True) 

#test
df_clean.head()
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#                                         user_profile  reply_count  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#                                              replies attachments files  \
# 0                                                NaN         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                NaN         NaN   NaN
# 4                                                NaN         NaN   NaN
#
#   reactions channel_name day_name  day_number month day_type   time
# 0       NaN      general   Sunday           9   May  Weekend  08:00
# 1       NaN      general   Sunday           9   May  Weekend  08:01
# 2       NaN      general   Sunday           9   May  Weekend  15:27
# 3       NaN      general   Sunday           9   May  Weekend  15:30
# 4       NaN      general   Sunday           9   May  Weekend  15:32

# %%
#files column: extract who shared

def geturlfromfile(x):
    """this function is applied to column files
    """
    
    if x != x:
        return 'nofile'
    else:
        try:
            return x[0]['url_private']
        except KeyError:
            return 'nolink_infiles'

df_clean['link_of_file'] = df_clean['files'].apply(geturlfromfile)

df_clean
# Out:
# <ipython-input-964-81339308b45e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['link_of_file'] = df_clean['files'].apply(geturlfromfile)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 4444  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4445  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4446  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 4447  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 4448  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 4444                NaN                         NaN
# 4445                NaN                         NaN
# 4446                NaN                         NaN
# 4447                NaN                         NaN
# 4448                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 4444                                                NaN         NaN   NaN
# 4445                                                NaN         NaN   NaN
# 4446                                                NaN         NaN   NaN
# 4447                                                NaN         NaN   NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type   time link_of_file
# 0        Sunday           9    May  Weekend  08:00       nofile
# 1        Sunday           9    May  Weekend  08:01       nofile
# 2        Sunday           9    May  Weekend  15:27       nofile
# 3        Sunday           9    May  Weekend  15:30       nofile
# 4        Sunday           9    May  Weekend  15:32       nofile
# ...         ...         ...    ...      ...    ...          ...
# 4444    Tuesday           6  April  Weekday  16:43       nofile
# 4445    Tuesday           6  April  Weekday  16:44       nofile
# 4446     Friday           7    May  Weekday  14:48       nofile
# 4447     Friday           7    May  Weekday  15:00       nofile
# 4448  Wednesday           7  April  Weekday  21:44       nofile
#
# [4128 rows x 17 columns]

# %%
# drop files column
df_clean.drop('files', axis=1, inplace=True) 

#test
df_clean.head()
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#                                         user_profile  reply_count  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#                                              replies attachments reactions  \
# 0                                                NaN         NaN       NaN
# 1                                                NaN         NaN       NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN       NaN
# 3                                                NaN         NaN       NaN
# 4                                                NaN         NaN       NaN
#
#   channel_name day_name  day_number month day_type   time link_of_file
# 0      general   Sunday           9   May  Weekend  08:00       nofile
# 1      general   Sunday           9   May  Weekend  08:01       nofile
# 2      general   Sunday           9   May  Weekend  15:27       nofile
# 3      general   Sunday           9   May  Weekend  15:30       nofile
# 4      general   Sunday           9   May  Weekend  15:32       nofile

# %%
# attachments column: extract link

def geturlfromattachments(x):
    """this function is applied to column attachments
    """
    
    if x != x:
        return 'nolink'
    else:
        try:
            return x[0]['app_unfurl_url']
        except KeyError:
            return 'nolink_infiles'
        
df_clean['link_of_attachments'] = df_clean['attachments'].apply(geturlfromattachments)

df_clean
# Out:
# <ipython-input-966-770c2eb46bef>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['link_of_attachments'] = df_clean['attachments'].apply(geturlfromattachments)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 4444  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4445  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4446  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 4447  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 4448  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 4444                NaN                         NaN
# 4445                NaN                         NaN
# 4446                NaN                         NaN
# 4447                NaN                         NaN
# 4448                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4444                                                NaN         NaN
# 4445                                                NaN         NaN
# 4446                                                NaN         NaN
# 4447                                                NaN         NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type   time link_of_file  \
# 0        Sunday           9    May  Weekend  08:00       nofile
# 1        Sunday           9    May  Weekend  08:01       nofile
# 2        Sunday           9    May  Weekend  15:27       nofile
# 3        Sunday           9    May  Weekend  15:30       nofile
# 4        Sunday           9    May  Weekend  15:32       nofile
# ...         ...         ...    ...      ...    ...          ...
# 4444    Tuesday           6  April  Weekday  16:43       nofile
# 4445    Tuesday           6  April  Weekday  16:44       nofile
# 4446     Friday           7    May  Weekday  14:48       nofile
# 4447     Friday           7    May  Weekday  15:00       nofile
# 4448  Wednesday           7  April  Weekday  21:44       nofile
#
#      link_of_attachments
# 0                 nolink
# 1                 nolink
# 2                 nolink
# 3                 nolink
# 4                 nolink
# ...                  ...
# 4444              nolink
# 4445              nolink
# 4446              nolink
# 4447              nolink
# 4448              nolink
#
# [4128 rows x 17 columns]

# %%
# user_profile column: extract real_name

def getrealnamefromprofile(x):
    """this function is applied to column user_profile
    """
    
    if x != x:
        return 'noname'
    else:
        return x['real_name']

df_clean['real_name'] = df_clean['user_profile'].apply(getrealnamefromprofile)

df_clean
# Out:
# <ipython-input-967-ce73fd54f28f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['real_name'] = df_clean['user_profile'].apply(getrealnamefromprofile)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 4444  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4445  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 4446  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 4447  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 4448  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 4444                NaN                         NaN
# 4445                NaN                         NaN
# 4446                NaN                         NaN
# 4447                NaN                         NaN
# 4448                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4444                                                NaN         NaN
# 4445                                                NaN         NaN
# 4446                                                NaN         NaN
# 4447                                                NaN         NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type   time link_of_file  \
# 0        Sunday           9    May  Weekend  08:00       nofile
# 1        Sunday           9    May  Weekend  08:01       nofile
# 2        Sunday           9    May  Weekend  15:27       nofile
# 3        Sunday           9    May  Weekend  15:30       nofile
# 4        Sunday           9    May  Weekend  15:32       nofile
# ...         ...         ...    ...      ...    ...          ...
# 4444    Tuesday           6  April  Weekday  16:43       nofile
# 4445    Tuesday           6  April  Weekday  16:44       nofile
# 4446     Friday           7    May  Weekday  14:48       nofile
# 4447     Friday           7    May  Weekday  15:00       nofile
# 4448  Wednesday           7  April  Weekday  21:44       nofile
#
#      link_of_attachments          real_name
# 0                 nolink    Karina Condeixa
# 1                 nolink    Karina Condeixa
# 2                 nolink  Francisco Ebeling
# 3                 nolink    Karina Condeixa
# 4                 nolink  Francisco Ebeling
# ...                  ...                ...
# 4444              nolink         Simon Data
# 4445              nolink         Simon Data
# 4446              nolink    Sam Katterfield
# 4447              nolink              Kosta
# 4448              nolink         Simon Data
#
# [4128 rows x 18 columns]

# %%
# drop user_profile column
df_clean.drop('user_profile', axis=1, inplace=True) 

#test
df_clean.head(100)
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                  text         user  \
# 0                 Hang told me to add it in education  U01S79YDELR
# 1   What improved my score was adding metrics of a...  U01S79YDELR
# 2   I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3   Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                             Ah, ok!  U01RRV4JX6Z
# ..                                                ...          ...
# 95  Focused in one playlist I have so it's fav art...  U01RW2X7S9Z
# 96  had to be 20 artists or did i hear that wrong?...  U01RW2X7S9Z
# 97                              aaaaaaaaa Morcheeeeba  U01RXCQHMHT
# 98  well i would struggle to correctly type 20 <@U...  U01RW140HBP
# 99  artists = [‘Angra’, ‘Viper’, ‘Andre Matos’, ‘D...  U01RRV4JX6Z
#
#     reply_count  reply_users_count                 reply_users  \
# 0           NaN                NaN                         NaN
# 1           NaN                NaN                         NaN
# 2          31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3           NaN                NaN                         NaN
# 4           NaN                NaN                         NaN
# ..          ...                ...                         ...
# 95          NaN                NaN                         NaN
# 96          NaN                NaN                         NaN
# 97          NaN                NaN                         NaN
# 98          NaN                NaN                         NaN
# 99          NaN                NaN                         NaN
#
#                                               replies attachments  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2   [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 95                                                NaN         NaN
# 96                                                NaN         NaN
# 97                                                NaN         NaN
# 98                                                NaN         NaN
# 99                                                NaN         NaN
#
#                                             reactions channel_name   day_name  \
# 0                                                 NaN      general     Sunday
# 1                                                 NaN      general     Sunday
# 2                                                 NaN      general     Sunday
# 3                                                 NaN      general     Sunday
# 4                                                 NaN      general     Sunday
# ..                                                ...          ...        ...
# 95                                                NaN      general  Wednesday
# 96                                                NaN      general  Wednesday
# 97  [{'name': 'raised_hands', 'users': ['U01RW140H...      general  Wednesday
# 98                                                NaN      general  Wednesday
# 99                                                NaN      general  Wednesday
#
#     day_number month day_type   time link_of_file link_of_attachments  \
# 0            9   May  Weekend  08:00       nofile              nolink
# 1            9   May  Weekend  08:01       nofile              nolink
# 2            9   May  Weekend  15:27       nofile              nolink
# 3            9   May  Weekend  15:30       nofile              nolink
# 4            9   May  Weekend  15:32       nofile              nolink
# ..         ...   ...      ...    ...          ...                 ...
# 95           5   May  Weekday  08:52       nofile              nolink
# 96           5   May  Weekday  08:53       nofile              nolink
# 97           5   May  Weekday  08:54       nofile              nolink
# 98           5   May  Weekday  08:57       nofile              nolink
# 99           5   May  Weekday  08:57       nofile              nolink
#
#                                     real_name
# 0                             Karina Condeixa
# 1                             Karina Condeixa
# 2                           Francisco Ebeling
# 3                             Karina Condeixa
# 4                           Francisco Ebeling
# ..                                        ...
# 95                       Alexandre Sommerkamp
# 96                       Alexandre Sommerkamp
# 97  Thanh Tung Ha Thuc DAFT Berlin March 2021
# 98                     siand the LT (she/her)
# 99                          Francisco Ebeling
#
# [100 rows x 17 columns]

# %%
# reactions column:  count

def getcountfromreactions(x):
    """this function is applied to column reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['count']

df_clean['reactions_count'] = df_clean['reactions'].apply(getcountfromreactions)

df_clean
# Out:
# <ipython-input-969-0eab6a7d50fd>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reactions_count'] = df_clean['reactions'].apply(getcountfromreactions)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4444                                                NaN         NaN
# 4445                                                NaN         NaN
# 4446                                                NaN         NaN
# 4447                                                NaN         NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  day_number  month day_type   time link_of_file  \
# 0        Sunday           9    May  Weekend  08:00       nofile
# 1        Sunday           9    May  Weekend  08:01       nofile
# 2        Sunday           9    May  Weekend  15:27       nofile
# 3        Sunday           9    May  Weekend  15:30       nofile
# 4        Sunday           9    May  Weekend  15:32       nofile
# ...         ...         ...    ...      ...    ...          ...
# 4444    Tuesday           6  April  Weekday  16:43       nofile
# 4445    Tuesday           6  April  Weekday  16:44       nofile
# 4446     Friday           7    May  Weekday  14:48       nofile
# 4447     Friday           7    May  Weekday  15:00       nofile
# 4448  Wednesday           7  April  Weekday  21:44       nofile
#
#      link_of_attachments          real_name  reactions_count
# 0                 nolink    Karina Condeixa                0
# 1                 nolink    Karina Condeixa                0
# 2                 nolink  Francisco Ebeling                0
# 3                 nolink    Karina Condeixa                0
# 4                 nolink  Francisco Ebeling                0
# ...                  ...                ...              ...
# 4444              nolink         Simon Data                0
# 4445              nolink         Simon Data                0
# 4446              nolink    Sam Katterfield                0
# 4447              nolink              Kosta                1
# 4448              nolink         Simon Data                0
#
# [4128 rows x 18 columns]

# %%
# create a new boolean column if comment has reply
df_clean['replies_true'] = df_clean['reply_count'].notna()
df_clean

# create a new boolean column if comment has files
df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")
df_clean

# create a new boolean column if comment has attachments
df_clean['attachments_true'] = df_clean['link_of_attachments'].str.contains("https")
df_clean
# Out:
# <ipython-input-970-3e80364f881f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['replies_true'] = df_clean['reply_count'].notna()
# <ipython-input-970-3e80364f881f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")
# <ipython-input-970-3e80364f881f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['attachments_true'] = df_clean['link_of_attachments'].str.contains("https")
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4444                                                NaN         NaN
# 4445                                                NaN         NaN
# 4446                                                NaN         NaN
# 4447                                                NaN         NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  ...  month day_type   time link_of_file link_of_attachments  \
# 0        Sunday  ...    May  Weekend  08:00       nofile              nolink
# 1        Sunday  ...    May  Weekend  08:01       nofile              nolink
# 2        Sunday  ...    May  Weekend  15:27       nofile              nolink
# 3        Sunday  ...    May  Weekend  15:30       nofile              nolink
# 4        Sunday  ...    May  Weekend  15:32       nofile              nolink
# ...         ...  ...    ...      ...    ...          ...                 ...
# 4444    Tuesday  ...  April  Weekday  16:43       nofile              nolink
# 4445    Tuesday  ...  April  Weekday  16:44       nofile              nolink
# 4446     Friday  ...    May  Weekday  14:48       nofile              nolink
# 4447     Friday  ...    May  Weekday  15:00       nofile              nolink
# 4448  Wednesday  ...  April  Weekday  21:44       nofile              nolink
#
#               real_name reactions_count  replies_true  files_true  \
# 0       Karina Condeixa               0         False       False
# 1       Karina Condeixa               0         False       False
# 2     Francisco Ebeling               0          True       False
# 3       Karina Condeixa               0         False       False
# 4     Francisco Ebeling               0         False       False
# ...                 ...             ...           ...         ...
# 4444         Simon Data               0         False       False
# 4445         Simon Data               0         False       False
# 4446    Sam Katterfield               0         False       False
# 4447              Kosta               1         False       False
# 4448         Simon Data               0          True       False
#
#       attachments_true
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 4444             False
# 4445             False
# 4446             False
# 4447             False
# 4448             False
#
# [4128 rows x 21 columns]

# %%
# create a new column with text length
df_clean['text_length'] = df['text'].astype(str).map(len)
# test
df_clean
# Out:
# <ipython-input-971-15536c45761f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['text_length'] = df['text'].astype(str).map(len)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 4444          NaN                NaN                         NaN
# 4445          NaN                NaN                         NaN
# 4446          NaN                NaN                         NaN
# 4447          NaN                NaN                         NaN
# 4448          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 4444                                                NaN         NaN
# 4445                                                NaN         NaN
# 4446                                                NaN         NaN
# 4447                                                NaN         NaN
# 4448  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 4444                                                NaN      vanilla
# 4445                                                NaN      vanilla
# 4446                                                NaN      vanilla
# 4447  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 4448                                                NaN      vanilla
#
#        day_name  ...  day_type   time link_of_file link_of_attachments  \
# 0        Sunday  ...   Weekend  08:00       nofile              nolink
# 1        Sunday  ...   Weekend  08:01       nofile              nolink
# 2        Sunday  ...   Weekend  15:27       nofile              nolink
# 3        Sunday  ...   Weekend  15:30       nofile              nolink
# 4        Sunday  ...   Weekend  15:32       nofile              nolink
# ...         ...  ...       ...    ...          ...                 ...
# 4444    Tuesday  ...   Weekday  16:43       nofile              nolink
# 4445    Tuesday  ...   Weekday  16:44       nofile              nolink
# 4446     Friday  ...   Weekday  14:48       nofile              nolink
# 4447     Friday  ...   Weekday  15:00       nofile              nolink
# 4448  Wednesday  ...   Weekday  21:44       nofile              nolink
#
#               real_name reactions_count replies_true  files_true  \
# 0       Karina Condeixa               0        False       False
# 1       Karina Condeixa               0        False       False
# 2     Francisco Ebeling               0         True       False
# 3       Karina Condeixa               0        False       False
# 4     Francisco Ebeling               0        False       False
# ...                 ...             ...          ...         ...
# 4444         Simon Data               0        False       False
# 4445         Simon Data               0        False       False
# 4446    Sam Katterfield               0        False       False
# 4447              Kosta               1        False       False
# 4448         Simon Data               0         True       False
#
#       attachments_true  text_length
# 0                False           35
# 1                False           98
# 2                False          261
# 3                False           76
# 4                False            7
# ...                ...          ...
# 4444             False           21
# 4445             False           82
# 4446             False           41
# 4447             False           45
# 4448             False          542
#
# [4128 rows x 22 columns]

# %%
# droppig unneccessary columns
df_clean.drop(['reactions', 'attachments', 'reply_users', 'replies'], axis=1, inplace=True)
# test
df_clean.shape
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (4128, 18)

# %%
# replace NaN values with zero
df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
df_clean['reply_count'] = df_clean['reply_count'].astype(int)
df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)


df_clean
# Out:
# <ipython-input-973-5cc785cc1679>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
# <ipython-input-973-5cc785cc1679>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
# <ipython-input-973-5cc785cc1679>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_count'] = df_clean['reply_count'].astype(int)
# <ipython-input-973-5cc785cc1679>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks  U01S133DZ9A
# 4445  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 4447      I will have a look after the presentation :v:  U01RSRE0N3D
# 4448  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count channel_name   day_name  day_number  \
# 0               0                  0      general     Sunday           9
# 1               0                  0      general     Sunday           9
# 2              31                  2      general     Sunday           9
# 3               0                  0      general     Sunday           9
# 4               0                  0      general     Sunday           9
# ...           ...                ...          ...        ...         ...
# 4444            0                  0      vanilla    Tuesday           6
# 4445            0                  0      vanilla    Tuesday           6
# 4446            0                  0      vanilla     Friday           7
# 4447            0                  0      vanilla     Friday           7
# 4448            1                  1      vanilla  Wednesday           7
#
#       month day_type   time link_of_file link_of_attachments  \
# 0       May  Weekend  08:00       nofile              nolink
# 1       May  Weekend  08:01       nofile              nolink
# 2       May  Weekend  15:27       nofile              nolink
# 3       May  Weekend  15:30       nofile              nolink
# 4       May  Weekend  15:32       nofile              nolink
# ...     ...      ...    ...          ...                 ...
# 4444  April  Weekday  16:43       nofile              nolink
# 4445  April  Weekday  16:44       nofile              nolink
# 4446    May  Weekday  14:48       nofile              nolink
# 4447    May  Weekday  15:00       nofile              nolink
# 4448  April  Weekday  21:44       nofile              nolink
#
#               real_name  reactions_count  replies_true  files_true  \
# 0       Karina Condeixa                0         False       False
# 1       Karina Condeixa                0         False       False
# 2     Francisco Ebeling                0          True       False
# 3       Karina Condeixa                0         False       False
# 4     Francisco Ebeling                0         False       False
# ...                 ...              ...           ...         ...
# 4444         Simon Data                0         False       False
# 4445         Simon Data                0         False       False
# 4446    Sam Katterfield                0         False       False
# 4447              Kosta                1         False       False
# 4448         Simon Data                0          True       False
#
#       attachments_true  text_length
# 0                False           35
# 1                False           98
# 2                False          261
# 3                False           76
# 4                False            7
# ...                ...          ...
# 4444             False           21
# 4445             False           82
# 4446             False           41
# 4447             False           45
# 4448             False          542
#
# [4128 rows x 18 columns]

# %%
df_clean.columns
# Out:
# Index(['text', 'user', 'reply_count', 'reply_users_count', 'channel_name',
#        'day_name', 'day_number', 'month', 'day_type', 'time', 'link_of_file',
#        'link_of_attachments', 'real_name', 'reactions_count', 'replies_true',
#        'files_true', 'attachments_true', 'text_length'],
#       dtype='object')

# %%
# reordering columns
df_clean = df_clean[['channel_name', 'user', 'real_name', 'text', 'text_length', 'reply_count', 'reply_users_count',
       'replies_true', 'day_name', 'day_type', 'time', 'day_number', 'month', 'reactions_count', 'link_of_file', 'files_true', 
       'link_of_attachments', 'attachments_true']]
# test 
df_clean
# Out:
#      channel_name         user          real_name  \
# 0         general  U01S79YDELR    Karina Condeixa
# 1         general  U01S79YDELR    Karina Condeixa
# 2         general  U01RRV4JX6Z  Francisco Ebeling
# 3         general  U01S79YDELR    Karina Condeixa
# 4         general  U01RRV4JX6Z  Francisco Ebeling
# ...           ...          ...                ...
# 4444      vanilla  U01S133DZ9A         Simon Data
# 4445      vanilla  U01S133DZ9A         Simon Data
# 4446      vanilla  U01S7KCL3DF    Sam Katterfield
# 4447      vanilla  U01RSRE0N3D              Kosta
# 4448      vanilla  U01S133DZ9A         Simon Data
#
#                                                    text  text_length  \
# 0                   Hang told me to add it in education           35
# 1     What improved my score was adding metrics of a...           98
# 2     I feel like a slave to this dumb Resume Worded...          261
# 3     Francisco, we have to remove the fancy/beautif...           76
# 4                                               Ah, ok!            7
# ...                                                 ...          ...
# 4444                              Just saw this. Thanks           21
# 4445  I'll have a think. Need to develop a strategy ...           82
# 4446          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:           41
# 4447      I will have a look after the presentation :v:           45
# 4448  I quite like the Kaggle explanations. Been rea...          542
#
#       reply_count  reply_users_count  replies_true   day_name day_type   time  \
# 0               0                  0         False     Sunday  Weekend  08:00
# 1               0                  0         False     Sunday  Weekend  08:01
# 2              31                  2          True     Sunday  Weekend  15:27
# 3               0                  0         False     Sunday  Weekend  15:30
# 4               0                  0         False     Sunday  Weekend  15:32
# ...           ...                ...           ...        ...      ...    ...
# 4444            0                  0         False    Tuesday  Weekday  16:43
# 4445            0                  0         False    Tuesday  Weekday  16:44
# 4446            0                  0         False     Friday  Weekday  14:48
# 4447            0                  0         False     Friday  Weekday  15:00
# 4448            1                  1          True  Wednesday  Weekday  21:44
#
#       day_number  month  reactions_count link_of_file  files_true  \
# 0              9    May                0       nofile       False
# 1              9    May                0       nofile       False
# 2              9    May                0       nofile       False
# 3              9    May                0       nofile       False
# 4              9    May                0       nofile       False
# ...          ...    ...              ...          ...         ...
# 4444           6  April                0       nofile       False
# 4445           6  April                0       nofile       False
# 4446           7    May                0       nofile       False
# 4447           7    May                1       nofile       False
# 4448           7  April                0       nofile       False
#
#      link_of_attachments  attachments_true
# 0                 nolink             False
# 1                 nolink             False
# 2                 nolink             False
# 3                 nolink             False
# 4                 nolink             False
# ...                  ...               ...
# 4444              nolink             False
# 4445              nolink             False
# 4446              nolink             False
# 4447              nolink             False
# 4448              nolink             False
#
# [4128 rows x 18 columns]

# %%
# save to csv
df_clean.to_csv(r'../data/data_clean.csv', index = False)

# %%
df_clean.to_excel(r'../data/data_clean.xlsx', index = False)
