# %% [markdown]
# **EDA**
# - how much traffic per channel
# - which post in which channel gets the most reaction/traction
# - what time of the day students are posting the most per day
# - distribution of  % links, % memes, % emojis
# - frequency of messages from teaching staff vs students
# - count of messages per person
# - avg length of messages per person
# - statistics of mentions within a date range
# - which channel is the most useful(most messages)
#
# **Automated function**
# - a report at the end of each day, with a few summary statistics for that day
# - a daily / weekly extract of all the links/uploads posted in public channels
#
# **NLP**
# - whats the top 5 words used per channel (bi-grams, tri-grams)
# - how negative or positive posts were on the lab help channel specifically
# - who is the happiest/most sad person
# - number of people who asks questions, who are the asking the most
#
# **Network Analysis: (if I have time):**
# - identify people who answer most questions

# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe/channel

# %% [markdown]
# ### channel_gen

# %%
# defining file path
path_to_json = '../data/general/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_gen = pd.concat(dfs, ignore_index=True)
# test
channel_gen.tail(100)
# Out:
#                              client_msg_id     type  \
# 1061  3d62b711-9c19-4aa8-8874-615579ff48e7  message
# 1062  f790d842-a5e8-44e7-be76-678d69cfb06d  message
# 1063  67fff521-642a-4209-82be-42a6b25e91d7  message
# 1064  16c8cc9f-f308-41d9-a642-4120f2fb3041  message
# 1065  9682cdd5-2cf6-4344-9542-9e2711dcf6c1  message
# ...                                    ...      ...
# 1156                                   NaN  message
# 1157                                   NaN  message
# 1158                                   NaN  message
# 1159                                   NaN  message
# 1160                                   NaN  message
#
#                                                    text         user  \
# 1061                         yes and then using the app  U01S79YDELR
# 1062  <!channel>,\ncan you access the content now? W...  U01SJKB2MG8
# 1063                                mine not signing in  U01S0P26NKD
# 1064  yes, thanks. I have problems to go the the cla...  U01S79YDELR
# 1065             <@U01SJKB2MG8> i cannot join the class  U01S79YDELR
# ...                                                 ...          ...
# 1156              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1157              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1158              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1159              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1160              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 1061  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1062  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1063  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1064  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1065  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1156  1.616166e+09          NaN          NaN          NaN
# 1157  1.616167e+09          NaN          NaN          NaN
# 1158  1.616168e+09          NaN          NaN          NaN
# 1159  1.616172e+09          NaN          NaN          NaN
# 1160  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 1061  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1062  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1063  {'avatar_hash': 'g7b30129d02b', 'image_72': 'h...
# 1064  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1065  {'avatar_hash': '606def897de6', 'image_72': 'h...
# ...                                                 ...
# 1156                                                NaN
# 1157                                                NaN
# 1158                                                NaN
# 1159                                                NaN
# 1160                                                NaN
#
#                                                  blocks  ...  upload  \
# 1061  [{'type': 'rich_text', 'block_id': 'Bie', 'ele...  ...     NaN
# 1062  [{'type': 'rich_text', 'block_id': '6p6z', 'el...  ...     NaN
# 1063  [{'type': 'rich_text', 'block_id': 'UCLUf', 'e...  ...     NaN
# 1064  [{'type': 'rich_text', 'block_id': 'Voo', 'ele...  ...     NaN
# 1065  [{'type': 'rich_text', 'block_id': 'upS/I', 'e...  ...     NaN
# ...                                                 ...  ...     ...
# 1156                                                NaN  ...     NaN
# 1157                                                NaN  ...     NaN
# 1158                                                NaN  ...     NaN
# 1159                                                NaN  ...     NaN
# 1160                                                NaN  ...     NaN
#
#      display_as_bot reactions  last_read  bot_id  bot_profile       subtype  \
# 1061            NaN       NaN        NaN     NaN          NaN           NaN
# 1062            NaN       NaN        NaN     NaN          NaN           NaN
# 1063            NaN       NaN        NaN     NaN          NaN           NaN
# 1064            NaN       NaN        NaN     NaN          NaN           NaN
# 1065            NaN       NaN        NaN     NaN          NaN           NaN
# ...             ...       ...        ...     ...          ...           ...
# 1156            NaN       NaN        NaN     NaN          NaN  channel_join
# 1157            NaN       NaN        NaN     NaN          NaN  channel_join
# 1158            NaN       NaN        NaN     NaN          NaN  channel_join
# 1159            NaN       NaN        NaN     NaN          NaN  channel_join
# 1160            NaN       NaN        NaN     NaN          NaN  channel_join
#
#      topic root purpose
# 1061   NaN  NaN     NaN
# 1062   NaN  NaN     NaN
# 1063   NaN  NaN     NaN
# 1064   NaN  NaN     NaN
# 1065   NaN  NaN     NaN
# ...    ...  ...     ...
# 1156   NaN  NaN     NaN
# 1157   NaN  NaN     NaN
# 1158   NaN  NaN     NaN
# 1159   NaN  NaN     NaN
# 1160   NaN  NaN     NaN
#
# [100 rows x 32 columns]

# %%
# save to csv
channel_gen.to_csv(r'../data/general/channel_gen.csv', index = False)

# %% [markdown]
# **Assessment Part1**

# %%
# assess shape
channel_gen.shape
# Out:
# (1161, 32)

# %%
# assess column names
channel_gen.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'blocks', 'thread_ts', 'parent_user_id',
#        'edited', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'attachments',
#        'files', 'upload', 'display_as_bot', 'reactions', 'last_read', 'bot_id',
#        'bot_profile', 'subtype', 'topic', 'root', 'purpose'],
#       dtype='object')

# %%
# used this cell to check through each column's values to validate if I need them or not ahead of any other cleaning
channel_gen['type'].value_counts()
# Out:
# message    1161
# Name: type, dtype: int64

# %%
# check for outliers in the numerical part
channel_gen_clean.describe()
# Out:
#        reply_count  reply_users_count  weekday_number
# count   134.000000         134.000000     1138.000000
# mean      5.343284           2.880597        2.508787
# std       6.021396           2.237899        1.601564
# min       1.000000           1.000000        0.000000
# 25%       2.000000           2.000000        1.000000
# 50%       4.000000           2.000000        3.000000
# 75%       6.000000           3.000000        4.000000
# max      41.000000          16.000000        6.000000

# %% [markdown]
# There are no outliers in this data, it seems healthy.

# %% [markdown]
# **Summary of Assesment Part1**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# **Columns to clean & wrangle:**
# - subtype: filter out it's values from df, remove the original column
# - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day
# - user_profile: extract real_name in new column, remove the original
# - attachments: extract title, text, link in new columns
# - files: extract url_private and who shared
# - attachments: extract title, text, link in new columns
# - reactions: extract user, count, name of the emoji
# - text: ?
#
# **Columns to visualise**
# - reply_count: how many
# - reply_users_count: how many
# - reply_users: who
# - replies: who and when
# - files, attachment, reactions

# %% [markdown]
# **Cleaning Part1**

# %%
# drop columns
channel_gen.drop(['type', 'team', 'user_team', 'source_team', 
                  'latest_reply', 'last_read', 'bot_id', 
                  'bot_profile', 'display_as_bot', 
                  'topic', 'blocks', 'edited', 'is_locked', 
                  'subscribed', 'upload', 'display_as_bot', 
                  'root', 'purpose', 'thread_ts', 
                  'parent_user_id', 'client_msg_id'], axis=1, inplace=True)

# %%
# test
channel_gen.shape
# Out:
# (1161, 13)

# %% [markdown]
# **Assessment Part2**

# %%
# list of columns, their non-null objects and data type of columns
channel_gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1161 entries, 0 to 1160
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_msg_id      1018 non-null   object
#  1   text               1161 non-null   object
#  2   user               1161 non-null   object
#  3   ts                 1161 non-null   float64
#  4   user_profile       1015 non-null   object
#  5   reply_count        134 non-null    float64
#  6   reply_users_count  134 non-null    float64
#  7   reply_users        134 non-null    object
#  8   replies            134 non-null    object
#  9   attachments        83 non-null     object
#  10  files              103 non-null    object
#  11  reactions          267 non-null    object
#  12  subtype            30 non-null     object
# dtypes: float64(3), object(10)
# memory usage: 118.0+ KB

# %%
# check, if there are any nulls and NaN values in our data set
channel_gen.isna().sum()
# Out:
# client_msg_id         143
# text                    0
# user                    0
# ts                      0
# user_profile          146
# reply_count          1027
# reply_users_count    1027
# reply_users          1027
# replies              1027
# attachments          1078
# files                1058
# reactions             894
# subtype              1131
# dtype: int64

# %%
#to summarise this in one line of code and round the values 
channel_gen.isna().mean().round(4) *100
# Out:
# client_msg_id        12.32
# text                  0.00
# user                  0.00
# ts                    0.00
# user_profile         12.58
# reply_count          88.46
# reply_users_count    88.46
# reply_users          88.46
# replies              88.46
# attachments          92.85
# files                91.13
# reactions            77.00
# subtype              97.42
# dtype: float64

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. The only important thing is that each value is coming from a user, and it is because I can see there are no missing values at the text or user columns. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
channel_gen['subtype'].value_counts()
# Out:
# channel_join        20
# channel_topic        7
# channel_purpose      2
# thread_broadcast     1
# Name: subtype, dtype: int64

# %%
# filter out for the rows which has subtype values
channel_gen_clean = channel_gen[(channel_gen.subtype != 'channel_join') & 
                                (channel_gen.subtype != 'channel_join') &
                                (channel_gen.subtype != 'channel_purpose') &
                                (channel_gen.subtype != 'thread_broadcast')]


#test 
channel_gen_clean.shape
# Out:
# (1138, 13)

# %%
# drop subtype column
channel_gen_clean.drop('subtype', axis=1, inplace=True) 

#test
channel_gen_clean.shape
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (1138, 12)

# %%
#convert ts to datetime from float
from datetime import datetime
channel_gen_clean['ts'] = pd.to_datetime(channel_gen['ts'], unit='s')

# remove miliseconds 
channel_gen_clean['ts'] = channel_gen_clean['ts'].astype('datetime64[s]')

channel_gen_clean
# Out:
# <ipython-input-895-34f3db2b859e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['ts'] = pd.to_datetime(channel_gen['ts'], unit='s')
# <ipython-input-895-34f3db2b859e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['ts'] = channel_gen_clean['ts'].astype('datetime64[s]')
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...
# 1145                                                NaN
#
# [1138 rows x 12 columns]

# %%
# create a column for the days of the week using the ts column

channel_gen_clean['day_number'] = channel_gen_clean['ts'].dt.dayofweek   
channel_gen_clean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ts'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-913-4f1b3ba4378d> in <module>
#       1 # create a column for the days of the week using the ts column
#       2
# ----> 3 channel_gen_clean['day_number'] = channel_gen_clean['ts'].dt.dayofweek
#       4 channel_gen_clean
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ts'

# %%
# create a column for the months of the year using the ts column
channel_gen_clean['month'] = pd.DatetimeIndex(channel_gen_clean['ts']).month

# convert values to date time and then month names

channel_gen_clean['month'] = pd.to_datetime(channel_gen_clean['month'], format='%m').dt.month_name()
channel_gen_clean
# Out:
# <ipython-input-897-7170c0871572>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['month'] = pd.DatetimeIndex(channel_gen_clean['ts']).month
# <ipython-input-897-7170c0871572>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['month'] = pd.to_datetime(channel_gen_clean['month'], format='%m').dt.month_name()
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions  weekday_number  month
# 0                                                   NaN               6    May
# 1                                                   NaN               6    May
# 2                                                   NaN               6    May
# 3                                                   NaN               6    May
# 4                                                   NaN               6    May
# ...                                                 ...             ...    ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1  April
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2  April
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2  April
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2  April
# 1145                                                NaN               2  April
#
# [1138 rows x 14 columns]

# %%
# create a column for the type of the weekday using the ts column
channel_gen_clean['day_type'] = channel_gen_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x < 5 else 'Weekend')
channel_gen_clean
# Out:
# <ipython-input-898-416e60aeff65>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['day_type'] = channel_gen_clean.ts.dt.weekday.apply(
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions  weekday_number  \
# 0                                                   NaN               6
# 1                                                   NaN               6
# 2                                                   NaN               6
# 3                                                   NaN               6
# 4                                                   NaN               6
# ...                                                 ...             ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2
# 1145                                                NaN               2
#
#       month day_type
# 0       May  Weekend
# 1       May  Weekend
# 2       May  Weekend
# 3       May  Weekend
# 4       May  Weekend
# ...     ...      ...
# 1141  April  Weekday
# 1142  April  Weekday
# 1143  April  Weekday
# 1144  April  Weekday
# 1145  April  Weekday
#
# [1138 rows x 15 columns]

# %%
# create a column for the hour of the day using the ts column
channel_gen_clean['time']= channel_gen_clean['ts'].dt.strftime('%H:%M')
channel_gen_clean
# Out:
# <ipython-input-899-2bbb22e40bc3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['time']= channel_gen_clean['ts'].dt.strftime('%H:%M')
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions  weekday_number  \
# 0                                                   NaN               6
# 1                                                   NaN               6
# 2                                                   NaN               6
# 3                                                   NaN               6
# 4                                                   NaN               6
# ...                                                 ...             ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2
# 1145                                                NaN               2
#
#       month day_type   time
# 0       May  Weekend  08:00
# 1       May  Weekend  08:01
# 2       May  Weekend  15:27
# 3       May  Weekend  15:30
# 4       May  Weekend  15:32
# ...     ...      ...    ...
# 1141  April  Weekday  16:16
# 1142  April  Weekday  06:45
# 1143  April  Weekday  06:48
# 1144  April  Weekday  06:48
# 1145  April  Weekday  06:52
#
# [1138 rows x 16 columns]

# %%
# drop ts column
channel_gen_clean.drop('ts', axis=1, inplace=True) 

#test
channel_gen_clean.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-908-f6acf2e1ebdd> in <module>
#       1 # drop ts column
# ----> 2 channel_gen_clean.drop('ts', axis=1, inplace=True)
#       3
#       4 #test
#       5 channel_gen_clean.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['ts'] not found in axis"

# %% [markdown]
# - user_profile: extract real_name in new column, remove the original
# - attachments: extract title, text, link in new columns
# - files: extract url_private and who shared
# - reactions: extract user, count, name of the emoji
# - text: ?

# %%
# check dictionary values in files column
channel_gen[~channel_gen['files'].isna()]['files'].iloc[30][0]
# Out:
# {'id': 'F01T66CCE7M',
#  'created': 1617376819,
#  'timestamp': 1617376819,
#  'name': 'm.jpg',
#  'title': 'm.jpg',
#  'mimetype': 'image/jpeg',
#  'filetype': 'jpg',
#  'pretty_type': 'JPEG',
#  'user': 'U01S0P26NKD',
#  'editable': False,
#  'size': 407181,
#  'mode': 'hosted',
#  'is_external': False,
#  'external_type': '',
#  'is_public': True,
#  'public_url_shared': False,
#  'display_as_bot': False,
#  'username': '',
#  'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01T66CCE7M/m.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01T66CCE7M/download/m.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_64.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_80.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_360.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_360_w': 360,
#  'thumb_360_h': 270,
#  'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_480.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_480_w': 480,
#  'thumb_480_h': 360,
#  'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_160.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_720.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_720_w': 720,
#  'thumb_720_h': 540,
#  'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_800.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_800_w': 800,
#  'thumb_800_h': 600,
#  'thumb_960': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_960.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_960_w': 960,
#  'thumb_960_h': 720,
#  'thumb_1024': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01T66CCE7M-a66afdce77/m_1024.jpg?t=xoxe-1861879185255-2047593969042-2053756158948-4cf6552631c579c36efd5d2fd242de30',
#  'thumb_1024_w': 1024,
#  'thumb_1024_h': 768,
#  'original_w': 2048,
#  'original_h': 1536,
#  'thumb_tiny': '',
#  'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01S0P26NKD/F01T66CCE7M/m.jpg',
#  'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F01T66CCE7M-01f6637610',
#  'is_starred': False,
#  'has_rich_preview': False}

# %%
#files column: extract url_private

def geturlfromfile(x):
    """this function is applied to column files
    """
    
    if x != x:
        return 'nouser'
    else:
        return x[0]['user']

channel_gen_clean['who_shared_files'] = channel_gen_clean['files'].apply(geturlfromfile)

channel_gen_clean
# Out:
# <ipython-input-900-279c87ce1172>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['who_shared_files'] = channel_gen_clean['files'].apply(geturlfromfile)
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions  weekday_number  \
# 0                                                   NaN               6
# 1                                                   NaN               6
# 2                                                   NaN               6
# 3                                                   NaN               6
# 4                                                   NaN               6
# ...                                                 ...             ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2
# 1145                                                NaN               2
#
#       month day_type   time who_shared_files
# 0       May  Weekend  08:00           nouser
# 1       May  Weekend  08:01           nouser
# 2       May  Weekend  15:27           nouser
# 3       May  Weekend  15:30           nouser
# 4       May  Weekend  15:32           nouser
# ...     ...      ...    ...              ...
# 1141  April  Weekday  16:16           nouser
# 1142  April  Weekday  06:45           nouser
# 1143  April  Weekday  06:48           nouser
# 1144  April  Weekday  06:48           nouser
# 1145  April  Weekday  06:52           nouser
#
# [1138 rows x 17 columns]

# %%
#files column: extract who shared

def geturlfromfile(x):
    """this function is applied to column files
    """
    
    if x != x:
        return 'nofile'
    else:
        return x[0]['url_private']

channel_gen_clean['link_of_file'] = channel_gen_clean['files'].apply(geturlfromfile)

channel_gen_clean
# Out:
# <ipython-input-901-6d3a3054ef04>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['link_of_file'] = channel_gen_clean['files'].apply(geturlfromfile)
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 1141 2021-04-27 16:16:45  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 1142 2021-04-28 06:45:19  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 1143 2021-04-28 06:48:05  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1144 2021-04-28 06:48:51  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1145 2021-04-28 06:52:44  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#       reply_count  reply_users_count                              reply_users  \
# 0             NaN                NaN                                      NaN
# 1             NaN                NaN                                      NaN
# 2            31.0                2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                                      NaN
# 4             NaN                NaN                                      NaN
# ...           ...                ...                                      ...
# 1141          NaN                NaN                                      NaN
# 1142          4.0                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143          NaN                NaN                                      NaN
# 1144          NaN                NaN                                      NaN
# 1145          NaN                NaN                                      NaN
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 1141                                                NaN         NaN   NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN   NaN
# 1143                                                NaN         NaN   NaN
# 1144                                                NaN         NaN   NaN
# 1145                                                NaN         NaN   NaN
#
#                                               reactions  weekday_number  \
# 0                                                   NaN               6
# 1                                                   NaN               6
# 2                                                   NaN               6
# 3                                                   NaN               6
# 4                                                   NaN               6
# ...                                                 ...             ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2
# 1145                                                NaN               2
#
#       month day_type   time who_shared_files link_of_file
# 0       May  Weekend  08:00           nouser       nofile
# 1       May  Weekend  08:01           nouser       nofile
# 2       May  Weekend  15:27           nouser       nofile
# 3       May  Weekend  15:30           nouser       nofile
# 4       May  Weekend  15:32           nouser       nofile
# ...     ...      ...    ...              ...          ...
# 1141  April  Weekday  16:16           nouser       nofile
# 1142  April  Weekday  06:45           nouser       nofile
# 1143  April  Weekday  06:48           nouser       nofile
# 1144  April  Weekday  06:48           nouser       nofile
# 1145  April  Weekday  06:52           nouser       nofile
#
# [1138 rows x 18 columns]

# %%
# drop files column
channel_gen_clean.drop('files', axis=1, inplace=True) 

#test
channel_gen_clean.head()
# Out:
#                           client_msg_id  \
# 0  2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1  a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2  ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3  0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4  39e4728b-90f7-4d84-b149-74d765ca544a
#
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#                                         user_profile  reply_count  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#                                              replies attachments reactions  \
# 0                                                NaN         NaN       NaN
# 1                                                NaN         NaN       NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN       NaN
# 3                                                NaN         NaN       NaN
# 4                                                NaN         NaN       NaN
#
#    weekday_number month day_type   time who_shared_files link_of_file
# 0               6   May  Weekend  08:00           nouser       nofile
# 1               6   May  Weekend  08:01           nouser       nofile
# 2               6   May  Weekend  15:27           nouser       nofile
# 3               6   May  Weekend  15:30           nouser       nofile
# 4               6   May  Weekend  15:32           nouser       nofile

# %%
channel_gen[~channel_gen['attachments'].isna()]['attachments'].iloc[30][0]['app_unfurl_url']
# Out:
# 'https://github.com/Caparisun/Linear_Regression_Project'

# %%
# attachments column: extract link

def geturlfromattachments(x):
    """this function is applied to column attachments
    """
    
    if x != x:
        return 'nolink'
    else:
        return x[0]['app_unfurl_url']

channel_gen_clean['link_of_attachments'] = channel_gen_clean['attachments'].apply(geturlfromattachments)

channel_gen_clean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-904-c7d7ca3d5fd4> in <module>
#      10         return x[0]['app_unfurl_url']
#      11
# ---> 12 channel_gen_clean['link_of_attachments'] = channel_gen_clean['attachments'].apply(geturlfromattachments)
#      13
#      14 channel_gen_clean
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-904-c7d7ca3d5fd4> in geturlfromattachments(x)
#       8         return 'nolink'
#       9     else:
# ---> 10         return x[0]['app_unfurl_url']
#      11
#      12 channel_gen_clean['link_of_attachments'] = channel_gen_clean['attachments'].apply(geturlfromattachments)
#
# KeyError: 'app_unfurl_url'

# %%
channel_gen[~channel_gen['user_profile'].isna()]['user_profile'].iloc[0]['real_name']
# Out:
# 'Karina Condeixa'

# %%
# user_profile column: extract real_name

def getrealnamefromprofile(x):
    """this function is applied to column user_profile
    """
    
    if x != x:
        return 'noname'
    else:
        return x['real_name']

channel_gen_clean['real_name'] = channel_gen_clean['user_profile'].apply(getrealnamefromprofile)

channel_gen_clean
# Out:
# <ipython-input-911-9471f2560cf3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_gen_clean['real_name'] = channel_gen_clean['user_profile'].apply(getrealnamefromprofile)
#                              client_msg_id  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4     39e4728b-90f7-4d84-b149-74d765ca544a
# ...                                    ...
# 1141  b78965a7-bbb5-4095-977d-0277d523be45
# 1142  c0cb9b40-89a9-4fc8-a2d5-6d7f5fbc7a3c
# 1143  58ea4cb8-c316-44e5-bf8b-e02b79dd69b4
# 1144  6a631562-e138-4d10-89c9-7b54adbe7f31
# 1145  e157dee6-ddbe-41b5-83b6-c9804ba5bffa
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1141                                        absolutely!  U01RW140HBP
# 1142  Morning all. - anyone completed the RFM lab fr...  U01S133DZ9A
# 1143  Morning simon, mine is here:\n<https://public....  U01S7BM4N81
# 1144  Bur if I recall correctly there’s screenshots ...  U01S7BM4N81
# 1145            there is indeed :slightly_smiling_face:  U01RW140HBP
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 1141  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...          NaN
# 1142  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          4.0
# 1143  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...          NaN
# 1144  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...          NaN
# 1145  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...          NaN
#
#       reply_users_count                              reply_users  \
# 0                   NaN                                      NaN
# 1                   NaN                                      NaN
# 2                   2.0               [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                                      NaN
# 4                   NaN                                      NaN
# ...                 ...                                      ...
# 1141                NaN                                      NaN
# 1142                3.0  [U01S7BM4N81, U01RW140HBP, U01S133DZ9A]
# 1143                NaN                                      NaN
# 1144                NaN                                      NaN
# 1145                NaN                                      NaN
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 1141                                                NaN         NaN
# 1142  [{'user': 'U01S7BM4N81', 'ts': '1619592485.075...         NaN
# 1143                                                NaN         NaN
# 1144                                                NaN         NaN
# 1145                                                NaN         NaN
#
#                                               reactions  weekday_number  \
# 0                                                   NaN               6
# 1                                                   NaN               6
# 2                                                   NaN               6
# 3                                                   NaN               6
# 4                                                   NaN               6
# ...                                                 ...             ...
# 1141  [{'name': '+1', 'users': ['U01SK96QF5E'], 'cou...               1
# 1142  [{'name': '+1', 'users': ['U01S7KCL3DF'], 'cou...               2
# 1143  [{'name': '+1', 'users': ['U01S133DZ9A'], 'cou...               2
# 1144  [{'name': '+1', 'users': ['U01RW140HBP', 'U01S...               2
# 1145                                                NaN               2
#
#       month day_type   time who_shared_files link_of_file  \
# 0       May  Weekend  08:00           nouser       nofile
# 1       May  Weekend  08:01           nouser       nofile
# 2       May  Weekend  15:27           nouser       nofile
# 3       May  Weekend  15:30           nouser       nofile
# 4       May  Weekend  15:32           nouser       nofile
# ...     ...      ...    ...              ...          ...
# 1141  April  Weekday  16:16           nouser       nofile
# 1142  April  Weekday  06:45           nouser       nofile
# 1143  April  Weekday  06:48           nouser       nofile
# 1144  April  Weekday  06:48           nouser       nofile
# 1145  April  Weekday  06:52           nouser       nofile
#
#                    real_name
# 0            Karina Condeixa
# 1            Karina Condeixa
# 2          Francisco Ebeling
# 3            Karina Condeixa
# 4          Francisco Ebeling
# ...                      ...
# 1141  siand the LT (she/her)
# 1142              Simon Data
# 1143                   Thamo
# 1144                   Thamo
# 1145  siand the LT (she/her)
#
# [1138 rows x 17 columns]

# %%
# drop user_profile column
channel_gen_clean.drop('user_profile', axis=1, inplace=True) 

#test
channel_gen_clean.head()
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                           client_msg_id  \
# 0  2d1b171f-ab27-4a43-a0b7-0ecabcfc3294
# 1  a3c6083b-3a42-43a0-a621-bd32e26972d2
# 2  ec4aa0c0-53f5-4e94-9080-2e98ec280b3d
# 3  0aac10ae-ccff-47cf-bb2a-69a34819375b
# 4  39e4728b-90f7-4d84-b149-74d765ca544a
#
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#    reply_count  reply_users_count                 reply_users  \
# 0          NaN                NaN                         NaN
# 1          NaN                NaN                         NaN
# 2         31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3          NaN                NaN                         NaN
# 4          NaN                NaN                         NaN
#
#                                              replies attachments reactions  \
# 0                                                NaN         NaN       NaN
# 1                                                NaN         NaN       NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN       NaN
# 3                                                NaN         NaN       NaN
# 4                                                NaN         NaN       NaN
#
#    weekday_number month day_type   time who_shared_files link_of_file  \
# 0               6   May  Weekend  08:00           nouser       nofile
# 1               6   May  Weekend  08:01           nouser       nofile
# 2               6   May  Weekend  15:27           nouser       nofile
# 3               6   May  Weekend  15:30           nouser       nofile
# 4               6   May  Weekend  15:32           nouser       nofile
#
#            real_name
# 0    Karina Condeixa
# 1    Karina Condeixa
# 2  Francisco Ebeling
# 3    Karina Condeixa
# 4  Francisco Ebeling

# %%
# filter out for the rows which has subtype values
channel_topic_changes = channel_gen.loc[channel_gen['text'].str.contains("channel topic", case=False)]
channel_topic_changes

# %% [markdown]
# ### channel_books

# %%
### books channel
# defining file path
path_to_json = '../data/books/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_books = pd.concat(dfs, ignore_index=True)
# test
channel_books

# %%
# save to csv
channel_books.to_csv(r'../data/books/channel_books.csv', index = False)

# %% [markdown]
# ### channel_dresource

# %%
### data_resources channel
# defining file path
path_to_json = '../data/data_resources/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dresource = pd.concat(dfs, ignore_index=True)
# test
channel_dresource

# %%
# save to csv
channel_dresource.to_csv(r'../data/data_resources/channel_dresource.csv', index = False)

# %% [markdown]
# ### channel_dbootcamp

# %%
### data-bootcamp channel
# defining file path
path_to_json = '../data/data-bootcamp/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dbootcamp = pd.concat(dfs, ignore_index=True)
# test
channel_dbootcamp

# %%
# save to csv
channel_dbootcamp.to_csv(r'../data/data-bootcamp/channel_dbootcamp.csv', index = False)

# %% [markdown]
# ### channel_dmemes

# %%
### data-memes channel
# defining file path
path_to_json = '../data/data-memes/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dmemes = pd.concat(dfs, ignore_index=True)
# test
channel_dmemes

# %%
# save to csv
channel_dmemes.to_csv(r'../data/data-memes/channel_dmemes.csv', index = False)

# %% [markdown]
# ### channel_dvizbeauties|

# %%
### data-viz-beauties channel
# defining file path
path_to_json = '../data/data-viz-beauties/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dvizbeauties = pd.concat(dfs, ignore_index=True)
# test
channel_dvizbeauties

# %%
# save to csv
channel_dvizbeauties.to_csv(r'../data/data-viz-beauties/channel_dvizbeauties.csv', index = False)

# %% [markdown]
# ### channel_finalproject

# %%
### final-project channel
# defining file path
path_to_json = '../data/final-project/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_finalproject = pd.concat(dfs, ignore_index=True)
# test
channel_finalproject.head(10)

# %%
# save to csv
channel_finalproject.to_csv(r'../data/final-project/finalproject.csv', index = False)

# %% [markdown]
# ### channel_frustrations

# %%
### frustrations-shared channel
# defining file path
path_to_json = '../data/frustrations-shared/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_frustrations = pd.concat(dfs, ignore_index=True)
# test
channel_frustrations

# %%
# save to csv
channel_frustrations.to_csv(r'../data/frustrations-shared/frustrations.csv', index = False)

# %% [markdown]
# ### channel_funcommittee

# %%
### fun_committee channel
# defining file path
path_to_json = '../data/fun_committee/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_funcommittee = pd.concat(dfs, ignore_index=True)
# test
channel_funcommittee

# %%
# save to csv
channel_funcommittee.to_csv(r'../data/fun_committee/channel_funcommittee.csv', index = False)

# %% [markdown]
# ### channel_katas

# %%
### katas channel
# defining file path
path_to_json = '../data/katas/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_katas = pd.concat(dfs, ignore_index=True)
# test
channel_katas

# %%
# save to csv
channel_katas.to_csv(r'../data/katas/channel_katas.csv', index = False)

# %% [markdown]
# ### channel_labhelp

# %%
### lab-help channel
# defining file path
path_to_json = '../data/lab-help/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_labhelp = pd.concat(dfs, ignore_index=True)
# test
channel_labhelp

# %%
# save to csv
channel_labhelp.to_csv(r'../data/lab-help/channel_labhelp.csv', index = False)

# %% [markdown]
# ### channel_music

# %%
### music channel
# defining file path
path_to_json = '../data/music/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_music = pd.concat(dfs, ignore_index=True)
# test
channel_music

# %%
# save to csv
channel_music.to_csv(r'../data/music/channel_music.csv', index = False)

# %% [markdown]
# ### channel_random

# %%
### random channel
# defining file path
path_to_json = '../data/random/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_random = pd.concat(dfs, ignore_index=True)
# test
channel_random

# %%
# save to csv
channel_random.to_csv(r'../data/random/channel_random.csv', index = False)

# %% [markdown]
# ### channel_vanilla

# %%
### vanilla_plus_more channel
# defining file path
path_to_json = '../data/vanilla_plus_more/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_vanilla = pd.concat(dfs, ignore_index=True)
# test
channel_vanilla

# %%
# save to csv
channel_vanilla.to_csv(r'../data/vanilla_plus_more/channel_vanilla.csv', index = False)
