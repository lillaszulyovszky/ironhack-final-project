# %% [markdown]
# **EDA**
# - how much traffic per channel
# - which post in which channel gets the most reaction/traction
# - what time of the day students are posting the most per day
# - distribution of  % links, % memes, % emojis
# - frequency of messages from teaching staff vs students
# - count of messages per person
# - avg length of messages per person
# - statistics of mentions within a date range
# - which channel is the most useful(most messages)
#
# **Automated function**
# - a report at the end of each day, with a few summary statistics for that day
# - a daily / weekly extract of all the links/uploads posted in public channels
#
# **NLP**
# - whats the top 5 words used per channel (bi-grams, tri-grams)
# - how negative or positive posts were on the lab help channel specifically
# - who is the happiest/most sad person
# - number of people who asks questions, who are the asking the most
#
# **Network Analysis: (if I have time):**
# - identify people who answer most questions

# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe/channel

# %% [markdown]
# ### channel_gen

# %%
# defining file path
path_to_json = '../data/general/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_gen = pd.concat(dfs, ignore_index=True)
# test
channel_gen.head(10)
# Out:
#                           client_msg_id     type  \
# 0  2d1b171f-ab27-4a43-a0b7-0ecabcfc3294  message
# 1  a3c6083b-3a42-43a0-a621-bd32e26972d2  message
# 2  ec4aa0c0-53f5-4e94-9080-2e98ec280b3d  message
# 3  0aac10ae-ccff-47cf-bb2a-69a34819375b  message
# 4  39e4728b-90f7-4d84-b149-74d765ca544a  message
# 5  4ee51612-754e-49c8-83f4-8270b097b4f8  message
# 6  b17119d9-9d3e-41ef-b4de-207edada3a3d  message
# 7  2cfa7355-ae1c-4908-9ff9-fda495b50267  message
# 8  a10a43cc-3a19-4f4b-a9d8-f60a5cca2ee2  message
# 9  5e8e90ae-3423-4b75-aa8b-f0b2c9c7a870  message
#
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
# 5  I just copied each session. without any table,...  U01S79YDELR
# 6  Yeah, I did this. It has improved, but not qui...  U01RRV4JX6Z
# 7                      Did you put career mid level?  U01RRV4JX6Z
# 8  take a look in each feature you need most to i...  U01S79YDELR
# 9  I put first as junior, later as mid. I had bet...  U01S79YDELR
#
#              ts         team    user_team  source_team  \
# 0  1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1  1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 5  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 6  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 7  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9  1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                         user_profile  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 5  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 6  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 7  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 8  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 9  {'avatar_hash': '606def897de6', 'image_72': 'h...
#
#                                               blocks  ...  upload  \
# 0  [{'type': 'rich_text', 'block_id': '8oy', 'ele...  ...     NaN
# 1  [{'type': 'rich_text', 'block_id': 'wr=L', 'el...  ...     NaN
# 2  [{'type': 'rich_text', 'block_id': 'pRRNj', 'e...  ...     NaN
# 3  [{'type': 'rich_text', 'block_id': 'Daw', 'ele...  ...     NaN
# 4  [{'type': 'rich_text', 'block_id': '7YE+G', 'e...  ...     NaN
# 5  [{'type': 'rich_text', 'block_id': 'hjI0', 'el...  ...     NaN
# 6  [{'type': 'rich_text', 'block_id': 'BooPC', 'e...  ...     NaN
# 7  [{'type': 'rich_text', 'block_id': 'F9WIK', 'e...  ...     NaN
# 8  [{'type': 'rich_text', 'block_id': 'W4g/R', 'e...  ...     NaN
# 9  [{'type': 'rich_text', 'block_id': 'X8/b', 'el...  ...     NaN
#
#   display_as_bot reactions  last_read  bot_id  bot_profile subtype topic root  \
# 0            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 1            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 2            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 3            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 4            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 5            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 6            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 7            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 8            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
# 9            NaN       NaN        NaN     NaN          NaN     NaN   NaN  NaN
#
#   purpose
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
#
# [10 rows x 32 columns]

# %%
# save to csv
channel_gen.to_csv(r'../data/general/channel_gen.csv', index = False)

# %% [markdown]
# **Assessment Part1**

# %%
# assess shape
channel_gen.shape
# Out:
# (1161, 32)

# %%
# assess column names
channel_gen.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'blocks', 'thread_ts', 'parent_user_id',
#        'edited', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'attachments',
#        'files', 'upload', 'display_as_bot', 'reactions', 'last_read', 'bot_id',
#        'bot_profile', 'subtype', 'topic', 'root', 'purpose'],
#       dtype='object')

# %%
# used this cell to check through each column's values to validate if I need them or not ahead of any other cleaning
channel_gen['type'].value_counts()
# Out:
# message    1161
# Name: type, dtype: int64

# %% [markdown]
# **Summary of Assesment Part1**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose
#
# **Columns to get info from:**
# - client_msd_id: might be useful later
# - text: keeping it
# - user: keeping it
# - ts: changing it to datetime
# - user_profile: get real_name
# - thread_ts: timestamp of thread
# - reply_count: how many
# - reply_users_count: how many
# - reply_users: who
# - replies: who and when
# - attachments: title, text, link
# - files: user, timestamp, url_private
# - reactions: user, count, name
# - subtype: could bin channel_join and channel_topic values?
# - parent_user_id: might be useful later

# %% [markdown]
# **Cleaning Part1**

# %%
# drop columns
channel_gen.drop(['type', 'team', 'user_team', 'source_team', 
                  'latest_reply', 'last_read', 'bot_id', 
                  'bot_profile', 'display_as_bot', 
                  'topic', 'blocks', 'edited', 'is_locked', 
                  'subscribed', 'upload', 'display_as_bot', 
                  'root', 'purpose'], axis=1, inplace=True)

# %%
# test
channel_gen.shape
# Out:
# (1161, 15)

# %% [markdown]
# **Assessment Part2**

# %%
# list of columns, their non-null objects and data type of columns
channel_gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1161 entries, 0 to 1160
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   client_msg_id      1018 non-null   object
#  1   text               1161 non-null   object
#  2   user               1161 non-null   object
#  3   ts                 1161 non-null   float64
#  4   user_profile       1015 non-null   object
#  5   thread_ts          850 non-null    float64
#  6   parent_user_id     715 non-null    object
#  7   reply_count        134 non-null    float64
#  8   reply_users_count  134 non-null    float64
#  9   reply_users        134 non-null    object
#  10  replies            134 non-null    object
#  11  attachments        83 non-null     object
#  12  files              103 non-null    object
#  13  reactions          267 non-null    object
#  14  subtype            30 non-null     object
# dtypes: float64(4), object(11)
# memory usage: 136.2+ KB

# %%
# check, if there are any nulls and NaN values in our data set
channel_gen.isna().sum()
# Out:
# client_msg_id         143
# text                    0
# user                    0
# ts                      0
# user_profile          146
# thread_ts             311
# parent_user_id        446
# reply_count          1027
# reply_users_count    1027
# reply_users          1027
# replies              1027
# attachments          1078
# files                1058
# reactions             894
# subtype              1131
# dtype: int64

# %%
#to summarise this in one line of code and round the values 
channel_gen.isna().mean().round(4) *100
# Out:
# client_msg_id        12.32
# text                  0.00
# user                  0.00
# ts                    0.00
# user_profile         12.58
# thread_ts            26.79
# parent_user_id       38.42
# reply_count          88.46
# reply_users_count    88.46
# reply_users          88.46
# replies              88.46
# attachments          92.85
# files                91.13
# reactions            77.00
# subtype              97.42
# dtype: float64

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
channel_gen['subtype'].value_counts()
# Out:
# channel_join        20
# channel_topic        7
# channel_purpose      2
# thread_broadcast     1
# Name: subtype, dtype: int64

# %%
# filter for the rows which has subtype values
only_messages = channel_gen.loc[channel_gen['text'].str.contains("joined channel", case=False)]
only_messages
# Out:
# Empty DataFrame
# Columns: [client_msg_id, text, user, ts, user_profile, thread_ts, parent_user_id, reply_count, reply_users_count, reply_users, replies, attachments, files, reactions, subtype]
# Index: []

# %%
# check for outliers in the numerical part
channel_gen.describe()
# Out:
#                  ts     thread_ts  reply_count  reply_users_count
# count  1.161000e+03  8.500000e+02   134.000000         134.000000
# mean   1.618189e+09  1.618230e+09     5.343284           2.880597
# std    1.435450e+06  1.434152e+06     6.021396           2.237899
# min    1.616107e+09  1.616406e+09     1.000000           1.000000
# 25%    1.616691e+09  1.616691e+09     2.000000           2.000000
# 50%    1.617975e+09  1.617974e+09     4.000000           2.000000
# 75%    1.619519e+09  1.619519e+09     6.000000           3.000000
# max    1.620638e+09  1.620574e+09    41.000000          16.000000

# %% [markdown]
# There are no outliers in this data, it seems healthy.

# %% [markdown]
# ### channel_books

# %%
### books channel
# defining file path
path_to_json = '../data/books/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_books = pd.concat(dfs, ignore_index=True)
# test
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks
# 0                                                NaN
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...

# %%
# save to csv
channel_books.to_csv(r'../data/books/channel_books.csv', index = False)

# %% [markdown]
# ### channel_dresource

# %%
### data_resources channel
# defining file path
path_to_json = '../data/data_resources/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dresource = pd.concat(dfs, ignore_index=True)
# test
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 183  message           NaN  1.619510e+09  U01S7KCL3DF
# 184  message           NaN  1.619513e+09  U01RW140HBP
# 185  message           NaN  1.619513e+09  U01RW140HBP
# 186  message  channel_join  1.616163e+09  U01S79YDELR
# 187  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 183  aaahhhh yes thanks… i must scroll down more of...
# 184  we are working hard to keep that Notion up to ...
# 185  because of the free slack thing :confounded:- ...
# 186              <@U01S79YDELR> has joined the channel
# 187              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 183  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 184  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 185  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 186                                   NaN          NaN          NaN
# 187                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 183  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 184  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 185  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 186          NaN                                                NaN  ...
# 187          NaN                                                NaN  ...
#
#         last_read                                              files upload  \
# 0             NaN                                                NaN    NaN
# 1             NaN                                                NaN    NaN
# 2    1.619337e+09                                                NaN    NaN
# 3             NaN  [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False
# 4             NaN  [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False
# ..            ...                                                ...    ...
# 183           NaN                                                NaN    NaN
# 184           NaN                                                NaN    NaN
# 185           NaN                                                NaN    NaN
# 186           NaN                                                NaN    NaN
# 187           NaN                                                NaN    NaN
#
#      display_as_bot                                          reactions  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               0.0  [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...
# 4               0.0                                                NaN
# ..              ...                                                ...
# 183             NaN  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...
# 184             NaN                                                NaN
# 185             NaN                                                NaN
# 186             NaN                                                NaN
# 187             NaN                                                NaN
#
#      parent_user_id  bot_id bot_profile inviter  topic
# 0               NaN     NaN         NaN     NaN    NaN
# 1               NaN     NaN         NaN     NaN    NaN
# 2               NaN     NaN         NaN     NaN    NaN
# 3               NaN     NaN         NaN     NaN    NaN
# 4               NaN     NaN         NaN     NaN    NaN
# ..              ...     ...         ...     ...    ...
# 183     U01S7KCL3DF     NaN         NaN     NaN    NaN
# 184             NaN     NaN         NaN     NaN    NaN
# 185             NaN     NaN         NaN     NaN    NaN
# 186             NaN     NaN         NaN     NaN    NaN
# 187             NaN     NaN         NaN     NaN    NaN
#
# [188 rows x 31 columns]

# %%
# save to csv
channel_dresource.to_csv(r'../data/data_resources/channel_dresource.csv', index = False)

# %% [markdown]
# ### channel_dbootcamp

# %%
### data-bootcamp channel
# defining file path
path_to_json = '../data/data-bootcamp/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dbootcamp = pd.concat(dfs, ignore_index=True)
# test
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text
# 0   <@U01RVSTNRRT> has joined the channel
# 1   <@U01RW140HBP> has joined the channel
# 2   <@U01S65G72SY> has joined the channel
# 3   <@U01RSRE0N3D> has joined the channel
# 4   <@U01RRV4JX6Z> has joined the channel
# 5   <@U01S79YDELR> has joined the channel
# 6   <@U01RUTP1ZQB> has joined the channel
# 7   <@U01RUU9SK4K> has joined the channel
# 8   <@U01S7BM4N81> has joined the channel
# 9   <@U01SJKB2MG8> has joined the channel
# 10  <@U01RV3K524T> has joined the channel
# 11  <@U01S133DZ9A> has joined the channel
# 12  <@U01RN7BVD1C> has joined the channel
# 13  <@U01S7KCL3DF> has joined the channel
# 14  <@U01S1CWGTU4> has joined the channel
# 15  <@U01RNEU3SNA> has joined the channel
# 16  <@U01RS9Y6UJH> has joined the channel
# 17  <@U01SK96QF5E> has joined the channel
# 18  <@U01RP2K1606> has joined the channel
# 19  <@U01RW2X7S9Z> has joined the channel

# %%
# save to csv
channel_dbootcamp.to_csv(r'../data/data-bootcamp/channel_dbootcamp.csv', index = False)

# %% [markdown]
# ### channel_dmemes

# %%
### data-memes channel
# defining file path
path_to_json = '../data/data-memes/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dmemes = pd.concat(dfs, ignore_index=True)
# test
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 252  message  this made me realise there is no krispy branch...
# 253  message
# 254  message                                     <@U01S0E0MRJ7>
# 255  message                               haha this is tots me
# 256  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 252                                                NaN    NaN  U01SK96QF5E
# 253  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 254  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 255                                                NaN    NaN  U01S0E0MRJ7
# 256  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 252            NaN  1.616509e+09  1.616498e+09          NaN
# 253            0.0  1.616518e+09           NaN          NaN
# 254            0.0  1.619509e+09  1.619509e+09          1.0
# 255            NaN  1.619510e+09  1.619509e+09          NaN
# 256            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...  source_team  \
# 0                  NaN  ...          NaN
# 1                  1.0  ...          NaN
# 2                  NaN  ...          NaN
# 3                  NaN  ...          NaN
# 4                  NaN  ...          NaN
# ..                 ...  ...          ...
# 252                NaN  ...  T01RBRV5F7H
# 253                NaN  ...          NaN
# 254                1.0  ...          NaN
# 255                NaN  ...  T01RBRV5F7H
# 256                NaN  ...          NaN
#
#                                           user_profile attachments  bot_id  \
# 0                                                  NaN         NaN     NaN
# 1                                                  NaN         NaN     NaN
# 2                                                  NaN         NaN     NaN
# 3                                                  NaN         NaN     NaN
# 4                                                  NaN         NaN     NaN
# ..                                                 ...         ...     ...
# 252  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...         NaN     NaN
# 253                                                NaN         NaN     NaN
# 254                                                NaN         NaN     NaN
# 255  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...         NaN     NaN
# 256                                                NaN         NaN     NaN
#
#      bot_profile last_read edited subtype purpose inviter
# 0            NaN       NaN    NaN     NaN     NaN     NaN
# 1            NaN       NaN    NaN     NaN     NaN     NaN
# 2            NaN       NaN    NaN     NaN     NaN     NaN
# 3            NaN       NaN    NaN     NaN     NaN     NaN
# 4            NaN       NaN    NaN     NaN     NaN     NaN
# ..           ...       ...    ...     ...     ...     ...
# 252          NaN       NaN    NaN     NaN     NaN     NaN
# 253          NaN       NaN    NaN     NaN     NaN     NaN
# 254          NaN       NaN    NaN     NaN     NaN     NaN
# 255          NaN       NaN    NaN     NaN     NaN     NaN
# 256          NaN       NaN    NaN     NaN     NaN     NaN
#
# [257 rows x 31 columns]

# %%
# save to csv
channel_dmemes.to_csv(r'../data/data-memes/channel_dmemes.csv', index = False)

# %% [markdown]
# ### channel_dvizbeauties|

# %%
### data-viz-beauties channel
# defining file path
path_to_json = '../data/data-viz-beauties/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dvizbeauties = pd.concat(dfs, ignore_index=True)
# test
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 249  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 250  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 251  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 252  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 253  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 249  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 250  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 251  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 252                                   a late night sam  U01RS9Y6UJH
# 253  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 249  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 250  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 251  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 252  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 253  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 249  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 250  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 251  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 252  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 253  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  subscribed  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...         NaN
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...         NaN
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...         0.0
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...         NaN
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...         NaN
# ..                                                 ...  ...         ...
# 249  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...         0.0
# 250  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...         0.0
# 251  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...         NaN
# 252  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...         NaN
# 253  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...         NaN
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 249  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 250  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 251  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 252  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 253                                                NaN         NaN
#
#                                                 edited bot_id  bot_profile  \
# 0                                                  NaN    NaN          NaN
# 1                                                  NaN    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3                                                  NaN    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 249                                                NaN    NaN          NaN
# 250  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN          NaN
# 251                                                NaN    NaN          NaN
# 252                                                NaN    NaN          NaN
# 253                                                NaN    NaN          NaN
#
#      subtype  purpose inviter last_read
# 0        NaN      NaN     NaN       NaN
# 1        NaN      NaN     NaN       NaN
# 2        NaN      NaN     NaN       NaN
# 3        NaN      NaN     NaN       NaN
# 4        NaN      NaN     NaN       NaN
# ..       ...      ...     ...       ...
# 249      NaN      NaN     NaN       NaN
# 250      NaN      NaN     NaN       NaN
# 251      NaN      NaN     NaN       NaN
# 252      NaN      NaN     NaN       NaN
# 253      NaN      NaN     NaN       NaN
#
# [254 rows x 31 columns]

# %%
# save to csv
channel_dvizbeauties.to_csv(r'../data/data-viz-beauties/channel_dvizbeauties.csv', index = False)

# %% [markdown]
# ### channel_finalproject

# %%
### final-project channel
# defining file path
path_to_json = '../data/final-project/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_finalproject = pd.concat(dfs, ignore_index=True)
# test
channel_finalproject.head(10)
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.620629e+09  U01RSRE0N3D
# 1  message  channel_join  1.620629e+09  U01SJKB2MG8
# 2  message  channel_join  1.620640e+09  U01RXCQHMHT
# 3  message  channel_join  1.620640e+09  U01S7BM4N81
# 4  message  channel_join  1.620640e+09  U01S133DZ9A
# 5  message  channel_join  1.620640e+09  U01S7KCL3DF
# 6  message  channel_join  1.620640e+09  U01RNEU3SNA
# 7  message  channel_join  1.620640e+09  U01RVSTNRRT
# 8  message  channel_join  1.620640e+09  U01RV3K524T
# 9  message  channel_join  1.620640e+09  U01RS9Y6UJH
#
#                                     text      inviter client_msg_id team  \
# 0  <@U01RSRE0N3D> has joined the channel          NaN           NaN  NaN
# 1  <@U01SJKB2MG8> has joined the channel  U01RSRE0N3D           NaN  NaN
# 2  <@U01RXCQHMHT> has joined the channel  U01RSRE0N3D           NaN  NaN
# 3  <@U01S7BM4N81> has joined the channel  U01RSRE0N3D           NaN  NaN
# 4  <@U01S133DZ9A> has joined the channel  U01RSRE0N3D           NaN  NaN
# 5  <@U01S7KCL3DF> has joined the channel  U01RSRE0N3D           NaN  NaN
# 6  <@U01RNEU3SNA> has joined the channel  U01RSRE0N3D           NaN  NaN
# 7  <@U01RVSTNRRT> has joined the channel  U01RSRE0N3D           NaN  NaN
# 8  <@U01RV3K524T> has joined the channel  U01RSRE0N3D           NaN  NaN
# 9  <@U01RS9Y6UJH> has joined the channel  U01RSRE0N3D           NaN  NaN
#
#   user_team source_team  ... blocks thread_ts  reply_count  reply_users_count  \
# 0       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 1       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 2       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 3       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 4       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 5       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 6       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 7       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 8       NaN         NaN  ...    NaN       NaN          NaN                NaN
# 9       NaN         NaN  ...    NaN       NaN          NaN                NaN
#
#    latest_reply  reply_users replies is_locked  subscribed  parent_user_id
# 0           NaN          NaN     NaN       NaN         NaN             NaN
# 1           NaN          NaN     NaN       NaN         NaN             NaN
# 2           NaN          NaN     NaN       NaN         NaN             NaN
# 3           NaN          NaN     NaN       NaN         NaN             NaN
# 4           NaN          NaN     NaN       NaN         NaN             NaN
# 5           NaN          NaN     NaN       NaN         NaN             NaN
# 6           NaN          NaN     NaN       NaN         NaN             NaN
# 7           NaN          NaN     NaN       NaN         NaN             NaN
# 8           NaN          NaN     NaN       NaN         NaN             NaN
# 9           NaN          NaN     NaN       NaN         NaN             NaN
#
# [10 rows x 21 columns]

# %%
# save to csv
channel_finalproject.to_csv(r'../data/final-project/finalproject.csv', index = False)

# %% [markdown]
# ### channel_frustrations

# %%
### frustrations-shared channel
# defining file path
path_to_json = '../data/frustrations-shared/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_frustrations = pd.concat(dfs, ignore_index=True)
# test
channel_frustrations
# Out:
#       type          subtype            ts         user  \
# 0  message     channel_join  1.616696e+09  U01S133DZ9A
# 1  message  channel_purpose  1.616696e+09  U01S133DZ9A
# 2  message              NaN  1.616696e+09  U01S133DZ9A
#
#                                                 text  \
# 0              <@U01S133DZ9A> has joined the channel
# 1  <@U01S133DZ9A> set the channel description: A ...
# 2  Finally got my files to upload to github.\nWhy...
#
#                                              purpose  \
# 0                                                NaN
# 1  A place to vent your frustration with the worl...
# 2                                                NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  9325906b-46b4-4d98-82e9-d8475aaca20b  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  T01RBRV5F7H  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                               edited  \
# 0                                                NaN
# 1                                                NaN
# 2  {'user': 'U01S133DZ9A', 'ts': '1616695732.0000...
#
#                                               blocks
# 0                                                NaN
# 1                                                NaN
# 2  [{'type': 'rich_text', 'block_id': 'NFV', 'ele...

# %%
# save to csv
channel_frustrations.to_csv(r'../data/frustrations-shared/frustrations.csv', index = False)

# %% [markdown]
# ### channel_funcommittee

# %%
### fun_committee channel
# defining file path
path_to_json = '../data/fun_committee/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_funcommittee = pd.concat(dfs, ignore_index=True)
# test
channel_funcommittee
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619595e+09  U01S7KCL3DF
# 2    message           NaN  1.617614e+09  U01SK96QF5E
# 3    message           NaN  1.617615e+09  U01RRV4JX6Z
# 4    message           NaN  1.617615e+09  U01S0E0MRJ7
# ..       ...           ...           ...          ...
# 147  message           NaN  1.619546e+09  U01RW2X7S9Z
# 148  message           NaN  1.619547e+09  U01S7KCL3DF
# 149  message           NaN  1.619547e+09  U01RXCQHMHT
# 150  message  channel_join  1.616166e+09  U01RNEU3SNA
# 151  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    in case anyone is hungry for feijoada on satur...
# 2    What did you guys do for Easter? :eyes: I went...
# 3    Its astonishing how Alpacas/Llamas/vicunas are...
# 4                                easter egg coloring:)
# ..                                                 ...
# 147                 this is what i'm needing right now
# 148                       Thank you Japanese fisherman
# 149      <https://www.youtube.com/watch?v=ZXsQAXx_ao0>
# 150              <@U01RNEU3SNA> has joined the channel
# 151              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    38b1be29-6601-49f2-9ec2-a99524c9484d  T01RBRV5F7H  T01RBRV5F7H
# 2    6C6C6CE9-8155-4728-A64B-83ABECAC9A7F          NaN          NaN
# 3    1ea1e83f-b494-493b-80a2-deacfa2f3d26  T01RBRV5F7H  T01RBRV5F7H
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 147  2aabb6c6-f8be-4294-b2d1-546622c56aa8  T01RBRV5F7H  T01RBRV5F7H
# 148  0d88d0f4-2fca-45ab-829e-2c61f762b0c9  T01RBRV5F7H  T01RBRV5F7H
# 149  6352006c-7e75-46fc-868c-8f57a72663c2  T01RBRV5F7H  T01RBRV5F7H
# 150                                   NaN          NaN          NaN
# 151                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 2            NaN                                                NaN  ...
# 3    T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 147  T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# 148  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 149  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 150          NaN                                                NaN  ...
# 151          NaN                                                NaN  ...
#
#                                                replies is_locked subscribed  \
# 0                                                  NaN       NaN        NaN
# 1                                                  NaN       NaN        NaN
# 2    [{'user': 'U01RRV4JX6Z', 'ts': '1617615034.003...       0.0        0.0
# 3                                                  NaN       NaN        NaN
# 4                                                  NaN       NaN        NaN
# ..                                                 ...       ...        ...
# 147                                                NaN       NaN        NaN
# 148                                                NaN       NaN        NaN
# 149                                                NaN       NaN        NaN
# 150                                                NaN       NaN        NaN
# 151                                                NaN       NaN        NaN
#
#     parent_user_id bot_id  bot_profile  last_read  \
# 0              NaN    NaN          NaN        NaN
# 1              NaN    NaN          NaN        NaN
# 2              NaN    NaN          NaN        NaN
# 3      U01SK96QF5E    NaN          NaN        NaN
# 4      U01SK96QF5E    NaN          NaN        NaN
# ..             ...    ...          ...        ...
# 147    U01RXCQHMHT    NaN          NaN        NaN
# 148    U01RXCQHMHT    NaN          NaN        NaN
# 149            NaN    NaN          NaN        NaN
# 150            NaN    NaN          NaN        NaN
# 151            NaN    NaN          NaN        NaN
#
#                                            attachments  edited inviter
# 0                                                  NaN     NaN     NaN
# 1                                                  NaN     NaN     NaN
# 2                                                  NaN     NaN     NaN
# 3                                                  NaN     NaN     NaN
# 4                                                  NaN     NaN     NaN
# ..                                                 ...     ...     ...
# 147                                                NaN     NaN     NaN
# 148                                                NaN     NaN     NaN
# 149  [{'service_name': 'YouTube', 'service_url': 'h...     NaN     NaN
# 150                                                NaN     NaN     NaN
# 151                                                NaN     NaN     NaN
#
# [152 rows x 30 columns]

# %%
# save to csv
channel_funcommittee.to_csv(r'../data/fun_committee/channel_funcommittee.csv', index = False)

# %% [markdown]
# ### channel_katas

# %%
### katas channel
# defining file path
path_to_json = '../data/katas/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_katas = pd.concat(dfs, ignore_index=True)
# test
channel_katas
# Out:
#                             client_msg_id     type  \
# 0    593fe4d1-4a6b-4827-9c53-260376d6493f  message
# 1    c2d95c8b-3e50-4d48-8135-648704bf35d3  message
# 2    33452e06-616f-439e-9ad6-02aeb31269b5  message
# 3    67dc2652-03b5-4f43-b826-e8883ea5bc58  message
# 4    b63eafaf-fd31-4a13-b26b-81ee65d897fd  message
# ..                                    ...      ...
# 141  2be1b256-f82f-4595-9bac-52058ec61358  message
# 142  ffcf0cf8-92a3-4235-8210-0dd5421d4f4c  message
# 143  627524f7-2692-4e03-a542-61c3f55d6d67  message
# 144  dbd3a788-8ac0-4da3-b16e-5acd857ab571  message
# 145  a98df046-4c44-4bf2-ae2c-1a1f970dee86  message
#
#                                                   text         user  \
# 0    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01RSRE0N3D
# 1                               Who was first? :smile:  U01S7BM4N81
# 2                                         Where is it?  U01RRV4JX6Z
# 3    <https://www.codewars.com/kata/57a0556c7cb1f31...  U01SD3CDH9P
# 4    to know the answer or to put the tick? :girl-g...  U01RW2X7S9Z
# ..                                                 ...          ...
# 141  no… you might find people do and on a new line...  U01RW140HBP
# 142  <https://www.codewars.com/kata/5a8ed96bfd8c066...  U01RSRE0N3D
# 143  ```hint… WHERE country IN('United States of Am...  U01RW140HBP
# 144  <https://www.codewars.com/kata/5abcf0f930488ff...  U01SJKB2MG8
# 145                                     :harry-potter:  U01RW140HBP
#
#                ts         team    user_team  source_team  \
# 0    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4    1.618229e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 141  1.617715e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 142  1.617798e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 143  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 144  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 145  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 2    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    {'avatar_hash': '735d50ad8f34', 'image_72': 'h...
# 4    {'avatar_hash': '7e12d75d168a', 'image_72': 'h...
# ..                                                 ...
# 141  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 142  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 143  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 144  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 145  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#                                            attachments  ...  \
# 0    [{'service_name': 'Codewars', 'title': 'Traini...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 141                                                NaN  ...
# 142  [{'service_name': 'Codewars', 'title': 'Traini...  ...
# 143                                                NaN  ...
# 144  [{'service_name': 'Codewars', 'title': 'SQL wi...  ...
# 145                                                NaN  ...
#
#                                                 edited  parent_user_id  \
# 0                                                  NaN             NaN
# 1    {'user': 'U01S7BM4N81', 'ts': '1618229077.0000...     U01RSRE0N3D
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN     U01RSRE0N3D
# ..                                                 ...             ...
# 141                                                NaN     U01SJKB2MG8
# 142                                                NaN             NaN
# 143                                                NaN     U01RSRE0N3D
# 144                                                NaN             NaN
# 145                                                NaN     U01SJKB2MG8
#
#      bot_id  bot_profile  files upload display_as_bot  subtype  inviter  topic
# 0       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 1       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 2       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 3       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 4       NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# ..      ...          ...    ...    ...            ...      ...      ...    ...
# 141     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 142     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 143     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 144     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
# 145     NaN          NaN    NaN    NaN            NaN      NaN      NaN    NaN
#
# [146 rows x 31 columns]

# %%
# save to csv
channel_katas.to_csv(r'../data/katas/channel_katas.csv', index = False)

# %% [markdown]
# ### channel_labhelp

# %%
### lab-help channel
# defining file path
path_to_json = '../data/lab-help/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_labhelp = pd.concat(dfs, ignore_index=True)
# test
channel_labhelp
# Out:
#          type       subtype            ts         user  \
# 0     message  channel_join  1.616237e+09  U01S1CWGTU4
# 1     message           NaN  1.617866e+09  U01S79YDELR
# 2     message           NaN  1.617866e+09  U01RW140HBP
# 3     message           NaN  1.617867e+09  U01RW140HBP
# 4     message           NaN  1.617867e+09  U01S79YDELR
# ...       ...           ...           ...          ...
# 1455  message           NaN  1.619542e+09  U01S0E0MRJ7
# 1456  message           NaN  1.619543e+09  U01RW140HBP
# 1457  message           NaN  1.619543e+09  U01RW140HBP
# 1458  message           NaN  1.619543e+09  U01S0E0MRJ7
# 1459  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                    text  \
# 0                 <@U01S1CWGTU4> has joined the channel
# 1     <@U01RSRE0N3D>  <https://www.ibm.com/docs/en/i...
# 2     we will do more on this today in the lesson Ka...
# 3     ok no problem we will revisit rank this mornin...
# 4     it is the syntax in dbeaver, sakila is the dat...
# ...                                                 ...
# 1455  hey im confused. what is this data? i was work...
# 1456  i think Andrea decided to work on a dashboard ...
# 1457                so this is from the superstore data
# 1458  ah ok NP I just saw Phine also had US map and ...
# 1459              <@U01RW2X7S9Z> has joined the channel
#
#                              client_msg_id         team    user_team  \
# 0                                      NaN          NaN          NaN
# 1     d1f113e1-d517-427f-8f17-a8b2695ca580  T01RBRV5F7H  T01RBRV5F7H
# 2     547c153e-d251-492f-8502-81a3b04809cb  T01RBRV5F7H  T01RBRV5F7H
# 3     e04e1c54-28fd-46a3-a61e-f2c976be85d6  T01RBRV5F7H  T01RBRV5F7H
# 4     90ed80d9-2e55-4f1d-ad2c-52f112e8f70f  T01RBRV5F7H  T01RBRV5F7H
# ...                                    ...          ...          ...
# 1455  e1c01335-c973-43d8-b462-161e3735243c  T01RBRV5F7H  T01RBRV5F7H
# 1456  233723f5-fe02-4f1c-8b08-1de2b2913610  T01RBRV5F7H  T01RBRV5F7H
# 1457  a02ee96f-e064-45d8-ac54-dab50887a95e  T01RBRV5F7H  T01RBRV5F7H
# 1458  9214dcbf-8ffe-447b-b970-c182e7260801  T01RBRV5F7H  T01RBRV5F7H
# 1459                                   NaN          NaN          NaN
#
#       source_team                                       user_profile  ...  \
# 0             NaN                                                NaN  ...
# 1     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 3     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 4     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# ...           ...                                                ...  ...
# 1455  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1456  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1457  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1458  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1459          NaN                                                NaN  ...
#
#      attachments last_read  bot_id bot_profile root  old_name  name  inviter  \
# 0            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 2            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 3            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 4            NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# ...          ...       ...     ...         ...  ...       ...   ...      ...
# 1455         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1456         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1457         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1458         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1459         NaN       NaN     NaN         NaN  NaN       NaN   NaN      NaN
#
#      hidden x_files
# 0       NaN     NaN
# 1       NaN     NaN
# 2       NaN     NaN
# 3       NaN     NaN
# 4       NaN     NaN
# ...     ...     ...
# 1455    NaN     NaN
# 1456    NaN     NaN
# 1457    NaN     NaN
# 1458    NaN     NaN
# 1459    NaN     NaN
#
# [1460 rows x 35 columns]

# %%
# save to csv
channel_labhelp.to_csv(r'../data/lab-help/channel_labhelp.csv', index = False)

# %% [markdown]
# ### channel_music

# %%
### music channel
# defining file path
path_to_json = '../data/music/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_music = pd.concat(dfs, ignore_index=True)
# test
channel_music
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.617897e+09  U01S7BM4N81
# 2    message           NaN  1.620200e+09  U01S7KCL3DF
# 3    message           NaN  1.620211e+09  U01RSRE0N3D
# 4    message           NaN  1.620213e+09  U01RW2X7S9Z
# ..       ...           ...           ...          ...
# 157  message           NaN  1.619530e+09  U01RXCQHMHT
# 158  message           NaN  1.619535e+09  U01SK96QF5E
# 159  message           NaN  1.619554e+09  U01RXCQHMHT
# 160  message           NaN  1.619586e+09  U01RXCQHMHT
# 161  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1        <https://www.youtube.com/watch?v=qW1eTP9CKSE>
# 2    <@U01RXCQHMHT> here’s a bangin track about Nig...
# 3    For all of you LotR ravers\n<https://www.youtu...
# 4    my recommender:\n`input("introduce your song:"...
# ..                                                 ...
# 157  someone showed me a video from the pre-corona ...
# 158  got totally addicted to this playlist since Fr...
# 159  <https://www.youtube.com/watch?v=HeyfOEb7ET0&a...
# 160  <https://soundcloud.com/hate_music/premiere-vo...
# 161              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 2    a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 3    41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# 4    003f3fc9-1d77-4811-9017-68c20dd995bd  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 157  3bd07a1a-d9b4-401a-ab6d-9da03d5c109c  T01RBRV5F7H  T01RBRV5F7H
# 158  d8b6518c-f8d6-4527-b70d-8eceee1bb1df  T01RBRV5F7H  T01RBRV5F7H
# 159  d255756e-a269-4280-9ca6-5f50b2b1cabf  T01RBRV5F7H  T01RBRV5F7H
# 160  3079ffd3-2d1e-41db-a66e-a611d080d371  T01RBRV5F7H  T01RBRV5F7H
# 161                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 3    T01RBRV5F7H  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...  ...
# 4    T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# ..           ...                                                ...  ...
# 157  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 158  T01RBRV5F7H  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...  ...
# 159  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 160  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 161          NaN                                                NaN  ...
#
#     subscribed     last_read  \
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          1.0  1.620242e+09
# 4          NaN           NaN
# ..         ...           ...
# 157        NaN           NaN
# 158        NaN           NaN
# 159        NaN           NaN
# 160        NaN           NaN
# 161        NaN           NaN
#
#                                              reactions  parent_user_id  files  \
# 0                                                  NaN             NaN    NaN
# 1                                                  NaN             NaN    NaN
# 2                                                  NaN             NaN    NaN
# 3    [{'name': 'white_check_mark', 'users': ['U01RW...             NaN    NaN
# 4    [{'name': 'rickroll', 'users': ['U01RSRE0N3D',...     U01RSRE0N3D    NaN
# ..                                                 ...             ...    ...
# 157                                                NaN     U01RXCQHMHT    NaN
# 158  [{'name': 'man_dancing', 'users': ['U01RW140HB...             NaN    NaN
# 159                                                NaN             NaN    NaN
# 160                                                NaN             NaN    NaN
# 161                                                NaN             NaN    NaN
#
#      upload  display_as_bot bot_id bot_profile inviter
# 0       NaN             NaN    NaN         NaN     NaN
# 1       NaN             NaN    NaN         NaN     NaN
# 2       NaN             NaN    NaN         NaN     NaN
# 3       NaN             NaN    NaN         NaN     NaN
# 4       NaN             NaN    NaN         NaN     NaN
# ..      ...             ...    ...         ...     ...
# 157     NaN             NaN    NaN         NaN     NaN
# 158     NaN             NaN    NaN         NaN     NaN
# 159     NaN             NaN    NaN         NaN     NaN
# 160     NaN             NaN    NaN         NaN     NaN
# 161     NaN             NaN    NaN         NaN     NaN
#
# [162 rows x 30 columns]

# %%
# save to csv
channel_music.to_csv(r'../data/music/channel_music.csv', index = False)

# %% [markdown]
# ### channel_random

# %%
### random channel
# defining file path
path_to_json = '../data/random/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_random = pd.concat(dfs, ignore_index=True)
# test
channel_random
# Out:
#         type                                               text  \
# 0    message                                     <@U01S7BM4N81>
# 1    message  decentralized (which is the original spirit of...
# 2    message  leute we’re missing the bigger picture….Gold, ...
# 3    message                       Oooof how could I miss this?
# 4    message  I think it very much depends on the issuing co...
# ..       ...                                                ...
# 422  message              <@U01RNEU3SNA> has joined the channel
# 423  message              <@U01RS9Y6UJH> has joined the channel
# 424  message              <@U01SK96QF5E> has joined the channel
# 425  message              <@U01RP2K1606> has joined the channel
# 426  message              <@U01RW2X7S9Z> has joined the channel
#
#                                                  files upload  \
# 0    [{'id': 'F021HK4BWG4', 'created': 1620544574, ...    0.0
# 1                                                  NaN    NaN
# 2    [{'id': 'F0218DDJN7P', 'created': 1620549030, ...    0.0
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 422                                                NaN    NaN
# 423                                                NaN    NaN
# 424                                                NaN    NaN
# 425                                                NaN    NaN
# 426                                                NaN    NaN
#
#                                                 blocks         user  \
# 0    [{'type': 'rich_text', 'block_id': 'p4HE', 'el...  U01RRV4JX6Z
# 1    [{'type': 'rich_text', 'block_id': 'Fal', 'ele...  U01S7BM4N81
# 2    [{'type': 'rich_text', 'block_id': 'aFRzS', 'e...  U01S7KCL3DF
# 3    [{'type': 'rich_text', 'block_id': 'mgxv', 'el...  U01S7BM4N81
# 4    [{'type': 'rich_text', 'block_id': 'OMH/u', 'e...  U01RRV4JX6Z
# ..                                                 ...          ...
# 422                                                NaN  U01RNEU3SNA
# 423                                                NaN  U01RS9Y6UJH
# 424                                                NaN  U01SK96QF5E
# 425                                                NaN  U01RP2K1606
# 426                                                NaN  U01RW2X7S9Z
#
#      display_as_bot            ts                         client_msg_id  \
# 0               0.0  1.620545e+09  dd000aef-264c-4bd5-8426-e1e08552643b
# 1               NaN  1.620546e+09  0ad68149-64a1-454e-9e9c-6abf8c3d185c
# 2               0.0  1.620549e+09                                   NaN
# 3               NaN  1.620551e+09  579D4E6F-0E09-4FC7-A811-656CC403647F
# 4               NaN  1.620555e+09  78e0293a-be09-4b28-bf3d-2f70ab3b48fb
# ..              ...           ...                                   ...
# 422             NaN  1.616166e+09                                   NaN
# 423             NaN  1.616167e+09                                   NaN
# 424             NaN  1.616168e+09                                   NaN
# 425             NaN  1.616172e+09                                   NaN
# 426             NaN  1.616172e+09                                   NaN
#
#         thread_ts  ...  source_team  \
# 0    1.620545e+09  ...          NaN
# 1    1.620545e+09  ...  T01RBRV5F7H
# 2    1.620369e+09  ...          NaN
# 3    1.620369e+09  ...  T01RBRV5F7H
# 4    1.620545e+09  ...  T01RBRV5F7H
# ..            ...  ...          ...
# 422           NaN  ...          NaN
# 423           NaN  ...          NaN
# 424           NaN  ...          NaN
# 425           NaN  ...          NaN
# 426           NaN  ...          NaN
#
#                                           user_profile  parent_user_id  \
# 0                                                  NaN             NaN
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RRV4JX6Z
# 2                                                  NaN     U01RN7BVD1C
# 3    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RN7BVD1C
# 4    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...     U01RRV4JX6Z
# ..                                                 ...             ...
# 422                                                NaN             NaN
# 423                                                NaN             NaN
# 424                                                NaN             NaN
# 425                                                NaN             NaN
# 426                                                NaN             NaN
#
#                                              reactions edited  attachments  \
# 0                                                  NaN    NaN          NaN
# 1    [{'name': 'dart', 'users': ['U01S1CWGTU4'], 'c...    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3    [{'name': 'stonks', 'users': ['U01S7KCL3DF', '...    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 422                                                NaN    NaN          NaN
# 423                                                NaN    NaN          NaN
# 424                                                NaN    NaN          NaN
# 425                                                NaN    NaN          NaN
# 426                                                NaN    NaN          NaN
#
#      last_read bot_id bot_profile       subtype
# 0          NaN    NaN         NaN           NaN
# 1          NaN    NaN         NaN           NaN
# 2          NaN    NaN         NaN           NaN
# 3          NaN    NaN         NaN           NaN
# 4          NaN    NaN         NaN           NaN
# ..         ...    ...         ...           ...
# 422        NaN    NaN         NaN  channel_join
# 423        NaN    NaN         NaN  channel_join
# 424        NaN    NaN         NaN  channel_join
# 425        NaN    NaN         NaN  channel_join
# 426        NaN    NaN         NaN  channel_join
#
# [427 rows x 29 columns]

# %%
# save to csv
channel_random.to_csv(r'../data/random/channel_random.csv', index = False)

# %% [markdown]
# ### channel_vanilla

# %%
### vanilla_plus_more channel
# defining file path
path_to_json = '../data/vanilla_plus_more/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_vanilla = pd.concat(dfs, ignore_index=True)
# test
channel_vanilla
# Out:
#                            client_msg_id     type  \
# 0   8e064300-53cc-41fc-ba3d-4e91e2c08c29  message
# 1                                    NaN  message
# 2                                    NaN  message
# 3                                    NaN  message
# 4                                    NaN  message
# 5                                    NaN  message
# 6                                    NaN  message
# 7   4fa27f27-ab48-484f-a533-618372e1fc2a  message
# 8   ee7a5ff1-78a3-405f-9708-cdd1341e63fe  message
# 9                                    NaN  message
# 10                                   NaN  message
# 11                                   NaN  message
# 12  d4dbab7e-4cf4-41b2-a757-cb742906e69c  message
# 13                                   NaN  message
# 14                                   NaN  message
# 15                                   NaN  message
# 16                                   NaN  message
# 17                                   NaN  message
# 18  91408448-9d71-4e9c-b843-027ac87d700a  message
# 19                                   NaN  message
# 20                                   NaN  message
# 21                                   NaN  message
# 22  7d6a7c94-05cd-4f77-90cd-b0ea898dcf51  message
# 23                                   NaN  message
# 24  bf443b38-0344-4475-8566-cff212d62e95  message
# 25  3d4e6b69-bf6c-4c44-9b3f-73d06a942f56  message
# 26  688c219f-d79d-4d97-90b1-4775ca9fc066  message
# 27  8379b0d9-3f32-4640-b862-bfc145490afa  message
# 28  2e58f4f3-c217-424a-a2bf-b5e8ae0599ae  message
# 29  479b925a-b941-42c6-99a1-ba3f6101cd91  message
# 30  8ef58321-5220-46aa-9f53-f0df443cd398  message
# 31  e40bbb01-efc0-4ab9-a7dd-665bf168af0c  message
#
#                                                  text         user  \
# 0   I think there's no need in treating Pandas as ...  U01SJKB2MG8
# 1               <@U01RW140HBP> has joined the channel  U01RW140HBP
# 2   <@U01RW140HBP> set the channel description: th...  U01RW140HBP
# 3               <@U01SJKB2MG8> has joined the channel  U01SJKB2MG8
# 4               <@U01RSRE0N3D> has joined the channel  U01RSRE0N3D
# 5                                                      U01SJKB2MG8
# 6               <@U01RKN0EGDV> has joined the channel  U01RKN0EGDV
# 7   Pandas intro on Kaggle - this is a great littl...  U01RW140HBP
# 8                might be good for you <@U01S79YDELR>  U01RW140HBP
# 9               <@U01S79YDELR> has joined the channel  U01S79YDELR
# 10              <@U01S7KCL3DF> has joined the channel  U01S7KCL3DF
# 11              <@U01S133DZ9A> has joined the channel  U01S133DZ9A
# 12  if you find yourself asking: “what are these *...  U01RW140HBP
# 13                                   generic dtypes :  U01RW140HBP
# 14                                    python dtypes :  U01RW140HBP
# 15                                     mysql dtypes :  U01RW140HBP
# 16                                   tableau dtypes :  U01RW140HBP
# 17              <@U01S0MFJ3HR> has joined the channel  U01S0MFJ3HR
# 18  a quick bonus lab on STRINGS <https://github.c...  U01RW140HBP
# 19              <@U01RV3K524T> has joined the channel  U01RV3K524T
# 20              <@U01SD3CDH9P> has joined the channel  U01SD3CDH9P
# 21              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 22  1.5 hours in. I'm struggling with Question 2. ...  U01S133DZ9A
# 23              <@U01RN7BVD1C> has joined the channel  U01RN7BVD1C
# 24  thats ok… we can do a breakout call and go thr...  U01RW140HBP
# 25  i’ve been going back over the Kaggles chapters...  U01S7KCL3DF
# 26  or ask one of the TAs to do the same with you,...  U01RW140HBP
# 27                              Just saw this. Thanks  U01S133DZ9A
# 28  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 29          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 30      I will have a look after the presentation :v:  U01RSRE0N3D
# 31  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#               ts         team    user_team  source_team  \
# 0   1.617869e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1.617637e+09          NaN          NaN          NaN
# 2   1.617637e+09          NaN          NaN          NaN
# 3   1.617637e+09          NaN          NaN          NaN
# 4   1.617637e+09          NaN          NaN          NaN
# 5   1.617637e+09          NaN          NaN          NaN
# 6   1.617637e+09          NaN          NaN          NaN
# 7   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9   1.617637e+09          NaN          NaN          NaN
# 10  1.617637e+09          NaN          NaN          NaN
# 11  1.617638e+09          NaN          NaN          NaN
# 12  1.617638e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 13  1.617638e+09          NaN          NaN          NaN
# 14  1.617638e+09          NaN          NaN          NaN
# 15  1.617638e+09          NaN          NaN          NaN
# 16  1.617638e+09          NaN          NaN          NaN
# 17  1.617638e+09          NaN          NaN          NaN
# 18  1.617639e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 19  1.617644e+09          NaN          NaN          NaN
# 20  1.617644e+09          NaN          NaN          NaN
# 21  1.617652e+09          NaN          NaN          NaN
# 22  1.617658e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 23  1.617691e+09          NaN          NaN          NaN
# 24  1.617692e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 25  1.619986e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 26  1.617693e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 27  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 28  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 29  1.620399e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 30  1.620400e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 31  1.617832e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                          user_profile  \
# 0   {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 8   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 23                                                NaN
# 24  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 25  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 26  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 27  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 28  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 29  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 30  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 31  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                                edited  ... display_as_bot  \
# 0   {'user': 'U01SJKB2MG8', 'ts': '1617869310.0000...  ...            NaN
# 1                                                 NaN  ...            NaN
# 2                                                 NaN  ...            NaN
# 3                                                 NaN  ...            NaN
# 4                                                 NaN  ...            NaN
# 5                                                 NaN  ...            0.0
# 6                                                 NaN  ...            NaN
# 7                                                 NaN  ...            NaN
# 8                                                 NaN  ...            NaN
# 9                                                 NaN  ...            NaN
# 10                                                NaN  ...            NaN
# 11                                                NaN  ...            NaN
# 12  {'user': 'U01RW140HBP', 'ts': '1617638000.0000...  ...            NaN
# 13                                                NaN  ...            0.0
# 14                                                NaN  ...            0.0
# 15                                                NaN  ...            0.0
# 16                                                NaN  ...            0.0
# 17                                                NaN  ...            NaN
# 18  {'user': 'U01RW140HBP', 'ts': '1617638650.0000...  ...            NaN
# 19                                                NaN  ...            NaN
# 20                                                NaN  ...            NaN
# 21                                                NaN  ...            NaN
# 22                                                NaN  ...            NaN
# 23                                                NaN  ...            NaN
# 24                                                NaN  ...            NaN
# 25                                                NaN  ...            NaN
# 26                                                NaN  ...            NaN
# 27                                                NaN  ...            NaN
# 28                                                NaN  ...            NaN
# 29                                                NaN  ...            NaN
# 30                                                NaN  ...            NaN
# 31                                                NaN  ...            NaN
#
#                                           attachments reply_count  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7   [{'title': 'Learn Pandas Tutorials', 'title_li...         1.0
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         4.0
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18                                                NaN         5.0
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25  [{'title': 'Summary Functions and Maps', 'titl...         2.0
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         1.0
#
#    reply_users_count  latest_reply                 reply_users  \
# 0                NaN           NaN                         NaN
# 1                NaN           NaN                         NaN
# 2                NaN           NaN                         NaN
# 3                NaN           NaN                         NaN
# 4                NaN           NaN                         NaN
# 5                NaN           NaN                         NaN
# 6                NaN           NaN                         NaN
# 7                1.0  1.617637e+09               [U01RW140HBP]
# 8                NaN           NaN                         NaN
# 9                NaN           NaN                         NaN
# 10               NaN           NaN                         NaN
# 11               NaN           NaN                         NaN
# 12               1.0  1.617638e+09               [U01RW140HBP]
# 13               NaN           NaN                         NaN
# 14               NaN           NaN                         NaN
# 15               NaN           NaN                         NaN
# 16               NaN           NaN                         NaN
# 17               NaN           NaN                         NaN
# 18               2.0  1.617727e+09  [U01S133DZ9A, U01RW140HBP]
# 19               NaN           NaN                         NaN
# 20               NaN           NaN                         NaN
# 21               NaN           NaN                         NaN
# 22               NaN           NaN                         NaN
# 23               NaN           NaN                         NaN
# 24               NaN           NaN                         NaN
# 25               2.0  1.620400e+09  [U01S7KCL3DF, U01RSRE0N3D]
# 26               NaN           NaN                         NaN
# 27               NaN           NaN                         NaN
# 28               NaN           NaN                         NaN
# 29               NaN           NaN                         NaN
# 30               NaN           NaN                         NaN
# 31               1.0  1.617869e+09               [U01SJKB2MG8]
#
#                                               replies is_locked  subscribed  \
# 0                                                 NaN       NaN         NaN
# 1                                                 NaN       NaN         NaN
# 2                                                 NaN       NaN         NaN
# 3                                                 NaN       NaN         NaN
# 4                                                 NaN       NaN         NaN
# 5                                                 NaN       NaN         NaN
# 6                                                 NaN       NaN         NaN
# 7   [{'user': 'U01RW140HBP', 'ts': '1617637354.002...       0.0         0.0
# 8                                                 NaN       NaN         NaN
# 9                                                 NaN       NaN         NaN
# 10                                                NaN       NaN         NaN
# 11                                                NaN       NaN         NaN
# 12  [{'user': 'U01RW140HBP', 'ts': '1617638007.007...       0.0         0.0
# 13                                                NaN       NaN         NaN
# 14                                                NaN       NaN         NaN
# 15                                                NaN       NaN         NaN
# 16                                                NaN       NaN         NaN
# 17                                                NaN       NaN         NaN
# 18  [{'user': 'U01S133DZ9A', 'ts': '1617658367.010...       0.0         0.0
# 19                                                NaN       NaN         NaN
# 20                                                NaN       NaN         NaN
# 21                                                NaN       NaN         NaN
# 22                                                NaN       NaN         NaN
# 23                                                NaN       NaN         NaN
# 24                                                NaN       NaN         NaN
# 25  [{'user': 'U01S7KCL3DF', 'ts': '1620398926.000...     False        True
# 26                                                NaN       NaN         NaN
# 27                                                NaN       NaN         NaN
# 28                                                NaN       NaN         NaN
# 29                                                NaN       NaN         NaN
# 30                                                NaN       NaN         NaN
# 31  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...     False       False
#
#        last_read
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25  1.620399e+09
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
#
# [32 rows x 29 columns]

# %%
# save to csv
channel_vanilla.to_csv(r'../data/vanilla_plus_more/channel_vanilla.csv', index = False)
