# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %%
# this does the job for getting one json into a df
import pandas as pd
with open('/Users/lilmac/Documents/GitHub/ironhack-final-project/data/lab-help/2021-05-06.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)

# %%
# test
df.head(100)
# Out:
#                            client_msg_id     type  \
# 0   2e23f826-a499-4e37-910e-627f3aec0ac8  message
# 1   ea9c592b-a12a-41cf-824e-a0c9d3b556e0  message
# 2   a8f693bc-d917-40ac-ab2a-f750cde61a15  message
# 3   87d43ab5-96e1-4ce9-a777-2ff40f566f70  message
# 4   7501ab8d-764f-4085-b89c-608d5316426e  message
# ..                                   ...      ...
# 95  eeec0f81-76b3-40db-91c7-3e8818b3bc0c  message
# 96  4453aca7-35a3-4fae-8088-56b81878326b  message
# 97  e8136542-b3c9-4f4b-b1f3-67177c522dc6  message
# 98  9b8c94c2-f438-4d97-983d-49dec6333c89  message
# 99                                   NaN  message
#
#                                                  text         user  \
# 0   <@U01RN7BVD1C> it might be a bit easier if you...  U01S7BM4N81
# 1   yeah thats also a better idea haha, thanks!\nI...  U01RN7BVD1C
# 2   I gave up on that riddle, but if you are able ...  U01S7BM4N81
# 3           yeah I might also just skip that for now.  U01RN7BVD1C
# 4   Is it possible to create an index in which the...  U01RRV4JX6Z
# ..                                                ...          ...
# 95  Alex, one more question, how did you unpack th...  U01S7BM4N81
# 96  ```\nsong =[ 3.34169084e-01,  2.94517180e-01, ...  U01SD3CDH9P
# 97                                  got it, nevermind  U01S7BM4N81
# 98  looks like you didnt train the model, but not ...  U01S7BM4N81
# 99  if i have 51 clusters it splits all my songs i...  U01S0E0MRJ7
#
#                    ts         team    user_team  source_team  \
# 0   1620284946.114700  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1620285012.114900  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2   1620285060.115100  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3   1620285459.115300  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4   1620291711.116300  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..                ...          ...          ...          ...
# 95  1620312175.160400  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 96  1620312392.160600  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 97  1620312600.160800  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 98  1620312971.161000  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 99  1620313115.161200          NaN          NaN          NaN
#
#                                          user_profile  \
# 0   {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 1   {'avatar_hash': '55e0c1b57456', 'image_72': 'h...
# 2   {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 3   {'avatar_hash': '55e0c1b57456', 'image_72': 'h...
# 4   {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ..                                                ...
# 95  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 96  {'avatar_hash': '735d50ad8f34', 'image_72': 'h...
# 97  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 98  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 99                                                NaN
#
#                                                blocks  ...  \
# 0   [{'type': 'rich_text', 'block_id': '0QIJ', 'el...  ...
# 1   [{'type': 'rich_text', 'block_id': '7=t', 'ele...  ...
# 2   [{'type': 'rich_text', 'block_id': 'exL', 'ele...  ...
# 3   [{'type': 'rich_text', 'block_id': 'RKyun', 'e...  ...
# 4   [{'type': 'rich_text', 'block_id': 'W1V9', 'el...  ...
# ..                                                ...  ...
# 95  [{'type': 'rich_text', 'block_id': 'AU3Q', 'el...  ...
# 96  [{'type': 'rich_text', 'block_id': 'SY8x', 'el...  ...
# 97  [{'type': 'rich_text', 'block_id': '37LjK', 'e...  ...
# 98  [{'type': 'rich_text', 'block_id': 'xQP2', 'el...  ...
# 99  [{'type': 'rich_text', 'block_id': 'ahC', 'ele...  ...
#
#                                           reply_users  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [U01RW2X7S9Z, U01S7BM4N81, U01RRV4JX6Z, U01RW1...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                               replies is_locked  subscribed  \
# 0                                                 NaN       NaN         NaN
# 1                                                 NaN       NaN         NaN
# 2                                                 NaN       NaN         NaN
# 3                                                 NaN       NaN         NaN
# 4   [{'user': 'U01RW2X7S9Z', 'ts': '1620291741.116...     False       False
# ..                                                ...       ...         ...
# 95                                                NaN       NaN         NaN
# 96                                                NaN       NaN         NaN
# 97                                                NaN       NaN         NaN
# 98                                                NaN       NaN         NaN
# 99                                                NaN       NaN         NaN
#
#                                                 files upload display_as_bot  \
# 0                                                 NaN    NaN            NaN
# 1                                                 NaN    NaN            NaN
# 2                                                 NaN    NaN            NaN
# 3                                                 NaN    NaN            NaN
# 4                                                 NaN    NaN            NaN
# ..                                                ...    ...            ...
# 95                                                NaN    NaN            NaN
# 96                                                NaN    NaN            NaN
# 97                                                NaN    NaN            NaN
# 98                                                NaN    NaN            NaN
# 99  [{'id': 'F0210RF6VBP', 'created': 1620313112, ...  False          False
#
#    reactions attachments x_files
# 0        NaN         NaN     NaN
# 1        NaN         NaN     NaN
# 2        NaN         NaN     NaN
# 3        NaN         NaN     NaN
# 4        NaN         NaN     NaN
# ..       ...         ...     ...
# 95       NaN         NaN     NaN
# 96       NaN         NaN     NaN
# 97       NaN         NaN     NaN
# 98       NaN         NaN     NaN
# 99       NaN         NaN     NaN
#
# [100 rows x 26 columns]

# %%
# first try to get all json files into one dataframe from that folder, 
# not sure what this does, but doesn't get me all the columns
# file path shows that it should get all -> *

data = []

files = glob.glob('/Users/lilmac/Documents/GitHub/ironhack-final-project/data/general/*', recursive=True)

# Loop through files
for single_file in files:
    with open(single_file, 'r') as f:
        json_file = json.load(f)
df = pd.DataFrame(json_file)

# %%
# test 
df.head(100)
# Out:
#        type       subtype                 ts         user  \
# 0   message  channel_join  1616158729.000200  U01S79YDELR
# 1   message  channel_join  1616158788.000400  U01RUTP1ZQB
# 2   message  channel_join  1616159021.000700  U01RUU9SK4K
# 3   message  channel_join  1616159457.000900  U01S7BM4N81
# 4   message  channel_join  1616160530.001100  U01SJKB2MG8
# 5   message  channel_join  1616161193.001300  U01RV3K524T
# 6   message  channel_join  1616161614.001500  U01S133DZ9A
# 7   message  channel_join  1616162617.001700  U01RN7BVD1C
# 8   message  channel_join  1616162776.001900  U01S7KCL3DF
# 9   message  channel_join  1616165496.002400  U01S1CWGTU4
# 10  message  channel_join  1616165610.002600  U01RNEU3SNA
# 11  message  channel_join  1616167026.002800  U01RS9Y6UJH
# 12  message  channel_join  1616168064.003300  U01SK96QF5E
# 13  message  channel_join  1616172018.003700  U01RP2K1606
# 14  message  channel_join  1616172267.003900  U01RW2X7S9Z
#
#                                      text
# 0   <@U01S79YDELR> has joined the channel
# 1   <@U01RUTP1ZQB> has joined the channel
# 2   <@U01RUU9SK4K> has joined the channel
# 3   <@U01S7BM4N81> has joined the channel
# 4   <@U01SJKB2MG8> has joined the channel
# 5   <@U01RV3K524T> has joined the channel
# 6   <@U01S133DZ9A> has joined the channel
# 7   <@U01RN7BVD1C> has joined the channel
# 8   <@U01S7KCL3DF> has joined the channel
# 9   <@U01S1CWGTU4> has joined the channel
# 10  <@U01RNEU3SNA> has joined the channel
# 11  <@U01RS9Y6UJH> has joined the channel
# 12  <@U01SK96QF5E> has joined the channel
# 13  <@U01RP2K1606> has joined the channel
# 14  <@U01RW2X7S9Z> has joined the channel

# %%
# second try, again, not sure why it doesn't work but it should get all files into a df

path_to_json = '/Users/lilmac/Documents/GitHub/ironhack-final-project/data/general/*.json' 

json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# %%
dfs = [] # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file, lines=True) # read data frame from json file
    dfs.append(data) # append the data frame to the list

temp = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-102877058c7a> in <module>
#       4     dfs.append(data) # append the data frame to the list
#       5
# ----> 6 temp = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     340
#     341         if len(objs) == 0:
# --> 342             raise ValueError("No objects to concatenate")
#     343
#     344         if keys is None:
#
# ValueError: No objects to concatenate
