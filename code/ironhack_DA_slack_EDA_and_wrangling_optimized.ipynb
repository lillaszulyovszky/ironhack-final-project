# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp
#
# ## Wrangle Data
# - create a couple of boolean columns from reactions, files, attachments, replies

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe with all the channels in it

# %%
main_folder_path = '../raw_data' 

def parse_all_json(main_folder_path):
    df = pd.DataFrame()

### Iterate through the group of folders
    for folder in os.listdir(main_folder_path):
        folder_path = os.path.join(main_folder_path, folder)
        
        if os.path.isdir(folder_path):
## Iterate through each individual folder
            for file in os.listdir(folder_path):
                file = os.path.join(main_folder_path, folder, file)
            
            #add a channel name column and add which folder is the value coming from: general, labhelp, 
                if file.endswith('.json'):
                    data = pd.read_json(file)
                    data['channel_name'] = folder
                    df = pd.concat([df, data])
    return df

#def get_text_content(df):
#return df['text']

#if __name__ == '__main__':
data = parse_all_json('../raw_data/')

# %% [markdown]
# ### Assessment

# %%
data.shape
# Out:
# (5185, 38)

# %%
data.head()
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616237e+09  U01S1CWGTU4
# 0  message           NaN  1.617897e+09  U01S7BM4N81
# 0  message           NaN  1.620900e+09  U01RXCQHMHT
# 0  message           NaN  1.620200e+09  U01S7KCL3DF
# 1  message           NaN  1.620211e+09  U01RSRE0N3D
#
#                                                 text channel_name  \
# 0              <@U01S1CWGTU4> has joined the channel        music
# 0      <https://www.youtube.com/watch?v=qW1eTP9CKSE>        music
# 0  A thematic name for a playlist\n\n<https://sou...        music
# 0  <@U01RXCQHMHT> here’s a bangin track about Nig...        music
# 1  For all of you LotR ravers\n<https://www.youtu...        music
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 0  98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 0  c097123a-a43a-47a7-8d6b-c4ed6574b2c6  T01RBRV5F7H  T01RBRV5F7H
# 0  a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 1  41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team  ... bot_id bot_profile inviter purpose topic  root  old_name  \
# 0          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0  T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0  T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0  T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 1  T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
#
#    name  x_files hidden
# 0   NaN      NaN    NaN
# 0   NaN      NaN    NaN
# 0   NaN      NaN    NaN
# 0   NaN      NaN    NaN
# 1   NaN      NaN    NaN
#
# [5 rows x 38 columns]

# %%
# assess column names
data.columns
# Out:
# Index(['type', 'subtype', 'ts', 'user', 'text', 'channel_name',
#        'client_msg_id', 'team', 'user_team', 'source_team', 'user_profile',
#        'attachments', 'blocks', 'edited', 'reactions', 'thread_ts',
#        'reply_count', 'reply_users_count', 'latest_reply', 'reply_users',
#        'replies', 'is_locked', 'subscribed', 'last_read', 'parent_user_id',
#        'files', 'upload', 'display_as_bot', 'bot_id', 'bot_profile', 'inviter',
#        'purpose', 'topic', 'root', 'old_name', 'name', 'x_files', 'hidden'],
#       dtype='object')

# %%
# make a copy
df = data.copy()

# %%
# assess column names
df.columns
# Out:
# Index(['type', 'subtype', 'ts', 'user', 'text', 'channel_name',
#        'client_msg_id', 'team', 'user_team', 'source_team', 'user_profile',
#        'attachments', 'blocks', 'edited', 'reactions', 'thread_ts',
#        'reply_count', 'reply_users_count', 'latest_reply', 'reply_users',
#        'replies', 'is_locked', 'subscribed', 'last_read', 'parent_user_id',
#        'files', 'upload', 'display_as_bot', 'bot_id', 'bot_profile', 'inviter',
#        'purpose', 'topic', 'root', 'old_name', 'name', 'x_files', 'hidden'],
#       dtype='object')

# %%
# check how many values each channel has
df.channel_name.value_counts()
# Out:
# lab-help                1777
# general                 1342
# random                   465
# data-memes               302
# data-viz-beauties        265
# music                    227
# data_resources           199
# katas                    172
# fun_committee            159
# final-project            134
# web-scraping-latino       37
# vanilla_plus_more         33
# project-storytelling      24
# rogue-squadron            21
# data-bootcamp             20
# books                      3
# frustrations-shared        3
# rogue-one                  2
# Name: channel_name, dtype: int64

# %%
# list of columns, their non-null objects and data type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5185 entries, 0 to 36
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               5185 non-null   object
#  1   subtype            338 non-null    object
#  2   ts                 5185 non-null   float64
#  3   user               5184 non-null   object
#  4   text               5185 non-null   object
#  5   channel_name       5185 non-null   object
#  6   client_msg_id      4279 non-null   object
#  7   team               4323 non-null   object
#  8   user_team          4227 non-null   object
#  9   source_team        4227 non-null   object
#  10  user_profile       4227 non-null   object
#  11  attachments        424 non-null    object
#  12  blocks             4668 non-null   object
#  13  edited             315 non-null    object
#  14  reactions          1096 non-null   object
#  15  thread_ts          3974 non-null   float64
#  16  reply_count        583 non-null    float64
#  17  reply_users_count  583 non-null    float64
#  18  latest_reply       583 non-null    float64
#  19  reply_users        583 non-null    object
#  20  replies            583 non-null    object
#  21  is_locked          583 non-null    float64
#  22  subscribed         583 non-null    float64
#  23  last_read          89 non-null     float64
#  24  parent_user_id     3369 non-null   object
#  25  files              524 non-null    object
#  26  upload             524 non-null    float64
#  27  display_as_bot     503 non-null    float64
#  28  bot_id             97 non-null     object
#  29  bot_profile        96 non-null     object
#  30  inviter            194 non-null    object
#  31  purpose            9 non-null      object
#  32  topic              9 non-null      object
#  33  root               2 non-null      object
#  34  old_name           2 non-null      object
#  35  name               2 non-null      object
#  36  x_files            2 non-null      object
#  37  hidden             1 non-null      float64
# dtypes: float64(11), object(27)
# memory usage: 1.5+ MB

# %%
#check if there are any null values in the dataset 
df.isna().mean().round(4) *100
# Out:
# type                  0.00
# subtype              93.48
# ts                    0.00
# user                  0.02
# text                  0.00
# channel_name          0.00
# client_msg_id        17.47
# team                 16.62
# user_team            18.48
# source_team          18.48
# user_profile         18.48
# attachments          91.82
# blocks                9.97
# edited               93.92
# reactions            78.86
# thread_ts            23.36
# reply_count          88.76
# reply_users_count    88.76
# latest_reply         88.76
# reply_users          88.76
# replies              88.76
# is_locked            88.76
# subscribed           88.76
# last_read            98.28
# parent_user_id       35.02
# files                89.89
# upload               89.89
# display_as_bot       90.30
# bot_id               98.13
# bot_profile          98.15
# inviter              96.26
# purpose              99.83
# topic                99.83
# root                 99.96
# old_name             99.96
# name                 99.96
# x_files              99.96
# hidden               99.98
# dtype: float64

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. The only important thing is that each value is coming from a user, and it is because I can see there are no missing values at the text or user columns. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
df['subtype'].value_counts()
# Out:
# channel_join         309
# channel_purpose        9
# channel_topic          9
# channel_archive        3
# channel_name           2
# thread_broadcast       2
# channel_unarchive      2
# tombstone              1
# bot_message            1
# Name: subtype, dtype: int64

# %% [markdown]
# **Summary of Assesment**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# **Columns to clean & wrangle:**\
#     - subtype: filter out it's values from df, remove the original column\
#     - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day\
#     - user_profile: extract real_name in new column, remove the original\
#     - attachments: extract title, text, link in new columns\
#     - files: extract url_private and who shared\
#     - attachments: extract title, text, link in new columns\
#     - reactions: extract user, count, name of the emoji\

# %%
df_clean = df.copy()

# %% [markdown]
# ### Cleaning

# %%
def clean_dataframe(df_clean):
    """this function is applied to clean the dataframe
    """
    # drop columns not needed
    df.drop(['type', 'client_msg_id', 'team', 'user_team',
             'source_team', 'blocks', 'upload', 'display_as_bot',
             'thread_ts', 'latest_reply', 'is_locked', 'subscribed',
             'parent_user_id', 'bot_id', 'bot_profile', 'last_read', 'edited',
             'purpose', 'inviter', 'topic', 'root', 'old_name', 'name', 'hidden',
             'x_files'], axis=1, inplace=True)
    
    # filter out for the rows which has subtype values
    df_clean = df[(df.subtype != 'channel_join') & 
                                (df.subtype != 'channel_join') &
                                (df.subtype != 'channel_purpose') &
                                (df.subtype != 'thread_broadcast')]
    # drop subtype column with the values we don't need anymore
    df_clean.drop('subtype', axis=1, inplace=True) 
    
    return df_clean

# %% [markdown]
# ### Wrangling

# %%
def datetime_wrangling(df_clean):
    
    """this function is applied to summarise wrangling steps with datetime
    """
    # convert ts to datetime from float
    df_clean['ts'] = pd.to_datetime(df_clean['ts'], unit='s').astype('datetime64[s]')
    
    # create a column for the days of the week using the ts column
    df_clean['day_name'] = df_clean['ts'].dt.day_name()
    df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
    
    # create a column for the months of the year using the ts column
    df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month

    # convert values to date time and then month names
    df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
    
    # create a column for the type of the weekday using the ts column
    df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x < 5 else 'Weekend')
    
    # create a column for the hour of the day using the ts column
    df_clean['time']= df_clean['ts'].dt.strftime('%H')
    
    # create a column for the parts of the day
    df_clean['dayparts'] = (df_clean['ts'].dt.hour % 24 + 4) // 4
    df_clean['dayparts'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Afternoon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)
    # drop ts column
    df_clean.drop('ts', axis=1, inplace=True) 

    
    return df_clean

# %%
df_clean.columns
# Out:
# Index(['type', 'subtype', 'ts', 'user', 'text', 'channel_name',
#        'client_msg_id', 'team', 'user_team', 'source_team', 'user_profile',
#        'attachments', 'blocks', 'edited', 'reactions', 'thread_ts',
#        'reply_count', 'reply_users_count', 'latest_reply', 'reply_users',
#        'replies', 'is_locked', 'subscribed', 'last_read', 'parent_user_id',
#        'files', 'upload', 'display_as_bot', 'bot_id', 'bot_profile', 'inviter',
#        'purpose', 'topic', 'root', 'old_name', 'name', 'x_files', 'hidden'],
#       dtype='object')

# %%
df_clean.files.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [{'id': 'F021S3CNVUY', 'created': 1620287426, 'timestamp': 1620287426, 'name': 'Music Recommender v.2.ipynb', 'title': 'Music Recommender v.2.ipynb', 'mimetype': 'application/octet-stream', 'filetype': 'binary', 'pretty_type': 'Binary', 'user': 'U01RW140HBP', 'editable': False, 'size': 91794, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021S3CNVUY/music_recommender_v.2.ipynb?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021S3CNVUY/download/music_recommender_v.2.ipynb?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RW140HBP/F021S3CNVUY/music_recommender_v.2.ipynb', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F021S3CNVUY-452354bc1b', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             2
# [{'id': 'F01SHSGLG90', 'created': 1616754010, 'timestamp': 1616754010, 'name': 'Playing_with_NumPy_arrays.ipynb.zip', 'title': 'Playing_with_NumPy_arrays.ipynb.zip', 'mimetype': 'application/zip', 'filetype': 'zip', 'pretty_type': 'Zip', 'user': 'U01RSRE0N3D', 'editable': False, 'size': 227840, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01SHSGLG90/playing_with_numpy_arrays.ipynb.zip?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01SHSGLG90/download/playing_with_numpy_arrays.ipynb.zip?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RSRE0N3D/F01SHSGLG90/playing_with_numpy_arrays.ipynb.zip', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F01SHSGLG90-0b8784fb29', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2
# [{'id': 'F021NM91FAA', 'created': 1620934493, 'timestamp': 1620934493, 'name': 'Image from iOS.jpg', 'title': 'Image from iOS', 'mimetype': 'image/jpeg', 'filetype': 'jpg', 'pretty_type': 'JPEG', 'user': 'U01RN7BVD1C', 'editable': False, 'size': 67216, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021NM91FAA/image_from_ios.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021NM91FAA/download/image_from_ios.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_64.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_80.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_360.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 292, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_480.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 389, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_160.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_720.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 584, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_800.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 648, 'thumb_960': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_960.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_960_w': 960, 'thumb_960_h': 778, 'thumb_1024': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021NM91FAA-40445e9993/image_from_ios_1024.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_1024_w': 1024, 'thumb_1024_h': 830, 'original_w': 1024, 'original_h': 830, 'thumb_tiny': 'AwAmADDSbPYUnzf5FDdaAeOpoAPmo+bFLmm5oAdzQM96QHNOoAY3WlA5yDSN1oUZoEPqOpKjoGKMe1Ppij3pwHvQAFcmk2+9OooAMe9JtFLRQAm33NAGO9LRQB//2Q==', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RN7BVD1C/F021NM91FAA/image_from_ios.jpg', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F021NM91FAA-3a984a49fe', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                         1
# [{'id': 'F01TX5A8X8W', 'created': 1618300945, 'timestamp': 1618300945, 'name': 'process.jpg', 'title': 'process.jpg', 'mimetype': 'image/jpeg', 'filetype': 'jpg', 'pretty_type': 'JPEG', 'user': 'U01S0MFJ3HR', 'editable': False, 'size': 1763612, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01TX5A8X8W/process.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01TX5A8X8W/download/process.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_64.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_80.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_360.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 270, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_480.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 360, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_160.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_720.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 540, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_800.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 600, 'thumb_960': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_960.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_960_w': 960, 'thumb_960_h': 720, 'thumb_1024': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01TX5A8X8W-3c573d63b0/process_1024.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_1024_w': 1024, 'thumb_1024_h': 768, 'original_w': 4032, 'original_h': 3024, 'thumb_tiny': 'AwAkADB4Ue/50uPc/nSA0tAC49zS4HqaB9aWgAx7mjHvSilxQBBmnCmU4GkAoNOJ5pmaWmBIKUCmA04GgCGiiikAUtJRQA4GnA0wU8UwP//Z', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01S0MFJ3HR/F01TX5A8X8W/process.jpg', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F01TX5A8X8W-20e04b52c1', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                        1
# [{'id': 'F021TR9LM2M', 'created': 1620667625, 'timestamp': 1620667625, 'name': '181338594_310488097098646_3320073358901552513_n.jpg', 'title': '181338594_310488097098646_3320073358901552513_n.jpg', 'mimetype': 'image/jpeg', 'filetype': 'jpg', 'pretty_type': 'JPEG', 'user': 'U01RRV4JX6Z', 'editable': False, 'size': 56205, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021TR9LM2M/181338594_310488097098646_3320073358901552513_n.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F021TR9LM2M/download/181338594_310488097098646_3320073358901552513_n.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_64.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_80.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_360.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 297, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_480.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 396, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_160.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_720.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 595, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F021TR9LM2M-d79bc7e43d/181338594_310488097098646_3320073358901552513_n_800.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 661, 'original_w': 827, 'original_h': 683, 'thumb_tiny': '', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RRV4JX6Z/F021TR9LM2M/181338594_310488097098646_3320073358901552513_n.jpg', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F021TR9LM2M-3c748ee2f4', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                           1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ..
# [{'id': 'F020ZBPQRCJ', 'created': 1620227709, 'timestamp': 1620227709, 'name': 'Bildschirmfoto 2021-05-05 um 17.14.32.png', 'title': 'Bildschirmfoto 2021-05-05 um 17.14.32.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01S7BM4N81', 'editable': False, 'size': 120201, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F020ZBPQRCJ/bildschirmfoto_2021-05-05_um_17.14.32.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F020ZBPQRCJ/download/bildschirmfoto_2021-05-05_um_17.14.32.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_64.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_80.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_360.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 162, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_480.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 216, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_160.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_720.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 324, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_800.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 360, 'thumb_960': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_960.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_960_w': 960, 'thumb_960_h': 432, 'thumb_1024': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020ZBPQRCJ-6a5708c1e2/bildschirmfoto_2021-05-05_um_17.14.32_1024.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_1024_w': 1024, 'thumb_1024_h': 461, 'original_w': 1207, 'original_h': 543, 'thumb_tiny': 'AwAVADDRYHI7UmD6mnHqKQ/TNAC80UmT6Gnc0AJzRzS0UAIRmk2inUUAN2ijaKdRQA3aKWlooA//2Q==', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01S7BM4N81/F020ZBPQRCJ/bildschirmfoto_2021-05-05_um_17.14.32.png', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F020ZBPQRCJ-2b9bb7777f', 'is_starred': False, 'has_rich_preview': False}]    1
# [{'id': 'F020QG0ATNY', 'created': 1619775093, 'timestamp': 1619775093, 'name': 'image.png', 'title': 'image.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01RKN0EGDV', 'editable': False, 'size': 9852, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F020QG0ATNY/image.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F020QG0ATNY/download/image.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020QG0ATNY-c920feece2/image_64.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020QG0ATNY-c920feece2/image_80.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020QG0ATNY-c920feece2/image_360.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 181, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020QG0ATNY-c920feece2/image_480.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 241, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F020QG0ATNY-c920feece2/image_160.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'original_w': 538, 'original_h': 270, 'thumb_tiny': 'AwAYADDTz7U0596gu7eScqUcDHqTVkcAUANGSe9OoooAKKKKACiiigAooooAKKKKAP/Z', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RKN0EGDV/F020QG0ATNY/image.png', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F020QG0ATNY-30e70e3230', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# [{'id': 'F01SMB9UGGH', 'created': 1616573027, 'timestamp': 1616573027, 'name': 'WhatsApp Image 2021-03-23 at 22.17.22.jpeg', 'title': 'WhatsApp Image 2021-03-23 at 22.17.22.jpeg', 'mimetype': 'image/jpeg', 'filetype': 'jpg', 'pretty_type': 'JPEG', 'user': 'U01S7KCL3DF', 'editable': False, 'size': 63324, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01SMB9UGGH/whatsapp_image_2021-03-23_at_22.17.22.jpeg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01SMB9UGGH/download/whatsapp_image_2021-03-23_at_22.17.22.jpeg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_64.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_80.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_360.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 244, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_480.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 325, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_160.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_720.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 487, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01SMB9UGGH-6aec720784/whatsapp_image_2021-03-23_at_22.17.22_800.jpg?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 541, 'original_w': 878, 'original_h': 594, 'thumb_tiny': 'AwAgADDRffxsIHrkUmJM8suPpTicDpmk3n+41ACYl9U/I05d38WPwoLYA+Un6UtABRRQTgetACEZ60gUDufzpxAPWkCgdBQAhH4/jSY9j+dOIz2zTdv+yPzoAMex/OlA4PX86Nv+yPzoC8HigD//2Q==', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01S7KCL3DF/F01SMB9UGGH/whatsapp_image_2021-03-23_at_22.17.22.jpeg', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F01SMB9UGGH-3bb2efde24', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# [{'id': 'F02182W72HM', 'created': 1620816490, 'timestamp': 1620816490, 'name': 'LAB_decision_tree_cookies_students.ipynb', 'title': 'LAB_decision_tree_cookies_students.ipynb', 'mimetype': 'application/octet-stream', 'filetype': 'binary', 'pretty_type': 'Binary', 'user': 'U01RN7BVD1C', 'editable': False, 'size': 431239, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F02182W72HM/lab_decision_tree_cookies_students.ipynb?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F02182W72HM/download/lab_decision_tree_cookies_students.ipynb?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01RN7BVD1C/F02182W72HM/lab_decision_tree_cookies_students.ipynb', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F02182W72HM-3552861ee9', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# [{'id': 'F01UB13NL9J', 'created': 1618317542, 'timestamp': 1618317542, 'name': 'image.png', 'title': 'image.png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U01S7KCL3DF', 'editable': False, 'size': 1668658, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': True, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01UB13NL9J/image.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'url_private_download': 'https://files.slack.com/files-pri/T01RBRV5F7H-F01UB13NL9J/download/image.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_64': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_64.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_80': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_80.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_360.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_360_w': 360, 'thumb_360_h': 360, 'thumb_480': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_480.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_480_w': 480, 'thumb_480_h': 480, 'thumb_160': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_160.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_720.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_720_w': 720, 'thumb_720_h': 720, 'thumb_800': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_800.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_800_w': 800, 'thumb_800_h': 800, 'thumb_960': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_960.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_960_w': 960, 'thumb_960_h': 960, 'thumb_1024': 'https://files.slack.com/files-tmb/T01RBRV5F7H-F01UB13NL9J-d9ef8d13c8/image_1024.png?t=xoxe-1861879185255-2068564688150-2068564727718-519dfbdd8f50e154f7dac1ab76bfc0d2', 'thumb_1024_w': 1024, 'thumb_1024_h': 1024, 'original_w': 1500, 'original_h': 1500, 'thumb_tiny': '', 'permalink': 'https://data-ft-ber-03-2021.slack.com/files/U01S7KCL3DF/F01UB13NL9J/image.png', 'permalink_public': 'https://slack-files.com/T01RBRV5F7H-F01UB13NL9J-fb5d4533b7', 'is_starred': False, 'has_rich_preview': False}]                                                                                                                                             1
# Name: files, Length: 522, dtype: int64

# %%
def url_file(x):
    """this function is applied to column files
    """
    try:
        return x[0]['url_private']
    except KeyError:
        return 'nolink_infiles'

    df_clean['link_of_file'] = df_clean['files'].apply(url_file)

    # save to csv
    df_links = df_clean[(df_clean.link_of_file != 'nofile')]
    header = ['link_of_file']
    df_links.to_csv(r'../csv/links.csv', columns = header, index = False)

    # drop files column
    df_clean.drop('files', axis=1, inplace=True) 

    return df_clean

# %%
def url_attachments(x):
    """this function is applied to column attachments to extract link
    """
    
    try:
        return x[0]['app_unfurl_url']
    except KeyError:
        return 'nolink_infiles'
        
    df_clean['github_links'] = df_clean['attachments'].apply(url_attachments)

    # save to csv
    df_githublinks = df_clean[(df_clean.github_links != 'nolink')
                         & (df_clean.github_links != 'nolink_infiles')]
    header = ['github_links']
    df_githublinks.to_csv(r'../csv/github_links.csv', columns = header, index = False)

    return df_clean

# %%
def real_name(x):
    """this function is applied to column user_profile to extract real_name
    """
    
    if x != x:
        return 'noname'
    else:
        return x['real_name']

    df_clean['real_name'] = df_clean['user_profile'].apply(real_name)

    # drop user_profile column
    df_clean.drop('user_profile', axis=1, inplace=True) 

    return df_clean

# %%
def reactions_count(x):
    """this function is applied to column reactions to count reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['count']

    df_clean['reactions_count'] = df_clean['reactions'].apply(reactions_count)
    
    return df_clean

# %%
def reactions_name(x):
    """this function is applied to column reactions to count them
    """
    
    if x != x:
        return 0
    else:
        return x[0]['name']

    df_clean['reactions_name'] = df_clean['reactions'].apply(reactions_name)
    
    return df_clean

# %%
def boolean_features(df_clean):
    """this function is applied to create a new column with boolean features
    """
    # create a new boolean column if comment has reaction
    df_clean['reaction_true'] = df_clean['reactions'].notnull()

    # create a new boolean column if comment has reply
    df_clean['replies_true'] = df_clean['reply_count'].notna()

    # create a new boolean column if comment has files
    df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")

    # create a new boolean column if comment has attachments
    df_clean['attachments_true'] = df_clean['github_links'].str.contains("https")
    
    return df_clean

# %%
def type_of_participant(s):
    """this function is applied to create a new column with teaching and students
    """
    if s == 'siand the LT (she/her)':
        return 'teacher'
    if s ==  'Florian Titze':
        return 'teacher'
    if s ==  'Kosta':
        return 'teacher'
    else:
        return 'student'
    return ''

    # apply
    df_clean['participant'] = df_clean['real_name'].apply(type_of_participant)
    
    return df_clean

# %%
def text_length(df_clean):
    """this function is applied to create a new column with text length
    """
    df_clean['text_length'] = df['text'].astype(str).map(len)
    
    return df_clean

# %%
df_clean
# Out:
#        type            subtype            ts         user  \
# 0   message       channel_join  1.616237e+09  U01S1CWGTU4
# 0   message                NaN  1.617897e+09  U01S7BM4N81
# 0   message                NaN  1.620900e+09  U01RXCQHMHT
# 0   message                NaN  1.620200e+09  U01S7KCL3DF
# 1   message                NaN  1.620211e+09  U01RSRE0N3D
# ..      ...                ...           ...          ...
# 32  message       channel_join  1.620038e+09  U01S081EULS
# 33  message  channel_unarchive  1.620038e+09  U01S081EULS
# 34  message       channel_join  1.620038e+09  U01SD3CDH9P
# 35  message       channel_join  1.620038e+09  U01S1CWGTU4
# 36  message    channel_archive  1.620039e+09  U01SD3CDH9P
#
#                                                  text         channel_name  \
# 0               <@U01S1CWGTU4> has joined the channel                music
# 0       <https://www.youtube.com/watch?v=qW1eTP9CKSE>                music
# 0   A thematic name for a playlist\n\n<https://sou...                music
# 0   <@U01RXCQHMHT> here’s a bangin track about Nig...                music
# 1   For all of you LotR ravers\n<https://www.youtu...                music
# ..                                                ...                  ...
# 32              <@U01S081EULS> has joined the channel  web-scraping-latino
# 33             <@U01S081EULS> un-archived the channel  web-scraping-latino
# 34              <@U01SD3CDH9P> has joined the channel  web-scraping-latino
# 35              <@U01S1CWGTU4> has joined the channel  web-scraping-latino
# 36                <@U01SD3CDH9P> archived the channel  web-scraping-latino
#
#                            client_msg_id         team    user_team  \
# 0                                    NaN          NaN          NaN
# 0   98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 0   c097123a-a43a-47a7-8d6b-c4ed6574b2c6  T01RBRV5F7H  T01RBRV5F7H
# 0   a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 1   41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# ..                                   ...          ...          ...
# 32                                   NaN          NaN          NaN
# 33                                   NaN          NaN          NaN
# 34                                   NaN          NaN          NaN
# 35                                   NaN          NaN          NaN
# 36                                   NaN          NaN          NaN
#
#     source_team  ... bot_id bot_profile inviter purpose topic  root  old_name  \
# 0           NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0   T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0   T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 0   T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 1   T01RBRV5F7H  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# ..          ...  ...    ...         ...     ...     ...   ...   ...       ...
# 32          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 33          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 34          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 35          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
# 36          NaN  ...    NaN         NaN     NaN     NaN   NaN   NaN       NaN
#
#     name  x_files hidden
# 0    NaN      NaN    NaN
# 0    NaN      NaN    NaN
# 0    NaN      NaN    NaN
# 0    NaN      NaN    NaN
# 1    NaN      NaN    NaN
# ..   ...      ...    ...
# 32   NaN      NaN    NaN
# 33   NaN      NaN    NaN
# 34   NaN      NaN    NaN
# 35   NaN      NaN    NaN
# 36   NaN      NaN    NaN
#
# [5185 rows x 38 columns]

# %% [markdown]
# ### Function calls

# %%
df_clean = clean_dataframe(df_clean)
df_clean = datetime_wrangling(df_clean)
df_clean = url_file(df_clean)
df_clean = url_attachments(df_clean)
df_clean = real_name(df_clean)
df_clean = reactions_count(df_clean)
df_clean = reactions_name(df_clean)
df_clean = type_of_participant(df_clean)
df_clean = boolean_features(df_clean)
df_clean = text_length(df_clean)

df_clean.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-cd4c83049052> in <module>
#       2 df_clean = datetime_wrangling(df_clean)
#       3 df_clean = url_file(df_clean)
# ----> 4 df_clean = url_attachments(df_clean)
#       5 df_clean = real_name(df_clean)
#       6 df_clean = reactions_count(df_clean)
#
# <ipython-input-123-c3a3fc0df5d1> in url_attachments(x)
#       4
#       5     try:
# ----> 6         return x[0]['app_unfurl_url']
#       7     except KeyError:
#       8         return 'nolink_infiles'
#
# TypeError: string indices must be integers

# %% [markdown]
# ### Cleaning again after Feature engineering

# %%
def clean_post_feature_eng(df_clean):
    
   # droppig unneccessary columns
    df_clean.drop(['reactions', 'attachments', 'reply_users', 'replies'], axis=1, inplace=True)
    
    # replace NaN values with zero
    df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
    df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
    df_clean['reply_count'] = df_clean['reply_count'].astype(int)
    df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)
    
    # reordering columns
    df_clean = df_clean[['channel_name', 'user', 'real_name', 'participant',
                     'text', 'text_length', 'reply_count', 'reply_users_count',
                     'replies_true', 'day_name', 'day_type', 'time',
                     'dayparts', 'day_number', 'month', 'reactions_count', 
                     'reactions_name', 'link_of_file', 'files_true', 
                     'github_links', 'attachments_true', 'reaction_true']]
    
    return df_clean

# %%
df_clean = clean_post_feature_eng(df_clean)

# %%
df_clean.head()

# %%
# save to csv
df_clean.to_csv(r'../csv/data_clean_optimized.csv', index = False)

# %%
# save to excel
df_clean.to_excel(r'../csv/data_clean_optimized.xlsx', index = False)
