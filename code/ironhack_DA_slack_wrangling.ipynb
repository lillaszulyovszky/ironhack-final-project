# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp
#
# ## Wrangle Data
# - create a couple of boolean columns from reactions, files, attachments, replies

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe/channel

# %% [markdown]
# ### channel_gen

# %%
# defining file path
path_to_json = '../raw_data/general/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_gen = pd.concat(dfs, ignore_index=True)
# test
channel_gen.tail(100)
# Out:
#                              client_msg_id     type  \
# 1242  3d62b711-9c19-4aa8-8874-615579ff48e7  message
# 1243  f790d842-a5e8-44e7-be76-678d69cfb06d  message
# 1244  67fff521-642a-4209-82be-42a6b25e91d7  message
# 1245  16c8cc9f-f308-41d9-a642-4120f2fb3041  message
# 1246  9682cdd5-2cf6-4344-9542-9e2711dcf6c1  message
# ...                                    ...      ...
# 1337                                   NaN  message
# 1338                                   NaN  message
# 1339                                   NaN  message
# 1340                                   NaN  message
# 1341                                   NaN  message
#
#                                                    text         user  \
# 1242                         yes and then using the app  U01S79YDELR
# 1243  <!channel>,\ncan you access the content now? W...  U01SJKB2MG8
# 1244                                mine not signing in  U01S0P26NKD
# 1245  yes, thanks. I have problems to go the the cla...  U01S79YDELR
# 1246             <@U01SJKB2MG8> i cannot join the class  U01S79YDELR
# ...                                                 ...          ...
# 1337              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1338              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1339              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1340              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1341              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 1242  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1243  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1244  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1245  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1246  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1337  1.616166e+09          NaN          NaN          NaN
# 1338  1.616167e+09          NaN          NaN          NaN
# 1339  1.616168e+09          NaN          NaN          NaN
# 1340  1.616172e+09          NaN          NaN          NaN
# 1341  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 1242  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1243  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1244  {'avatar_hash': 'g7b30129d02b', 'image_72': 'h...
# 1245  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1246  {'avatar_hash': '606def897de6', 'image_72': 'h...
# ...                                                 ...
# 1337                                                NaN
# 1338                                                NaN
# 1339                                                NaN
# 1340                                                NaN
# 1341                                                NaN
#
#                                                  blocks  ...  upload  \
# 1242  [{'type': 'rich_text', 'block_id': 'Bie', 'ele...  ...     NaN
# 1243  [{'type': 'rich_text', 'block_id': '6p6z', 'el...  ...     NaN
# 1244  [{'type': 'rich_text', 'block_id': 'UCLUf', 'e...  ...     NaN
# 1245  [{'type': 'rich_text', 'block_id': 'Voo', 'ele...  ...     NaN
# 1246  [{'type': 'rich_text', 'block_id': 'upS/I', 'e...  ...     NaN
# ...                                                 ...  ...     ...
# 1337                                                NaN  ...     NaN
# 1338                                                NaN  ...     NaN
# 1339                                                NaN  ...     NaN
# 1340                                                NaN  ...     NaN
# 1341                                                NaN  ...     NaN
#
#      display_as_bot reactions  last_read  bot_id  bot_profile       subtype  \
# 1242            NaN       NaN        NaN     NaN          NaN           NaN
# 1243            NaN       NaN        NaN     NaN          NaN           NaN
# 1244            NaN       NaN        NaN     NaN          NaN           NaN
# 1245            NaN       NaN        NaN     NaN          NaN           NaN
# 1246            NaN       NaN        NaN     NaN          NaN           NaN
# ...             ...       ...        ...     ...          ...           ...
# 1337            NaN       NaN        NaN     NaN          NaN  channel_join
# 1338            NaN       NaN        NaN     NaN          NaN  channel_join
# 1339            NaN       NaN        NaN     NaN          NaN  channel_join
# 1340            NaN       NaN        NaN     NaN          NaN  channel_join
# 1341            NaN       NaN        NaN     NaN          NaN  channel_join
#
#      topic root purpose
# 1242   NaN  NaN     NaN
# 1243   NaN  NaN     NaN
# 1244   NaN  NaN     NaN
# 1245   NaN  NaN     NaN
# 1246   NaN  NaN     NaN
# ...    ...  ...     ...
# 1337   NaN  NaN     NaN
# 1338   NaN  NaN     NaN
# 1339   NaN  NaN     NaN
# 1340   NaN  NaN     NaN
# 1341   NaN  NaN     NaN
#
# [100 rows x 32 columns]

# %%
channel_gen['channel_name'] = 'general'
channel_gen
# Out:
#                              client_msg_id     type  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294  message
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2  message
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d  message
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b  message
# 4     39e4728b-90f7-4d84-b149-74d765ca544a  message
# ...                                    ...      ...
# 1337                                   NaN  message
# 1338                                   NaN  message
# 1339                                   NaN  message
# 1340                                   NaN  message
# 1341                                   NaN  message
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1337              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1338              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1339              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1340              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1341              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 0     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1337  1.616166e+09          NaN          NaN          NaN
# 1338  1.616167e+09          NaN          NaN          NaN
# 1339  1.616168e+09          NaN          NaN          NaN
# 1340  1.616172e+09          NaN          NaN          NaN
# 1341  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                                                 ...
# 1337                                                NaN
# 1338                                                NaN
# 1339                                                NaN
# 1340                                                NaN
# 1341                                                NaN
#
#                                                  blocks  ...  display_as_bot  \
# 0     [{'type': 'rich_text', 'block_id': '8oy', 'ele...  ...             NaN
# 1     [{'type': 'rich_text', 'block_id': 'wr=L', 'el...  ...             NaN
# 2     [{'type': 'rich_text', 'block_id': 'pRRNj', 'e...  ...             NaN
# 3     [{'type': 'rich_text', 'block_id': 'Daw', 'ele...  ...             NaN
# 4     [{'type': 'rich_text', 'block_id': '7YE+G', 'e...  ...             NaN
# ...                                                 ...  ...             ...
# 1337                                                NaN  ...             NaN
# 1338                                                NaN  ...             NaN
# 1339                                                NaN  ...             NaN
# 1340                                                NaN  ...             NaN
# 1341                                                NaN  ...             NaN
#
#      reactions last_read  bot_id  bot_profile       subtype topic root  \
# 0          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 1          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 2          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 3          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 4          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# ...        ...       ...     ...          ...           ...   ...  ...
# 1337       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1338       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1339       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1340       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1341       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
#
#      purpose channel_name
# 0        NaN      general
# 1        NaN      general
# 2        NaN      general
# 3        NaN      general
# 4        NaN      general
# ...      ...          ...
# 1337     NaN      general
# 1338     NaN      general
# 1339     NaN      general
# 1340     NaN      general
# 1341     NaN      general
#
# [1342 rows x 33 columns]

# %%
# save to csv
channel_gen.to_csv(r'../raw_data/general/channel_gen.csv', index = False)

# %% [markdown]
# ### channel_books

# %%
### books channel
# defining file path
path_to_json = '../raw_data/books/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_books = pd.concat(dfs, ignore_index=True)
# test
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks
# 0                                                NaN
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...

# %%
channel_books['channel_name'] = 'books'
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks channel_name
# 0                                                NaN        books
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...        books
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...        books

# %%
# save to csv
channel_books.to_csv(r'../raw_data/books/channel_books.csv', index = False)

# %% [markdown]
# ### channel_dresource

# %%
### data_resources channel
# defining file path
path_to_json = '../raw_data/data_resources/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dresource = pd.concat(dfs, ignore_index=True)
# test
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 194  message           NaN  1.619510e+09  U01S7KCL3DF
# 195  message           NaN  1.619513e+09  U01RW140HBP
# 196  message           NaN  1.619513e+09  U01RW140HBP
# 197  message  channel_join  1.616163e+09  U01S79YDELR
# 198  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 194  aaahhhh yes thanks… i must scroll down more of...
# 195  we are working hard to keep that Notion up to ...
# 196  because of the free slack thing :confounded:- ...
# 197              <@U01S79YDELR> has joined the channel
# 198              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 194  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 195  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 196  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 197                                   NaN          NaN          NaN
# 198                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 194  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 195  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 196  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 197          NaN                                                NaN  ...
# 198          NaN                                                NaN  ...
#
#         last_read                                              files upload  \
# 0             NaN                                                NaN    NaN
# 1             NaN                                                NaN    NaN
# 2    1.619337e+09                                                NaN    NaN
# 3             NaN  [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False
# 4             NaN  [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False
# ..            ...                                                ...    ...
# 194           NaN                                                NaN    NaN
# 195           NaN                                                NaN    NaN
# 196           NaN                                                NaN    NaN
# 197           NaN                                                NaN    NaN
# 198           NaN                                                NaN    NaN
#
#      display_as_bot                                          reactions  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               0.0  [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...
# 4               0.0                                                NaN
# ..              ...                                                ...
# 194             NaN  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...
# 195             NaN                                                NaN
# 196             NaN                                                NaN
# 197             NaN                                                NaN
# 198             NaN                                                NaN
#
#      parent_user_id  bot_id bot_profile inviter  topic
# 0               NaN     NaN         NaN     NaN    NaN
# 1               NaN     NaN         NaN     NaN    NaN
# 2               NaN     NaN         NaN     NaN    NaN
# 3               NaN     NaN         NaN     NaN    NaN
# 4               NaN     NaN         NaN     NaN    NaN
# ..              ...     ...         ...     ...    ...
# 194     U01S7KCL3DF     NaN         NaN     NaN    NaN
# 195             NaN     NaN         NaN     NaN    NaN
# 196             NaN     NaN         NaN     NaN    NaN
# 197             NaN     NaN         NaN     NaN    NaN
# 198             NaN     NaN         NaN     NaN    NaN
#
# [199 rows x 31 columns]

# %%
channel_dresource['channel_name'] = 'dresource'
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 194  message           NaN  1.619510e+09  U01S7KCL3DF
# 195  message           NaN  1.619513e+09  U01RW140HBP
# 196  message           NaN  1.619513e+09  U01RW140HBP
# 197  message  channel_join  1.616163e+09  U01S79YDELR
# 198  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 194  aaahhhh yes thanks… i must scroll down more of...
# 195  we are working hard to keep that Notion up to ...
# 196  because of the free slack thing :confounded:- ...
# 197              <@U01S79YDELR> has joined the channel
# 198              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 194  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 195  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 196  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 197                                   NaN          NaN          NaN
# 198                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 194  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 195  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 196  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 197          NaN                                                NaN  ...
# 198          NaN                                                NaN  ...
#
#                                                  files upload display_as_bot  \
# 0                                                  NaN    NaN            NaN
# 1                                                  NaN    NaN            NaN
# 2                                                  NaN    NaN            NaN
# 3    [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False            0.0
# 4    [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False            0.0
# ..                                                 ...    ...            ...
# 194                                                NaN    NaN            NaN
# 195                                                NaN    NaN            NaN
# 196                                                NaN    NaN            NaN
# 197                                                NaN    NaN            NaN
# 198                                                NaN    NaN            NaN
#
#                                              reactions  parent_user_id  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3    [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 194  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...     U01S7KCL3DF
# 195                                                NaN             NaN
# 196                                                NaN             NaN
# 197                                                NaN             NaN
# 198                                                NaN             NaN
#
#      bot_id  bot_profile inviter topic  channel_name
# 0       NaN          NaN     NaN   NaN     dresource
# 1       NaN          NaN     NaN   NaN     dresource
# 2       NaN          NaN     NaN   NaN     dresource
# 3       NaN          NaN     NaN   NaN     dresource
# 4       NaN          NaN     NaN   NaN     dresource
# ..      ...          ...     ...   ...           ...
# 194     NaN          NaN     NaN   NaN     dresource
# 195     NaN          NaN     NaN   NaN     dresource
# 196     NaN          NaN     NaN   NaN     dresource
# 197     NaN          NaN     NaN   NaN     dresource
# 198     NaN          NaN     NaN   NaN     dresource
#
# [199 rows x 32 columns]

# %%
# save to csv
channel_dresource.to_csv(r'../raw_data/data_resources/channel_dresource.csv', index = False)

# %% [markdown]
# ### channel_dbootcamp

# %%
### data-bootcamp channel
# defining file path
path_to_json = '../raw_data/data-bootcamp/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dbootcamp = pd.concat(dfs, ignore_index=True)
# test
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text
# 0   <@U01RVSTNRRT> has joined the channel
# 1   <@U01RW140HBP> has joined the channel
# 2   <@U01S65G72SY> has joined the channel
# 3   <@U01RSRE0N3D> has joined the channel
# 4   <@U01RRV4JX6Z> has joined the channel
# 5   <@U01S79YDELR> has joined the channel
# 6   <@U01RUTP1ZQB> has joined the channel
# 7   <@U01RUU9SK4K> has joined the channel
# 8   <@U01S7BM4N81> has joined the channel
# 9   <@U01SJKB2MG8> has joined the channel
# 10  <@U01RV3K524T> has joined the channel
# 11  <@U01S133DZ9A> has joined the channel
# 12  <@U01RN7BVD1C> has joined the channel
# 13  <@U01S7KCL3DF> has joined the channel
# 14  <@U01S1CWGTU4> has joined the channel
# 15  <@U01RNEU3SNA> has joined the channel
# 16  <@U01RS9Y6UJH> has joined the channel
# 17  <@U01SK96QF5E> has joined the channel
# 18  <@U01RP2K1606> has joined the channel
# 19  <@U01RW2X7S9Z> has joined the channel

# %%
channel_dbootcamp['channel_name'] = 'dbootcamp'
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text channel_name
# 0   <@U01RVSTNRRT> has joined the channel    dbootcamp
# 1   <@U01RW140HBP> has joined the channel    dbootcamp
# 2   <@U01S65G72SY> has joined the channel    dbootcamp
# 3   <@U01RSRE0N3D> has joined the channel    dbootcamp
# 4   <@U01RRV4JX6Z> has joined the channel    dbootcamp
# 5   <@U01S79YDELR> has joined the channel    dbootcamp
# 6   <@U01RUTP1ZQB> has joined the channel    dbootcamp
# 7   <@U01RUU9SK4K> has joined the channel    dbootcamp
# 8   <@U01S7BM4N81> has joined the channel    dbootcamp
# 9   <@U01SJKB2MG8> has joined the channel    dbootcamp
# 10  <@U01RV3K524T> has joined the channel    dbootcamp
# 11  <@U01S133DZ9A> has joined the channel    dbootcamp
# 12  <@U01RN7BVD1C> has joined the channel    dbootcamp
# 13  <@U01S7KCL3DF> has joined the channel    dbootcamp
# 14  <@U01S1CWGTU4> has joined the channel    dbootcamp
# 15  <@U01RNEU3SNA> has joined the channel    dbootcamp
# 16  <@U01RS9Y6UJH> has joined the channel    dbootcamp
# 17  <@U01SK96QF5E> has joined the channel    dbootcamp
# 18  <@U01RP2K1606> has joined the channel    dbootcamp
# 19  <@U01RW2X7S9Z> has joined the channel    dbootcamp

# %%
# save to csv
channel_dbootcamp.to_csv(r'../raw_data/data-bootcamp/channel_dbootcamp.csv', index = False)

# %% [markdown]
# ### channel_dmemes

# %%
### data-memes channel
# defining file path
path_to_json = '../raw_data/data-memes/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dmemes = pd.concat(dfs, ignore_index=True)
# test
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 297  message  this made me realise there is no krispy branch...
# 298  message
# 299  message                                     <@U01S0E0MRJ7>
# 300  message                               haha this is tots me
# 301  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 297                                                NaN    NaN  U01SK96QF5E
# 298  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 299  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 300                                                NaN    NaN  U01S0E0MRJ7
# 301  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 297            NaN  1.616509e+09  1.616498e+09          NaN
# 298            0.0  1.616518e+09           NaN          NaN
# 299            0.0  1.619509e+09  1.619509e+09          1.0
# 300            NaN  1.619510e+09  1.619509e+09          NaN
# 301            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...    user_team  source_team  \
# 0                  NaN  ...          NaN          NaN
# 1                  1.0  ...          NaN          NaN
# 2                  NaN  ...          NaN          NaN
# 3                  NaN  ...          NaN          NaN
# 4                  NaN  ...          NaN          NaN
# ..                 ...  ...          ...          ...
# 297                NaN  ...  T01RBRV5F7H  T01RBRV5F7H
# 298                NaN  ...          NaN          NaN
# 299                1.0  ...          NaN          NaN
# 300                NaN  ...  T01RBRV5F7H  T01RBRV5F7H
# 301                NaN  ...          NaN          NaN
#
#                                           user_profile  attachments  bot_id  \
# 0                                                  NaN          NaN     NaN
# 1                                                  NaN          NaN     NaN
# 2                                                  NaN          NaN     NaN
# 3                                                  NaN          NaN     NaN
# 4                                                  NaN          NaN     NaN
# ..                                                 ...          ...     ...
# 297  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...          NaN     NaN
# 298                                                NaN          NaN     NaN
# 299                                                NaN          NaN     NaN
# 300  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...          NaN     NaN
# 301                                                NaN          NaN     NaN
#
#     bot_profile last_read subtype purpose inviter
# 0           NaN       NaN     NaN     NaN     NaN
# 1           NaN       NaN     NaN     NaN     NaN
# 2           NaN       NaN     NaN     NaN     NaN
# 3           NaN       NaN     NaN     NaN     NaN
# 4           NaN       NaN     NaN     NaN     NaN
# ..          ...       ...     ...     ...     ...
# 297         NaN       NaN     NaN     NaN     NaN
# 298         NaN       NaN     NaN     NaN     NaN
# 299         NaN       NaN     NaN     NaN     NaN
# 300         NaN       NaN     NaN     NaN     NaN
# 301         NaN       NaN     NaN     NaN     NaN
#
# [302 rows x 31 columns]

# %%
channel_dmemes['channel_name'] = 'dmemes'
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 297  message  this made me realise there is no krispy branch...
# 298  message
# 299  message                                     <@U01S0E0MRJ7>
# 300  message                               haha this is tots me
# 301  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 297                                                NaN    NaN  U01SK96QF5E
# 298  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 299  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 300                                                NaN    NaN  U01S0E0MRJ7
# 301  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 297            NaN  1.616509e+09  1.616498e+09          NaN
# 298            0.0  1.616518e+09           NaN          NaN
# 299            0.0  1.619509e+09  1.619509e+09          1.0
# 300            NaN  1.619510e+09  1.619509e+09          NaN
# 301            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...  source_team  \
# 0                  NaN  ...          NaN
# 1                  1.0  ...          NaN
# 2                  NaN  ...          NaN
# 3                  NaN  ...          NaN
# 4                  NaN  ...          NaN
# ..                 ...  ...          ...
# 297                NaN  ...  T01RBRV5F7H
# 298                NaN  ...          NaN
# 299                1.0  ...          NaN
# 300                NaN  ...  T01RBRV5F7H
# 301                NaN  ...          NaN
#
#                                           user_profile attachments  bot_id  \
# 0                                                  NaN         NaN     NaN
# 1                                                  NaN         NaN     NaN
# 2                                                  NaN         NaN     NaN
# 3                                                  NaN         NaN     NaN
# 4                                                  NaN         NaN     NaN
# ..                                                 ...         ...     ...
# 297  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...         NaN     NaN
# 298                                                NaN         NaN     NaN
# 299                                                NaN         NaN     NaN
# 300  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...         NaN     NaN
# 301                                                NaN         NaN     NaN
#
#      bot_profile last_read subtype purpose inviter channel_name
# 0            NaN       NaN     NaN     NaN     NaN       dmemes
# 1            NaN       NaN     NaN     NaN     NaN       dmemes
# 2            NaN       NaN     NaN     NaN     NaN       dmemes
# 3            NaN       NaN     NaN     NaN     NaN       dmemes
# 4            NaN       NaN     NaN     NaN     NaN       dmemes
# ..           ...       ...     ...     ...     ...          ...
# 297          NaN       NaN     NaN     NaN     NaN       dmemes
# 298          NaN       NaN     NaN     NaN     NaN       dmemes
# 299          NaN       NaN     NaN     NaN     NaN       dmemes
# 300          NaN       NaN     NaN     NaN     NaN       dmemes
# 301          NaN       NaN     NaN     NaN     NaN       dmemes
#
# [302 rows x 32 columns]

# %%
# save to csv
channel_dmemes.to_csv(r'../raw_data/data-memes/channel_dmemes.csv', index = False)

# %% [markdown]
# ### channel_dvizbeauties|

# %%
### data-viz-beauties channel
# defining file path
path_to_json = '../raw_data/data-viz-beauties/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dvizbeauties = pd.concat(dfs, ignore_index=True)
# test
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 260  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 261  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 262  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 263  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 264  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 260  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 261  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 262  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 263                                   a late night sam  U01RS9Y6UJH
# 264  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 260  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 261  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 262  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 263  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 264  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 260  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 261  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 262  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 263  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 264  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  subscribed  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...         NaN
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...         NaN
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...         0.0
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...         NaN
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...         NaN
# ..                                                 ...  ...         ...
# 260  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...         0.0
# 261  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...         0.0
# 262  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...         NaN
# 263  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...         NaN
# 264  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...         NaN
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 260  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 261  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 262  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 263  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 264                                                NaN         NaN
#
#                                                 edited bot_id  bot_profile  \
# 0                                                  NaN    NaN          NaN
# 1                                                  NaN    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3                                                  NaN    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 260                                                NaN    NaN          NaN
# 261  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN          NaN
# 262                                                NaN    NaN          NaN
# 263                                                NaN    NaN          NaN
# 264                                                NaN    NaN          NaN
#
#      subtype  purpose inviter last_read
# 0        NaN      NaN     NaN       NaN
# 1        NaN      NaN     NaN       NaN
# 2        NaN      NaN     NaN       NaN
# 3        NaN      NaN     NaN       NaN
# 4        NaN      NaN     NaN       NaN
# ..       ...      ...     ...       ...
# 260      NaN      NaN     NaN       NaN
# 261      NaN      NaN     NaN       NaN
# 262      NaN      NaN     NaN       NaN
# 263      NaN      NaN     NaN       NaN
# 264      NaN      NaN     NaN       NaN
#
# [265 rows x 31 columns]

# %%
channel_dvizbeauties['channel_name'] = 'dvizbeauties'
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 260  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 261  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 262  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 263  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 264  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 260  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 261  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 262  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 263                                   a late night sam  U01RS9Y6UJH
# 264  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 260  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 261  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 262  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 263  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 264  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 260  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 261  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 262  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 263  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 264  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...
# ..                                                 ...  ...
# 260  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...
# 261  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...
# 262  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...
# 263  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...
# 264  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 260  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 261  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 262  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 263  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 264                                                NaN         NaN
#
#                                                 edited bot_id bot_profile  \
# 0                                                  NaN    NaN         NaN
# 1                                                  NaN    NaN         NaN
# 2                                                  NaN    NaN         NaN
# 3                                                  NaN    NaN         NaN
# 4                                                  NaN    NaN         NaN
# ..                                                 ...    ...         ...
# 260                                                NaN    NaN         NaN
# 261  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN         NaN
# 262                                                NaN    NaN         NaN
# 263                                                NaN    NaN         NaN
# 264                                                NaN    NaN         NaN
#
#      subtype  purpose  inviter last_read  channel_name
# 0        NaN      NaN      NaN       NaN  dvizbeauties
# 1        NaN      NaN      NaN       NaN  dvizbeauties
# 2        NaN      NaN      NaN       NaN  dvizbeauties
# 3        NaN      NaN      NaN       NaN  dvizbeauties
# 4        NaN      NaN      NaN       NaN  dvizbeauties
# ..       ...      ...      ...       ...           ...
# 260      NaN      NaN      NaN       NaN  dvizbeauties
# 261      NaN      NaN      NaN       NaN  dvizbeauties
# 262      NaN      NaN      NaN       NaN  dvizbeauties
# 263      NaN      NaN      NaN       NaN  dvizbeauties
# 264      NaN      NaN      NaN       NaN  dvizbeauties
#
# [265 rows x 32 columns]

# %%
# save to csv
channel_dvizbeauties.to_csv(r'../raw_data/data-viz-beauties/channel_dvizbeauties.csv', index = False)

# %% [markdown]
# ### channel_finalproject

# %%
### final-project channel
# defining file path
path_to_json = '../raw_data/final-project/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_finalproject = pd.concat(dfs, ignore_index=True)
# test
channel_finalproject.head(10)
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.620629e+09  U01RSRE0N3D
# 1  message  channel_join  1.620629e+09  U01SJKB2MG8
# 2  message           NaN  1.620890e+09  U01RW2X7S9Z
# 3  message           NaN  1.620891e+09  U01S7KCL3DF
# 4  message           NaN  1.620892e+09  U01RW2X7S9Z
# 5  message           NaN  1.620895e+09  U01RSRE0N3D
# 6  message           NaN  1.620895e+09  U01RW140HBP
# 7  message           NaN  1.620896e+09  U01RRV4JX6Z
# 8  message           NaN  1.620896e+09  U01RSRE0N3D
# 9  message           NaN  1.620898e+09  U01S133DZ9A
#
#                                                 text      inviter  \
# 0              <@U01RSRE0N3D> has joined the channel          NaN
# 1              <@U01SJKB2MG8> has joined the channel  U01RSRE0N3D
# 2  i went up against e-bay, it didn't work for me...          NaN
# 3  do you need to watch the Japanese fisherman ag...          NaN
# 4    nah, i went into the honeypot labeled as:kaggle          NaN
# 5  Update: we are currently running about 10 min ...          NaN
# 6  to help us help you… please *try* to be succin...          NaN
# 7                                I mislooked my time          NaN
# 8  Also, please wait for us to call you in the br...          NaN
# 9  "Ludwig aims to democratize machine learning, ...          NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  a043d08e-4721-4a9a-9617-b1ed00ab92ed  T01RBRV5F7H  T01RBRV5F7H
# 3  817352ee-cad4-4cdf-a674-a04006b042af  T01RBRV5F7H  T01RBRV5F7H
# 4  32c7409c-7e42-40a6-9fd5-c1ab9b900691  T01RBRV5F7H  T01RBRV5F7H
# 5  f6bd54dd-4851-4eea-9e94-cad00b269361  T01RBRV5F7H  T01RBRV5F7H
# 6  f0339af4-1164-4f9e-9876-7b2dd4baaa27  T01RBRV5F7H  T01RBRV5F7H
# 7  a220ece5-72ac-4fbf-bfc4-51e949ce4eea  T01RBRV5F7H  T01RBRV5F7H
# 8  26e7b2f7-d117-43de-9c2c-bbe856c83c8e  T01RBRV5F7H  T01RBRV5F7H
# 9  e8f9a32b-915c-4fd5-9226-430b37f85c29  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team  ...                 reply_users  \
# 0          NaN  ...                         NaN
# 1          NaN  ...                         NaN
# 2  T01RBRV5F7H  ...                         NaN
# 3  T01RBRV5F7H  ...                         NaN
# 4  T01RBRV5F7H  ...                         NaN
# 5  T01RBRV5F7H  ...  [U01RRV4JX6Z, U01RN7BVD1C]
# 6  T01RBRV5F7H  ...                         NaN
# 7  T01RBRV5F7H  ...                         NaN
# 8  T01RBRV5F7H  ...                         NaN
# 9  T01RBRV5F7H  ...                         NaN
#
#                                              replies  is_locked subscribed  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
# 5  [{'user': 'U01RRV4JX6Z', 'ts': '1620895842.043...        0.0        1.0
# 6                                                NaN        NaN        NaN
# 7                                                NaN        NaN        NaN
# 8                                                NaN        NaN        NaN
# 9                                                NaN        NaN        NaN
#
#       last_read                                        attachments  files  \
# 0           NaN                                                NaN    NaN
# 1           NaN                                                NaN    NaN
# 2           NaN                                                NaN    NaN
# 3           NaN                                                NaN    NaN
# 4           NaN                                                NaN    NaN
# 5  1.620899e+09                                                NaN    NaN
# 6           NaN                                                NaN    NaN
# 7           NaN                                                NaN    NaN
# 8           NaN                                                NaN    NaN
# 9           NaN  [{'service_name': 'Uber Engineering Blog', 'ti...    NaN
#
#    upload display_as_bot edited
# 0     NaN            NaN    NaN
# 1     NaN            NaN    NaN
# 2     NaN            NaN    NaN
# 3     NaN            NaN    NaN
# 4     NaN            NaN    NaN
# 5     NaN            NaN    NaN
# 6     NaN            NaN    NaN
# 7     NaN            NaN    NaN
# 8     NaN            NaN    NaN
# 9     NaN            NaN    NaN
#
# [10 rows x 28 columns]

# %%
channel_finalproject['channel_name'] = 'finalproject'
channel_finalproject
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.620629e+09  U01RSRE0N3D
# 1    message  channel_join  1.620629e+09  U01SJKB2MG8
# 2    message           NaN  1.620890e+09  U01RW2X7S9Z
# 3    message           NaN  1.620891e+09  U01S7KCL3DF
# 4    message           NaN  1.620892e+09  U01RW2X7S9Z
# ..       ...           ...           ...          ...
# 129  message           NaN  1.620645e+09  U01S7BM4N81
# 130  message           NaN  1.620645e+09  U01S7BM4N81
# 131  message           NaN  1.620645e+09  U01RW140HBP
# 132  message           NaN  1.620645e+09  U01S7BM4N81
# 133  message           NaN  1.620646e+09  U01RW140HBP
#
#                                                   text      inviter  \
# 0                <@U01RSRE0N3D> has joined the channel          NaN
# 1                <@U01SJKB2MG8> has joined the channel  U01RSRE0N3D
# 2    i went up against e-bay, it didn't work for me...          NaN
# 3    do you need to watch the Japanese fisherman ag...          NaN
# 4      nah, i went into the honeypot labeled as:kaggle          NaN
# ..                                                 ...          ...
# 129  I have trouble with part 6 - Train the model. ...          NaN
# 130                              Here is the error log          NaN
# 131                             hmmm ill check it out!          NaN
# 132                                                             NaN
# 133                thanks thamo - afternoon challenge!          NaN
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1                                     NaN          NaN          NaN
# 2    a043d08e-4721-4a9a-9617-b1ed00ab92ed  T01RBRV5F7H  T01RBRV5F7H
# 3    817352ee-cad4-4cdf-a674-a04006b042af  T01RBRV5F7H  T01RBRV5F7H
# 4    32c7409c-7e42-40a6-9fd5-c1ab9b900691  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 129  9af16912-abf9-4f21-8eb1-ee543351655c  T01RBRV5F7H  T01RBRV5F7H
# 130  a718f9e5-f99f-4659-901c-cf638149eac0  T01RBRV5F7H  T01RBRV5F7H
# 131  facae6a6-895b-4ff8-ba74-3108e6b30275  T01RBRV5F7H  T01RBRV5F7H
# 132                                   NaN          NaN          NaN
# 133  f908478f-c8ac-476c-a58e-f459f12328af  T01RBRV5F7H  T01RBRV5F7H
#
#      source_team  ... replies is_locked  subscribed last_read attachments  \
# 0            NaN  ...     NaN       NaN         NaN       NaN         NaN
# 1            NaN  ...     NaN       NaN         NaN       NaN         NaN
# 2    T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# 3    T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# 4    T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# ..           ...  ...     ...       ...         ...       ...         ...
# 129  T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# 130  T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# 131  T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
# 132          NaN  ...     NaN       NaN         NaN       NaN         NaN
# 133  T01RBRV5F7H  ...     NaN       NaN         NaN       NaN         NaN
#
#                                                  files  upload  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3                                                  NaN     NaN
# 4                                                  NaN     NaN
# ..                                                 ...     ...
# 129                                                NaN     NaN
# 130                                                NaN     NaN
# 131                                                NaN     NaN
# 132  [{'id': 'F021KPCMVE0', 'created': 1620645478, ...     0.0
# 133                                                NaN     NaN
#
#      display_as_bot edited  channel_name
# 0               NaN    NaN  finalproject
# 1               NaN    NaN  finalproject
# 2               NaN    NaN  finalproject
# 3               NaN    NaN  finalproject
# 4               NaN    NaN  finalproject
# ..              ...    ...           ...
# 129             NaN    NaN  finalproject
# 130             NaN    NaN  finalproject
# 131             NaN    NaN  finalproject
# 132             0.0    NaN  finalproject
# 133             NaN    NaN  finalproject
#
# [134 rows x 29 columns]

# %%
# save to csv
channel_finalproject.to_csv(r'../raw_data/final-project/finalproject.csv', index = False)

# %% [markdown]
# ### channel_frustrations

# %%
### frustrations-shared channel
# defining file path
path_to_json = '../raw_data/frustrations-shared/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_frustrations = pd.concat(dfs, ignore_index=True)
# test
channel_frustrations
# Out:
#       type          subtype            ts         user  \
# 0  message     channel_join  1.616696e+09  U01S133DZ9A
# 1  message  channel_purpose  1.616696e+09  U01S133DZ9A
# 2  message              NaN  1.616696e+09  U01S133DZ9A
#
#                                                 text  \
# 0              <@U01S133DZ9A> has joined the channel
# 1  <@U01S133DZ9A> set the channel description: A ...
# 2  Finally got my files to upload to github.\nWhy...
#
#                                              purpose  \
# 0                                                NaN
# 1  A place to vent your frustration with the worl...
# 2                                                NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  9325906b-46b4-4d98-82e9-d8475aaca20b  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  T01RBRV5F7H  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                               edited  \
# 0                                                NaN
# 1                                                NaN
# 2  {'user': 'U01S133DZ9A', 'ts': '1616695732.0000...
#
#                                               blocks
# 0                                                NaN
# 1                                                NaN
# 2  [{'type': 'rich_text', 'block_id': 'NFV', 'ele...

# %%
channel_frustrations['channel_name'] = 'frustrations'
channel_frustrations
# Out:
#       type          subtype            ts         user  \
# 0  message     channel_join  1.616696e+09  U01S133DZ9A
# 1  message  channel_purpose  1.616696e+09  U01S133DZ9A
# 2  message              NaN  1.616696e+09  U01S133DZ9A
#
#                                                 text  \
# 0              <@U01S133DZ9A> has joined the channel
# 1  <@U01S133DZ9A> set the channel description: A ...
# 2  Finally got my files to upload to github.\nWhy...
#
#                                              purpose  \
# 0                                                NaN
# 1  A place to vent your frustration with the worl...
# 2                                                NaN
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1                                   NaN          NaN          NaN
# 2  9325906b-46b4-4d98-82e9-d8475aaca20b  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  T01RBRV5F7H  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                               edited  \
# 0                                                NaN
# 1                                                NaN
# 2  {'user': 'U01S133DZ9A', 'ts': '1616695732.0000...
#
#                                               blocks  channel_name
# 0                                                NaN  frustrations
# 1                                                NaN  frustrations
# 2  [{'type': 'rich_text', 'block_id': 'NFV', 'ele...  frustrations

# %%
# save to csv
channel_frustrations.to_csv(r'../raw_data/frustrations-shared/frustrations.csv', index = False)

# %% [markdown]
# ### channel_funcommittee

# %%
### fun_committee channel
# defining file path
path_to_json = '../raw_data/fun_committee/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_funcommittee = pd.concat(dfs, ignore_index=True)
# test
channel_funcommittee
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619595e+09  U01S7KCL3DF
# 2    message           NaN  1.617614e+09  U01SK96QF5E
# 3    message           NaN  1.617615e+09  U01RRV4JX6Z
# 4    message           NaN  1.617615e+09  U01S0E0MRJ7
# ..       ...           ...           ...          ...
# 154  message           NaN  1.619546e+09  U01RW2X7S9Z
# 155  message           NaN  1.619547e+09  U01S7KCL3DF
# 156  message           NaN  1.619547e+09  U01RXCQHMHT
# 157  message  channel_join  1.616166e+09  U01RNEU3SNA
# 158  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    in case anyone is hungry for feijoada on satur...
# 2    What did you guys do for Easter? :eyes: I went...
# 3    Its astonishing how Alpacas/Llamas/vicunas are...
# 4                                easter egg coloring:)
# ..                                                 ...
# 154                 this is what i'm needing right now
# 155                       Thank you Japanese fisherman
# 156      <https://www.youtube.com/watch?v=ZXsQAXx_ao0>
# 157              <@U01RNEU3SNA> has joined the channel
# 158              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    38b1be29-6601-49f2-9ec2-a99524c9484d  T01RBRV5F7H  T01RBRV5F7H
# 2    6C6C6CE9-8155-4728-A64B-83ABECAC9A7F          NaN          NaN
# 3    1ea1e83f-b494-493b-80a2-deacfa2f3d26  T01RBRV5F7H  T01RBRV5F7H
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 154  2aabb6c6-f8be-4294-b2d1-546622c56aa8  T01RBRV5F7H  T01RBRV5F7H
# 155  0d88d0f4-2fca-45ab-829e-2c61f762b0c9  T01RBRV5F7H  T01RBRV5F7H
# 156  6352006c-7e75-46fc-868c-8f57a72663c2  T01RBRV5F7H  T01RBRV5F7H
# 157                                   NaN          NaN          NaN
# 158                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 2            NaN                                                NaN  ...
# 3    T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 154  T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# 155  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 156  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 157          NaN                                                NaN  ...
# 158          NaN                                                NaN  ...
#
#                                                replies is_locked subscribed  \
# 0                                                  NaN       NaN        NaN
# 1                                                  NaN       NaN        NaN
# 2    [{'user': 'U01RRV4JX6Z', 'ts': '1617615034.003...       0.0        0.0
# 3                                                  NaN       NaN        NaN
# 4                                                  NaN       NaN        NaN
# ..                                                 ...       ...        ...
# 154                                                NaN       NaN        NaN
# 155                                                NaN       NaN        NaN
# 156                                                NaN       NaN        NaN
# 157                                                NaN       NaN        NaN
# 158                                                NaN       NaN        NaN
#
#     parent_user_id bot_id  bot_profile  last_read  \
# 0              NaN    NaN          NaN        NaN
# 1              NaN    NaN          NaN        NaN
# 2              NaN    NaN          NaN        NaN
# 3      U01SK96QF5E    NaN          NaN        NaN
# 4      U01SK96QF5E    NaN          NaN        NaN
# ..             ...    ...          ...        ...
# 154    U01RXCQHMHT    NaN          NaN        NaN
# 155    U01RXCQHMHT    NaN          NaN        NaN
# 156            NaN    NaN          NaN        NaN
# 157            NaN    NaN          NaN        NaN
# 158            NaN    NaN          NaN        NaN
#
#                                            attachments  edited inviter
# 0                                                  NaN     NaN     NaN
# 1                                                  NaN     NaN     NaN
# 2                                                  NaN     NaN     NaN
# 3                                                  NaN     NaN     NaN
# 4                                                  NaN     NaN     NaN
# ..                                                 ...     ...     ...
# 154                                                NaN     NaN     NaN
# 155                                                NaN     NaN     NaN
# 156  [{'service_name': 'YouTube', 'service_url': 'h...     NaN     NaN
# 157                                                NaN     NaN     NaN
# 158                                                NaN     NaN     NaN
#
# [159 rows x 30 columns]

# %%
channel_funcommittee['channel_name'] = 'funcommittee'
channel_funcommittee
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619595e+09  U01S7KCL3DF
# 2    message           NaN  1.617614e+09  U01SK96QF5E
# 3    message           NaN  1.617615e+09  U01RRV4JX6Z
# 4    message           NaN  1.617615e+09  U01S0E0MRJ7
# ..       ...           ...           ...          ...
# 154  message           NaN  1.619546e+09  U01RW2X7S9Z
# 155  message           NaN  1.619547e+09  U01S7KCL3DF
# 156  message           NaN  1.619547e+09  U01RXCQHMHT
# 157  message  channel_join  1.616166e+09  U01RNEU3SNA
# 158  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    in case anyone is hungry for feijoada on satur...
# 2    What did you guys do for Easter? :eyes: I went...
# 3    Its astonishing how Alpacas/Llamas/vicunas are...
# 4                                easter egg coloring:)
# ..                                                 ...
# 154                 this is what i'm needing right now
# 155                       Thank you Japanese fisherman
# 156      <https://www.youtube.com/watch?v=ZXsQAXx_ao0>
# 157              <@U01RNEU3SNA> has joined the channel
# 158              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    38b1be29-6601-49f2-9ec2-a99524c9484d  T01RBRV5F7H  T01RBRV5F7H
# 2    6C6C6CE9-8155-4728-A64B-83ABECAC9A7F          NaN          NaN
# 3    1ea1e83f-b494-493b-80a2-deacfa2f3d26  T01RBRV5F7H  T01RBRV5F7H
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 154  2aabb6c6-f8be-4294-b2d1-546622c56aa8  T01RBRV5F7H  T01RBRV5F7H
# 155  0d88d0f4-2fca-45ab-829e-2c61f762b0c9  T01RBRV5F7H  T01RBRV5F7H
# 156  6352006c-7e75-46fc-868c-8f57a72663c2  T01RBRV5F7H  T01RBRV5F7H
# 157                                   NaN          NaN          NaN
# 158                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 2            NaN                                                NaN  ...
# 3    T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 154  T01RBRV5F7H  {'avatar_hash': '7e12d75d168a', 'image_72': 'h...  ...
# 155  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 156  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 157          NaN                                                NaN  ...
# 158          NaN                                                NaN  ...
#
#     is_locked subscribed parent_user_id bot_id bot_profile  last_read  \
# 0         NaN        NaN            NaN    NaN         NaN        NaN
# 1         NaN        NaN            NaN    NaN         NaN        NaN
# 2         0.0        0.0            NaN    NaN         NaN        NaN
# 3         NaN        NaN    U01SK96QF5E    NaN         NaN        NaN
# 4         NaN        NaN    U01SK96QF5E    NaN         NaN        NaN
# ..        ...        ...            ...    ...         ...        ...
# 154       NaN        NaN    U01RXCQHMHT    NaN         NaN        NaN
# 155       NaN        NaN    U01RXCQHMHT    NaN         NaN        NaN
# 156       NaN        NaN            NaN    NaN         NaN        NaN
# 157       NaN        NaN            NaN    NaN         NaN        NaN
# 158       NaN        NaN            NaN    NaN         NaN        NaN
#
#                                            attachments  edited  inviter  \
# 0                                                  NaN     NaN      NaN
# 1                                                  NaN     NaN      NaN
# 2                                                  NaN     NaN      NaN
# 3                                                  NaN     NaN      NaN
# 4                                                  NaN     NaN      NaN
# ..                                                 ...     ...      ...
# 154                                                NaN     NaN      NaN
# 155                                                NaN     NaN      NaN
# 156  [{'service_name': 'YouTube', 'service_url': 'h...     NaN      NaN
# 157                                                NaN     NaN      NaN
# 158                                                NaN     NaN      NaN
#
#      channel_name
# 0    funcommittee
# 1    funcommittee
# 2    funcommittee
# 3    funcommittee
# 4    funcommittee
# ..            ...
# 154  funcommittee
# 155  funcommittee
# 156  funcommittee
# 157  funcommittee
# 158  funcommittee
#
# [159 rows x 31 columns]

# %%
# save to csv
channel_funcommittee.to_csv(r'../raw_data/fun_committee/channel_funcommittee.csv', index = False)

# %% [markdown]
# ### channel_katas

# %%
### katas channel
# defining file path
path_to_json = '../raw_data/katas/' 
# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_katas = pd.concat(dfs, ignore_index=True)
# test
channel_katas
# Out:
#                             client_msg_id     type  \
# 0    9c1d2d3f-8f81-454f-b226-889b1b448ca0  message
# 1    9b882dbb-5765-484d-a4b3-def269b340f4  message
# 2    f61d6775-34c5-4415-b23e-d50ec374abec  message
# 3    a8c1aec4-b529-411d-9868-25d80d3a8606  message
# 4    665917ef-41f8-4c22-85e3-3a8370bd31aa  message
# ..                                    ...      ...
# 167  2be1b256-f82f-4595-9bac-52058ec61358  message
# 168  ffcf0cf8-92a3-4235-8210-0dd5421d4f4c  message
# 169  627524f7-2692-4e03-a542-61c3f55d6d67  message
# 170  dbd3a788-8ac0-4da3-b16e-5acd857ab571  message
# 171  a98df046-4c44-4bf2-ae2c-1a1f970dee86  message
#
#                                                   text         user  \
# 0    I have an ambition to actually complete a Pyth...  U01S7KCL3DF
# 1            good idea! we havent done any for a while  U01RW140HBP
# 2    Im sure <@U01SJKB2MG8> or <@U01RSRE0N3D> can m...  U01RW140HBP
# 3                                               i'm in  U01RKN0EGDV
# 4                                        :matrix_code:  U01RKN0EGDV
# ..                                                 ...          ...
# 167  no… you might find people do and on a new line...  U01RW140HBP
# 168  <https://www.codewars.com/kata/5a8ed96bfd8c066...  U01RSRE0N3D
# 169  ```hint… WHERE country IN('United States of Am...  U01RW140HBP
# 170  <https://www.codewars.com/kata/5abcf0f930488ff...  U01SJKB2MG8
# 171                                     :harry-potter:  U01RW140HBP
#
#                ts         team    user_team  source_team  \
# 0    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 167  1.617715e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 168  1.617798e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 169  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 170  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 171  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 1    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3    {'avatar_hash': 'abe46e9352ee', 'image_72': 'h...
# 4    {'avatar_hash': 'abe46e9352ee', 'image_72': 'h...
# ..                                                 ...
# 167  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 168  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 169  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 170  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 171  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#                                                 blocks  ...     last_read  \
# 0    [{'type': 'rich_text', 'block_id': 'AiUna', 'e...  ...           NaN
# 1    [{'type': 'rich_text', 'block_id': 'q7bJO', 'e...  ...           NaN
# 2    [{'type': 'rich_text', 'block_id': 'w66Dx', 'e...  ...           NaN
# 3    [{'type': 'rich_text', 'block_id': 'GmAh+', 'e...  ...           NaN
# 4    [{'type': 'rich_text', 'block_id': 'bPY', 'ele...  ...           NaN
# ..                                                 ...  ...           ...
# 167  [{'type': 'rich_text', 'block_id': 'pV5+L', 'e...  ...           NaN
# 168  [{'type': 'rich_text', 'block_id': 'RFWz', 'el...  ...  1.617799e+09
# 169  [{'type': 'rich_text', 'block_id': 'QrO', 'ele...  ...           NaN
# 170  [{'type': 'rich_text', 'block_id': '/XskB', 'e...  ...           NaN
# 171  [{'type': 'rich_text', 'block_id': 'WW2c', 'el...  ...           NaN
#
#      edited  bot_id  bot_profile files upload  display_as_bot  subtype  \
# 0       NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 1       NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 2       NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 3       NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 4       NaN     NaN          NaN   NaN    NaN             NaN      NaN
# ..      ...     ...          ...   ...    ...             ...      ...
# 167     NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 168     NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 169     NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 170     NaN     NaN          NaN   NaN    NaN             NaN      NaN
# 171     NaN     NaN          NaN   NaN    NaN             NaN      NaN
#
#     inviter topic
# 0       NaN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ..      ...   ...
# 167     NaN   NaN
# 168     NaN   NaN
# 169     NaN   NaN
# 170     NaN   NaN
# 171     NaN   NaN
#
# [172 rows x 31 columns]

# %%
channel_katas['channel_name'] = 'katas'
channel_katas
# Out:
#                             client_msg_id     type  \
# 0    9c1d2d3f-8f81-454f-b226-889b1b448ca0  message
# 1    9b882dbb-5765-484d-a4b3-def269b340f4  message
# 2    f61d6775-34c5-4415-b23e-d50ec374abec  message
# 3    a8c1aec4-b529-411d-9868-25d80d3a8606  message
# 4    665917ef-41f8-4c22-85e3-3a8370bd31aa  message
# ..                                    ...      ...
# 167  2be1b256-f82f-4595-9bac-52058ec61358  message
# 168  ffcf0cf8-92a3-4235-8210-0dd5421d4f4c  message
# 169  627524f7-2692-4e03-a542-61c3f55d6d67  message
# 170  dbd3a788-8ac0-4da3-b16e-5acd857ab571  message
# 171  a98df046-4c44-4bf2-ae2c-1a1f970dee86  message
#
#                                                   text         user  \
# 0    I have an ambition to actually complete a Pyth...  U01S7KCL3DF
# 1            good idea! we havent done any for a while  U01RW140HBP
# 2    Im sure <@U01SJKB2MG8> or <@U01RSRE0N3D> can m...  U01RW140HBP
# 3                                               i'm in  U01RKN0EGDV
# 4                                        :matrix_code:  U01RKN0EGDV
# ..                                                 ...          ...
# 167  no… you might find people do and on a new line...  U01RW140HBP
# 168  <https://www.codewars.com/kata/5a8ed96bfd8c066...  U01RSRE0N3D
# 169  ```hint… WHERE country IN('United States of Am...  U01RW140HBP
# 170  <https://www.codewars.com/kata/5abcf0f930488ff...  U01SJKB2MG8
# 171                                     :harry-potter:  U01RW140HBP
#
#                ts         team    user_team  source_team  \
# 0    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4    1.620892e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 167  1.617715e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 168  1.617798e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 169  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 170  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 171  1.617799e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 1    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3    {'avatar_hash': 'abe46e9352ee', 'image_72': 'h...
# 4    {'avatar_hash': 'abe46e9352ee', 'image_72': 'h...
# ..                                                 ...
# 167  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 168  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 169  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 170  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 171  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
#
#                                                 blocks  ...  edited  bot_id  \
# 0    [{'type': 'rich_text', 'block_id': 'AiUna', 'e...  ...     NaN     NaN
# 1    [{'type': 'rich_text', 'block_id': 'q7bJO', 'e...  ...     NaN     NaN
# 2    [{'type': 'rich_text', 'block_id': 'w66Dx', 'e...  ...     NaN     NaN
# 3    [{'type': 'rich_text', 'block_id': 'GmAh+', 'e...  ...     NaN     NaN
# 4    [{'type': 'rich_text', 'block_id': 'bPY', 'ele...  ...     NaN     NaN
# ..                                                 ...  ...     ...     ...
# 167  [{'type': 'rich_text', 'block_id': 'pV5+L', 'e...  ...     NaN     NaN
# 168  [{'type': 'rich_text', 'block_id': 'RFWz', 'el...  ...     NaN     NaN
# 169  [{'type': 'rich_text', 'block_id': 'QrO', 'ele...  ...     NaN     NaN
# 170  [{'type': 'rich_text', 'block_id': '/XskB', 'e...  ...     NaN     NaN
# 171  [{'type': 'rich_text', 'block_id': 'WW2c', 'el...  ...     NaN     NaN
#
#      bot_profile  files upload display_as_bot  subtype  inviter topic  \
# 0            NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 1            NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 2            NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 3            NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 4            NaN    NaN    NaN            NaN      NaN      NaN   NaN
# ..           ...    ...    ...            ...      ...      ...   ...
# 167          NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 168          NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 169          NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 170          NaN    NaN    NaN            NaN      NaN      NaN   NaN
# 171          NaN    NaN    NaN            NaN      NaN      NaN   NaN
#
#     channel_name
# 0          katas
# 1          katas
# 2          katas
# 3          katas
# 4          katas
# ..           ...
# 167        katas
# 168        katas
# 169        katas
# 170        katas
# 171        katas
#
# [172 rows x 32 columns]

# %%
# save to csv
channel_katas.to_csv(r'../raw_data/katas/channel_katas.csv', index = False)

# %% [markdown]
# ### channel_labhelp

# %%
### lab-help channel
# defining file path
path_to_json = '../raw_data/lab-help/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_labhelp = pd.concat(dfs, ignore_index=True)
# test
channel_labhelp
# Out:
#          type       subtype            ts         user  \
# 0     message  channel_join  1.616237e+09  U01S1CWGTU4
# 1     message           NaN  1.617866e+09  U01S79YDELR
# 2     message           NaN  1.617866e+09  U01RW140HBP
# 3     message           NaN  1.617867e+09  U01RW140HBP
# 4     message           NaN  1.617867e+09  U01S79YDELR
# ...       ...           ...           ...          ...
# 1772  message           NaN  1.619542e+09  U01S0E0MRJ7
# 1773  message           NaN  1.619543e+09  U01RW140HBP
# 1774  message           NaN  1.619543e+09  U01RW140HBP
# 1775  message           NaN  1.619543e+09  U01S0E0MRJ7
# 1776  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                    text  \
# 0                 <@U01S1CWGTU4> has joined the channel
# 1     <@U01RSRE0N3D>  <https://www.ibm.com/docs/en/i...
# 2     we will do more on this today in the lesson Ka...
# 3     ok no problem we will revisit rank this mornin...
# 4     it is the syntax in dbeaver, sakila is the dat...
# ...                                                 ...
# 1772  hey im confused. what is this data? i was work...
# 1773  i think Andrea decided to work on a dashboard ...
# 1774                so this is from the superstore data
# 1775  ah ok NP I just saw Phine also had US map and ...
# 1776              <@U01RW2X7S9Z> has joined the channel
#
#                              client_msg_id         team    user_team  \
# 0                                      NaN          NaN          NaN
# 1     d1f113e1-d517-427f-8f17-a8b2695ca580  T01RBRV5F7H  T01RBRV5F7H
# 2     547c153e-d251-492f-8502-81a3b04809cb  T01RBRV5F7H  T01RBRV5F7H
# 3     e04e1c54-28fd-46a3-a61e-f2c976be85d6  T01RBRV5F7H  T01RBRV5F7H
# 4     90ed80d9-2e55-4f1d-ad2c-52f112e8f70f  T01RBRV5F7H  T01RBRV5F7H
# ...                                    ...          ...          ...
# 1772  e1c01335-c973-43d8-b462-161e3735243c  T01RBRV5F7H  T01RBRV5F7H
# 1773  233723f5-fe02-4f1c-8b08-1de2b2913610  T01RBRV5F7H  T01RBRV5F7H
# 1774  a02ee96f-e064-45d8-ac54-dab50887a95e  T01RBRV5F7H  T01RBRV5F7H
# 1775  9214dcbf-8ffe-447b-b970-c182e7260801  T01RBRV5F7H  T01RBRV5F7H
# 1776                                   NaN          NaN          NaN
#
#       source_team                                       user_profile  ...  \
# 0             NaN                                                NaN  ...
# 1     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 3     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 4     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# ...           ...                                                ...  ...
# 1772  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1773  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1774  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1775  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1776          NaN                                                NaN  ...
#
#      last_read attachments  bot_id bot_profile root  old_name  name  x_files  \
# 0          NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1          NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 2          NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 3          NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 4          NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# ...        ...         ...     ...         ...  ...       ...   ...      ...
# 1772       NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1773       NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1774       NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1775       NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
# 1776       NaN         NaN     NaN         NaN  NaN       NaN   NaN      NaN
#
#      inviter hidden
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN
# ...      ...    ...
# 1772     NaN    NaN
# 1773     NaN    NaN
# 1774     NaN    NaN
# 1775     NaN    NaN
# 1776     NaN    NaN
#
# [1777 rows x 35 columns]

# %%
channel_labhelp['channel_name'] = 'labhelp'
channel_labhelp
# Out:
#          type       subtype            ts         user  \
# 0     message  channel_join  1.616237e+09  U01S1CWGTU4
# 1     message           NaN  1.617866e+09  U01S79YDELR
# 2     message           NaN  1.617866e+09  U01RW140HBP
# 3     message           NaN  1.617867e+09  U01RW140HBP
# 4     message           NaN  1.617867e+09  U01S79YDELR
# ...       ...           ...           ...          ...
# 1772  message           NaN  1.619542e+09  U01S0E0MRJ7
# 1773  message           NaN  1.619543e+09  U01RW140HBP
# 1774  message           NaN  1.619543e+09  U01RW140HBP
# 1775  message           NaN  1.619543e+09  U01S0E0MRJ7
# 1776  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                    text  \
# 0                 <@U01S1CWGTU4> has joined the channel
# 1     <@U01RSRE0N3D>  <https://www.ibm.com/docs/en/i...
# 2     we will do more on this today in the lesson Ka...
# 3     ok no problem we will revisit rank this mornin...
# 4     it is the syntax in dbeaver, sakila is the dat...
# ...                                                 ...
# 1772  hey im confused. what is this data? i was work...
# 1773  i think Andrea decided to work on a dashboard ...
# 1774                so this is from the superstore data
# 1775  ah ok NP I just saw Phine also had US map and ...
# 1776              <@U01RW2X7S9Z> has joined the channel
#
#                              client_msg_id         team    user_team  \
# 0                                      NaN          NaN          NaN
# 1     d1f113e1-d517-427f-8f17-a8b2695ca580  T01RBRV5F7H  T01RBRV5F7H
# 2     547c153e-d251-492f-8502-81a3b04809cb  T01RBRV5F7H  T01RBRV5F7H
# 3     e04e1c54-28fd-46a3-a61e-f2c976be85d6  T01RBRV5F7H  T01RBRV5F7H
# 4     90ed80d9-2e55-4f1d-ad2c-52f112e8f70f  T01RBRV5F7H  T01RBRV5F7H
# ...                                    ...          ...          ...
# 1772  e1c01335-c973-43d8-b462-161e3735243c  T01RBRV5F7H  T01RBRV5F7H
# 1773  233723f5-fe02-4f1c-8b08-1de2b2913610  T01RBRV5F7H  T01RBRV5F7H
# 1774  a02ee96f-e064-45d8-ac54-dab50887a95e  T01RBRV5F7H  T01RBRV5F7H
# 1775  9214dcbf-8ffe-447b-b970-c182e7260801  T01RBRV5F7H  T01RBRV5F7H
# 1776                                   NaN          NaN          NaN
#
#       source_team                                       user_profile  ...  \
# 0             NaN                                                NaN  ...
# 1     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 3     T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 4     T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# ...           ...                                                ...  ...
# 1772  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1773  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1774  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 1775  T01RBRV5F7H  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...  ...
# 1776          NaN                                                NaN  ...
#
#      attachments bot_id  bot_profile root old_name  name  x_files  inviter  \
# 0            NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 1            NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 2            NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 3            NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 4            NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# ...          ...    ...          ...  ...      ...   ...      ...      ...
# 1772         NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 1773         NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 1774         NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 1775         NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
# 1776         NaN    NaN          NaN  NaN      NaN   NaN      NaN      NaN
#
#      hidden channel_name
# 0       NaN      labhelp
# 1       NaN      labhelp
# 2       NaN      labhelp
# 3       NaN      labhelp
# 4       NaN      labhelp
# ...     ...          ...
# 1772    NaN      labhelp
# 1773    NaN      labhelp
# 1774    NaN      labhelp
# 1775    NaN      labhelp
# 1776    NaN      labhelp
#
# [1777 rows x 36 columns]

# %%
# save to csv
channel_labhelp.to_csv(r'../raw_data/lab-help/channel_labhelp.csv', index = False)

# %% [markdown]
# ### channel_music

# %%
### music channel
# defining file path
path_to_json = '../raw_data/music/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_music = pd.concat(dfs, ignore_index=True)
# test
channel_music
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.617897e+09  U01S7BM4N81
# 2    message           NaN  1.620900e+09  U01RXCQHMHT
# 3    message           NaN  1.620200e+09  U01S7KCL3DF
# 4    message           NaN  1.620211e+09  U01RSRE0N3D
# ..       ...           ...           ...          ...
# 222  message           NaN  1.619530e+09  U01RXCQHMHT
# 223  message           NaN  1.619535e+09  U01SK96QF5E
# 224  message           NaN  1.619554e+09  U01RXCQHMHT
# 225  message           NaN  1.619586e+09  U01RXCQHMHT
# 226  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1        <https://www.youtube.com/watch?v=qW1eTP9CKSE>
# 2    A thematic name for a playlist\n\n<https://sou...
# 3    <@U01RXCQHMHT> here’s a bangin track about Nig...
# 4    For all of you LotR ravers\n<https://www.youtu...
# ..                                                 ...
# 222  someone showed me a video from the pre-corona ...
# 223  got totally addicted to this playlist since Fr...
# 224  <https://www.youtube.com/watch?v=HeyfOEb7ET0&a...
# 225  <https://soundcloud.com/hate_music/premiere-vo...
# 226              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 2    c097123a-a43a-47a7-8d6b-c4ed6574b2c6  T01RBRV5F7H  T01RBRV5F7H
# 3    a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 4    41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 222  3bd07a1a-d9b4-401a-ab6d-9da03d5c109c  T01RBRV5F7H  T01RBRV5F7H
# 223  d8b6518c-f8d6-4527-b70d-8eceee1bb1df  T01RBRV5F7H  T01RBRV5F7H
# 224  d255756e-a269-4280-9ca6-5f50b2b1cabf  T01RBRV5F7H  T01RBRV5F7H
# 225  3079ffd3-2d1e-41db-a66e-a611d080d371  T01RBRV5F7H  T01RBRV5F7H
# 226                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 3    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 4    T01RBRV5F7H  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...  ...
# ..           ...                                                ...  ...
# 222  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 223  T01RBRV5F7H  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...  ...
# 224  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 225  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 226          NaN                                                NaN  ...
#
#     is_locked subscribed     last_read parent_user_id  files  upload  \
# 0         NaN        NaN           NaN            NaN    NaN     NaN
# 1         NaN        NaN           NaN            NaN    NaN     NaN
# 2         NaN        NaN           NaN            NaN    NaN     NaN
# 3         NaN        NaN           NaN            NaN    NaN     NaN
# 4         0.0        1.0  1.620242e+09            NaN    NaN     NaN
# ..        ...        ...           ...            ...    ...     ...
# 222       NaN        NaN           NaN    U01RXCQHMHT    NaN     NaN
# 223       NaN        NaN           NaN            NaN    NaN     NaN
# 224       NaN        NaN           NaN            NaN    NaN     NaN
# 225       NaN        NaN           NaN            NaN    NaN     NaN
# 226       NaN        NaN           NaN            NaN    NaN     NaN
#
#      display_as_bot  bot_id bot_profile inviter
# 0               NaN     NaN         NaN     NaN
# 1               NaN     NaN         NaN     NaN
# 2               NaN     NaN         NaN     NaN
# 3               NaN     NaN         NaN     NaN
# 4               NaN     NaN         NaN     NaN
# ..              ...     ...         ...     ...
# 222             NaN     NaN         NaN     NaN
# 223             NaN     NaN         NaN     NaN
# 224             NaN     NaN         NaN     NaN
# 225             NaN     NaN         NaN     NaN
# 226             NaN     NaN         NaN     NaN
#
# [227 rows x 30 columns]

# %%
channel_music['channel_name'] = 'music'
channel_music
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.617897e+09  U01S7BM4N81
# 2    message           NaN  1.620900e+09  U01RXCQHMHT
# 3    message           NaN  1.620200e+09  U01S7KCL3DF
# 4    message           NaN  1.620211e+09  U01RSRE0N3D
# ..       ...           ...           ...          ...
# 222  message           NaN  1.619530e+09  U01RXCQHMHT
# 223  message           NaN  1.619535e+09  U01SK96QF5E
# 224  message           NaN  1.619554e+09  U01RXCQHMHT
# 225  message           NaN  1.619586e+09  U01RXCQHMHT
# 226  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1        <https://www.youtube.com/watch?v=qW1eTP9CKSE>
# 2    A thematic name for a playlist\n\n<https://sou...
# 3    <@U01RXCQHMHT> here’s a bangin track about Nig...
# 4    For all of you LotR ravers\n<https://www.youtu...
# ..                                                 ...
# 222  someone showed me a video from the pre-corona ...
# 223  got totally addicted to this playlist since Fr...
# 224  <https://www.youtube.com/watch?v=HeyfOEb7ET0&a...
# 225  <https://soundcloud.com/hate_music/premiere-vo...
# 226              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    98d2a1df-fcab-4a15-a96c-514cd4fa55fa  T01RBRV5F7H  T01RBRV5F7H
# 2    c097123a-a43a-47a7-8d6b-c4ed6574b2c6  T01RBRV5F7H  T01RBRV5F7H
# 3    a153f00e-8a2f-4c0f-9f4f-ebcf678f250e  T01RBRV5F7H  T01RBRV5F7H
# 4    41475476-99d9-41d5-beb7-727785d8cd49  T01RBRV5F7H  T01RBRV5F7H
# ..                                    ...          ...          ...
# 222  3bd07a1a-d9b4-401a-ab6d-9da03d5c109c  T01RBRV5F7H  T01RBRV5F7H
# 223  d8b6518c-f8d6-4527-b70d-8eceee1bb1df  T01RBRV5F7H  T01RBRV5F7H
# 224  d255756e-a269-4280-9ca6-5f50b2b1cabf  T01RBRV5F7H  T01RBRV5F7H
# 225  3079ffd3-2d1e-41db-a66e-a611d080d371  T01RBRV5F7H  T01RBRV5F7H
# 226                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 3    T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 4    T01RBRV5F7H  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...  ...
# ..           ...                                                ...  ...
# 222  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 223  T01RBRV5F7H  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...  ...
# 224  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 225  T01RBRV5F7H  {'avatar_hash': '7290c61c38a0', 'image_72': 'h...  ...
# 226          NaN                                                NaN  ...
#
#     subscribed     last_read parent_user_id files  upload  display_as_bot  \
# 0          NaN           NaN            NaN   NaN     NaN             NaN
# 1          NaN           NaN            NaN   NaN     NaN             NaN
# 2          NaN           NaN            NaN   NaN     NaN             NaN
# 3          NaN           NaN            NaN   NaN     NaN             NaN
# 4          1.0  1.620242e+09            NaN   NaN     NaN             NaN
# ..         ...           ...            ...   ...     ...             ...
# 222        NaN           NaN    U01RXCQHMHT   NaN     NaN             NaN
# 223        NaN           NaN            NaN   NaN     NaN             NaN
# 224        NaN           NaN            NaN   NaN     NaN             NaN
# 225        NaN           NaN            NaN   NaN     NaN             NaN
# 226        NaN           NaN            NaN   NaN     NaN             NaN
#
#      bot_id  bot_profile inviter channel_name
# 0       NaN          NaN     NaN        music
# 1       NaN          NaN     NaN        music
# 2       NaN          NaN     NaN        music
# 3       NaN          NaN     NaN        music
# 4       NaN          NaN     NaN        music
# ..      ...          ...     ...          ...
# 222     NaN          NaN     NaN        music
# 223     NaN          NaN     NaN        music
# 224     NaN          NaN     NaN        music
# 225     NaN          NaN     NaN        music
# 226     NaN          NaN     NaN        music
#
# [227 rows x 31 columns]

# %%
# save to csv
channel_music.to_csv(r'../raw_data/music/channel_music.csv', index = False)

# %% [markdown]
# ### channel_random

# %%
### random channel
# defining file path
path_to_json = '../raw_data/random/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_random = pd.concat(dfs, ignore_index=True)
# test
channel_random
# Out:
#         type                                               text  \
# 0    message                                     <@U01S7BM4N81>
# 1    message  decentralized (which is the original spirit of...
# 2    message  leute we’re missing the bigger picture….Gold, ...
# 3    message                       Oooof how could I miss this?
# 4    message  I think it very much depends on the issuing co...
# ..       ...                                                ...
# 460  message              <@U01RNEU3SNA> has joined the channel
# 461  message              <@U01RS9Y6UJH> has joined the channel
# 462  message              <@U01SK96QF5E> has joined the channel
# 463  message              <@U01RP2K1606> has joined the channel
# 464  message              <@U01RW2X7S9Z> has joined the channel
#
#                                                  files upload  \
# 0    [{'id': 'F021HK4BWG4', 'created': 1620544574, ...    0.0
# 1                                                  NaN    NaN
# 2    [{'id': 'F0218DDJN7P', 'created': 1620549030, ...    0.0
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 460                                                NaN    NaN
# 461                                                NaN    NaN
# 462                                                NaN    NaN
# 463                                                NaN    NaN
# 464                                                NaN    NaN
#
#                                                 blocks         user  \
# 0    [{'type': 'rich_text', 'block_id': 'p4HE', 'el...  U01RRV4JX6Z
# 1    [{'type': 'rich_text', 'block_id': 'Fal', 'ele...  U01S7BM4N81
# 2    [{'type': 'rich_text', 'block_id': 'aFRzS', 'e...  U01S7KCL3DF
# 3    [{'type': 'rich_text', 'block_id': 'mgxv', 'el...  U01S7BM4N81
# 4    [{'type': 'rich_text', 'block_id': 'OMH/u', 'e...  U01RRV4JX6Z
# ..                                                 ...          ...
# 460                                                NaN  U01RNEU3SNA
# 461                                                NaN  U01RS9Y6UJH
# 462                                                NaN  U01SK96QF5E
# 463                                                NaN  U01RP2K1606
# 464                                                NaN  U01RW2X7S9Z
#
#     display_as_bot            ts                         client_msg_id  \
# 0              0.0  1.620545e+09  dd000aef-264c-4bd5-8426-e1e08552643b
# 1              NaN  1.620546e+09  0ad68149-64a1-454e-9e9c-6abf8c3d185c
# 2              0.0  1.620549e+09                                   NaN
# 3              NaN  1.620551e+09  579D4E6F-0E09-4FC7-A811-656CC403647F
# 4              NaN  1.620555e+09  78e0293a-be09-4b28-bf3d-2f70ab3b48fb
# ..             ...           ...                                   ...
# 460            NaN  1.616166e+09                                   NaN
# 461            NaN  1.616167e+09                                   NaN
# 462            NaN  1.616168e+09                                   NaN
# 463            NaN  1.616172e+09                                   NaN
# 464            NaN  1.616172e+09                                   NaN
#
#         thread_ts  ...  source_team  \
# 0    1.620545e+09  ...          NaN
# 1    1.620545e+09  ...  T01RBRV5F7H
# 2    1.620369e+09  ...          NaN
# 3    1.620369e+09  ...  T01RBRV5F7H
# 4    1.620545e+09  ...  T01RBRV5F7H
# ..            ...  ...          ...
# 460           NaN  ...          NaN
# 461           NaN  ...          NaN
# 462           NaN  ...          NaN
# 463           NaN  ...          NaN
# 464           NaN  ...          NaN
#
#                                           user_profile  parent_user_id  \
# 0                                                  NaN             NaN
# 1    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RRV4JX6Z
# 2                                                  NaN     U01RN7BVD1C
# 3    {'avatar_hash': '2adfc641e87e', 'image_72': 'h...     U01RN7BVD1C
# 4    {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...     U01RRV4JX6Z
# ..                                                 ...             ...
# 460                                                NaN             NaN
# 461                                                NaN             NaN
# 462                                                NaN             NaN
# 463                                                NaN             NaN
# 464                                                NaN             NaN
#
#                                              reactions edited  attachments  \
# 0                                                  NaN    NaN          NaN
# 1    [{'name': 'dart', 'users': ['U01S1CWGTU4'], 'c...    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3    [{'name': 'stonks', 'users': ['U01S7KCL3DF', '...    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 460                                                NaN    NaN          NaN
# 461                                                NaN    NaN          NaN
# 462                                                NaN    NaN          NaN
# 463                                                NaN    NaN          NaN
# 464                                                NaN    NaN          NaN
#
#      last_read bot_id bot_profile       subtype
# 0          NaN    NaN         NaN           NaN
# 1          NaN    NaN         NaN           NaN
# 2          NaN    NaN         NaN           NaN
# 3          NaN    NaN         NaN           NaN
# 4          NaN    NaN         NaN           NaN
# ..         ...    ...         ...           ...
# 460        NaN    NaN         NaN  channel_join
# 461        NaN    NaN         NaN  channel_join
# 462        NaN    NaN         NaN  channel_join
# 463        NaN    NaN         NaN  channel_join
# 464        NaN    NaN         NaN  channel_join
#
# [465 rows x 29 columns]

# %%
channel_random['channel_name'] = 'random'
channel_random
# Out:
#         type                                               text  \
# 0    message                                     <@U01S7BM4N81>
# 1    message  decentralized (which is the original spirit of...
# 2    message  leute we’re missing the bigger picture….Gold, ...
# 3    message                       Oooof how could I miss this?
# 4    message  I think it very much depends on the issuing co...
# ..       ...                                                ...
# 460  message              <@U01RNEU3SNA> has joined the channel
# 461  message              <@U01RS9Y6UJH> has joined the channel
# 462  message              <@U01SK96QF5E> has joined the channel
# 463  message              <@U01RP2K1606> has joined the channel
# 464  message              <@U01RW2X7S9Z> has joined the channel
#
#                                                  files upload  \
# 0    [{'id': 'F021HK4BWG4', 'created': 1620544574, ...    0.0
# 1                                                  NaN    NaN
# 2    [{'id': 'F0218DDJN7P', 'created': 1620549030, ...    0.0
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 460                                                NaN    NaN
# 461                                                NaN    NaN
# 462                                                NaN    NaN
# 463                                                NaN    NaN
# 464                                                NaN    NaN
#
#                                                 blocks         user  \
# 0    [{'type': 'rich_text', 'block_id': 'p4HE', 'el...  U01RRV4JX6Z
# 1    [{'type': 'rich_text', 'block_id': 'Fal', 'ele...  U01S7BM4N81
# 2    [{'type': 'rich_text', 'block_id': 'aFRzS', 'e...  U01S7KCL3DF
# 3    [{'type': 'rich_text', 'block_id': 'mgxv', 'el...  U01S7BM4N81
# 4    [{'type': 'rich_text', 'block_id': 'OMH/u', 'e...  U01RRV4JX6Z
# ..                                                 ...          ...
# 460                                                NaN  U01RNEU3SNA
# 461                                                NaN  U01RS9Y6UJH
# 462                                                NaN  U01SK96QF5E
# 463                                                NaN  U01RP2K1606
# 464                                                NaN  U01RW2X7S9Z
#
#     display_as_bot            ts                         client_msg_id  \
# 0              0.0  1.620545e+09  dd000aef-264c-4bd5-8426-e1e08552643b
# 1              NaN  1.620546e+09  0ad68149-64a1-454e-9e9c-6abf8c3d185c
# 2              0.0  1.620549e+09                                   NaN
# 3              NaN  1.620551e+09  579D4E6F-0E09-4FC7-A811-656CC403647F
# 4              NaN  1.620555e+09  78e0293a-be09-4b28-bf3d-2f70ab3b48fb
# ..             ...           ...                                   ...
# 460            NaN  1.616166e+09                                   NaN
# 461            NaN  1.616167e+09                                   NaN
# 462            NaN  1.616168e+09                                   NaN
# 463            NaN  1.616172e+09                                   NaN
# 464            NaN  1.616172e+09                                   NaN
#
#         thread_ts  ...                                       user_profile  \
# 0    1.620545e+09  ...                                                NaN
# 1    1.620545e+09  ...  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 2    1.620369e+09  ...                                                NaN
# 3    1.620369e+09  ...  {'avatar_hash': '2adfc641e87e', 'image_72': 'h...
# 4    1.620545e+09  ...  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ..            ...  ...                                                ...
# 460           NaN  ...                                                NaN
# 461           NaN  ...                                                NaN
# 462           NaN  ...                                                NaN
# 463           NaN  ...                                                NaN
# 464           NaN  ...                                                NaN
#
#      parent_user_id                                          reactions edited  \
# 0               NaN                                                NaN    NaN
# 1       U01RRV4JX6Z  [{'name': 'dart', 'users': ['U01S1CWGTU4'], 'c...    NaN
# 2       U01RN7BVD1C                                                NaN    NaN
# 3       U01RN7BVD1C  [{'name': 'stonks', 'users': ['U01S7KCL3DF', '...    NaN
# 4       U01RRV4JX6Z                                                NaN    NaN
# ..              ...                                                ...    ...
# 460             NaN                                                NaN    NaN
# 461             NaN                                                NaN    NaN
# 462             NaN                                                NaN    NaN
# 463             NaN                                                NaN    NaN
# 464             NaN                                                NaN    NaN
#
#     attachments  last_read  bot_id bot_profile       subtype channel_name
# 0           NaN        NaN     NaN         NaN           NaN       random
# 1           NaN        NaN     NaN         NaN           NaN       random
# 2           NaN        NaN     NaN         NaN           NaN       random
# 3           NaN        NaN     NaN         NaN           NaN       random
# 4           NaN        NaN     NaN         NaN           NaN       random
# ..          ...        ...     ...         ...           ...          ...
# 460         NaN        NaN     NaN         NaN  channel_join       random
# 461         NaN        NaN     NaN         NaN  channel_join       random
# 462         NaN        NaN     NaN         NaN  channel_join       random
# 463         NaN        NaN     NaN         NaN  channel_join       random
# 464         NaN        NaN     NaN         NaN  channel_join       random
#
# [465 rows x 30 columns]

# %%
# save to csv
channel_random.to_csv(r'../raw_data/random/channel_random.csv', index = False)

# %% [markdown]
# ### channel_vanilla

# %%
### vanilla_plus_more channel
# defining file path
path_to_json = '../raw_data/vanilla_plus_more/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_vanilla = pd.concat(dfs, ignore_index=True)
# test
channel_vanilla
# Out:
#                            client_msg_id     type  \
# 0   8e064300-53cc-41fc-ba3d-4e91e2c08c29  message
# 1                                    NaN  message
# 2                                    NaN  message
# 3                                    NaN  message
# 4                                    NaN  message
# 5                                    NaN  message
# 6                                    NaN  message
# 7   4fa27f27-ab48-484f-a533-618372e1fc2a  message
# 8   ee7a5ff1-78a3-405f-9708-cdd1341e63fe  message
# 9                                    NaN  message
# 10                                   NaN  message
# 11                                   NaN  message
# 12  d4dbab7e-4cf4-41b2-a757-cb742906e69c  message
# 13                                   NaN  message
# 14                                   NaN  message
# 15                                   NaN  message
# 16                                   NaN  message
# 17                                   NaN  message
# 18  91408448-9d71-4e9c-b843-027ac87d700a  message
# 19                                   NaN  message
# 20                                   NaN  message
# 21                                   NaN  message
# 22  7d6a7c94-05cd-4f77-90cd-b0ea898dcf51  message
# 23                                   NaN  message
# 24  bf443b38-0344-4475-8566-cff212d62e95  message
# 25                                   NaN  message
# 26  3d4e6b69-bf6c-4c44-9b3f-73d06a942f56  message
# 27  688c219f-d79d-4d97-90b1-4775ca9fc066  message
# 28  8379b0d9-3f32-4640-b862-bfc145490afa  message
# 29  2e58f4f3-c217-424a-a2bf-b5e8ae0599ae  message
# 30  479b925a-b941-42c6-99a1-ba3f6101cd91  message
# 31  8ef58321-5220-46aa-9f53-f0df443cd398  message
# 32  e40bbb01-efc0-4ab9-a7dd-665bf168af0c  message
#
#                                                  text         user  \
# 0   I think there's no need in treating Pandas as ...  U01SJKB2MG8
# 1               <@U01RW140HBP> has joined the channel  U01RW140HBP
# 2   <@U01RW140HBP> set the channel description: th...  U01RW140HBP
# 3               <@U01SJKB2MG8> has joined the channel  U01SJKB2MG8
# 4               <@U01RSRE0N3D> has joined the channel  U01RSRE0N3D
# 5                                                      U01SJKB2MG8
# 6               <@U01RKN0EGDV> has joined the channel  U01RKN0EGDV
# 7   Pandas intro on Kaggle - this is a great littl...  U01RW140HBP
# 8                might be good for you <@U01S79YDELR>  U01RW140HBP
# 9               <@U01S79YDELR> has joined the channel  U01S79YDELR
# 10              <@U01S7KCL3DF> has joined the channel  U01S7KCL3DF
# 11              <@U01S133DZ9A> has joined the channel  U01S133DZ9A
# 12  if you find yourself asking: “what are these *...  U01RW140HBP
# 13                                   generic dtypes :  U01RW140HBP
# 14                                    python dtypes :  U01RW140HBP
# 15                                     mysql dtypes :  U01RW140HBP
# 16                                   tableau dtypes :  U01RW140HBP
# 17              <@U01S0MFJ3HR> has joined the channel  U01S0MFJ3HR
# 18  a quick bonus lab on STRINGS <https://github.c...  U01RW140HBP
# 19              <@U01RV3K524T> has joined the channel  U01RV3K524T
# 20              <@U01SD3CDH9P> has joined the channel  U01SD3CDH9P
# 21              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 22  1.5 hours in. I'm struggling with Question 2. ...  U01S133DZ9A
# 23              <@U01RN7BVD1C> has joined the channel  U01RN7BVD1C
# 24  thats ok… we can do a breakout call and go thr...  U01RW140HBP
# 25              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 26  i’ve been going back over the Kaggles chapters...  U01S7KCL3DF
# 27  or ask one of the TAs to do the same with you,...  U01RW140HBP
# 28                              Just saw this. Thanks  U01S133DZ9A
# 29  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 30          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 31      I will have a look after the presentation :v:  U01RSRE0N3D
# 32  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#               ts         team    user_team  source_team  \
# 0   1.617869e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1.617637e+09          NaN          NaN          NaN
# 2   1.617637e+09          NaN          NaN          NaN
# 3   1.617637e+09          NaN          NaN          NaN
# 4   1.617637e+09          NaN          NaN          NaN
# 5   1.617637e+09          NaN          NaN          NaN
# 6   1.617637e+09          NaN          NaN          NaN
# 7   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9   1.617637e+09          NaN          NaN          NaN
# 10  1.617637e+09          NaN          NaN          NaN
# 11  1.617638e+09          NaN          NaN          NaN
# 12  1.617638e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 13  1.617638e+09          NaN          NaN          NaN
# 14  1.617638e+09          NaN          NaN          NaN
# 15  1.617638e+09          NaN          NaN          NaN
# 16  1.617638e+09          NaN          NaN          NaN
# 17  1.617638e+09          NaN          NaN          NaN
# 18  1.617639e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 19  1.617644e+09          NaN          NaN          NaN
# 20  1.617644e+09          NaN          NaN          NaN
# 21  1.617652e+09          NaN          NaN          NaN
# 22  1.617658e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 23  1.617691e+09          NaN          NaN          NaN
# 24  1.617692e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 25  1.620808e+09          NaN          NaN          NaN
# 26  1.619986e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 27  1.617693e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 28  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 29  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 30  1.620399e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 31  1.620400e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 32  1.617832e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                          user_profile  \
# 0   {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 8   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 23                                                NaN
# 24  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 25                                                NaN
# 26  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 27  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 28  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 29  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 30  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 31  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 32  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                                edited  ... display_as_bot  \
# 0   {'user': 'U01SJKB2MG8', 'ts': '1617869310.0000...  ...            NaN
# 1                                                 NaN  ...            NaN
# 2                                                 NaN  ...            NaN
# 3                                                 NaN  ...            NaN
# 4                                                 NaN  ...            NaN
# 5                                                 NaN  ...            0.0
# 6                                                 NaN  ...            NaN
# 7                                                 NaN  ...            NaN
# 8                                                 NaN  ...            NaN
# 9                                                 NaN  ...            NaN
# 10                                                NaN  ...            NaN
# 11                                                NaN  ...            NaN
# 12  {'user': 'U01RW140HBP', 'ts': '1617638000.0000...  ...            NaN
# 13                                                NaN  ...            0.0
# 14                                                NaN  ...            0.0
# 15                                                NaN  ...            0.0
# 16                                                NaN  ...            0.0
# 17                                                NaN  ...            NaN
# 18  {'user': 'U01RW140HBP', 'ts': '1617638650.0000...  ...            NaN
# 19                                                NaN  ...            NaN
# 20                                                NaN  ...            NaN
# 21                                                NaN  ...            NaN
# 22                                                NaN  ...            NaN
# 23                                                NaN  ...            NaN
# 24                                                NaN  ...            NaN
# 25                                                NaN  ...            NaN
# 26                                                NaN  ...            NaN
# 27                                                NaN  ...            NaN
# 28                                                NaN  ...            NaN
# 29                                                NaN  ...            NaN
# 30                                                NaN  ...            NaN
# 31                                                NaN  ...            NaN
# 32                                                NaN  ...            NaN
#
#                                           attachments reply_count  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7   [{'title': 'Learn Pandas Tutorials', 'title_li...         1.0
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         4.0
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18                                                NaN         5.0
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26  [{'title': 'Summary Functions and Maps', 'titl...         2.0
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         NaN
# 32                                                NaN         1.0
#
#    reply_users_count  latest_reply                 reply_users  \
# 0                NaN           NaN                         NaN
# 1                NaN           NaN                         NaN
# 2                NaN           NaN                         NaN
# 3                NaN           NaN                         NaN
# 4                NaN           NaN                         NaN
# 5                NaN           NaN                         NaN
# 6                NaN           NaN                         NaN
# 7                1.0  1.617637e+09               [U01RW140HBP]
# 8                NaN           NaN                         NaN
# 9                NaN           NaN                         NaN
# 10               NaN           NaN                         NaN
# 11               NaN           NaN                         NaN
# 12               1.0  1.617638e+09               [U01RW140HBP]
# 13               NaN           NaN                         NaN
# 14               NaN           NaN                         NaN
# 15               NaN           NaN                         NaN
# 16               NaN           NaN                         NaN
# 17               NaN           NaN                         NaN
# 18               2.0  1.617727e+09  [U01S133DZ9A, U01RW140HBP]
# 19               NaN           NaN                         NaN
# 20               NaN           NaN                         NaN
# 21               NaN           NaN                         NaN
# 22               NaN           NaN                         NaN
# 23               NaN           NaN                         NaN
# 24               NaN           NaN                         NaN
# 25               NaN           NaN                         NaN
# 26               2.0  1.620400e+09  [U01S7KCL3DF, U01RSRE0N3D]
# 27               NaN           NaN                         NaN
# 28               NaN           NaN                         NaN
# 29               NaN           NaN                         NaN
# 30               NaN           NaN                         NaN
# 31               NaN           NaN                         NaN
# 32               1.0  1.617869e+09               [U01SJKB2MG8]
#
#                                               replies is_locked  subscribed  \
# 0                                                 NaN       NaN         NaN
# 1                                                 NaN       NaN         NaN
# 2                                                 NaN       NaN         NaN
# 3                                                 NaN       NaN         NaN
# 4                                                 NaN       NaN         NaN
# 5                                                 NaN       NaN         NaN
# 6                                                 NaN       NaN         NaN
# 7   [{'user': 'U01RW140HBP', 'ts': '1617637354.002...       0.0         0.0
# 8                                                 NaN       NaN         NaN
# 9                                                 NaN       NaN         NaN
# 10                                                NaN       NaN         NaN
# 11                                                NaN       NaN         NaN
# 12  [{'user': 'U01RW140HBP', 'ts': '1617638007.007...       0.0         0.0
# 13                                                NaN       NaN         NaN
# 14                                                NaN       NaN         NaN
# 15                                                NaN       NaN         NaN
# 16                                                NaN       NaN         NaN
# 17                                                NaN       NaN         NaN
# 18  [{'user': 'U01S133DZ9A', 'ts': '1617658367.010...       0.0         0.0
# 19                                                NaN       NaN         NaN
# 20                                                NaN       NaN         NaN
# 21                                                NaN       NaN         NaN
# 22                                                NaN       NaN         NaN
# 23                                                NaN       NaN         NaN
# 24                                                NaN       NaN         NaN
# 25                                                NaN       NaN         NaN
# 26  [{'user': 'U01S7KCL3DF', 'ts': '1620398926.000...     False        True
# 27                                                NaN       NaN         NaN
# 28                                                NaN       NaN         NaN
# 29                                                NaN       NaN         NaN
# 30                                                NaN       NaN         NaN
# 31                                                NaN       NaN         NaN
# 32  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...     False       False
#
#        last_read
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26  1.620400e+09
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
#
# [33 rows x 29 columns]

# %%
channel_vanilla['channel_name'] = 'vanilla'
channel_vanilla
# Out:
#                            client_msg_id     type  \
# 0   8e064300-53cc-41fc-ba3d-4e91e2c08c29  message
# 1                                    NaN  message
# 2                                    NaN  message
# 3                                    NaN  message
# 4                                    NaN  message
# 5                                    NaN  message
# 6                                    NaN  message
# 7   4fa27f27-ab48-484f-a533-618372e1fc2a  message
# 8   ee7a5ff1-78a3-405f-9708-cdd1341e63fe  message
# 9                                    NaN  message
# 10                                   NaN  message
# 11                                   NaN  message
# 12  d4dbab7e-4cf4-41b2-a757-cb742906e69c  message
# 13                                   NaN  message
# 14                                   NaN  message
# 15                                   NaN  message
# 16                                   NaN  message
# 17                                   NaN  message
# 18  91408448-9d71-4e9c-b843-027ac87d700a  message
# 19                                   NaN  message
# 20                                   NaN  message
# 21                                   NaN  message
# 22  7d6a7c94-05cd-4f77-90cd-b0ea898dcf51  message
# 23                                   NaN  message
# 24  bf443b38-0344-4475-8566-cff212d62e95  message
# 25                                   NaN  message
# 26  3d4e6b69-bf6c-4c44-9b3f-73d06a942f56  message
# 27  688c219f-d79d-4d97-90b1-4775ca9fc066  message
# 28  8379b0d9-3f32-4640-b862-bfc145490afa  message
# 29  2e58f4f3-c217-424a-a2bf-b5e8ae0599ae  message
# 30  479b925a-b941-42c6-99a1-ba3f6101cd91  message
# 31  8ef58321-5220-46aa-9f53-f0df443cd398  message
# 32  e40bbb01-efc0-4ab9-a7dd-665bf168af0c  message
#
#                                                  text         user  \
# 0   I think there's no need in treating Pandas as ...  U01SJKB2MG8
# 1               <@U01RW140HBP> has joined the channel  U01RW140HBP
# 2   <@U01RW140HBP> set the channel description: th...  U01RW140HBP
# 3               <@U01SJKB2MG8> has joined the channel  U01SJKB2MG8
# 4               <@U01RSRE0N3D> has joined the channel  U01RSRE0N3D
# 5                                                      U01SJKB2MG8
# 6               <@U01RKN0EGDV> has joined the channel  U01RKN0EGDV
# 7   Pandas intro on Kaggle - this is a great littl...  U01RW140HBP
# 8                might be good for you <@U01S79YDELR>  U01RW140HBP
# 9               <@U01S79YDELR> has joined the channel  U01S79YDELR
# 10              <@U01S7KCL3DF> has joined the channel  U01S7KCL3DF
# 11              <@U01S133DZ9A> has joined the channel  U01S133DZ9A
# 12  if you find yourself asking: “what are these *...  U01RW140HBP
# 13                                   generic dtypes :  U01RW140HBP
# 14                                    python dtypes :  U01RW140HBP
# 15                                     mysql dtypes :  U01RW140HBP
# 16                                   tableau dtypes :  U01RW140HBP
# 17              <@U01S0MFJ3HR> has joined the channel  U01S0MFJ3HR
# 18  a quick bonus lab on STRINGS <https://github.c...  U01RW140HBP
# 19              <@U01RV3K524T> has joined the channel  U01RV3K524T
# 20              <@U01SD3CDH9P> has joined the channel  U01SD3CDH9P
# 21              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 22  1.5 hours in. I'm struggling with Question 2. ...  U01S133DZ9A
# 23              <@U01RN7BVD1C> has joined the channel  U01RN7BVD1C
# 24  thats ok… we can do a breakout call and go thr...  U01RW140HBP
# 25              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 26  i’ve been going back over the Kaggles chapters...  U01S7KCL3DF
# 27  or ask one of the TAs to do the same with you,...  U01RW140HBP
# 28                              Just saw this. Thanks  U01S133DZ9A
# 29  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 30          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 31      I will have a look after the presentation :v:  U01RSRE0N3D
# 32  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#               ts         team    user_team  source_team  \
# 0   1.617869e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1   1.617637e+09          NaN          NaN          NaN
# 2   1.617637e+09          NaN          NaN          NaN
# 3   1.617637e+09          NaN          NaN          NaN
# 4   1.617637e+09          NaN          NaN          NaN
# 5   1.617637e+09          NaN          NaN          NaN
# 6   1.617637e+09          NaN          NaN          NaN
# 7   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 8   1.617637e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 9   1.617637e+09          NaN          NaN          NaN
# 10  1.617637e+09          NaN          NaN          NaN
# 11  1.617638e+09          NaN          NaN          NaN
# 12  1.617638e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 13  1.617638e+09          NaN          NaN          NaN
# 14  1.617638e+09          NaN          NaN          NaN
# 15  1.617638e+09          NaN          NaN          NaN
# 16  1.617638e+09          NaN          NaN          NaN
# 17  1.617638e+09          NaN          NaN          NaN
# 18  1.617639e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 19  1.617644e+09          NaN          NaN          NaN
# 20  1.617644e+09          NaN          NaN          NaN
# 21  1.617652e+09          NaN          NaN          NaN
# 22  1.617658e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 23  1.617691e+09          NaN          NaN          NaN
# 24  1.617692e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 25  1.620808e+09          NaN          NaN          NaN
# 26  1.619986e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 27  1.617693e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 28  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 29  1.617727e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 30  1.620399e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 31  1.620400e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 32  1.617832e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                          user_profile  \
# 0   {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 8   {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 23                                                NaN
# 24  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 25                                                NaN
# 26  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 27  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 28  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 29  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 30  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 31  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 32  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#                                                edited  ...  \
# 0   {'user': 'U01SJKB2MG8', 'ts': '1617869310.0000...  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12  {'user': 'U01RW140HBP', 'ts': '1617638000.0000...  ...
# 13                                                NaN  ...
# 14                                                NaN  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                                                NaN  ...
# 18  {'user': 'U01RW140HBP', 'ts': '1617638650.0000...  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24                                                NaN  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27                                                NaN  ...
# 28                                                NaN  ...
# 29                                                NaN  ...
# 30                                                NaN  ...
# 31                                                NaN  ...
# 32                                                NaN  ...
#
#                                           attachments  reply_count  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7   [{'title': 'Learn Pandas Tutorials', 'title_li...          1.0
# 8                                                 NaN          NaN
# 9                                                 NaN          NaN
# 10                                                NaN          NaN
# 11                                                NaN          NaN
# 12                                                NaN          4.0
# 13                                                NaN          NaN
# 14                                                NaN          NaN
# 15                                                NaN          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          5.0
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26  [{'title': 'Summary Functions and Maps', 'titl...          2.0
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          NaN
# 32                                                NaN          1.0
#
#    reply_users_count  latest_reply                 reply_users  \
# 0                NaN           NaN                         NaN
# 1                NaN           NaN                         NaN
# 2                NaN           NaN                         NaN
# 3                NaN           NaN                         NaN
# 4                NaN           NaN                         NaN
# 5                NaN           NaN                         NaN
# 6                NaN           NaN                         NaN
# 7                1.0  1.617637e+09               [U01RW140HBP]
# 8                NaN           NaN                         NaN
# 9                NaN           NaN                         NaN
# 10               NaN           NaN                         NaN
# 11               NaN           NaN                         NaN
# 12               1.0  1.617638e+09               [U01RW140HBP]
# 13               NaN           NaN                         NaN
# 14               NaN           NaN                         NaN
# 15               NaN           NaN                         NaN
# 16               NaN           NaN                         NaN
# 17               NaN           NaN                         NaN
# 18               2.0  1.617727e+09  [U01S133DZ9A, U01RW140HBP]
# 19               NaN           NaN                         NaN
# 20               NaN           NaN                         NaN
# 21               NaN           NaN                         NaN
# 22               NaN           NaN                         NaN
# 23               NaN           NaN                         NaN
# 24               NaN           NaN                         NaN
# 25               NaN           NaN                         NaN
# 26               2.0  1.620400e+09  [U01S7KCL3DF, U01RSRE0N3D]
# 27               NaN           NaN                         NaN
# 28               NaN           NaN                         NaN
# 29               NaN           NaN                         NaN
# 30               NaN           NaN                         NaN
# 31               NaN           NaN                         NaN
# 32               1.0  1.617869e+09               [U01SJKB2MG8]
#
#                                               replies is_locked subscribed  \
# 0                                                 NaN       NaN        NaN
# 1                                                 NaN       NaN        NaN
# 2                                                 NaN       NaN        NaN
# 3                                                 NaN       NaN        NaN
# 4                                                 NaN       NaN        NaN
# 5                                                 NaN       NaN        NaN
# 6                                                 NaN       NaN        NaN
# 7   [{'user': 'U01RW140HBP', 'ts': '1617637354.002...       0.0        0.0
# 8                                                 NaN       NaN        NaN
# 9                                                 NaN       NaN        NaN
# 10                                                NaN       NaN        NaN
# 11                                                NaN       NaN        NaN
# 12  [{'user': 'U01RW140HBP', 'ts': '1617638007.007...       0.0        0.0
# 13                                                NaN       NaN        NaN
# 14                                                NaN       NaN        NaN
# 15                                                NaN       NaN        NaN
# 16                                                NaN       NaN        NaN
# 17                                                NaN       NaN        NaN
# 18  [{'user': 'U01S133DZ9A', 'ts': '1617658367.010...       0.0        0.0
# 19                                                NaN       NaN        NaN
# 20                                                NaN       NaN        NaN
# 21                                                NaN       NaN        NaN
# 22                                                NaN       NaN        NaN
# 23                                                NaN       NaN        NaN
# 24                                                NaN       NaN        NaN
# 25                                                NaN       NaN        NaN
# 26  [{'user': 'U01S7KCL3DF', 'ts': '1620398926.000...     False       True
# 27                                                NaN       NaN        NaN
# 28                                                NaN       NaN        NaN
# 29                                                NaN       NaN        NaN
# 30                                                NaN       NaN        NaN
# 31                                                NaN       NaN        NaN
# 32  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...     False      False
#
#        last_read  channel_name
# 0            NaN       vanilla
# 1            NaN       vanilla
# 2            NaN       vanilla
# 3            NaN       vanilla
# 4            NaN       vanilla
# 5            NaN       vanilla
# 6            NaN       vanilla
# 7            NaN       vanilla
# 8            NaN       vanilla
# 9            NaN       vanilla
# 10           NaN       vanilla
# 11           NaN       vanilla
# 12           NaN       vanilla
# 13           NaN       vanilla
# 14           NaN       vanilla
# 15           NaN       vanilla
# 16           NaN       vanilla
# 17           NaN       vanilla
# 18           NaN       vanilla
# 19           NaN       vanilla
# 20           NaN       vanilla
# 21           NaN       vanilla
# 22           NaN       vanilla
# 23           NaN       vanilla
# 24           NaN       vanilla
# 25           NaN       vanilla
# 26  1.620400e+09       vanilla
# 27           NaN       vanilla
# 28           NaN       vanilla
# 29           NaN       vanilla
# 30           NaN       vanilla
# 31           NaN       vanilla
# 32           NaN       vanilla
#
# [33 rows x 30 columns]

# %%
# save to csv
channel_vanilla.to_csv(r'../raw_data/vanilla_plus_more/channel_vanilla.csv', index = False)

# %%
#frames = [channel_gen, channel_books, channel_dmemes, channel_dresource, channel_dbootcamp, channel_funcommittee, channel_dvizbeauties, channel_frustrations, channel_finalproject, channel_frustrations, channel_funcommittee, channel_katas, channel_labhelp, channel_music, channel_random, channel_vanilla]

df = pd.concat([channel_gen, channel_books,
                    channel_dmemes, channel_dresource, 
                    channel_dbootcamp, channel_funcommittee,
                    channel_dvizbeauties, channel_frustrations, 
                    channel_finalproject, channel_frustrations, 
                    channel_funcommittee, channel_katas, 
                    channel_labhelp, channel_music, 
                    channel_random, channel_vanilla], ignore_index=True, join="outer")

# %% [markdown]
# **Assessment Part1**

# %%
# assess shape
df.shape
# Out:
# (5263, 13)

# %%
# make a copy
df_copy = df.copy()

# %%
# assess column names
df.columns
# Out:
# Index(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'user_team',
#        'source_team', 'user_profile', 'blocks', 'thread_ts', 'parent_user_id',
#        'edited', 'reply_count', 'reply_users_count', 'latest_reply',
#        'reply_users', 'replies', 'is_locked', 'subscribed', 'attachments',
#        'files', 'upload', 'display_as_bot', 'reactions', 'last_read', 'bot_id',
#        'bot_profile', 'subtype', 'topic', 'root', 'purpose', 'channel_name',
#        'inviter', 'old_name', 'name', 'x_files', 'hidden'],
#       dtype='object')

# %%
# check how many values each channel has
df.channel_name.value_counts()
# Out:
# labhelp         1777
# general         1342
# random           465
# funcommittee     318
# dmemes           302
# dvizbeauties     265
# music            227
# dresource        199
# katas            172
# finalproject     134
# vanilla           33
# dbootcamp         20
# frustrations       6
# books              3
# Name: channel_name, dtype: int64

# %%
# check for outliers in the numerical part
df.describe()
# Out:
#                  ts     thread_ts  reply_count  reply_users_count  \
# count  5.263000e+03  4.044000e+03   597.000000         597.000000
# mean   1.618807e+09  1.619015e+09     5.773869           2.631491
# std    1.585420e+06  1.507222e+06     5.888003           1.595362
# min    1.616107e+09  1.616406e+09     1.000000           1.000000
# 25%    1.617290e+09  1.617716e+09     2.000000           2.000000
# 50%    1.619012e+09  1.619424e+09     4.000000           2.000000
# 75%    1.620293e+09  1.620365e+09     7.000000           3.000000
# max    1.621322e+09  1.621322e+09    45.000000          16.000000
#
#        latest_reply     last_read  hidden
# count  5.970000e+02  9.400000e+01     1.0
# mean   1.618809e+09  1.618640e+09     1.0
# std    1.524235e+06  1.514550e+06     NaN
# min    1.616414e+09  1.616414e+09     1.0
# 25%    1.617368e+09  1.617205e+09     1.0
# 50%    1.618990e+09  1.618482e+09     1.0
# 75%    1.620285e+09  1.620201e+09     1.0
# max    1.621322e+09  1.621242e+09     1.0

# %% [markdown]
# There are no outliers in this data, it seems healthy.

# %% [markdown]
# **Summary of Assesment Part1**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# **Columns to clean & wrangle:**\
#     - subtype: filter out it's values from df, remove the original column\
#     - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day\
#     - user_profile: extract real_name in new column, remove the original\
#     - attachments: extract title, text, link in new columns\
#     - files: extract url_private and who shared\
#     - attachments: extract title, text, link in new columns\
#     - reactions: extract user, count, name of the emoji\
#
# **Columns to visualise**
#     - reply_count: how many
#     - reply_users_count: how many
#     - reply_users: who
#     - replies: who and when
#     - files, attachment, reactions

# %% [markdown]
# **Cleaning Part1**

# %%
# drop columns
df.drop(['type', 'client_msg_id', 'team',
       'user_team', 'source_team', 'blocks', 'upload', 'display_as_bot',
       'thread_ts', 'latest_reply', 'is_locked', 'subscribed',
       'parent_user_id', 'bot_id', 'bot_profile', 'last_read', 'edited',
       'purpose', 'inviter', 'topic', 'root', 'old_name', 'name', 'hidden',
       'x_files'], axis=1, inplace=True)

# %%
# test
df.shape
# Out:
# (5263, 13)

# %%
df.head()
# Out:
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#              ts                                       user_profile  \
# 0  1.620547e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1  1.620547e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2  1.620574e+09  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3  1.620574e+09  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4  1.620574e+09  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#    reply_count  reply_users_count                 reply_users  \
# 0          NaN                NaN                         NaN
# 1          NaN                NaN                         NaN
# 2         31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3          NaN                NaN                         NaN
# 4          NaN                NaN                         NaN
#
#                                              replies attachments files  \
# 0                                                NaN         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                NaN         NaN   NaN
# 4                                                NaN         NaN   NaN
#
#   reactions subtype channel_name
# 0       NaN     NaN      general
# 1       NaN     NaN      general
# 2       NaN     NaN      general
# 3       NaN     NaN      general
# 4       NaN     NaN      general

# %% [markdown]
# **Assessment Part2**

# %%
# list of columns, their non-null objects and data type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5263 entries, 0 to 5262
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   text               5263 non-null   object
#  1   user               5262 non-null   object
#  2   ts                 5263 non-null   float64
#  3   user_profile       4284 non-null   object
#  4   reply_count        597 non-null    float64
#  5   reply_users_count  597 non-null    float64
#  6   reply_users        597 non-null    object
#  7   replies            597 non-null    object
#  8   attachments        430 non-null    object
#  9   files              535 non-null    object
#  10  reactions          1138 non-null   object
#  11  subtype            336 non-null    object
#  12  channel_name       5263 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 534.6+ KB

# %%
# check, if there are any nulls and NaN values in our data set
df.isna().sum()
# Out:
# text                    0
# user                    1
# ts                      0
# user_profile          979
# reply_count          4666
# reply_users_count    4666
# reply_users          4666
# replies              4666
# attachments          4833
# files                4728
# reactions            4125
# subtype              4927
# channel_name            0
# dtype: int64

# %%
#to summarise this in one line of code and round the values 
df.isna().mean().round(4) *100
# Out:
# text                  0.00
# user                  0.02
# ts                    0.00
# user_profile         18.60
# reply_count          88.66
# reply_users_count    88.66
# reply_users          88.66
# replies              88.66
# attachments          91.83
# files                89.83
# reactions            78.38
# subtype              93.62
# channel_name          0.00
# dtype: float64

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. The only important thing is that each value is coming from a user, and it is because I can see there are no missing values at the text or user columns. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
df['subtype'].value_counts()
# Out:
# channel_join        313
# channel_topic         9
# channel_purpose       8
# channel_name          2
# thread_broadcast      2
# bot_message           1
# tombstone             1
# Name: subtype, dtype: int64

# %%
# filter out for the rows which has subtype values
df_clean = df[(df.subtype != 'channel_join') & 
                                (df.subtype != 'channel_join') &
                                (df.subtype != 'channel_purpose') &
                                (df.subtype != 'thread_broadcast')]


#test 
df_clean.shape
# Out:
# (4940, 13)

# %%
# drop subtype column
df_clean.drop('subtype', axis=1, inplace=True) 

#test
df_clean.shape
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (4940, 12)

# %%
#convert ts to datetime from float
from datetime import datetime
df_clean['ts'] = pd.to_datetime(df['ts'], unit='s')

# remove miliseconds 
df_clean['ts'] = df_clean['ts'].astype('datetime64[s]')

df_clean
# Out:
# <ipython-input-60-c34f63df5ac6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['ts'] = pd.to_datetime(df['ts'], unit='s')
# <ipython-input-60-c34f63df5ac6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['ts'] = df_clean['ts'].astype('datetime64[s]')
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 5258 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5259 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5260 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 5261 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 5262 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
# [4940 rows x 12 columns]

# %%
# create a column for the days of the week using the ts column

df_clean['day_name'] = df_clean['ts'].dt.day_name()
df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
df_clean
# Out:
# <ipython-input-61-caaf00226462>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_name'] = df_clean['ts'].dt.day_name()
# <ipython-input-61-caaf00226462>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 5258 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5259 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5260 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 5261 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 5262 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number
# 0        Sunday           9
# 1        Sunday           9
# 2        Sunday           9
# 3        Sunday           9
# 4        Sunday           9
# ...         ...         ...
# 5258    Tuesday           6
# 5259    Tuesday           6
# 5260     Friday           7
# 5261     Friday           7
# 5262  Wednesday           7
#
# [4940 rows x 14 columns]

# %%
# create a column for the months of the year using the ts column
df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month

# convert values to date time and then month names

df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
df_clean
# Out:
# <ipython-input-62-6f5a2bd291be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month
# <ipython-input-62-6f5a2bd291be>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 5258 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5259 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5260 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 5261 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 5262 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month
# 0        Sunday           9    May
# 1        Sunday           9    May
# 2        Sunday           9    May
# 3        Sunday           9    May
# 4        Sunday           9    May
# ...         ...         ...    ...
# 5258    Tuesday           6  April
# 5259    Tuesday           6  April
# 5260     Friday           7    May
# 5261     Friday           7    May
# 5262  Wednesday           7  April
#
# [4940 rows x 15 columns]

# %%
# create a column for the type of the weekday using the ts column
df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x < 5 else 'Weekend')
df_clean
# Out:
# <ipython-input-63-995b0273217e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 5258 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5259 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5260 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 5261 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 5262 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type
# 0        Sunday           9    May  Weekend
# 1        Sunday           9    May  Weekend
# 2        Sunday           9    May  Weekend
# 3        Sunday           9    May  Weekend
# 4        Sunday           9    May  Weekend
# ...         ...         ...    ...      ...
# 5258    Tuesday           6  April  Weekday
# 5259    Tuesday           6  April  Weekday
# 5260     Friday           7    May  Weekday
# 5261     Friday           7    May  Weekday
# 5262  Wednesday           7  April  Weekday
#
# [4940 rows x 16 columns]

# %%
# create a column for the hour of the day using the ts column
df_clean['time']= df_clean['ts'].dt.strftime('%H')
df_clean
# Out:
# <ipython-input-64-c55fbc2a7015>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['time']= df_clean['ts'].dt.strftime('%H')
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                       ts                                       user_profile  \
# 0    2021-05-09 08:00:26  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1    2021-05-09 08:01:01  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2    2021-05-09 15:27:59  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3    2021-05-09 15:30:41  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4    2021-05-09 15:32:00  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                  ...                                                ...
# 5258 2021-04-06 16:43:00  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5259 2021-04-06 16:44:20  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
# 5260 2021-05-07 14:48:46  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 5261 2021-05-07 15:00:52  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...
# 5262 2021-04-07 21:44:26  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time
# 0        Sunday           9    May  Weekend   08
# 1        Sunday           9    May  Weekend   08
# 2        Sunday           9    May  Weekend   15
# 3        Sunday           9    May  Weekend   15
# 4        Sunday           9    May  Weekend   15
# ...         ...         ...    ...      ...  ...
# 5258    Tuesday           6  April  Weekday   16
# 5259    Tuesday           6  April  Weekday   16
# 5260     Friday           7    May  Weekday   14
# 5261     Friday           7    May  Weekday   15
# 5262  Wednesday           7  April  Weekday   21
#
# [4940 rows x 17 columns]

# %%
# create a column for the parts of the day
df_clean['dayparts'] = (df_clean['ts'].dt.hour % 24 + 4) // 4
df_clean['dayparts'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Afternoon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ts'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-01beb8961fe4> in <module>
#       1 # create a column for the parts of the day
# ----> 2 df_clean['dayparts'] = (df_clean['ts'].dt.hour % 24 + 4) // 4
#       3 df_clean['dayparts'].replace({1: 'Late Night',
#       4                       2: 'Early Morning',
#       5                       3: 'Morning',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'ts'

# %%
# drop ts column
df_clean.drop('ts', axis=1, inplace=True) 

#test
df_clean.head()
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#                                         user_profile  reply_count  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#                                              replies attachments files  \
# 0                                                NaN         NaN   NaN
# 1                                                NaN         NaN   NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                NaN         NaN   NaN
# 4                                                NaN         NaN   NaN
#
#   reactions channel_name day_name  day_number month day_type time   dayparts
# 0       NaN      general   Sunday           9   May  Weekend   08    Morning
# 1       NaN      general   Sunday           9   May  Weekend   08    Morning
# 2       NaN      general   Sunday           9   May  Weekend   15  Afternoon
# 3       NaN      general   Sunday           9   May  Weekend   15  Afternoon
# 4       NaN      general   Sunday           9   May  Weekend   15  Afternoon

# %%
#files column: extract link

def geturlfromfile(x):
    """this function is applied to column files
    """
    
    if x != x:
        return 'nofile'
    else:
        try:
            return x[0]['url_private']
        except KeyError:
            return 'nolink_infiles'

df_clean['link_of_file'] = df_clean['files'].apply(geturlfromfile)

df_clean
# Out:
# <ipython-input-67-86b733e6364b>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['link_of_file'] = df_clean['files'].apply(geturlfromfile)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 5258  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5259  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5260  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 5261  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 5262  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 5258                NaN                         NaN
# 5259                NaN                         NaN
# 5260                NaN                         NaN
# 5261                NaN                         NaN
# 5262                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments files  \
# 0                                                   NaN         NaN   NaN
# 1                                                   NaN         NaN   NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN   NaN
# 3                                                   NaN         NaN   NaN
# 4                                                   NaN         NaN   NaN
# ...                                                 ...         ...   ...
# 5258                                                NaN         NaN   NaN
# 5259                                                NaN         NaN   NaN
# 5260                                                NaN         NaN   NaN
# 5261                                                NaN         NaN   NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN   NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time   dayparts link_of_file
# 0        Sunday           9    May  Weekend   08    Morning       nofile
# 1        Sunday           9    May  Weekend   08    Morning       nofile
# 2        Sunday           9    May  Weekend   15  Afternoon       nofile
# 3        Sunday           9    May  Weekend   15  Afternoon       nofile
# 4        Sunday           9    May  Weekend   15  Afternoon       nofile
# ...         ...         ...    ...      ...  ...        ...          ...
# 5258    Tuesday           6  April  Weekday   16    Evening       nofile
# 5259    Tuesday           6  April  Weekday   16    Evening       nofile
# 5260     Friday           7    May  Weekday   14  Afternoon       nofile
# 5261     Friday           7    May  Weekday   15  Afternoon       nofile
# 5262  Wednesday           7  April  Weekday   21      Night       nofile
#
# [4940 rows x 18 columns]

# %%
# save to csv
df_links = df_clean[(df_clean.link_of_file != 'nofile')]
header = ['link_of_file']
df_links.to_csv(r'../csv/links.csv', columns = header, index = False)

# %%
# drop files column
df_clean.drop('files', axis=1, inplace=True) 

#test
df_clean.head()
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                 text         user  \
# 0                Hang told me to add it in education  U01S79YDELR
# 1  What improved my score was adding metrics of a...  U01S79YDELR
# 2  I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3  Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                            Ah, ok!  U01RRV4JX6Z
#
#                                         user_profile  reply_count  \
# 0  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3  {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
#
#    reply_users_count                 reply_users  \
# 0                NaN                         NaN
# 1                NaN                         NaN
# 2                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                NaN                         NaN
# 4                NaN                         NaN
#
#                                              replies attachments reactions  \
# 0                                                NaN         NaN       NaN
# 1                                                NaN         NaN       NaN
# 2  [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN       NaN
# 3                                                NaN         NaN       NaN
# 4                                                NaN         NaN       NaN
#
#   channel_name day_name  day_number month day_type time   dayparts  \
# 0      general   Sunday           9   May  Weekend   08    Morning
# 1      general   Sunday           9   May  Weekend   08    Morning
# 2      general   Sunday           9   May  Weekend   15  Afternoon
# 3      general   Sunday           9   May  Weekend   15  Afternoon
# 4      general   Sunday           9   May  Weekend   15  Afternoon
#
#   link_of_file
# 0       nofile
# 1       nofile
# 2       nofile
# 3       nofile
# 4       nofile

# %%
df_clean[~df_clean['attachments'].isna()]['attachments'].iloc[37][0]
# Out:
# {'fallback': 'Caparisun/Linear_Regression_Project',
#  'text': 'Using machine learning to predict real estate prices',
#  'title': 'Caparisun/Linear_Regression_Project',
#  'footer': '<https://github.com/Caparisun/Linear_Regression_Project|Caparisun/Linear_Regression_Project>',
#  'id': 1,
#  'footer_icon': 'https://github.githubassets.com/favicon.ico',
#  'ts': 1618578316,
#  'color': '24292f',
#  'fields': [{'title': 'Stars', 'value': '1', 'short': True},
#   {'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}],
#  'mrkdwn_in': ['text', 'fields'],
#  'bot_id': 'B01RM0CJC4X',
#  'app_unfurl_url': 'https://github.com/Caparisun/Linear_Regression_Project',
#  'is_app_unfurl': True}

# %%
# attachments column: extract link

def geturlfromattachments(x):
    """this function is applied to column attachments
    """
    
    if x != x:
        return 'nolink'
    else:
        try:
            return x[0]['app_unfurl_url']
        except KeyError:
            return 'nolink_infiles'
        
df_clean['github_links'] = df_clean['attachments'].apply(geturlfromattachments)

df_clean
# Out:
# <ipython-input-71-fc0e34b11d52>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['github_links'] = df_clean['attachments'].apply(geturlfromattachments)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 5258  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5259  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5260  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 5261  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 5262  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 5258                NaN                         NaN
# 5259                NaN                         NaN
# 5260                NaN                         NaN
# 5261                NaN                         NaN
# 5262                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time   dayparts link_of_file  \
# 0        Sunday           9    May  Weekend   08    Morning       nofile
# 1        Sunday           9    May  Weekend   08    Morning       nofile
# 2        Sunday           9    May  Weekend   15  Afternoon       nofile
# 3        Sunday           9    May  Weekend   15  Afternoon       nofile
# 4        Sunday           9    May  Weekend   15  Afternoon       nofile
# ...         ...         ...    ...      ...  ...        ...          ...
# 5258    Tuesday           6  April  Weekday   16    Evening       nofile
# 5259    Tuesday           6  April  Weekday   16    Evening       nofile
# 5260     Friday           7    May  Weekday   14  Afternoon       nofile
# 5261     Friday           7    May  Weekday   15  Afternoon       nofile
# 5262  Wednesday           7  April  Weekday   21      Night       nofile
#
#      github_links
# 0          nolink
# 1          nolink
# 2          nolink
# 3          nolink
# 4          nolink
# ...           ...
# 5258       nolink
# 5259       nolink
# 5260       nolink
# 5261       nolink
# 5262       nolink
#
# [4940 rows x 18 columns]

# %%
# save to csv
df_githublinks = df_clean[(df_clean.github_links != 'nolink')
                         & (df_clean.github_links != 'nolink_infiles')]
header = ['github_links']
df_githublinks.to_csv(r'../csv/github_links.csv', columns = header, index = False)

# %%
# user_profile column: extract real_name

def getrealnamefromprofile(x):
    """this function is applied to column user_profile
    """
    
    if x != x:
        return 'noname'
    else:
        return x['real_name']

df_clean['real_name'] = df_clean['user_profile'].apply(getrealnamefromprofile)

df_clean
# Out:
# <ipython-input-73-ce73fd54f28f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['real_name'] = df_clean['user_profile'].apply(getrealnamefromprofile)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#                                            user_profile  reply_count  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...         31.0
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...          NaN
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...          NaN
# ...                                                 ...          ...
# 5258  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5259  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          NaN
# 5260  {'avatar_hash': '17b52091bb62', 'image_72': 'h...          NaN
# 5261  {'avatar_hash': '5b0571ca5e6f', 'image_72': 'h...          NaN
# 5262  {'avatar_hash': 'adb8b81e55b5', 'image_72': 'h...          1.0
#
#       reply_users_count                 reply_users  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3                   NaN                         NaN
# 4                   NaN                         NaN
# ...                 ...                         ...
# 5258                NaN                         NaN
# 5259                NaN                         NaN
# 5260                NaN                         NaN
# 5261                NaN                         NaN
# 5262                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time   dayparts link_of_file  \
# 0        Sunday           9    May  Weekend   08    Morning       nofile
# 1        Sunday           9    May  Weekend   08    Morning       nofile
# 2        Sunday           9    May  Weekend   15  Afternoon       nofile
# 3        Sunday           9    May  Weekend   15  Afternoon       nofile
# 4        Sunday           9    May  Weekend   15  Afternoon       nofile
# ...         ...         ...    ...      ...  ...        ...          ...
# 5258    Tuesday           6  April  Weekday   16    Evening       nofile
# 5259    Tuesday           6  April  Weekday   16    Evening       nofile
# 5260     Friday           7    May  Weekday   14  Afternoon       nofile
# 5261     Friday           7    May  Weekday   15  Afternoon       nofile
# 5262  Wednesday           7  April  Weekday   21      Night       nofile
#
#      github_links          real_name
# 0          nolink    Karina Condeixa
# 1          nolink    Karina Condeixa
# 2          nolink  Francisco Ebeling
# 3          nolink    Karina Condeixa
# 4          nolink  Francisco Ebeling
# ...           ...                ...
# 5258       nolink         Simon Data
# 5259       nolink         Simon Data
# 5260       nolink    Sam Katterfield
# 5261       nolink              Kosta
# 5262       nolink         Simon Data
#
# [4940 rows x 19 columns]

# %%
# drop user_profile column
df_clean.drop('user_profile', axis=1, inplace=True) 

#test
df_clean.head(100)
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                  text         user  \
# 0                 Hang told me to add it in education  U01S79YDELR
# 1   What improved my score was adding metrics of a...  U01S79YDELR
# 2   I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3   Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                             Ah, ok!  U01RRV4JX6Z
# ..                                                ...          ...
# 95  I think today is normal retro at 9\nThe whole ...  U01RN7BVD1C
# 96                            Thank you phine :blush:  U01S7BM4N81
# 97  :slightly_smiling_face: I hope I'm correct tho...  U01RN7BVD1C
# 98                            You are correct, Phine!  U01SJKB2MG8
# 99  <!channel>,\ngood morning! It's Friday - that ...  U01SJKB2MG8
#
#     reply_count  reply_users_count                 reply_users  \
# 0           NaN                NaN                         NaN
# 1           NaN                NaN                         NaN
# 2          31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3           NaN                NaN                         NaN
# 4           NaN                NaN                         NaN
# ..          ...                ...                         ...
# 95          NaN                NaN                         NaN
# 96          NaN                NaN                         NaN
# 97          NaN                NaN                         NaN
# 98          NaN                NaN                         NaN
# 99          NaN                NaN                         NaN
#
#                                               replies attachments  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2   [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# ..                                                ...         ...
# 95                                                NaN         NaN
# 96                                                NaN         NaN
# 97                                                NaN         NaN
# 98                                                NaN         NaN
# 99                                                NaN         NaN
#
#                                             reactions channel_name day_name  \
# 0                                                 NaN      general   Sunday
# 1                                                 NaN      general   Sunday
# 2                                                 NaN      general   Sunday
# 3                                                 NaN      general   Sunday
# 4                                                 NaN      general   Sunday
# ..                                                ...          ...      ...
# 95  [{'name': '+1', 'users': ['U01SJKB2MG8'], 'cou...      general   Friday
# 96                                                NaN      general   Friday
# 97                                                NaN      general   Friday
# 98                                                NaN      general   Friday
# 99                                                NaN      general   Friday
#
#     day_number month day_type time       dayparts link_of_file github_links  \
# 0            9   May  Weekend   08        Morning       nofile       nolink
# 1            9   May  Weekend   08        Morning       nofile       nolink
# 2            9   May  Weekend   15      Afternoon       nofile       nolink
# 3            9   May  Weekend   15      Afternoon       nofile       nolink
# 4            9   May  Weekend   15      Afternoon       nofile       nolink
# ..         ...   ...      ...  ...            ...          ...          ...
# 95          14   May  Weekday   06  Early Morning       nofile       nolink
# 96          14   May  Weekday   06  Early Morning       nofile       nolink
# 97          14   May  Weekday   06  Early Morning       nofile       nolink
# 98          14   May  Weekday   06  Early Morning       nofile       nolink
# 99          14   May  Weekday   06  Early Morning       nofile       nolink
#
#                real_name
# 0        Karina Condeixa
# 1        Karina Condeixa
# 2      Francisco Ebeling
# 3        Karina Condeixa
# 4      Francisco Ebeling
# ..                   ...
# 95  Josephine Biedermann
# 96                 Thamo
# 97  Josephine Biedermann
# 98         Florian Titze
# 99         Florian Titze
#
# [100 rows x 18 columns]

# %%
# reactions column:  count

def getcountfromreactions(x):
    """this function is applied to column reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['count']

df_clean['reactions_count'] = df_clean['reactions'].apply(getcountfromreactions)

df_clean
# Out:
# <ipython-input-75-0eab6a7d50fd>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reactions_count'] = df_clean['reactions'].apply(getcountfromreactions)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time   dayparts link_of_file  \
# 0        Sunday           9    May  Weekend   08    Morning       nofile
# 1        Sunday           9    May  Weekend   08    Morning       nofile
# 2        Sunday           9    May  Weekend   15  Afternoon       nofile
# 3        Sunday           9    May  Weekend   15  Afternoon       nofile
# 4        Sunday           9    May  Weekend   15  Afternoon       nofile
# ...         ...         ...    ...      ...  ...        ...          ...
# 5258    Tuesday           6  April  Weekday   16    Evening       nofile
# 5259    Tuesday           6  April  Weekday   16    Evening       nofile
# 5260     Friday           7    May  Weekday   14  Afternoon       nofile
# 5261     Friday           7    May  Weekday   15  Afternoon       nofile
# 5262  Wednesday           7  April  Weekday   21      Night       nofile
#
#      github_links          real_name  reactions_count
# 0          nolink    Karina Condeixa                0
# 1          nolink    Karina Condeixa                0
# 2          nolink  Francisco Ebeling                0
# 3          nolink    Karina Condeixa                0
# 4          nolink  Francisco Ebeling                0
# ...           ...                ...              ...
# 5258       nolink         Simon Data                0
# 5259       nolink         Simon Data                0
# 5260       nolink    Sam Katterfield                0
# 5261       nolink              Kosta                1
# 5262       nolink         Simon Data                0
#
# [4940 rows x 19 columns]

# %%
df_clean[~df_clean['reactions'].isna()]['reactions'].iloc[37][0]['name']
# Out:
# 'handshake'

# %%
# reactions column:  count

def getnamefromreactions(x):
    """this function is applied to column reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['name']

df_clean['reactions_name'] = df_clean['reactions'].apply(getnamefromreactions)

df_clean
# Out:
# <ipython-input-77-6c046498aa40>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reactions_name'] = df_clean['reactions'].apply(getnamefromreactions)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  day_number  month day_type time   dayparts link_of_file  \
# 0        Sunday           9    May  Weekend   08    Morning       nofile
# 1        Sunday           9    May  Weekend   08    Morning       nofile
# 2        Sunday           9    May  Weekend   15  Afternoon       nofile
# 3        Sunday           9    May  Weekend   15  Afternoon       nofile
# 4        Sunday           9    May  Weekend   15  Afternoon       nofile
# ...         ...         ...    ...      ...  ...        ...          ...
# 5258    Tuesday           6  April  Weekday   16    Evening       nofile
# 5259    Tuesday           6  April  Weekday   16    Evening       nofile
# 5260     Friday           7    May  Weekday   14  Afternoon       nofile
# 5261     Friday           7    May  Weekday   15  Afternoon       nofile
# 5262  Wednesday           7  April  Weekday   21      Night       nofile
#
#      github_links          real_name  reactions_count reactions_name
# 0          nolink    Karina Condeixa                0              0
# 1          nolink    Karina Condeixa                0              0
# 2          nolink  Francisco Ebeling                0              0
# 3          nolink    Karina Condeixa                0              0
# 4          nolink  Francisco Ebeling                0              0
# ...           ...                ...              ...            ...
# 5258       nolink         Simon Data                0              0
# 5259       nolink         Simon Data                0              0
# 5260       nolink    Sam Katterfield                0              0
# 5261       nolink              Kosta                1    dancing_dog
# 5262       nolink         Simon Data                0              0
#
# [4940 rows x 20 columns]

# %%
df_clean['reactions_name'].value_counts()
# Out:
# 0                   3806
# +1                   259
# raised_hands         177
# joy                   83
# white_check_mark      77
#                     ...
# alex                   1
# ear                    1
# thinking_face          1
# harry-potter           1
# no_mouth               1
# Name: reactions_name, Length: 142, dtype: int64

# %%
# creating boolean variables

# create a new boolean column if comment has reaction
df_clean['reaction_true'] = df_clean['reactions'].notnull()
df_clean


# create a new boolean column if comment has reply
df_clean['replies_true'] = df_clean['reply_count'].notna()
df_clean

# create a new boolean column if comment has files
df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")
df_clean

# create a new boolean column if comment has attachments
df_clean['attachments_true'] = df_clean['github_links'].str.contains("https")
df_clean
# Out:
# <ipython-input-79-f61b7707ddd0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reaction_true'] = df_clean['reactions'].notnull()
# <ipython-input-79-f61b7707ddd0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['replies_true'] = df_clean['reply_count'].notna()
# <ipython-input-79-f61b7707ddd0>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")
# <ipython-input-79-f61b7707ddd0>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['attachments_true'] = df_clean['github_links'].str.contains("https")
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  ...   dayparts link_of_file github_links          real_name  \
# 0        Sunday  ...    Morning       nofile       nolink    Karina Condeixa
# 1        Sunday  ...    Morning       nofile       nolink    Karina Condeixa
# 2        Sunday  ...  Afternoon       nofile       nolink  Francisco Ebeling
# 3        Sunday  ...  Afternoon       nofile       nolink    Karina Condeixa
# 4        Sunday  ...  Afternoon       nofile       nolink  Francisco Ebeling
# ...         ...  ...        ...          ...          ...                ...
# 5258    Tuesday  ...    Evening       nofile       nolink         Simon Data
# 5259    Tuesday  ...    Evening       nofile       nolink         Simon Data
# 5260     Friday  ...  Afternoon       nofile       nolink    Sam Katterfield
# 5261     Friday  ...  Afternoon       nofile       nolink              Kosta
# 5262  Wednesday  ...      Night       nofile       nolink         Simon Data
#
#      reactions_count reactions_name reaction_true replies_true  files_true  \
# 0                  0              0         False        False       False
# 1                  0              0         False        False       False
# 2                  0              0         False         True       False
# 3                  0              0         False        False       False
# 4                  0              0         False        False       False
# ...              ...            ...           ...          ...         ...
# 5258               0              0         False        False       False
# 5259               0              0         False        False       False
# 5260               0              0         False        False       False
# 5261               1    dancing_dog          True        False       False
# 5262               0              0         False         True       False
#
#      attachments_true
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 5258            False
# 5259            False
# 5260            False
# 5261            False
# 5262            False
#
# [4940 rows x 24 columns]

# %%
df_clean['real_name'].value_counts()
# Out:
# siand the LT (she/her)                       837
# noname                                       656
# Thamo                                        450
# Sam Katterfield                              428
# Alexandre Sommerkamp                         426
# Francisco Ebeling                            380
# Florian Titze                                263
# Karina Condeixa                              252
# Josephine Biedermann                         166
# Marian Moreno                                155
# Kosta                                        144
# Thanh Tung Ha Thuc DAFT Berlin March 2021    132
# Simon Data                                   105
# Lilla Szulyovszky                            101
# Davis Pudans                                  96
# Neil Corteen                                  64
# Andrea Tognoli                                60
# Antonio Saleme Sastre                         53
# Isabel Jabs                                   24
# Jalal Karimov                                 24
# Federico Giuliani                             22
# Anja Fechner                                  20
# Jennipher Kasemire                            19
# Prebitha Abraham                              12
# Olubunmi Haastrup                             12
# peter.geo DAFT MAR2020                        12
# Jerrit Steinebach                             12
# Olubunmi Abimbola Haastrup                     7
# Jonas Tonndorff                                7
# Madini Liebscher                               1
# Name: real_name, dtype: int64

# %%
# create a new column with teaching and students
def applyFunc(s):
    if s == 'siand the LT (she/her)':
        return 'teacher'
    if s ==  'Florian Titze':
        return 'teacher'
    if s ==  'Kosta':
        return 'teacher'
    else:
        return 'student'
    return ''

df_clean['participant'] = df_clean['real_name'].apply(applyFunc)
df_clean['participant'].value_counts()
# Out:
# <ipython-input-81-22e916538365>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['participant'] = df_clean['real_name'].apply(applyFunc)
# student    3696
# teacher    1244
# Name: participant, dtype: int64

# %%
# create a new column with text length
df_clean['text_length'] = df['text'].astype(str).map(len)
# test
df_clean
# Out:
# <ipython-input-82-15536c45761f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['text_length'] = df['text'].astype(str).map(len)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count                 reply_users  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2            31.0                2.0  [U01S79YDELR, U01RRV4JX6Z]
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
# ...           ...                ...                         ...
# 5258          NaN                NaN                         NaN
# 5259          NaN                NaN                         NaN
# 5260          NaN                NaN                         NaN
# 5261          NaN                NaN                         NaN
# 5262          1.0                1.0               [U01SJKB2MG8]
#
#                                                 replies attachments  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     [{'user': 'U01S79YDELR', 'ts': '1620574241.002...         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 5258                                                NaN         NaN
# 5259                                                NaN         NaN
# 5260                                                NaN         NaN
# 5261                                                NaN         NaN
# 5262  [{'user': 'U01SJKB2MG8', 'ts': '1617869285.000...         NaN
#
#                                               reactions channel_name  \
# 0                                                   NaN      general
# 1                                                   NaN      general
# 2                                                   NaN      general
# 3                                                   NaN      general
# 4                                                   NaN      general
# ...                                                 ...          ...
# 5258                                                NaN      vanilla
# 5259                                                NaN      vanilla
# 5260                                                NaN      vanilla
# 5261  [{'name': 'dancing_dog', 'users': ['U01S7KCL3D...      vanilla
# 5262                                                NaN      vanilla
#
#        day_name  ...  github_links          real_name reactions_count  \
# 0        Sunday  ...        nolink    Karina Condeixa               0
# 1        Sunday  ...        nolink    Karina Condeixa               0
# 2        Sunday  ...        nolink  Francisco Ebeling               0
# 3        Sunday  ...        nolink    Karina Condeixa               0
# 4        Sunday  ...        nolink  Francisco Ebeling               0
# ...         ...  ...           ...                ...             ...
# 5258    Tuesday  ...        nolink         Simon Data               0
# 5259    Tuesday  ...        nolink         Simon Data               0
# 5260     Friday  ...        nolink    Sam Katterfield               0
# 5261     Friday  ...        nolink              Kosta               1
# 5262  Wednesday  ...        nolink         Simon Data               0
#
#      reactions_name reaction_true replies_true files_true attachments_true  \
# 0                 0         False        False      False            False
# 1                 0         False        False      False            False
# 2                 0         False         True      False            False
# 3                 0         False        False      False            False
# 4                 0         False        False      False            False
# ...             ...           ...          ...        ...              ...
# 5258              0         False        False      False            False
# 5259              0         False        False      False            False
# 5260              0         False        False      False            False
# 5261    dancing_dog          True        False      False            False
# 5262              0         False         True      False            False
#
#       participant text_length
# 0         student          35
# 1         student          98
# 2         student         261
# 3         student          76
# 4         student           7
# ...           ...         ...
# 5258      student          21
# 5259      student          82
# 5260      student          41
# 5261      teacher          45
# 5262      student         542
#
# [4940 rows x 26 columns]

# %%
# droppig unneccessary columns
df_clean.drop(['reactions', 'attachments', 'reply_users', 'replies'], axis=1, inplace=True)
# test
df_clean.shape
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (4940, 22)

# %%
# replace NaN values with zero
df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
df_clean['reply_count'] = df_clean['reply_count'].astype(int)
df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)


df_clean
# Out:
# <ipython-input-84-5cc785cc1679>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
# <ipython-input-84-5cc785cc1679>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
# <ipython-input-84-5cc785cc1679>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_count'] = df_clean['reply_count'].astype(int)
# <ipython-input-84-5cc785cc1679>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 5258                              Just saw this. Thanks  U01S133DZ9A
# 5259  I'll have a think. Need to develop a strategy ...  U01S133DZ9A
# 5260          heeeellppp…anyone? <@U01RSRE0N3D>? :eyes:  U01S7KCL3DF
# 5261      I will have a look after the presentation :v:  U01RSRE0N3D
# 5262  I quite like the Kaggle explanations. Been rea...  U01S133DZ9A
#
#       reply_count  reply_users_count channel_name   day_name  day_number  \
# 0               0                  0      general     Sunday           9
# 1               0                  0      general     Sunday           9
# 2              31                  2      general     Sunday           9
# 3               0                  0      general     Sunday           9
# 4               0                  0      general     Sunday           9
# ...           ...                ...          ...        ...         ...
# 5258            0                  0      vanilla    Tuesday           6
# 5259            0                  0      vanilla    Tuesday           6
# 5260            0                  0      vanilla     Friday           7
# 5261            0                  0      vanilla     Friday           7
# 5262            1                  1      vanilla  Wednesday           7
#
#       month day_type time  ... github_links          real_name  \
# 0       May  Weekend   08  ...       nolink    Karina Condeixa
# 1       May  Weekend   08  ...       nolink    Karina Condeixa
# 2       May  Weekend   15  ...       nolink  Francisco Ebeling
# 3       May  Weekend   15  ...       nolink    Karina Condeixa
# 4       May  Weekend   15  ...       nolink  Francisco Ebeling
# ...     ...      ...  ...  ...          ...                ...
# 5258  April  Weekday   16  ...       nolink         Simon Data
# 5259  April  Weekday   16  ...       nolink         Simon Data
# 5260    May  Weekday   14  ...       nolink    Sam Katterfield
# 5261    May  Weekday   15  ...       nolink              Kosta
# 5262  April  Weekday   21  ...       nolink         Simon Data
#
#      reactions_count reactions_name  reaction_true replies_true  files_true  \
# 0                  0              0          False        False       False
# 1                  0              0          False        False       False
# 2                  0              0          False         True       False
# 3                  0              0          False        False       False
# 4                  0              0          False        False       False
# ...              ...            ...            ...          ...         ...
# 5258               0              0          False        False       False
# 5259               0              0          False        False       False
# 5260               0              0          False        False       False
# 5261               1    dancing_dog           True        False       False
# 5262               0              0          False         True       False
#
#       attachments_true  participant  text_length
# 0                False      student           35
# 1                False      student           98
# 2                False      student          261
# 3                False      student           76
# 4                False      student            7
# ...                ...          ...          ...
# 5258             False      student           21
# 5259             False      student           82
# 5260             False      student           41
# 5261             False      teacher           45
# 5262             False      student          542
#
# [4940 rows x 22 columns]

# %%
df_clean.columns
# Out:
# Index(['text', 'user', 'reply_count', 'reply_users_count', 'channel_name',
#        'day_name', 'day_number', 'month', 'day_type', 'time', 'dayparts',
#        'link_of_file', 'github_links', 'real_name', 'reactions_count',
#        'reactions_name', 'reaction_true', 'replies_true', 'files_true',
#        'attachments_true', 'participant', 'text_length'],
#       dtype='object')

# %%
# reordering columns
df_clean = df_clean[['channel_name', 'user', 'real_name', 'participant',
                     'text', 'text_length', 'reply_count', 'reply_users_count',
                     'replies_true', 'day_name', 'day_type', 'time',
                     'dayparts', 'day_number', 'month', 'reactions_count', 
                     'reactions_name', 'link_of_file', 'files_true', 
                     'github_links', 'attachments_true', 'reaction_true']]
# test 
df_clean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-9b5ca277dd87> in <module>
#       7                      'github_links', 'attachments_true', 'reaction_true']]
#       8 # test
# ----> 9 df_clean(10)
#
# TypeError: 'DataFrame' object is not callable

# %%
# save to csv
df_clean.to_csv(r'../csv/data_clean.csv', index = False)

# %%
# save to excel
df_clean.to_excel(r'../csv/data_clean.xlsx', index = False)
