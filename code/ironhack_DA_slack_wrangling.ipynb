# %% [markdown]
# **EDA**
# - how much traffic per channel
# - count of messages per person
# - avg length of messages per person
# - longest messages by person
# - reaction to longer messages vs shorter messages
# - which post gets the most reaction/traction
# - what time of the day students are posting the most per day
# - distribution of  % links, % memes, % emojis
# - frequency of messages from teaching staff vs students
# - statistics of mentions within a date range
# - which channel is the most useful(most messages)
# - measure reactions based on length of messages
# - text features: ??, !!, capital letters, bolded statements, technical terms
# - extract number of emojis from text and make that a feature
#
# plot:
# - avg length / comment  vs how many replies/reactions count avg per person
# - most frequent emoji
# - frequency of messages per participant type
#
# **Automated function**
# - a report at the end of each day, with a few summary statistics for that day
# - a daily / weekly extract of all the links/uploads posted in public channels
#
# **NLP**
# - whats the top 5 words used per channel (bi-grams, tri-grams)
# - how negative or positive posts were on the lab help channel specifically
# - who is the happiest/most sad person
# - number of people who asks questions, who are the asking the most
#
# **Network Analysis: (if I have time):**
# - identify people who answer most questions

# %% [markdown]
# # EDA
#
# ## Preparing Data
# - load multiple json files into dataframes
#     - generate one dataframe per channel
#
# ## Assess and Clean Data
# - drop columns which doesn't make sense
# - drop rows which doesn't make sense
# - clear text which is not needed
# - change data types if needed
# - get normal date from timestamp
#
# ## Wrangle Data
# - create a couple of boolean columns from reactions, files, attachments, replies

# %%
# import basic libraries
import os, json
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ### Loading Multiple Json Files into DataFrames
# Generate one dataframe/channel

# %% [markdown]
# ### channel_gen

# %%
# defining file path
path_to_json = '../raw_data/general/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_gen = pd.concat(dfs, ignore_index=True)
# test
channel_gen.tail(100)
# Out:
#                              client_msg_id     type  \
# 1242  3d62b711-9c19-4aa8-8874-615579ff48e7  message
# 1243  f790d842-a5e8-44e7-be76-678d69cfb06d  message
# 1244  67fff521-642a-4209-82be-42a6b25e91d7  message
# 1245  16c8cc9f-f308-41d9-a642-4120f2fb3041  message
# 1246  9682cdd5-2cf6-4344-9542-9e2711dcf6c1  message
# ...                                    ...      ...
# 1337                                   NaN  message
# 1338                                   NaN  message
# 1339                                   NaN  message
# 1340                                   NaN  message
# 1341                                   NaN  message
#
#                                                    text         user  \
# 1242                         yes and then using the app  U01S79YDELR
# 1243  <!channel>,\ncan you access the content now? W...  U01SJKB2MG8
# 1244                                mine not signing in  U01S0P26NKD
# 1245  yes, thanks. I have problems to go the the cla...  U01S79YDELR
# 1246             <@U01SJKB2MG8> i cannot join the class  U01S79YDELR
# ...                                                 ...          ...
# 1337              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1338              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1339              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1340              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1341              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 1242  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1243  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1244  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1245  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1246  1.616487e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1337  1.616166e+09          NaN          NaN          NaN
# 1338  1.616167e+09          NaN          NaN          NaN
# 1339  1.616168e+09          NaN          NaN          NaN
# 1340  1.616172e+09          NaN          NaN          NaN
# 1341  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 1242  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1243  {'avatar_hash': '88fa894fdb53', 'image_72': 'h...
# 1244  {'avatar_hash': 'g7b30129d02b', 'image_72': 'h...
# 1245  {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1246  {'avatar_hash': '606def897de6', 'image_72': 'h...
# ...                                                 ...
# 1337                                                NaN
# 1338                                                NaN
# 1339                                                NaN
# 1340                                                NaN
# 1341                                                NaN
#
#                                                  blocks  ...  upload  \
# 1242  [{'type': 'rich_text', 'block_id': 'Bie', 'ele...  ...     NaN
# 1243  [{'type': 'rich_text', 'block_id': '6p6z', 'el...  ...     NaN
# 1244  [{'type': 'rich_text', 'block_id': 'UCLUf', 'e...  ...     NaN
# 1245  [{'type': 'rich_text', 'block_id': 'Voo', 'ele...  ...     NaN
# 1246  [{'type': 'rich_text', 'block_id': 'upS/I', 'e...  ...     NaN
# ...                                                 ...  ...     ...
# 1337                                                NaN  ...     NaN
# 1338                                                NaN  ...     NaN
# 1339                                                NaN  ...     NaN
# 1340                                                NaN  ...     NaN
# 1341                                                NaN  ...     NaN
#
#      display_as_bot reactions  last_read  bot_id  bot_profile       subtype  \
# 1242            NaN       NaN        NaN     NaN          NaN           NaN
# 1243            NaN       NaN        NaN     NaN          NaN           NaN
# 1244            NaN       NaN        NaN     NaN          NaN           NaN
# 1245            NaN       NaN        NaN     NaN          NaN           NaN
# 1246            NaN       NaN        NaN     NaN          NaN           NaN
# ...             ...       ...        ...     ...          ...           ...
# 1337            NaN       NaN        NaN     NaN          NaN  channel_join
# 1338            NaN       NaN        NaN     NaN          NaN  channel_join
# 1339            NaN       NaN        NaN     NaN          NaN  channel_join
# 1340            NaN       NaN        NaN     NaN          NaN  channel_join
# 1341            NaN       NaN        NaN     NaN          NaN  channel_join
#
#      topic root purpose
# 1242   NaN  NaN     NaN
# 1243   NaN  NaN     NaN
# 1244   NaN  NaN     NaN
# 1245   NaN  NaN     NaN
# 1246   NaN  NaN     NaN
# ...    ...  ...     ...
# 1337   NaN  NaN     NaN
# 1338   NaN  NaN     NaN
# 1339   NaN  NaN     NaN
# 1340   NaN  NaN     NaN
# 1341   NaN  NaN     NaN
#
# [100 rows x 32 columns]

# %%
channel_gen['channel_name'] = 'general'
channel_gen
# Out:
#                              client_msg_id     type  \
# 0     2d1b171f-ab27-4a43-a0b7-0ecabcfc3294  message
# 1     a3c6083b-3a42-43a0-a621-bd32e26972d2  message
# 2     ec4aa0c0-53f5-4e94-9080-2e98ec280b3d  message
# 3     0aac10ae-ccff-47cf-bb2a-69a34819375b  message
# 4     39e4728b-90f7-4d84-b149-74d765ca544a  message
# ...                                    ...      ...
# 1337                                   NaN  message
# 1338                                   NaN  message
# 1339                                   NaN  message
# 1340                                   NaN  message
# 1341                                   NaN  message
#
#                                                    text         user  \
# 0                   Hang told me to add it in education  U01S79YDELR
# 1     What improved my score was adding metrics of a...  U01S79YDELR
# 2     I feel like a slave to this dumb Resume Worded...  U01RRV4JX6Z
# 3     Francisco, we have to remove the fancy/beautif...  U01S79YDELR
# 4                                               Ah, ok!  U01RRV4JX6Z
# ...                                                 ...          ...
# 1337              <@U01RNEU3SNA> has joined the channel  U01RNEU3SNA
# 1338              <@U01RS9Y6UJH> has joined the channel  U01RS9Y6UJH
# 1339              <@U01SK96QF5E> has joined the channel  U01SK96QF5E
# 1340              <@U01RP2K1606> has joined the channel  U01RP2K1606
# 1341              <@U01RW2X7S9Z> has joined the channel  U01RW2X7S9Z
#
#                 ts         team    user_team  source_team  \
# 0     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1     1.620547e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 2     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 4     1.620574e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ...            ...          ...          ...          ...
# 1337  1.616166e+09          NaN          NaN          NaN
# 1338  1.616167e+09          NaN          NaN          NaN
# 1339  1.616168e+09          NaN          NaN          NaN
# 1340  1.616172e+09          NaN          NaN          NaN
# 1341  1.616172e+09          NaN          NaN          NaN
#
#                                            user_profile  \
# 0     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 1     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 2     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 3     {'avatar_hash': '606def897de6', 'image_72': 'h...
# 4     {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# ...                                                 ...
# 1337                                                NaN
# 1338                                                NaN
# 1339                                                NaN
# 1340                                                NaN
# 1341                                                NaN
#
#                                                  blocks  ...  display_as_bot  \
# 0     [{'type': 'rich_text', 'block_id': '8oy', 'ele...  ...             NaN
# 1     [{'type': 'rich_text', 'block_id': 'wr=L', 'el...  ...             NaN
# 2     [{'type': 'rich_text', 'block_id': 'pRRNj', 'e...  ...             NaN
# 3     [{'type': 'rich_text', 'block_id': 'Daw', 'ele...  ...             NaN
# 4     [{'type': 'rich_text', 'block_id': '7YE+G', 'e...  ...             NaN
# ...                                                 ...  ...             ...
# 1337                                                NaN  ...             NaN
# 1338                                                NaN  ...             NaN
# 1339                                                NaN  ...             NaN
# 1340                                                NaN  ...             NaN
# 1341                                                NaN  ...             NaN
#
#      reactions last_read  bot_id  bot_profile       subtype topic root  \
# 0          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 1          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 2          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 3          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# 4          NaN       NaN     NaN          NaN           NaN   NaN  NaN
# ...        ...       ...     ...          ...           ...   ...  ...
# 1337       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1338       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1339       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1340       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
# 1341       NaN       NaN     NaN          NaN  channel_join   NaN  NaN
#
#      purpose channel_name
# 0        NaN      general
# 1        NaN      general
# 2        NaN      general
# 3        NaN      general
# 4        NaN      general
# ...      ...          ...
# 1337     NaN      general
# 1338     NaN      general
# 1339     NaN      general
# 1340     NaN      general
# 1341     NaN      general
#
# [1342 rows x 33 columns]

# %%
# save to csv
channel_gen.to_csv(r'../raw_data/general/channel_gen.csv', index = False)

# %% [markdown]
# ### channel_books

# %%
### books channel
# defining file path
path_to_json = '../raw_data/books/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_books = pd.concat(dfs, ignore_index=True)
# test
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks
# 0                                                NaN
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...

# %%
channel_books['channel_name'] = 'books'
channel_books
# Out:
#       type       subtype            ts         user  \
# 0  message  channel_join  1.616671e+09  U01RRV4JX6Z
# 1  message           NaN  1.616671e+09  U01RRV4JX6Z
# 2  message           NaN  1.616672e+09  U01RRV4JX6Z
#
#                                                 text  \
# 0              <@U01RRV4JX6Z> has joined the channel
# 1  This is a quiet cool one from the point of  vi...
# 2  The main character, Dee, is a Data Analyst fro...
#
#                           client_msg_id         team    user_team  \
# 0                                   NaN          NaN          NaN
# 1  bfc81572-a75d-4133-b95d-31808e028431  T01RBRV5F7H  T01RBRV5F7H
# 2  2bce2b21-5442-4204-8bb4-29ea3ca3242f  T01RBRV5F7H  T01RBRV5F7H
#
#    source_team                                       user_profile  \
# 0          NaN                                                NaN
# 1  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
# 2  T01RBRV5F7H  {'avatar_hash': '339c4d69b7d9', 'image_72': 'h...
#
#                                               blocks channel_name
# 0                                                NaN        books
# 1  [{'type': 'rich_text', 'block_id': 'oC2', 'ele...        books
# 2  [{'type': 'rich_text', 'block_id': 'N8rxZ', 'e...        books

# %%
# save to csv
channel_books.to_csv(r'../raw_data/books/channel_books.csv', index = False)

# %% [markdown]
# ### channel_dresource

# %%
### data_resources channel
# defining file path
path_to_json = '../raw_data/data_resources/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dresource = pd.concat(dfs, ignore_index=True)
# test
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 194  message           NaN  1.619510e+09  U01S7KCL3DF
# 195  message           NaN  1.619513e+09  U01RW140HBP
# 196  message           NaN  1.619513e+09  U01RW140HBP
# 197  message  channel_join  1.616163e+09  U01S79YDELR
# 198  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 194  aaahhhh yes thanks… i must scroll down more of...
# 195  we are working hard to keep that Notion up to ...
# 196  because of the free slack thing :confounded:- ...
# 197              <@U01S79YDELR> has joined the channel
# 198              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 194  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 195  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 196  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 197                                   NaN          NaN          NaN
# 198                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 194  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 195  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 196  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 197          NaN                                                NaN  ...
# 198          NaN                                                NaN  ...
#
#         last_read                                              files upload  \
# 0             NaN                                                NaN    NaN
# 1             NaN                                                NaN    NaN
# 2    1.619337e+09                                                NaN    NaN
# 3             NaN  [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False
# 4             NaN  [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False
# ..            ...                                                ...    ...
# 194           NaN                                                NaN    NaN
# 195           NaN                                                NaN    NaN
# 196           NaN                                                NaN    NaN
# 197           NaN                                                NaN    NaN
# 198           NaN                                                NaN    NaN
#
#      display_as_bot                                          reactions  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               0.0  [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...
# 4               0.0                                                NaN
# ..              ...                                                ...
# 194             NaN  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...
# 195             NaN                                                NaN
# 196             NaN                                                NaN
# 197             NaN                                                NaN
# 198             NaN                                                NaN
#
#      parent_user_id  bot_id bot_profile inviter  topic
# 0               NaN     NaN         NaN     NaN    NaN
# 1               NaN     NaN         NaN     NaN    NaN
# 2               NaN     NaN         NaN     NaN    NaN
# 3               NaN     NaN         NaN     NaN    NaN
# 4               NaN     NaN         NaN     NaN    NaN
# ..              ...     ...         ...     ...    ...
# 194     U01S7KCL3DF     NaN         NaN     NaN    NaN
# 195             NaN     NaN         NaN     NaN    NaN
# 196             NaN     NaN         NaN     NaN    NaN
# 197             NaN     NaN         NaN     NaN    NaN
# 198             NaN     NaN         NaN     NaN    NaN
#
# [199 rows x 31 columns]

# %%
channel_dresource['channel_name'] = 'dresource'
channel_dresource
# Out:
#         type       subtype            ts         user  \
# 0    message  channel_join  1.616237e+09  U01S1CWGTU4
# 1    message           NaN  1.619253e+09  U01S79YDELR
# 2    message           NaN  1.619326e+09  U01S79YDELR
# 3    message           NaN  1.617873e+09  U01RW140HBP
# 4    message           NaN  1.617873e+09  U01RW140HBP
# ..       ...           ...           ...          ...
# 194  message           NaN  1.619510e+09  U01S7KCL3DF
# 195  message           NaN  1.619513e+09  U01RW140HBP
# 196  message           NaN  1.619513e+09  U01RW140HBP
# 197  message  channel_join  1.616163e+09  U01S79YDELR
# 198  message  channel_join  1.616177e+09  U01RW2X7S9Z
#
#                                                   text  \
# 0                <@U01S1CWGTU4> has joined the channel
# 1    I received this message. It seems we need to c...
# 2    <@U01RSRE0N3D>  <@U01SJKB2MG8> <@U01RW140HBP> ...
# 3                     <@U01S7KCL3DF> colourful handout
# 4                           also this might be helpful
# ..                                                 ...
# 194  aaahhhh yes thanks… i must scroll down more of...
# 195  we are working hard to keep that Notion up to ...
# 196  because of the free slack thing :confounded:- ...
# 197              <@U01S79YDELR> has joined the channel
# 198              <@U01RW2X7S9Z> has joined the channel
#
#                             client_msg_id         team    user_team  \
# 0                                     NaN          NaN          NaN
# 1    29c7e7e3-a723-4af5-9a89-9e09c1a2a82a  T01RBRV5F7H  T01RBRV5F7H
# 2    31f652b8-9c65-439a-b7e8-44ec149fb0f2  T01RBRV5F7H  T01RBRV5F7H
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# ..                                    ...          ...          ...
# 194  69dd621f-6439-487c-89ee-434b611df276  T01RBRV5F7H  T01RBRV5F7H
# 195  cd80362b-3ff6-4ad2-a2c3-130cc88a843a  T01RBRV5F7H  T01RBRV5F7H
# 196  3c259a4e-0f04-4b95-a557-0cdc415b5f04  T01RBRV5F7H  T01RBRV5F7H
# 197                                   NaN          NaN          NaN
# 198                                   NaN          NaN          NaN
#
#      source_team                                       user_profile  ...  \
# 0            NaN                                                NaN  ...
# 1    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 2    T01RBRV5F7H  {'avatar_hash': '606def897de6', 'image_72': 'h...  ...
# 3            NaN                                                NaN  ...
# 4            NaN                                                NaN  ...
# ..           ...                                                ...  ...
# 194  T01RBRV5F7H  {'avatar_hash': '17b52091bb62', 'image_72': 'h...  ...
# 195  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 196  T01RBRV5F7H  {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...  ...
# 197          NaN                                                NaN  ...
# 198          NaN                                                NaN  ...
#
#                                                  files upload display_as_bot  \
# 0                                                  NaN    NaN            NaN
# 1                                                  NaN    NaN            NaN
# 2                                                  NaN    NaN            NaN
# 3    [{'id': 'F01U0QHA4M7', 'created': 1617872529, ...  False            0.0
# 4    [{'id': 'F01TNCSFFGB', 'created': 1617872605, ...  False            0.0
# ..                                                 ...    ...            ...
# 194                                                NaN    NaN            NaN
# 195                                                NaN    NaN            NaN
# 196                                                NaN    NaN            NaN
# 197                                                NaN    NaN            NaN
# 198                                                NaN    NaN            NaN
#
#                                              reactions  parent_user_id  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3    [{'name': 'rainbow', 'users': ['U01S7KCL3DF'],...             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 194  [{'name': 'catjam', 'users': ['U01S7BM4N81'], ...     U01S7KCL3DF
# 195                                                NaN             NaN
# 196                                                NaN             NaN
# 197                                                NaN             NaN
# 198                                                NaN             NaN
#
#      bot_id  bot_profile inviter topic  channel_name
# 0       NaN          NaN     NaN   NaN     dresource
# 1       NaN          NaN     NaN   NaN     dresource
# 2       NaN          NaN     NaN   NaN     dresource
# 3       NaN          NaN     NaN   NaN     dresource
# 4       NaN          NaN     NaN   NaN     dresource
# ..      ...          ...     ...   ...           ...
# 194     NaN          NaN     NaN   NaN     dresource
# 195     NaN          NaN     NaN   NaN     dresource
# 196     NaN          NaN     NaN   NaN     dresource
# 197     NaN          NaN     NaN   NaN     dresource
# 198     NaN          NaN     NaN   NaN     dresource
#
# [199 rows x 32 columns]

# %%
# save to csv
channel_dresource.to_csv(r'../raw_data/data_resources/channel_dresource.csv', index = False)

# %% [markdown]
# ### channel_dbootcamp

# %%
### data-bootcamp channel
# defining file path
path_to_json = '../raw_data/data-bootcamp/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dbootcamp = pd.concat(dfs, ignore_index=True)
# test
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text
# 0   <@U01RVSTNRRT> has joined the channel
# 1   <@U01RW140HBP> has joined the channel
# 2   <@U01S65G72SY> has joined the channel
# 3   <@U01RSRE0N3D> has joined the channel
# 4   <@U01RRV4JX6Z> has joined the channel
# 5   <@U01S79YDELR> has joined the channel
# 6   <@U01RUTP1ZQB> has joined the channel
# 7   <@U01RUU9SK4K> has joined the channel
# 8   <@U01S7BM4N81> has joined the channel
# 9   <@U01SJKB2MG8> has joined the channel
# 10  <@U01RV3K524T> has joined the channel
# 11  <@U01S133DZ9A> has joined the channel
# 12  <@U01RN7BVD1C> has joined the channel
# 13  <@U01S7KCL3DF> has joined the channel
# 14  <@U01S1CWGTU4> has joined the channel
# 15  <@U01RNEU3SNA> has joined the channel
# 16  <@U01RS9Y6UJH> has joined the channel
# 17  <@U01SK96QF5E> has joined the channel
# 18  <@U01RP2K1606> has joined the channel
# 19  <@U01RW2X7S9Z> has joined the channel

# %%
channel_dbootcamp['channel_name'] = 'dbootcamp'
channel_dbootcamp
# Out:
#        type       subtype            ts         user  \
# 0   message  channel_join  1.616337e+09  U01RVSTNRRT
# 1   message  channel_join  1.616346e+09  U01RW140HBP
# 2   message  channel_join  1.616395e+09  U01S65G72SY
# 3   message  channel_join  1.616108e+09  U01RSRE0N3D
# 4   message  channel_join  1.616400e+09  U01RRV4JX6Z
# 5   message  channel_join  1.616159e+09  U01S79YDELR
# 6   message  channel_join  1.616159e+09  U01RUTP1ZQB
# 7   message  channel_join  1.616159e+09  U01RUU9SK4K
# 8   message  channel_join  1.616159e+09  U01S7BM4N81
# 9   message  channel_join  1.616161e+09  U01SJKB2MG8
# 10  message  channel_join  1.616161e+09  U01RV3K524T
# 11  message  channel_join  1.616162e+09  U01S133DZ9A
# 12  message  channel_join  1.616163e+09  U01RN7BVD1C
# 13  message  channel_join  1.616163e+09  U01S7KCL3DF
# 14  message  channel_join  1.616165e+09  U01S1CWGTU4
# 15  message  channel_join  1.616166e+09  U01RNEU3SNA
# 16  message  channel_join  1.616167e+09  U01RS9Y6UJH
# 17  message  channel_join  1.616168e+09  U01SK96QF5E
# 18  message  channel_join  1.616172e+09  U01RP2K1606
# 19  message  channel_join  1.616172e+09  U01RW2X7S9Z
#
#                                      text channel_name
# 0   <@U01RVSTNRRT> has joined the channel    dbootcamp
# 1   <@U01RW140HBP> has joined the channel    dbootcamp
# 2   <@U01S65G72SY> has joined the channel    dbootcamp
# 3   <@U01RSRE0N3D> has joined the channel    dbootcamp
# 4   <@U01RRV4JX6Z> has joined the channel    dbootcamp
# 5   <@U01S79YDELR> has joined the channel    dbootcamp
# 6   <@U01RUTP1ZQB> has joined the channel    dbootcamp
# 7   <@U01RUU9SK4K> has joined the channel    dbootcamp
# 8   <@U01S7BM4N81> has joined the channel    dbootcamp
# 9   <@U01SJKB2MG8> has joined the channel    dbootcamp
# 10  <@U01RV3K524T> has joined the channel    dbootcamp
# 11  <@U01S133DZ9A> has joined the channel    dbootcamp
# 12  <@U01RN7BVD1C> has joined the channel    dbootcamp
# 13  <@U01S7KCL3DF> has joined the channel    dbootcamp
# 14  <@U01S1CWGTU4> has joined the channel    dbootcamp
# 15  <@U01RNEU3SNA> has joined the channel    dbootcamp
# 16  <@U01RS9Y6UJH> has joined the channel    dbootcamp
# 17  <@U01SK96QF5E> has joined the channel    dbootcamp
# 18  <@U01RP2K1606> has joined the channel    dbootcamp
# 19  <@U01RW2X7S9Z> has joined the channel    dbootcamp

# %%
# save to csv
channel_dbootcamp.to_csv(r'../raw_data/data-bootcamp/channel_dbootcamp.csv', index = False)

# %% [markdown]
# ### channel_dmemes

# %%
### data-memes channel
# defining file path
path_to_json = '../raw_data/data-memes/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dmemes = pd.concat(dfs, ignore_index=True)
# test
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 297  message  this made me realise there is no krispy branch...
# 298  message
# 299  message                                     <@U01S0E0MRJ7>
# 300  message                               haha this is tots me
# 301  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 297                                                NaN    NaN  U01SK96QF5E
# 298  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 299  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 300                                                NaN    NaN  U01S0E0MRJ7
# 301  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 297            NaN  1.616509e+09  1.616498e+09          NaN
# 298            0.0  1.616518e+09           NaN          NaN
# 299            0.0  1.619509e+09  1.619509e+09          1.0
# 300            NaN  1.619510e+09  1.619509e+09          NaN
# 301            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...    user_team  source_team  \
# 0                  NaN  ...          NaN          NaN
# 1                  1.0  ...          NaN          NaN
# 2                  NaN  ...          NaN          NaN
# 3                  NaN  ...          NaN          NaN
# 4                  NaN  ...          NaN          NaN
# ..                 ...  ...          ...          ...
# 297                NaN  ...  T01RBRV5F7H  T01RBRV5F7H
# 298                NaN  ...          NaN          NaN
# 299                1.0  ...          NaN          NaN
# 300                NaN  ...  T01RBRV5F7H  T01RBRV5F7H
# 301                NaN  ...          NaN          NaN
#
#                                           user_profile  attachments  bot_id  \
# 0                                                  NaN          NaN     NaN
# 1                                                  NaN          NaN     NaN
# 2                                                  NaN          NaN     NaN
# 3                                                  NaN          NaN     NaN
# 4                                                  NaN          NaN     NaN
# ..                                                 ...          ...     ...
# 297  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...          NaN     NaN
# 298                                                NaN          NaN     NaN
# 299                                                NaN          NaN     NaN
# 300  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...          NaN     NaN
# 301                                                NaN          NaN     NaN
#
#     bot_profile last_read subtype purpose inviter
# 0           NaN       NaN     NaN     NaN     NaN
# 1           NaN       NaN     NaN     NaN     NaN
# 2           NaN       NaN     NaN     NaN     NaN
# 3           NaN       NaN     NaN     NaN     NaN
# 4           NaN       NaN     NaN     NaN     NaN
# ..          ...       ...     ...     ...     ...
# 297         NaN       NaN     NaN     NaN     NaN
# 298         NaN       NaN     NaN     NaN     NaN
# 299         NaN       NaN     NaN     NaN     NaN
# 300         NaN       NaN     NaN     NaN     NaN
# 301         NaN       NaN     NaN     NaN     NaN
#
# [302 rows x 31 columns]

# %%
channel_dmemes['channel_name'] = 'dmemes'
channel_dmemes
# Out:
#         type                                               text  \
# 0    message
# 1    message
# 2    message
# 3    message
# 4    message
# ..       ...                                                ...
# 297  message  this made me realise there is no krispy branch...
# 298  message
# 299  message                                     <@U01S0E0MRJ7>
# 300  message                               haha this is tots me
# 301  message  About yesterday's labs and the importance of b...
#
#                                                  files upload         user  \
# 0    [{'id': 'F01VCF9TZBL', 'created': 1619333970, ...  False  U01S79YDELR
# 1    [{'id': 'F01U0P8KBDF', 'created': 1617871905, ...  False  U01RW2X7S9Z
# 2    [{'id': 'F01TK4TTDRT', 'created': 1617872916, ...  False  U01S7BM4N81
# 3    [{'id': 'F01TNKFF7C2', 'created': 1617880468, ...  False  U01S7BM4N81
# 4    [{'id': 'F01T8RDEYRM', 'created': 1617893627, ...  False  U01RW140HBP
# ..                                                 ...    ...          ...
# 297                                                NaN    NaN  U01SK96QF5E
# 298  [{'id': 'F01S6KCP5SP', 'created': 1616518378, ...    0.0  U01SJKB2MG8
# 299  [{'id': 'F0204JAB27M', 'created': 1619509279, ...    0.0  U01RKN0EGDV
# 300                                                NaN    NaN  U01S0E0MRJ7
# 301  [{'id': 'F020YC4JZS4', 'created': 1619585438, ...    0.0  U01RRV4JX6Z
#
#     display_as_bot            ts     thread_ts  reply_count  \
# 0            False  1.619334e+09           NaN          NaN
# 1            False  1.617873e+09  1.617873e+09          1.0
# 2            False  1.617873e+09  1.617873e+09          NaN
# 3            False  1.617880e+09           NaN          NaN
# 4            False  1.617894e+09           NaN          NaN
# ..             ...           ...           ...          ...
# 297            NaN  1.616509e+09  1.616498e+09          NaN
# 298            0.0  1.616518e+09           NaN          NaN
# 299            0.0  1.619509e+09  1.619509e+09          1.0
# 300            NaN  1.619510e+09  1.619509e+09          NaN
# 301            0.0  1.619585e+09           NaN          NaN
#
#      reply_users_count  ...  source_team  \
# 0                  NaN  ...          NaN
# 1                  1.0  ...          NaN
# 2                  NaN  ...          NaN
# 3                  NaN  ...          NaN
# 4                  NaN  ...          NaN
# ..                 ...  ...          ...
# 297                NaN  ...  T01RBRV5F7H
# 298                NaN  ...          NaN
# 299                1.0  ...          NaN
# 300                NaN  ...  T01RBRV5F7H
# 301                NaN  ...          NaN
#
#                                           user_profile attachments  bot_id  \
# 0                                                  NaN         NaN     NaN
# 1                                                  NaN         NaN     NaN
# 2                                                  NaN         NaN     NaN
# 3                                                  NaN         NaN     NaN
# 4                                                  NaN         NaN     NaN
# ..                                                 ...         ...     ...
# 297  {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...         NaN     NaN
# 298                                                NaN         NaN     NaN
# 299                                                NaN         NaN     NaN
# 300  {'avatar_hash': 'ad6853d3a1f4', 'image_72': 'h...         NaN     NaN
# 301                                                NaN         NaN     NaN
#
#      bot_profile last_read subtype purpose inviter channel_name
# 0            NaN       NaN     NaN     NaN     NaN       dmemes
# 1            NaN       NaN     NaN     NaN     NaN       dmemes
# 2            NaN       NaN     NaN     NaN     NaN       dmemes
# 3            NaN       NaN     NaN     NaN     NaN       dmemes
# 4            NaN       NaN     NaN     NaN     NaN       dmemes
# ..           ...       ...     ...     ...     ...          ...
# 297          NaN       NaN     NaN     NaN     NaN       dmemes
# 298          NaN       NaN     NaN     NaN     NaN       dmemes
# 299          NaN       NaN     NaN     NaN     NaN       dmemes
# 300          NaN       NaN     NaN     NaN     NaN       dmemes
# 301          NaN       NaN     NaN     NaN     NaN       dmemes
#
# [302 rows x 32 columns]

# %%
# save to csv
channel_dmemes.to_csv(r'../raw_data/data-memes/channel_dmemes.csv', index = False)

# %% [markdown]
# ### channel_dvizbeauties|

# %%
### data-viz-beauties channel
# defining file path
path_to_json = '../raw_data/data-viz-beauties/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_dvizbeauties = pd.concat(dfs, ignore_index=True)
# test
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 260  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 261  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 262  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 263  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 264  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 260  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 261  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 262  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 263                                   a late night sam  U01RS9Y6UJH
# 264  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 260  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 261  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 262  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 263  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 264  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 260  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 261  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 262  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 263  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 264  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  subscribed  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...         NaN
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...         NaN
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...         0.0
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...         NaN
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...         NaN
# ..                                                 ...  ...         ...
# 260  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...         0.0
# 261  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...         0.0
# 262  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...         NaN
# 263  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...         NaN
# 264  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...         NaN
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 260  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 261  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 262  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 263  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 264                                                NaN         NaN
#
#                                                 edited bot_id  bot_profile  \
# 0                                                  NaN    NaN          NaN
# 1                                                  NaN    NaN          NaN
# 2                                                  NaN    NaN          NaN
# 3                                                  NaN    NaN          NaN
# 4                                                  NaN    NaN          NaN
# ..                                                 ...    ...          ...
# 260                                                NaN    NaN          NaN
# 261  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN          NaN
# 262                                                NaN    NaN          NaN
# 263                                                NaN    NaN          NaN
# 264                                                NaN    NaN          NaN
#
#      subtype  purpose inviter last_read
# 0        NaN      NaN     NaN       NaN
# 1        NaN      NaN     NaN       NaN
# 2        NaN      NaN     NaN       NaN
# 3        NaN      NaN     NaN       NaN
# 4        NaN      NaN     NaN       NaN
# ..       ...      ...     ...       ...
# 260      NaN      NaN     NaN       NaN
# 261      NaN      NaN     NaN       NaN
# 262      NaN      NaN     NaN       NaN
# 263      NaN      NaN     NaN       NaN
# 264      NaN      NaN     NaN       NaN
#
# [265 rows x 31 columns]

# %%
channel_dvizbeauties['channel_name'] = 'dvizbeauties'
channel_dvizbeauties
# Out:
#                             client_msg_id     type  \
# 0    b968ce51-25e9-4afb-bc0d-3bc28db4fc5c  message
# 1                                     NaN  message
# 2    080412b3-57d0-4963-a60e-09dbc2c2458b  message
# 3                                     NaN  message
# 4    39a9b19c-59cf-4d76-8464-7d34b83d3600  message
# ..                                    ...      ...
# 260  15029ef3-9fe6-4914-ad46-ac281385efc1  message
# 261  0ec01770-ceb3-44b1-8b03-29a725cfa93a  message
# 262  f52e6e6c-eb24-403b-b090-4032824237dc  message
# 263  1dc9f879-f9b1-4cb3-9e43-ba4c71c147fc  message
# 264  cbb632f5-7788-47ec-91e8-b0adc50a5cce  message
#
#                                                   text         user  \
# 0                                             just wow  U01SK96QF5E
# 1    staphney is your middle name? so pretty!\n\nI ...  U01RW140HBP
# 2    <@U01SD3CDH9P> just to check youre in this cha...  U01RW140HBP
# 3    well done Federico! I am sorry to hear your la...  U01RW140HBP
# 4    Appreciate the feedbacks Sian, I'm going to wo...  U01S6L7HLUC
# ..                                                 ...          ...
# 260  <https://public.tableau.com/profile/antonio.sa...  U01S1CWGTU4
# 261  not sure what i’m looking to show, but clickin...  U01S7KCL3DF
# 262  Hey, love your dashboard based on a big map, v...  U01RS9Y6UJH
# 263                                   a late night sam  U01RS9Y6UJH
# 264  Thank you very much Neil for your feedback! I ...  U01S1CWGTU4
#
#                ts         team    user_team  source_team  \
# 0    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 1    1.619593e+09          NaN          NaN          NaN
# 2    1.619593e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 3    1.619594e+09          NaN          NaN          NaN
# 4    1.619594e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# ..            ...          ...          ...          ...
# 260  1.619556e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 261  1.619559e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 262  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 263  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
# 264  1.619591e+09  T01RBRV5F7H  T01RBRV5F7H  T01RBRV5F7H
#
#                                           user_profile  \
# 0    {'avatar_hash': '94c1e7ff9e09', 'image_72': 'h...
# 1                                                  NaN
# 2    {'avatar_hash': '4c43a3a8d10b', 'image_72': 'h...
# 3                                                  NaN
# 4    {'avatar_hash': '503ff2e9e293', 'image_72': 'h...
# ..                                                 ...
# 260  {'avatar_hash': '09076999792d', 'image_72': 'h...
# 261  {'avatar_hash': '17b52091bb62', 'image_72': 'h...
# 262  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 263  {'avatar_hash': 'g7e6abc9bdfa', 'image_72': 'h...
# 264  {'avatar_hash': '09076999792d', 'image_72': 'h...
#
#                                                 blocks  ...  \
# 0    [{'type': 'rich_text', 'block_id': 'FUDBD', 'e...  ...
# 1    [{'type': 'rich_text', 'block_id': 'T0I', 'ele...  ...
# 2    [{'type': 'rich_text', 'block_id': '/mQ', 'ele...  ...
# 3    [{'type': 'rich_text', 'block_id': 'D4IQ', 'el...  ...
# 4    [{'type': 'rich_text', 'block_id': 'Qpsd', 'el...  ...
# ..                                                 ...  ...
# 260  [{'type': 'rich_text', 'block_id': 'Fqz=h', 'e...  ...
# 261  [{'type': 'rich_text', 'block_id': '=t8', 'ele...  ...
# 262  [{'type': 'rich_text', 'block_id': 'OZ8/p', 'e...  ...
# 263  [{'type': 'rich_text', 'block_id': 'xGG', 'ele...  ...
# 264  [{'type': 'rich_text', 'block_id': '5tzll', 'e...  ...
#
#                                              reactions attachments  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    [{'name': '+1', 'users': ['U01S081EULS'], 'cou...         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 260  [{'name': 'raised_hands', 'users': ['U01S7KCL3...         NaN
# 261  [{'name': 'raised_hands', 'users': ['U01RNEU3S...         NaN
# 262  [{'name': 'pray', 'users': ['U01S1CWGTU4'], 'c...         NaN
# 263  [{'name': 'owl', 'users': ['U01S7KCL3DF'], 'co...         NaN
# 264                                                NaN         NaN
#
#                                                 edited bot_id bot_profile  \
# 0                                                  NaN    NaN         NaN
# 1                                                  NaN    NaN         NaN
# 2                                                  NaN    NaN         NaN
# 3                                                  NaN    NaN         NaN
# 4                                                  NaN    NaN         NaN
# ..                                                 ...    ...         ...
# 260                                                NaN    NaN         NaN
# 261  {'user': 'U01S7KCL3DF', 'ts': '1619559382.0000...    NaN         NaN
# 262                                                NaN    NaN         NaN
# 263                                                NaN    NaN         NaN
# 264                                                NaN    NaN         NaN
#
#      subtype  purpose  inviter last_read  channel_name
# 0        NaN      NaN      NaN       NaN  dvizbeauties
# 1        NaN      NaN      NaN       NaN  dvizbeauties
# 2        NaN      NaN      NaN       NaN  dvizbeauties
# 3        NaN      NaN      NaN       NaN  dvizbeauties
# 4        NaN      NaN      NaN       NaN  dvizbeauties
# ..       ...      ...      ...       ...           ...
# 260      NaN      NaN      NaN       NaN  dvizbeauties
# 261      NaN      NaN      NaN       NaN  dvizbeauties
# 262      NaN      NaN      NaN       NaN  dvizbeauties
# 263      NaN      NaN      NaN       NaN  dvizbeauties
# 264      NaN      NaN      NaN       NaN  dvizbeauties
#
# [265 rows x 32 columns]

# %%
# save to csv
channel_dvizbeauties.to_csv(r'../raw_data/data-viz-beauties/channel_dvizbeauties.csv', index = False)raw_
# Out:
#   File "<ipython-input-19-795fedcc2107>", line 2
#     channel_dvizbeauties.to_csv(r'../raw_data/data-viz-beauties/channel_dvizbeauties.csv', index = False)raw_
#                                                                                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### channel_finalproject

# %%
### final-project channel
# defining file path
path_to_json = '../raw_data/final-project/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_finalproject = pd.concat(dfs, ignore_index=True)
# test
channel_finalproject.head(10)

# %%
channel_finalproject['channel_name'] = 'finalproject'
channel_finalproject

# %%
# save to csv
channel_finalproject.to_csv(r'../raw_data/final-project/finalproject.csv', index = False)

# %% [markdown]
# ### channel_frustrations

# %%
### frustrations-shared channel
# defining file path
path_to_json = '../raw_data/frustrations-shared/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_frustrations = pd.concat(dfs, ignore_index=True)
# test
channel_frustrations

# %%
channel_frustrations['channel_name'] = 'frustrations'
channel_frustrations

# %%
# save to csv
channel_frustrations.to_csv(r'../raw_data/frustrations-shared/frustrations.csv', index = False)

# %% [markdown]
# ### channel_funcommittee

# %%
### fun_committee channel
# defining file path
path_to_json = '../raw_data/fun_committee/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_funcommittee = pd.concat(dfs, ignore_index=True)
# test
channel_funcommittee

# %%
channel_funcommittee['channel_name'] = 'funcommittee'
channel_funcommittee

# %%
# save to csv
channel_funcommittee.to_csv(r'../raw_data/fun_committee/channel_funcommittee.csv', index = False)

# %% [markdown]
# ### channel_katas

# %%
### katas channel
# defining file path
path_to_json = '../raw_data/katas/' 
# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_katas = pd.concat(dfs, ignore_index=True)
# test
channel_katas

# %%
channel_katas['channel_name'] = 'katas'
channel_katas

# %%
# save to csv
channel_katas.to_csv(r'../raw_data/katas/channel_katas.csv', index = False)

# %% [markdown]
# ### channel_labhelp

# %%
### lab-help channel
# defining file path
path_to_json = '../raw_data/lab-help/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_labhelp = pd.concat(dfs, ignore_index=True)
# test
channel_labhelp

# %%
channel_labhelp['channel_name'] = 'labhelp'
channel_labhelp

# %%
# save to csv
channel_labhelp.to_csv(r'../raw_data/lab-help/channel_labhelp.csv', index = False)

# %% [markdown]
# ### channel_music

# %%
### music channel
# defining file path
path_to_json = '../raw_data/music/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_music = pd.concat(dfs, ignore_index=True)
# test
channel_music

# %%
channel_music['channel_name'] = 'music'
channel_music

# %%
# save to csv
channel_music.to_csv(r'../raw_data/music/channel_music.csv', index = False)

# %% [markdown]
# ### channel_random

# %%
### random channel
# defining file path
path_to_json = '../raw_data/random/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_random = pd.concat(dfs, ignore_index=True)
# test
channel_random

# %%
channel_random['channel_name'] = 'random'
channel_random

# %%
# save to csv
channel_random.to_csv(r'../raw_data/random/channel_random.csv', index = False)

# %% [markdown]
# ### channel_vanilla

# %%
### vanilla_plus_more channel
# defining file path
path_to_json = '../raw_data/vanilla_plus_more/' 

# get all json files from there
json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# an empty list to store the data frames
dfs = []
for file in file_list:
    # read data frame from json file
    data = pd.read_json(file)
    # append the data frame to the list
    dfs.append(data)

# concatenate all the data frames in the list
channel_vanilla = pd.concat(dfs, ignore_index=True)
# test
channel_vanilla

# %%
channel_vanilla['channel_name'] = 'vanilla'
channel_vanilla

# %%
# save to csv
channel_vanilla.to_csv(r'../raw_data/vanilla_plus_more/channel_vanilla.csv', index = False)

# %%
#frames = [channel_gen, channel_books, channel_dmemes, channel_dresource, channel_dbootcamp, channel_funcommittee, channel_dvizbeauties, channel_frustrations, channel_finalproject, channel_frustrations, channel_funcommittee, channel_katas, channel_labhelp, channel_music, channel_random, channel_vanilla]

df = pd.concat([channel_gen, channel_books,
                    channel_dmemes, channel_dresource, 
                    channel_dbootcamp, channel_funcommittee,
                    channel_dvizbeauties, channel_frustrations, 
                    channel_finalproject, channel_frustrations, 
                    channel_funcommittee, channel_katas, 
                    channel_labhelp, channel_music, 
                    channel_random, channel_vanilla], ignore_index=True, join="outer")

# %% [markdown]
# **Assessment Part1**

# %%
# assess shape
df.shape

# %%
# make a copy
df_copy = df.copy()

# %%
# assess column names
df.columns

# %%
# check how many values each channel has
df.channel_name.value_counts()

# %%
# check for outliers in the numerical part
df.describe()

# %% [markdown]
# There are no outliers in this data, it seems healthy.

# %% [markdown]
# **Summary of Assesment Part1**
#
# **Columns to drop:**
#     - type, team, user_team, source_team, latest_reply, last_read, bot_id, bot_profile, display_as_bot, topic, blocks, edited, is_locked, subscribed, upload, display_as_bot, root, purpose, thread_ts, parent_used_id
#
# **Columns to clean & wrangle:**
# - subtype: filter out it's values from df, remove the original column
# - ts: changing it to datetime, remove miliseconds, get days of the week, months of the year, type of the day, parts of the day
# - user_profile: extract real_name in new column, remove the original
# - attachments: extract title, text, link in new columns
# - files: extract url_private and who shared
# - attachments: extract title, text, link in new columns
# - reactions: extract user, count, name of the emoji
# - text: ?
#
# **Columns to visualise**
# - reply_count: how many
# - reply_users_count: how many
# - reply_users: who
# - replies: who and when
# - files, attachment, reactions

# %% [markdown]
# **Cleaning Part1**

# %%
# drop columns
df.drop(['type', 'client_msg_id', 'team',
       'user_team', 'source_team', 'blocks', 'upload', 'display_as_bot',
       'thread_ts', 'latest_reply', 'is_locked', 'subscribed',
       'parent_user_id', 'bot_id', 'bot_profile', 'last_read', 'edited',
       'purpose', 'inviter', 'topic', 'root', 'old_name', 'name', 'hidden',
       'x_files'], axis=1, inplace=True)

# %%
# test
df.shape

# %%
df.head()

# %% [markdown]
# **Assessment Part2**

# %%
# list of columns, their non-null objects and data type of columns
df.info()

# %%
# check, if there are any nulls and NaN values in our data set
df.isna().sum()

# %%
#to summarise this in one line of code and round the values 
df.isna().mean().round(4) *100

# %% [markdown]
# Due to the nature of the dataset, the missing values are not because of missing data, but because some posts didn't have replies, attachments, etc. The only important thing is that each value is coming from a user, and it is because I can see there are no missing values at the text or user columns. So I intend to keep everything as it is. I will dive deeper into rows that I don't need: channel join messages for example.

# %%
df['subtype'].value_counts()

# %%
# filter out for the rows which has subtype values
df_clean = df[(df.subtype != 'channel_join') & 
                                (df.subtype != 'channel_join') &
                                (df.subtype != 'channel_purpose') &
                                (df.subtype != 'thread_broadcast')]


#test 
df_clean.shape

# %%
# drop subtype column
df_clean.drop('subtype', axis=1, inplace=True) 

#test
df_clean.shape

# %%
#convert ts to datetime from float
from datetime import datetime
df_clean['ts'] = pd.to_datetime(df['ts'], unit='s')

# remove miliseconds 
df_clean['ts'] = df_clean['ts'].astype('datetime64[s]')

df_clean

# %%
# create a column for the days of the week using the ts column

df_clean['day_name'] = df_clean['ts'].dt.day_name()
df_clean['day_number'] = pd.DatetimeIndex(df_clean['ts']).day
df_clean

# %%
# create a column for the months of the year using the ts column
df_clean['month'] = pd.DatetimeIndex(df_clean['ts']).month

# convert values to date time and then month names

df_clean['month'] = pd.to_datetime(df_clean['month'], format='%m').dt.month_name()
df_clean

# %%
# create a column for the type of the weekday using the ts column
df_clean['day_type'] = df_clean.ts.dt.weekday.apply(
    lambda x: 'Weekday' if x < 5 else 'Weekend')
df_clean

# %%
# create a column for the hour of the day using the ts column
df_clean['time']= df_clean['ts'].dt.strftime('%H')
df_clean

# %%
df_clean['dayparts'] = (df_clean['ts'].dt.hour % 24 + 4) // 4
df_clean['dayparts'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Afternoon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)

# %%
# drop ts column
df_clean.drop('ts', axis=1, inplace=True) 

#test
df_clean.head()

# %%
#files column: extract link

def geturlfromfile(x):
    """this function is applied to column files
    """
    
    if x != x:
        return 'nofile'
    else:
        try:
            return x[0]['url_private']
        except KeyError:
            return 'nolink_infiles'

df_clean['link_of_file'] = df_clean['files'].apply(geturlfromfile)

df_clean

# %%
# save to csv
df_links = df_clean[(df_clean.link_of_file != 'nofile')]
header = ['link_of_file']
df_links.to_csv(r'../csv/links.csv', columns = header, index = False)

# %%
# drop files column
df_clean.drop('files', axis=1, inplace=True) 

#test
df_clean.head()

# %%
df_clean[~df_clean['attachments'].isna()]['attachments'].iloc[37][0]

# %%
# attachments column: extract link

def geturlfromattachments(x):
    """this function is applied to column attachments
    """
    
    if x != x:
        return 'nolink'
    else:
        try:
            return x[0]['app_unfurl_url']
        except KeyError:
            return 'nolink_infiles'
        
df_clean['github_links'] = df_clean['attachments'].apply(geturlfromattachments)

df_clean

# %%
# save to csv
df_githublinks = df_clean[(df_clean.github_links != 'nolink')
                         & (df_clean.github_links != 'nolink_infiles')]
header = ['github_links']
df_githublinks.to_csv(r'../csv/github_links.csv', columns = header, index = False)

# %%
# user_profile column: extract real_name

def getrealnamefromprofile(x):
    """this function is applied to column user_profile
    """
    
    if x != x:
        return 'noname'
    else:
        return x['real_name']

df_clean['real_name'] = df_clean['user_profile'].apply(getrealnamefromprofile)

df_clean

# %%
# drop user_profile column
df_clean.drop('user_profile', axis=1, inplace=True) 

#test
df_clean.head(100)

# %%
# reactions column:  count

def getcountfromreactions(x):
    """this function is applied to column reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['count']

df_clean['reactions_count'] = df_clean['reactions'].apply(getcountfromreactions)

df_clean

# %%
df_clean[~df_clean['reactions'].isna()]['reactions'].iloc[37][0]['name']

# %%
# reactions column:  count

def getnamefromreactions(x):
    """this function is applied to column reactions
    """
    
    if x != x:
        return 0
    else:
        return x[0]['name']

df_clean['reactions_name'] = df_clean['reactions'].apply(getnamefromreactions)

df_clean

# %%
df_clean['reactions_name'].value_counts()

# %%
# creating boolean variables

# create a new boolean column if comment has reaction
df_clean['reaction_true'] = df_clean['reactions'].notnull()
df_clean


# create a new boolean column if comment has reply
df_clean['replies_true'] = df_clean['reply_count'].notna()
df_clean

# create a new boolean column if comment has files
df_clean['files_true'] = df_clean['link_of_file'].str.contains("https")
df_clean

# create a new boolean column if comment has attachments
df_clean['attachments_true'] = df_clean['github_links'].str.contains("https")
df_clean

# %%
df_clean['real_name'].value_counts()

# %%
# create a new column with teaching and students
def applyFunc(s):
    if s == 'siand the LT (she/her)':
        return 'teacher'
    if s ==  'Florian Titze':
        return 'teacher'
    if s ==  'Kosta':
        return 'teacher'
    else:
        return 'student'
    return ''

df_clean['participant'] = df_clean['real_name'].apply(applyFunc)
df_clean['participant'].value_counts()

# %%
# create a new column with text length
df_clean['text_length'] = df['text'].astype(str).map(len)
# test
df_clean

# %%
# droppig unneccessary columns
df_clean.drop(['reactions', 'attachments', 'reply_users', 'replies'], axis=1, inplace=True)
# test
df_clean.shape

# %%
# replace NaN values with zero
df_clean['reply_count'] = df_clean['reply_count'].fillna(0)
df_clean['reply_users_count'] = df_clean['reply_users_count'].fillna(0)
df_clean['reply_count'] = df_clean['reply_count'].astype(int)
df_clean['reply_users_count'] = df_clean['reply_users_count'].astype(int)


df_clean

# %%
df_clean.columns

# %%
# reordering columns
df_clean = df_clean[['channel_name', 'user', 'real_name', 'participant',
                     'text', 'text_length', 'reply_count', 'reply_users_count',
                     'replies_true', 'day_name', 'day_type', 'time',
                     'dayparts', 'day_number', 'month', 'reactions_count', 
                     'reactions_name', 'link_of_file', 'files_true', 
                     'github_links', 'attachments_true', 'reaction_true']]
# test 
df_clean

# %%
# save to csv
df_clean.to_csv(r'../csv/data_clean.csv', index = False)

# %%
# save to excel
df_clean.to_excel(r'../csv/data_clean.xlsx', index = False)
